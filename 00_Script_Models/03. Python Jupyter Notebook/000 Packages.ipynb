# %%
import openpyxl
import pandasql
import pyxlsb
import pandas as pd
import numpy as np
import sqlite3
import openpyxl
import matplotlib
import textblob
import vaderSentiment
import lxml
import sklearn
import statsmodels
import seaborn

#import scikit
#import NLTK
#import selenium
#import beautifulsoup4

# %%
import openpyxl

# %%
# Out:
# 2

# %%
LoanBase = pd.read_excel(r'C:\Users\syahidhalid\OneDrive - Export-Import Bank of Malaysia (EXIM Bank)\Desktop\Work\00 SYAHIRAH\CSP 2024\Working\LOAN BASE\Loan Database 2019 until June 2023.xlsx', header=2)

# %%
LoanBase.head(1)
# Out:
#    No.  CIF Number        EXIM Account No. Application System Code  \
# 0  1.0  EXIM000012  3308-01137-209-0014-00                     NaN
#
#   CCRIS Master Account Number CCRIS Sub Account Number Finance(SAP) Number  \
# 0                         NaN                      NaN              500187
#
#           Company Group         Customer Name Relationship Manager (RM)  ...  \
# 0  Jewel Growth Sdn Bhd  Jewel Growth Sdn Bhd                      ARRD  ...
#
#   Overdue Amount (MYR) Date Classified as Watchlist Watchlist Reason  \
# 0                  0.0                          NaT              NaN
#
#   Date Declassified from Watchlist Date Impaired  \
# 0                              NaT    2020-06-25
#
#                                Reason for Impairment Partial Write off Date  \
# 0  Technical, acct transferred in 2020 but overdu...                    NaT
#
#   Write off Date Cancellation Date/Fully Settled Date Position as At
# 0     2021-12-21                                  NaT     2023-06-30
#
# [1 rows x 146 columns]

# %%
LoanBase.describe()
# Out:
#               No.  Date of Ready for Utilization (RU)  \
# count  394.000000                                 0.0
# mean   197.500000                                 NaN
# std    113.882249                                 NaN
# min      1.000000                                 NaN
# 25%     99.250000                                 NaN
# 50%    197.500000                                 NaN
# 75%    295.750000                                 NaN
# max    394.000000                                 NaN
#
#        Amount Approved / Facility Limit (Facility Currency)  \
# count                                       3.950000e+02
# mean                                        4.470648e+07
# std                                         4.452020e+08
# min                                         0.000000e+00
# 25%                                         2.000000e+06
# 50%                                         6.578558e+06
# 75%                                         2.250000e+07
# max                                         8.829529e+09
#
#        Amount Approved / Facility Limit (MYR)  \
# count                            3.950000e+02
# mean                             1.411466e+08
# std                              1.404714e+09
# min                              0.000000e+00
# 25%                              4.665000e+06
# 50%                              2.000000e+07
# 75%                              9.330000e+07
# max                              2.787646e+10
#
#        Cost/Principal Outstanding (Facility Currency)  \
# count                                    3.960000e+02
# mean                                     7.031965e+06
# std                                      7.132021e+07
# min                                     -8.567526e+05
# 25%                                      0.000000e+00
# 50%                                      0.000000e+00
# 75%                                      3.839295e+05
# max                                      1.392757e+09
#
#        Cost/Principal Outstanding (MYR)  \
# count                      3.970000e+02
# mean                       3.569232e+07
# std                        3.370604e+08
# min                        0.000000e+00
# 25%                        0.000000e+00
# 50%                        0.000000e+00
# 75%                        6.989422e+05
# max                        4.723284e+09
#
#        Contingent Liability Letter of Credit (Facility Currency)  \
# count                                         395.000000
# mean                                         1995.001519
# std                                         26089.643108
# min                                             0.000000
# 25%                                             0.000000
# 50%                                             0.000000
# 75%                                             0.000000
# max                                        394012.800000
#
#        Contingent Liability Letter of Credit (MYR)  \
# count                                   397.000000
# mean                                   4672.373804
# std                                   48933.654866
# min                                       0.000000
# 25%                                       0.000000
# 50%                                       0.000000
# 75%                                       0.000000
# max                                  618310.800000
#
#        Contingent Liability (Facility Currency)  Contingent Liability (MYR)  \
# count                              3.950000e+02                3.970000e+02
# mean                               4.116118e+05                1.023319e+06
# std                                4.750848e+06                1.016333e+07
# min                                0.000000e+00                0.000000e+00
# 25%                                0.000000e+00                0.000000e+00
# 50%                                0.000000e+00                0.000000e+00
# 75%                                0.000000e+00                0.000000e+00
# max                                8.129332e+07                1.354192e+08
#
#        ...  Moratorium Period (Month)   Tenure (Month)  \
# count  ...                   32.000000      350.000000
# mean   ...                    6.500000       50.968571
# std    ...                    1.524002       49.435456
# min    ...                    6.000000        0.000000
# 25%    ...                    6.000000       12.000000
# 50%    ...                    6.000000       38.000000
# 75%    ...                    6.000000       84.000000
# max    ...                   12.000000      231.000000
#
#        Profit/Interest Margin  Average Profit/Interest Rate  \
# count              200.000000                    209.000000
# mean                 2.277625                      4.604959
# std                  1.043026                      3.530740
# min                  0.000000                      0.000000
# 25%                  1.692500                      0.000000
# 50%                  2.400000                      5.390000
# 75%                  3.000000                      7.300000
# max                  6.000000                     10.980000
#
#        Date Untagged from R&R  Date of Overdue  Overdue (Days)  \
# count                5.000000              0.0             0.0
# mean             45006.400000              NaN             NaN
# std                 91.492076              NaN             NaN
# min              44846.000000              NaN             NaN
# 25%              45036.000000              NaN             NaN
# 50%              45036.000000              NaN             NaN
# 75%              45036.000000              NaN             NaN
# max              45078.000000              NaN             NaN
#
#        Month in Arrears  Overdue Amount (Facility Currency)  \
# count         76.000000                               398.0
# mean          73.315789                                 0.0
# std           41.837530                                 0.0
# min            7.000000                                 0.0
# 25%           51.000000                                 0.0
# 50%           68.500000                                 0.0
# 75%          102.000000                                 0.0
# max          187.000000                                 0.0
#
#        Overdue Amount (MYR)
# count                 397.0
# mean                    0.0
# std                     0.0
# min                     0.0
# 25%                     0.0
# 50%                     0.0
# 75%                     0.0
# max                     0.0
#
# [8 rows x 70 columns]

# %%
A = LoanBase.iloc[np.where(~(LoanBase['No.'].isna()))]

# %%
A.head(1)
# Out:
#    No.  CIF Number        EXIM Account No. Application System Code  \
# 0  1.0  EXIM000012  3308-01137-209-0014-00                     NaN
#
#   CCRIS Master Account Number CCRIS Sub Account Number Finance(SAP) Number  \
# 0                         NaN                      NaN              500187
#
#           Company Group         Customer Name Relationship Manager (RM)  ...  \
# 0  Jewel Growth Sdn Bhd  Jewel Growth Sdn Bhd                      ARRD  ...
#
#   Overdue Amount (MYR) Date Classified as Watchlist Watchlist Reason  \
# 0                  0.0                          NaT              NaN
#
#   Date Declassified from Watchlist Date Impaired  \
# 0                              NaT    2020-06-25
#
#                                Reason for Impairment Partial Write off Date  \
# 0  Technical, acct transferred in 2020 but overdu...                    NaT
#
#   Write off Date Cancellation Date/Fully Settled Date Position as At
# 0     2021-12-21                                  NaT     2023-06-30
#
# [1 rows x 146 columns]
