# %%
import pandas as pd
import numpy as np
pd.set_option("display.max_columns", None)

df = pd.read_excel(r'C:\Users\syahidhalid\OneDrive - Export-Import Bank of Malaysia (EXIM Bank)\Desktop\Work\Customer Churn Prediction\Compiled.xlsx', sheet_name='Sheet1')

#df['Position as At'].value_counts()

#df['Asset Quality Status'].value_counts()

#a = df.groupby(['Asset Quality Status'])[['Total Loans Outstanding (MYR)']].sum().reset_index()
#a

Sep23 = df.iloc[np.where((df['Position as At']=='2023-09-30')&(df['Asset Quality Status'].isin(['Active','Active-Watchlist','Impaired'])))]
Aug23 = df.iloc[np.where((df['Position as At']=='2023-08-31')&(df['Asset Quality Status'].isin(['Active','Active-Watchlist','Impaired'])))]
Jul23 = df.iloc[np.where((df['Position as At']=='2023-07-31')&(df['Asset Quality Status'].isin(['Active','Active-Watchlist','Impaired'])))]
Jun23 = df.iloc[np.where((df['Position as At']=='2023-06-30')&(df['Asset Quality Status'].isin(['Active','Active-Watchlist','Impaired'])))]
May23 = df.iloc[np.where((df['Position as At']=='2023-05-31')&(df['Asset Quality Status'].isin(['Active','Active-Watchlist','Impaired'])))]
Dec22 = df.iloc[np.where((df['Position as At']=='2022-12-30')&(df['Asset Quality Status'].isin(['Active','Active-Watchlist','Impaired'])))]
Dec21 = df.iloc[np.where((df['Position as At']=='2021-12-31')&(df['Asset Quality Status'].isin(['Active','Active-Watchlist','Impaired'])))]
Dec20 = df.iloc[np.where((df['Position as At']=='2020-12-31')&(df['Asset Quality Status'].isin(['Active','Active-Watchlist','Impaired'])))]

print(Sep23.shape)
print(Aug23.shape)
print(Jul23.shape)
print(Jun23.shape)
print(May23.shape)
print(Dec22.shape)
print(Dec21.shape)
print(Dec20.shape)
# Out:
# (117, 170)
# (124, 170)
# (122, 170)
# (122, 170)
# (122, 170)
# (119, 170)
# (138, 170)
# (162, 170)

# %% [markdown]
# #  Churn Criteria

# %%
#Sep23['Syndication (DAX)'].value_counts()

#Sep23['Payment Frequency'].value_counts()

#Sep23['Asset Quality Status'].value_counts()

#Sep23['Trade Non Trade'].value_counts()

#Sep23['Corporate Status'].value_counts()

#Sep23['Corporate Type'].value_counts()

#Sep23['Classification of Residency Status'].value_counts()

#Sep23['Classification of Entity / Customer Type'].value_counts()

#Sep23['Market Type'].value_counts()

#Sep23['Region'].value_counts()

#Sep23['Country Rating'].value_counts()

#Sep23['Country Exposure'].value_counts()

#Sep23['BNM Main Sector'].value_counts()

#Sep23["Disbursement/\nDrawdown Status"].value_counts()

#Sep23["Type of Financing"].value_counts()

#Sep23["Facility"].value_counts()

#Sep23["Facility Currency"].value_counts()

# %%
#Sep23.head(1)

# %%
#listing

Sep23_A_W = Sep23.iloc[np.where((Sep23['Asset Quality Status'].isin(['Active','Active-Watchlist'])))]
Sep23_A_I = Sep23.iloc[np.where((Sep23['Asset Quality Status'].isin(['Active','Impaired'])))]
Sep23_W_I = Sep23.iloc[np.where((Sep23['Asset Quality Status'].isin(['Active-Watchlist','Impaired'])))]

Sep23_A_W['Type of Financing'] = Sep23_A_W['Type of Financing'].str.upper()
Sep23_A_W['Syndication (DAX)'] = Sep23_A_W['Syndication (DAX)'].str.upper()

Sep23_A_I['Type of Financing'] = Sep23_A_I['Type of Financing'].str.upper()
Sep23_A_I['Syndication (DAX)'] = Sep23_A_I['Syndication (DAX)'].str.upper()

Sep23_W_I['Type of Financing'] = Sep23_W_I['Type of Financing'].str.upper()
Sep23_W_I['Syndication (DAX)'] = Sep23_W_I['Syndication (DAX)'].str.upper()

#Sep23_A_I

#Sep23_A_I.head(1)
# Out:
# C:\Users\syahidhalid\AppData\Local\Temp\1\ipykernel_17944\2970023867.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Sep23_A_W['Type of Financing'] = Sep23_A_W['Type of Financing'].str.upper()
# C:\Users\syahidhalid\AppData\Local\Temp\1\ipykernel_17944\2970023867.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Sep23_A_W['Syndication (DAX)'] = Sep23_A_W['Syndication (DAX)'].str.upper()
# ...

# %%
#impared 52
Sep23_A_W_train = Sep23_A_W[['Trade Non Trade',
                             'Market Type',
                             'Classification of Residency Status',
                             'Classification of Entity / Customer Type',
                             'Syndication (DAX)',
                             'Payment Frequency',
                             'Corporate Status',
                             'Corporate Type',
                             'Region',
                             'Country Rating',
                             'Type of Financing', 
                             'BNM Main Sector',
                             'Facility',
                             'Facility Currency',
                             'Oustanding Ratio',
                             'Collactable Profit',
                             'Tenure (Month)',
                             'Asset Quality Status']]

Sep23_A_W_train['Type of Financing'] = Sep23_A_W_train['Type of Financing'].str.upper()
Sep23_A_W_train['Syndication (DAX)'] = Sep23_A_W_train['Syndication (DAX)'].str.upper()

Sep23_A_W_train.shape
# Out:
# C:\Users\syahidhalid\AppData\Local\Temp\1\ipykernel_17944\2262977769.py:21: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Sep23_A_W_train['Type of Financing'] = Sep23_A_W_train['Type of Financing'].str.upper()
# C:\Users\syahidhalid\AppData\Local\Temp\1\ipykernel_17944\2262977769.py:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Sep23_A_W_train['Syndication (DAX)'] = Sep23_A_W_train['Syndication (DAX)'].str.upper()
# (65, 18)

# %%
#impared 52
Sep23_A_I_train = Sep23_A_I[['Trade Non Trade',
                             'Market Type',
                             'Classification of Residency Status',
                             'Classification of Entity / Customer Type',
                             'Syndication (DAX)',
                             'Payment Frequency',
                             'Corporate Status',
                             'Corporate Type',
                             'Region',
                             'Country Rating',
                             'Type of Financing', 
                             'BNM Main Sector',
                             'Facility',
                             'Facility Currency',
                             'Oustanding Ratio',
                             'Collactable Profit',
                             'Tenure (Month)',
                             'Asset Quality Status']]

Sep23_A_I_train['Type of Financing'] = Sep23_A_I_train['Type of Financing'].str.upper()
Sep23_A_I_train['Syndication (DAX)'] = Sep23_A_I_train['Syndication (DAX)'].str.upper()

Sep23_A_I_train.shape
# Out:
# C:\Users\syahidhalid\AppData\Local\Temp\11\ipykernel_13112\4245793610.py:21: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Sep23_A_I_train['Type of Financing'] = Sep23_A_I_train['Type of Financing'].str.upper()
# C:\Users\syahidhalid\AppData\Local\Temp\11\ipykernel_13112\4245793610.py:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Sep23_A_I_train['Syndication (DAX)'] = Sep23_A_I_train['Syndication (DAX)'].str.upper()
# (98, 18)

# %%
#impared 52
Sep23_W_I_train = Sep23_W_I[['Trade Non Trade',
                             'Market Type',
                             'Classification of Residency Status',
                             'Classification of Entity / Customer Type',
                             'Syndication (DAX)',
                             'Payment Frequency',
                             'Corporate Status',
                             'Corporate Type',
                             'Region',
                             'Country Rating',
                             'Type of Financing', 
                             'BNM Main Sector',
                             'Facility',
                             'Facility Currency',
                             'Oustanding Ratio',
                             'Collactable Profit',
                             'Tenure (Month)',
                             'Asset Quality Status']]

Sep23_W_I_train['Type of Financing'] = Sep23_W_I_train['Type of Financing'].str.upper()
Sep23_W_I_train['Syndication (DAX)'] = Sep23_W_I_train['Syndication (DAX)'].str.upper()


Sep23_W_I_train.shape
# Out:
# C:\Users\syahidhalid\AppData\Local\Temp\11\ipykernel_13112\437620539.py:21: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Sep23_W_I_train['Type of Financing'] = Sep23_W_I_train['Type of Financing'].str.upper()
# C:\Users\syahidhalid\AppData\Local\Temp\11\ipykernel_13112\437620539.py:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Sep23_W_I_train['Syndication (DAX)'] = Sep23_W_I_train['Syndication (DAX)'].str.upper()
# (71, 18)

# %%
#Sep23_W_I_train
#Sep23_A_I_train

# %%
writer2 = pd.ExcelWriter(r'C:\Users\syahidhalid\Downloads\Logistic (python).xlsx',engine='xlsxwriter')

Sep23_A_W_train.to_excel(writer2, sheet_name='Active - Watchlist', index = False)
Sep23_W_I_train.to_excel(writer2, sheet_name='Watchlist - Impaired', index = False)


writer2.save()
# Out:
# C:\Users\syahidhalid\AppData\Local\Temp\11\ipykernel_13112\2935140075.py:7: FutureWarning: save is not part of the public API, usage can give unexpected results and will be removed in a future version
#   writer2.save()

# %%
writer2 = pd.ExcelWriter(r'C:\Users\syahidhalid\Downloads\Logistic Asset Quality (Ori).xlsx',engine='xlsxwriter')

Sep23_A_W.to_excel(writer2, sheet_name='Active - Watchlist', index = False)
Sep23_W_I.to_excel(writer2, sheet_name='Watchlist - Impaired', index = False)


writer2.save()
# Out:
# C:\Users\syahidhalid\AppData\Local\Temp\1\ipykernel_17944\3806193563.py:7: FutureWarning: save is not part of the public API, usage can give unexpected results and will be removed in a future version
#   writer2.save()

# %%
pip install xlsxwriter
# Out:
# ...
#
# ...
#                                               0.0/154.8 kB ? eta -:--:--
#      -------                                 30.7/154.8 kB 1.3 MB/s eta 0:00:01
#      -------------------------------------  153.6/154.8 kB 1.8 MB/s eta 0:00:01
#      -------------------------------------- 154.8/154.8 kB 1.5 MB/s eta 0:00:00
# ...

# %% [markdown]
# # Profitability criteria

# %%
Sep23_A_W_I = Sep23.iloc[np.where((Sep23['Asset Quality Status'].isin(['Active','Active-Watchlist','Impaired'])))]

# %%
Sep23_A_W_I.shape
# Out:
# (117, 170)

# %%
Sep23_A_W_I.head(1)
# Out:
#       No.  CIF Number        EXIM Account No. Application System Code  \
# 2595  2.0  EXIM000023  3308-02105-205-0004-00                     CBD
#
#      CCRIS Master Account Number CCRIS Sub Account Number Finance(SAP) Number  \
# 2595                  BIT   0001               BIT   0001              500010
#
#                       Company Group                  Customer Name  \
# 2595  PT Bumi International Tankers  PT Bumi International Tankers
#
#      Relationship Manager (RM) Banking Team               Ownership  \
# 2595                      ARRD         ARRD  Asset Rehab & Recovery
#
#          Officer in Charge Syndicated / Club Deal Nature of Account  \
# 2595  En. Faizal Bin Yunos         Not Applicable         Non Trade
#
#           Facility Facility Currency Type of Financing  \
# 2595  Buyer Credit               USD      Conventional
#
#      Shariah Contract / Concept    Status Post Approval Stage  \
# 2595                        NaN  Impaired                 NaN
#
# ...

# %%
#impared 52
Sep23_A_W_I_train = Sep23_A_W_I[['Trade Non Trade',
                             'Market Type','Payment Frequency',
                             'Corporate Status','Region',
                             'Country Rating','BNM Main Sector',
                             'Facility',
                             'Facility Currency','Asset Quality Status','Return Status']]

                             #'Classification of Residency Status',
                             #'Classification of Entity / Customer Type',
                             #'Syndication (DAX)',
                             #'Corporate Type',
                             #'Type of Financing', 
                             #'Oustanding Ratio',
                             #'Collactable Profit',
                             #'Tenure (Month)',
            
#Sep23_A_W_I_train['Type of Financing'] = Sep23_A_W_I_train['Type of Financing'].str.upper()
#Sep23_A_W_I_train['Syndication (DAX)'] = Sep23_A_W_I_train['Syndication (DAX)'].str.upper()


Sep23_A_W_I_train.shape
# Out:
# (117, 11)

# %%
writer2 = pd.ExcelWriter(r'C:\Users\syahidhalid\Downloads\Logistic (profit - criteria - python).xlsx',engine='xlsxwriter')

Sep23_A_W_I_train.to_excel(writer2, sheet_name='Sep2023', index = False)

writer2.save()
# Out:
# C:\Users\syahidhalid\AppData\Local\Temp\10\ipykernel_12708\4180026091.py:5: FutureWarning: save is not part of the public API, usage can give unexpected results and will be removed in a future version
#   writer2.save()
