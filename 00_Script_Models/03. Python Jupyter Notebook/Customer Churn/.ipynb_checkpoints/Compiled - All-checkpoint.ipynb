# %%
import pandas as pd
import numpy as np
pd.set_option("display.max_columns", None)

df = pd.read_excel(r'C:\Users\syahidhalid\OneDrive - Export-Import Bank of Malaysia (EXIM Bank)\Desktop\Work\Customer Churn Prediction\Compiled.xlsx', sheet_name='Sheet1')

#df['Position as At'].value_counts()

#df['Asset Quality Status'].value_counts()

#a = df.groupby(['Asset Quality Status'])[['Total Loans Outstanding (MYR)']].sum().reset_index()
#a

Sep23 = df.iloc[np.where((df['Position as At']=='2023-09-30')&(df['Asset Quality Status'].isin(['Active','Active-Watchlist','Impaired'])))]
Aug23 = df.iloc[np.where((df['Position as At']=='2023-08-31')&(df['Asset Quality Status'].isin(['Active','Active-Watchlist','Impaired'])))]
Jul23 = df.iloc[np.where((df['Position as At']=='2023-07-31')&(df['Asset Quality Status'].isin(['Active','Active-Watchlist','Impaired'])))]
Jun23 = df.iloc[np.where((df['Position as At']=='2023-06-30')&(df['Asset Quality Status'].isin(['Active','Active-Watchlist','Impaired'])))]
May23 = df.iloc[np.where((df['Position as At']=='2023-05-31')&(df['Asset Quality Status'].isin(['Active','Active-Watchlist','Impaired'])))]
Dec22 = df.iloc[np.where((df['Position as At']=='2022-12-30')&(df['Asset Quality Status'].isin(['Active','Active-Watchlist','Impaired'])))]
Dec21 = df.iloc[np.where((df['Position as At']=='2021-12-31')&(df['Asset Quality Status'].isin(['Active','Active-Watchlist','Impaired'])))]
Dec20 = df.iloc[np.where((df['Position as At']=='2020-12-31')&(df['Asset Quality Status'].isin(['Active','Active-Watchlist','Impaired'])))]

print(Sep23.shape)
print(Aug23.shape)
print(Jul23.shape)
print(Jun23.shape)
print(May23.shape)
print(Dec22.shape)
print(Dec21.shape)
print(Dec20.shape)
# Out:
# (117, 165)
# (124, 165)
# (122, 165)
# (122, 165)
# (122, 165)
# (119, 165)
# (138, 165)
# (162, 165)

# %%
#Jul23.head(1)

#print(Jun23['Status'].unique())
#print(Jun23['Position as At'].unique())

#sum(Jul['Total Loans Outstanding (MYR)'])
#sum(Jun['Total Loans Outstanding (MYR)'])

# %% [markdown]
# # Track

# %% [markdown]
# # Check Acc yg Dec20 keluar Dec21

# %%
#yg masuk
combine_ = Dec21.merge(Dec20[['EXIM Account No.']], on='EXIM Account No.', how='left', indicator=True)

combine_._merge.value_counts()
# Out:
# both          129
# left_only       9
# right_only      0
# Name: _merge, dtype: int64

# %%
#maintain accounts
print(
sum(combine_.iloc[np.where(combine_._merge=='both')]['Total Loans Outstanding (MYR)']),
sum(combine_.iloc[np.where(combine_._merge=='both')]['Cumulative \nProfit Payment/\nInterest Repayment \n(MYR)'])
)
# Out:
# 4809832197.535089 117766046.96000001

# %%
#new account
print(
sum(combine_.iloc[np.where(combine_._merge=='left_only')].fillna(0)['Total Loans Outstanding (MYR)']),
sum(combine_.iloc[np.where(combine_._merge=='left_only')].fillna(0)['Cumulative \nProfit Payment/\nInterest Repayment \n(MYR)'])
)
# Out:
# 459035294.9406775 1731240.6600000001

# %%
#Dec20 yg keluar
combine = Dec20.merge(Dec21[['EXIM Account No.']], on='EXIM Account No.', how='outer', indicator=True)

combine._merge.value_counts()
# Out:
# both          129
# left_only      33
# right_only      9
# Name: _merge, dtype: int64

# %%
#listing yg keluar
a = combine.iloc[np.where(combine._merge=='left_only')].fillna(0)

print(
sum(a['Total Loans Outstanding (MYR)']),
sum(a['Cumulative \nProfit Payment/\nInterest Repayment \n(MYR)'])
)
# Out:
# 436775493.974911 13885757.19

# %%
#33 account yg hilg
#combine.iloc[np.where(combine._merge=='left_only')]

# %%
#9 account yg masuk
#combine_.iloc[np.where(combine_._merge=='left_only')]

# %%
#cek yg hilg tu pegi mne

NegateDec21 = df.iloc[np.where((df['Position as At']=='2021-12-31')&~(df['Asset Quality Status'].isin(['Active','Active-Watchlist','Impaired'])))]


info21 = NegateDec21.merge(combine.iloc[np.where(combine._merge=='left_only')][['EXIM Account No.']], on='EXIM Account No.', how='left', indicator=True)

# %%
#
info21._merge.value_counts()
# Out:
# left_only     153
# both           32
# right_only      0
# Name: _merge, dtype: int64

# %%
#cek dr 33 tu 32 je ad reason
info20 = combine.iloc[np.where(combine._merge=='left_only')].merge(NegateDec21[['EXIM Account No.']], on='EXIM Account No.', how='left', indicator='Tag')

# %%
info20.Tag.value_counts()
# Out:
# both          32
# left_only      1
# right_only     0
# Name: Tag, dtype: int64

# %%
info20.iloc[np.where(info20.Tag=='left_only')]#.Status.value_counts()
# Out:
#       No.  CIF Number        EXIM Account No. Application System Code  \
# 28  243.0  EXIM000248  3308-01137-112-0179-00                     NaN
#
#    CCRIS Master Account Number CCRIS Sub Account Number Finance(SAP) Number  \
# 28                         NaN                      NaN              500895
#
#                   Company Group                Customer Name  \
# 28  Fuciphagus Agritech Sdn Bhd  Fuciphagus Agritech Sdn Bhd
#
#    Relationship Manager (RM) Banking Team               Ownership  \
# 28                       NaN          NaN  Asset Rehab & Recovery
#
#                            Officer in Charge Syndicated / Club Deal  \
# 28  Cik Nur Syahira Atiqa binti Ahmad Faisal         Not Applicable
#
#    Nature of Account            Facility Facility Currency Type of Financing  \
# 28             Trade  Term Financing - i               MYR           Islamic
#
#    Shariah Contract / Concept    Status Post Approval Stage  \
# 28                        NaN  Impaired                 NaN
#
#     Date of Ready for Utilization (RU) Restructured / Rescheduled\n(Y/N)  \
# 28                                 NaN                               Yes
#
#     Amount Approved / Facility Limit (Facility Currency)  \
# 28                                         1942708.24
#
#     Amount Approved / Facility Limit (MYR)  \
# 28                              1942708.24
#
#     Cost/Principal Outstanding (Facility Currency)  \
# 28                                      1717185.88
#
#     Cost/Principal Outstanding (MYR)  \
# 28                        1770981.03
#
#     Contingent Liability Letter of Credit (Facility Currency)  \
# 28                                                NaN
#
#     Contingent Liability Letter of Credit (MYR)  \
# 28                                          NaN
#
#     Contingent Liability (Facility Currency)  Contingent Liability (MYR)  \
# 28                                       NaN                         NaN
#
#     Account Receivables/Past Due Claims (Facility Currency)  \
# 28                                                NaN
#
#     Account Receivable/Past Due Claims (MYR)  \
# 28                                       NaN
#
#     Total Banking Exposure \n(Facility Currency)  \
# 28                                           NaN
#
#     Total Banking Exposure (MYR)  \
# 28                           NaN
#
#     Accrued Profit/\nInterest of the month\n (Facility Currency)  \
# 28                                                NaN
#
#     Accrued Profit/Interest of the month\n (MYR)  \
# 28                                           NaN
#
#     Modification of Loss (Facility Currency)  Modification of Loss (MYR)  \
# 28                                       0.0                         0.0
#
#     Cumulative Accrued Profit/Interest (Facility Currency)  \
# 28                                                0.0
#
#     Cumulative Accrued Profit/Interest (MYR)  \
# 28                                       0.0
#
#     Penalty/Ta`widh (Facility Currency)  Penalty/Ta`widh (MYR)  \
# 28                                  0.0                    0.0
#
#     Income/Interest in Suspense (Facility Currency)  \
# 28                                         37516.74
#
#     Income/Interest in Suspense (MYR)  Other Charges (Facility Currency)  \
# 28                           37516.74                           10500.23
#
#     Other Charges (MYR)  Total Loans Outstanding (Facility Currency)  \
# 28             10500.23                                          NaN
#
#     Total Loans Outstanding (MYR)  \
# 28                     1781481.26
#
#     Expected Credit Loss (ECL) LAF (Facility Currency)  \
# 28                                          1781481.0
#
#     Expected Credit Loss LAF (ECL) (MYR)  \
# 28                             1781481.0
#
#     Expected Credit Loss C&C (ECL) (Facility Currency)  \
# 28                                                0.0
#
#     Expected Credit Loss C&C (ECL) (MYR) Disbursement/\nDrawdown Status  \
# 28                                   0.0                            NaN
#
#     Unutilised/\nUndrawn Amount (Facility Currency)  \
# 28                                              0.0
#
#     Unutilised/\nUndrawn Amount (MYR)  \
# 28                                0.0
#
#     Disbursement/\nDrawdown \n(Facility Currency)  \
# 28                                            NaN
#
#     Disbursement/Drawdown (MYR)  \
# 28                          NaN
#
#     Cumulative Disbursement/\nDrawdown \n(Facility Currency)  \
# 28                                                0.0
#
#     Cumulative Disbursement/\nDrawdown \n(MYR)  \
# 28                                         0.0
#
#     Cost Payment/\nPrincipal Repayment \n(Facility Currency)  \
# 28                                                NaN
#
#     Cost Payment/\nPrincipal Repayment \n(MYR)  \
# 28                                         NaN
#
#     Cumulative \nCost Payment/\nPrincipal Repayment (Facility Currency)  \
# 28                                           53649.58
#
#     Cumulative \nCost Payment/\nPrincipal Repayment \n(MYR)  \
# 28                                           67598.62
#
#     Profit Payment/\nInterest Repayment (Facility Currency)  \
# 28                                                NaN
#
#     Profit Payment/\nInterest Repayment \n(MYR)  \
# 28                                          NaN
#
#     Cumulative \nProfit Payment/\nInterest Repayment (Facility Currency)  \
# 28                                                0.0
#
#     Cumulative \nProfit Payment/\nInterest Repayment \n(MYR)  \
# 28                                                0.0
#
#     Ta`widh Payment/\nPenalty Repayment (Facility Currency)  \
# 28                                                NaN
#
#     Ta`widh Payment/\nPenalty Repayment  \n(MYR)  \
# 28                                           NaN
#
#     Cumulative \nTa`widh Payment/\nPenalty Repayment (Facility Currency)  \
# 28                                                NaN
#
#     Cumulative \nTa`widh Payment/\nPenalty Repayment  \n(MYR)  \
# 28                                                NaN
#
#     Other Charges Payment (Facility Currency)  Other Charges Payment (MYR)  \
# 28                                        NaN                          NaN
#
#     Cumulative Other Charges Payment (Facility Currency)  \
# 28                                                NaN
#
#     Cumulative Other Charges Payment (MYR) Rating at Origination  PD  PF  \
# 28                                     NaN                     3  10 NaN
#
#     CRMS Obligor Risk Rating  PD (%)  LGD (%)       Risk Analyst  \
# 28                       NaN     1.0      1.0  Nor Zalina Yaacob
#
#     MFRS9 Staging                    BNM Main Sector  \
# 28            3.0  Agriculture, Forestry and Fishing
#
#                                        BNM Sub Sector     EXIM Main Sector  \
# 28  Support activities to agriculture and post-har...  Primary Agriculture
#
#    Industry (Risk) Industry Classification  \
# 28          Others                     NaN
#
#                                  Purpose of Financing  \
# 28  To restructure the outstanding balance of the ...
#
#    Date Approved at Origination Approval Authority LO issuance Date  \
# 28                   2018-11-14               FIIC              NaN
#
#    Date of LO Acceptance 1st Disbursement/Drawdown Date  \
# 28   2016-09-26 00:00:00                     2017-01-11
#
#    1st Payment/\nRepayment Date Expiry of Availability Period  \
# 28                          NaT                      00:00:00
#
#    Facility Agreement Date Annual Review Date Watchlist Review Date  \
# 28                     NaT                NaT                   NaT
#
#    Maturity/Expired Date  Grace Period (Month)  Moratorium Period (Month)   \
# 28            2018-05-09                   NaN                         NaN
#
#    Start Moratorium Date Fund Type  Tenure (Month)  \
# 28                   NaN       NaN            12.0
#
#    Payment/Repayment Frequency (Profit/Interest)  \
# 28                                        Bullet
#
#    Payment/Repayment Frequency (Cost/Principal) Effective cost of borrowings  \
# 28                                       Bullet                        Fixed
#
#    Profit/Interest Margin Average Profit/Interest Rate  \
# 28    1900-01-06 00:00:00                     05:45:36
#
#    Ta`widh Compensation/Penalty Rate Operation Country Country Exposure  \
# 28                               NaN          Malaysia         Malaysia
#
#    Country Rating    Region  Market Type  \
# 28             a-  Malaysia  Traditional
#
#    Classification of Entity / Customer Type Entity / Customer Type  \
# 28                        Business Entities                Company
#
#    Classification of Residency Status           Residency Status  \
# 28                           Resident  Non-Bumiputera Controlled
#
#    Corporate Type SME Commercial Corporate Corporate Status  \
# 28       Non-Bumi                SME-Small              NaN
#
#    Justification on Corporate Status  Restructured / Rescheduled  \
# 28                                NaN               Restructured
#
#    Date of Approval Restructured / Rescheduled Effective Date          Reason  \
# 28                                       43418            NaN  Cashflow Tight
#
#    Date Untagged from R&R Justification for Untagged Frequency  \
# 28                    NaN                        NaN   2 Times
#
#     Date of Overdue  Overdue (Days)  Month in Arrears  \
# 28              NaN             NaN              33.0
#
#     Overdue Amount (Facility Currency) Overdue Amount (MYR)  \
# 28                                 0.0                    0
#
#    Date Classified as Watchlist                    Watchlist Reason  \
# 28          2018-02-26 00:00:00  Financing Activity - Payment Delay
#
#    Date Declassified from Watchlist Date Impaired Reason for Impairment  \
# 28                              NaT    2018-05-11                   NaN
#
#    Partial Write off Date Write off Date Cancellation Date/Fully Settled Date  \
# 28                    NaT            NaT                                  NaT
#
#    Position as At  Oustanding Ratio  Since Impaired (Months)  \
# 28     2020-12-31          0.917009                31.639344
#
#     Turned Impaired (Months) Outstanding Category Turned Impaired Category  \
# 28                 15.901639        2. Below 100%        1. Below 24 Month
#
#       Tenure Category Trade Non Trade  Since Watchlist (Months)  \
# 28  1. Below 60 Month           Trade                       0.0
#
#     Turned Watchlist (Months) Turned Watchlist Category  \
# 28                        0.0         1. Below 24 Month
#
#     Profit/Interest Margin (MYR)  Year Impaired  Year Watchlist  \
# 28                   106888.8756         2018.0          2018.0
#
#    Asset Quality Status Syndication (DAX) Payment Frequency  \
# 28             Impaired   Non-Syndication            Bullet
#
#    Since Impaired Category  Collactable Profit Collectable Profit Category  \
# 28       2. Below 48 Month                 0.0   1. Collectable below 100%
#
#        _merge        Tag
# 28  left_only  left_only

# %% [markdown]
# # Check Acc yg Dec21 keluar Dec22

# %%
#yg masuk
combine1_ = Dec22.merge(Dec21[['EXIM Account No.']], on='EXIM Account No.', how='left', indicator=True)
combine1_._merge.value_counts()
# Out:
# both          110
# left_only       9
# right_only      0
# Name: _merge, dtype: int64

# %%
#maintain accounts
print(
sum(combine1_.iloc[np.where(combine1_._merge=='both')]['Total Loans Outstanding (MYR)']),
sum(combine1_.iloc[np.where(combine1_._merge=='both')]['Cumulative \nProfit Payment/\nInterest Repayment \n(MYR)'])
)
# Out:
# 4316298616.238102 154916460.187625

# %%
#new account
print(
sum(combine1_.iloc[np.where(combine1_._merge=='left_only')].fillna(0)['Total Loans Outstanding (MYR)']),
sum(combine1_.iloc[np.where(combine1_._merge=='left_only')].fillna(0)['Cumulative \nProfit Payment/\nInterest Repayment \n(MYR)'])
)
# Out:
# 365202919.38 7365620.7

# %%
#yg keluar
combine1 = Dec21.merge(Dec22[['EXIM Account No.']], on='EXIM Account No.', how='outer', indicator=True)
combine1._merge.value_counts()
# Out:
# both          110
# left_only      28
# right_only      9
# Name: _merge, dtype: int64

# %%
#listing yg keluar
a = combine1.iloc[np.where(combine1._merge=='left_only')].fillna(0)

print(a.shape,
sum(a['Total Loans Outstanding (MYR)']),
sum(a['Cumulative \nProfit Payment/\nInterest Repayment \n(MYR)'])
)
# Out:
# (28, 166) 802100196.7385716 15798517.98

# %%
#28 account yg hilg
combine1.iloc[np.where(combine1._merge=='left_only')]

# %%
#9 account yg masuk
combine1_.iloc[np.where(combine1_._merge=='left_only')]

# %%
NegateDec22 = df.iloc[np.where((df['Position as At']=='2022-12-30')&~(df['Asset Quality Status'].isin(['Active','Active-Watchlist','Impaired'])))]

# %%
info = NegateDec22.merge(combine1.iloc[np.where(combine1._merge=='left_only')][['EXIM Account No.']], on='EXIM Account No.', how='left', indicator=True)
#info = combine.iloc[np.where(combine._merge=='left_only')].merge(NegateDec21[['EXIM Account No.']], on='EXIM Account No.', how='left', indicator='Tag')

# %%
info._merge.value_counts()
#info.Tag.value_counts()

# %%
info.iloc[np.where(info._merge=='both')].Status.value_counts()

# %%
#cek dr 33 tu wujud x infuture as luar active kita
info__ = combine1.iloc[np.where(combine1._merge=='left_only')].merge(NegateDec22[['EXIM Account No.']], on='EXIM Account No.', how='left', indicator='Tag')

# %%
info__.Tag.value_counts()

# %%
info__.iloc[np.where(info__.Tag=='both')].Status.value_counts()

# %% [markdown]
# # Check Acc yg Dec22 keluar Sep23

# %%
#yg masuk
combine2_ = Sep23.merge(Dec22[['EXIM Account No.']], on='EXIM Account No.', how='left', indicator=True)
combine2_._merge.value_counts()
# Out:
# both          101
# left_only      16
# right_only      0
# Name: _merge, dtype: int64

# %%
#maintain accounts
print(
sum(combine2_.iloc[np.where(combine2_._merge=='both')]['Total Loans Outstanding (MYR)']),
sum(combine2_.iloc[np.where(combine2_._merge=='both')]['Cumulative \nProfit Payment/\nInterest Repayment \n(MYR)'])
)
# Out:
# 4487356188.485584 138386375.99202502

# %%
#new account
print(
sum(combine2_.iloc[np.where(combine2_._merge=='left_only')].fillna(0)['Total Loans Outstanding (MYR)']),
sum(combine2_.iloc[np.where(combine2_._merge=='left_only')].fillna(0)['Cumulative \nProfit Payment/\nInterest Repayment \n(MYR)'])
)
# Out:
# 263449342.17000005 6074939.899999999

# %%
#yg keluar
combine2 = Dec22.merge(Sep23[['EXIM Account No.']], on='EXIM Account No.', how='left', indicator=True)
combine2._merge.value_counts()
# Out:
# both          101
# left_only      18
# right_only      0
# Name: _merge, dtype: int64

# %%
#listing yg keluar
a = combine2.iloc[np.where(combine2._merge=='left_only')].fillna(0)

print(
sum(a['Total Loans Outstanding (MYR)']),
sum(a['Cumulative \nProfit Payment/\nInterest Repayment \n(MYR)'])
)
# Out:
# 248949216.66876572 13474142.270000001

# %%
#cek = combine2.iloc[np.where(combine2._merge=='both')].merge(combine2_.iloc[np.where(combine2_._merge=='both')][['EXIM Account No.']], on='EXIM Account No.', how='left', indicator='lala')

#cek.lala.value_counts()

#cek.iloc[np.where(cek.lala=='left_only')]

# %%
#8 account yg hilg
combine2.iloc[np.where(combine2._merge=='left_only')]#.shape

# %%
#12 account yg masuk
combine2_.iloc[np.where(combine2_._merge=='left_only')]

# %%
#all listing as of sep23 non active, watchlist, impaired
NegateSep23 = df.iloc[np.where((df['Position as At']=='2023-09-30')&~(df['Asset Quality Status'].isin(['Active','Active-Watchlist','Impaired'])))]

# %%
info = NegateSep23.merge(combine2.iloc[np.where(combine2._merge=='left_only')][['EXIM Account No.']], on='EXIM Account No.', how='left', indicator=True)
info._merge.value_counts()
# Out:
# left_only     286
# both           17
# right_only      0
# Name: _merge, dtype: int64

# %%
info.iloc[np.where(info._merge=='both')].Status.value_counts()
# Out:
# Fully Write-Off    8
# Fully Settled      8
# Cancelled          1
# Name: Status, dtype: int64

# %%
#new account
print(
sum(info.iloc[np.where((info._merge=='both')&(info.Status=='Fully Settled'))].fillna(0)['Total Loans Outstanding (MYR)']),
sum(info.iloc[np.where((info._merge=='both')&(info.Status=='Fully Settled'))].fillna(0)['Cumulative \nProfit Payment/\nInterest Repayment \n(MYR)'])
)
# Out:
# -0.0015529041120316833 4364059.09

# %%
#cek yg xde dlm last year
info = combine2.iloc[np.where(combine2._merge=='left_only')].merge(NegateSep23[['EXIM Account No.']], on='EXIM Account No.', how='left', indicator='Tag')

info.Tag.value_counts()
# Out:
# both          17
# left_only      1
# right_only     0
# Name: Tag, dtype: int64

# %%
info.iloc[np.where(info.Tag=='left_only')].Status.value_counts()
# Out:
# Active    1
# Name: Status, dtype: int64

# %%
info.iloc[np.where(info.Tag=='left_only')]
# Out:
#     No.  CIF Number        EXIM Account No. Application System Code  \
# 1  15.0  EXIM000079  3308-01137-108-0241-00                     EFD
#
#   CCRIS Master Account Number CCRIS Sub Account Number Finance(SAP) Number  \
# 1                        ZICO               ZICO ESF-I              500995
#
#        Company Group      Customer Name Relationship Manager (RM)  \
# 1  Zaid Ibrahim & Co  Zaid Ibrahim & Co              Mohamad Aqif
#
#   Banking Team Ownership                 Officer in Charge  \
# 1    Banking 3     Trade  Cik. Nadiah Binti Abdul Mutallib
#
#   Syndicated / Club Deal Nature of Account               Facility  \
# 1         Not Applicable             Trade  Export of Services -i
#
#   Facility Currency Type of Financing Shariah Contract / Concept  Status  \
# 1               MYR           Islamic                   Tawarruq  Active
#
#   Post Approval Stage  Date of Ready for Utilization (RU)  \
# 1                 NaN                                 NaN
#
#   Restructured / Rescheduled\n(Y/N)  \
# 1                                No
#
#    Amount Approved / Facility Limit (Facility Currency)  \
# 1                                          8000000.0
#
#    Amount Approved / Facility Limit (MYR)  \
# 1                               8000000.0
#
#    Cost/Principal Outstanding (Facility Currency)  \
# 1                                       5899000.0
#
#    Cost/Principal Outstanding (MYR)  \
# 1                         5899000.0
#
#    Contingent Liability Letter of Credit (Facility Currency)  \
# 1                                                0.0
#
#    Contingent Liability Letter of Credit (MYR)  \
# 1                                          0.0
#
#    Contingent Liability (Facility Currency)  Contingent Liability (MYR)  \
# 1                                       0.0                         0.0
#
#    Account Receivables/Past Due Claims (Facility Currency)  \
# 1                                                0.0
#
#    Account Receivable/Past Due Claims (MYR)  \
# 1                                       0.0
#
#    Total Banking Exposure \n(Facility Currency)  Total Banking Exposure (MYR)  \
# 1                                     8000000.0                     8000000.0
#
#    Accrued Profit/\nInterest of the month\n (Facility Currency)  \
# 1                                       30354.904932
#
#    Accrued Profit/Interest of the month\n (MYR)  \
# 1                                  30354.904932
#
#    Modification of Loss (Facility Currency)  Modification of Loss (MYR)  \
# 1                                       0.0                         0.0
#
#    Cumulative Accrued Profit/Interest (Facility Currency)  \
# 1                                      108786.078219
#
#    Cumulative Accrued Profit/Interest (MYR)  \
# 1                                 108786.07
#
#    Penalty/Ta`widh (Facility Currency)  Penalty/Ta`widh (MYR)  \
# 1                                  0.0                    0.0
#
#    Income/Interest in Suspense (Facility Currency)  \
# 1                                              0.0
#
#    Income/Interest in Suspense (MYR)  Other Charges (Facility Currency)  \
# 1                                0.0                               73.6
#
#    Other Charges (MYR)  Total Loans Outstanding (Facility Currency)  \
# 1                 73.6                                 6.007860e+06
#
#    Total Loans Outstanding (MYR)  \
# 1                     6007859.67
#
#    Expected Credit Loss (ECL) LAF (Facility Currency)  \
# 1                                       466825.38622
#
#    Expected Credit Loss LAF (ECL) (MYR)  \
# 1                          466825.38622
#
#    Expected Credit Loss C&C (ECL) (Facility Currency)  \
# 1                                       86946.940357
#
#    Expected Credit Loss C&C (ECL) (MYR) Disbursement/\nDrawdown Status  \
# 1                          86946.940357           Ongoing Disbursement
#
#    Unutilised/\nUndrawn Amount (Facility Currency)  \
# 1                                        2101000.0
#
#    Unutilised/\nUndrawn Amount (MYR)  \
# 1                          2101000.0
#
#    Disbursement/\nDrawdown \n(Facility Currency)  Disbursement/Drawdown (MYR)  \
# 1                                            0.0                          0.0
#
#    Cumulative Disbursement/\nDrawdown \n(Facility Currency)  \
# 1                                         13898000.0
#
#    Cumulative Disbursement/\nDrawdown \n(MYR)  \
# 1                                  13898000.0
#
#    Cost Payment/\nPrincipal Repayment \n(Facility Currency)  \
# 1                                           990000.0
#
#    Cost Payment/\nPrincipal Repayment \n(MYR)  \
# 1                                    990000.0
#
#    Cumulative \nCost Payment/\nPrincipal Repayment (Facility Currency)  \
# 1                                         15998000.0
#
#    Cumulative \nCost Payment/\nPrincipal Repayment \n(MYR)  \
# 1                                         15998000.0
#
#    Profit Payment/\nInterest Repayment (Facility Currency)  \
# 1                                           24100.13
#
#    Profit Payment/\nInterest Repayment \n(MYR)  \
# 1                                     24100.13
#
#    Cumulative \nProfit Payment/\nInterest Repayment (Facility Currency)  \
# 1                                          389232.36
#
#    Cumulative \nProfit Payment/\nInterest Repayment \n(MYR)  \
# 1                                          389232.36
#
#    Ta`widh Payment/\nPenalty Repayment (Facility Currency)  \
# 1                                                0.0
#
#    Ta`widh Payment/\nPenalty Repayment  \n(MYR)  \
# 1                                           0.0
#
#    Cumulative \nTa`widh Payment/\nPenalty Repayment (Facility Currency)  \
# 1                                                0.0
#
#    Cumulative \nTa`widh Payment/\nPenalty Repayment  \n(MYR)  \
# 1                                                0.0
#
#    Other Charges Payment (Facility Currency)  Other Charges Payment (MYR)  \
# 1                                        0.0                          0.0
#
#    Cumulative Other Charges Payment (Facility Currency)  \
# 1                                               70.2
#
#    Cumulative Other Charges Payment (MYR) Rating at Origination PD  PF  \
# 1                                    70.2                     2  5 NaN
#
#    CRMS Obligor Risk Rating    PD (%)  LGD (%)    Risk Analyst  MFRS9 Staging  \
# 1                       4.1  0.107303   0.8082  Hakim Hariawan            1.0
#
#                                      BNM Main Sector  \
# 1  Professional, Scientific and Technical Activities
#
#                     BNM Sub Sector  \
# 1  Legal and accounting activities
#
#                                     EXIM Main Sector Industry (Risk)  \
# 1  Finance Insurance Real Estate and Business Act...          Others
#
#   Industry Classification                               Purpose of Financing  \
# 1                     NaN  To part finance the firm`s working capital for...
#
#   Date Approved at Origination Approval Authority     LO issuance Date  \
# 1                   2017-10-26                NaN  2017-10-26 00:00:00
#
#   Date of LO Acceptance 1st Disbursement/Drawdown Date  \
# 1   2017-11-01 00:00:00                     2019-04-26
#
#   1st Payment/\nRepayment Date Expiry of Availability Period  \
# 1                          NaT                      00:00:00
#
#   Facility Agreement Date Annual Review Date Watchlist Review Date  \
# 1              2018-08-30         2022-10-07                   NaT
#
#   Maturity/Expired Date  Grace Period (Month)  Moratorium Period (Month)   \
# 1            2023-10-07                   NaN                         NaN
#
#   Start Moratorium Date Fund Type  Tenure (Month)  \
# 1                   NaN       NaN            12.0
#
#   Payment/Repayment Frequency (Profit/Interest)  \
# 1                                        Bullet
#
#   Payment/Repayment Frequency (Cost/Principal) Effective cost of borrowings  \
# 1                                       Bullet                       ECOF-I
#
#   Profit/Interest Margin Average Profit/Interest Rate  \
# 1                    1.5                         5.79
#
#                   Ta`widh Compensation/Penalty Rate Operation Country  \
# 1  IIMM rate or Actual Cost rate whichever is lower          Malaysia
#
#   Country Exposure Country Rating Region  Market Type  \
# 1         Malaysia           BBB+   Asia  Traditional
#
#   Classification of Entity / Customer Type Entity / Customer Type  \
# 1                        Business Entities            Partnership
#
#   Classification of Residency Status       Residency Status Corporate Type  \
# 1                           Resident  Bumiputera Controlled       Non-Bumi
#
#   SME Commercial Corporate Corporate Status  \
# 1               Commercial          Non-SME
#
#   Justification on Corporate Status  Restructured / Rescheduled  \
# 1                                NaN              Annual Review
#
#   Date of Approval Restructured / Rescheduled Effective Date Reason  \
# 1                                         NaN            NaN    NaN
#
#   Date Untagged from R&R Justification for Untagged Frequency  \
# 1                    NaN                        NaN       NaN
#
#    Date of Overdue  Overdue (Days)  Month in Arrears  \
# 1              NaN             NaN               NaN
#
#    Overdue Amount (Facility Currency) Overdue Amount (MYR)  \
# 1                                 0.0                    0
#
#   Date Classified as Watchlist Watchlist Reason  \
# 1                          NaN              NaN
#
#   Date Declassified from Watchlist Date Impaired Reason for Impairment  \
# 1                              NaT           NaT                   NaN
#
#   Partial Write off Date Write off Date Cancellation Date/Fully Settled Date  \
# 1                    NaT            NaT                                  NaT
#
#   Position as At  Oustanding Ratio  Since Impaired (Months)  \
# 1     2022-12-30          0.750982                      0.0
#
#    Turned Impaired (Months) Outstanding Category Turned Impaired Category  \
# 1                       0.0        2. Below 100%        1. Below 24 Month
#
#      Tenure Category Trade Non Trade  Since Watchlist (Months)  \
# 1  1. Below 60 Month           Trade                       0.0
#
#    Turned Watchlist (Months) Turned Watchlist Category  \
# 1                        0.0         1. Below 24 Month
#
#    Profit/Interest Margin (MYR)  Year Impaired  Year Watchlist  \
# 1                   90117.89505            0.0             0.0
#
#   Asset Quality Status Syndication (DAX) Payment Frequency  \
# 1               Active   Non-Syndication            Bullet
#
#   Since Impaired Category  Collactable Profit Collectable Profit Category  \
# 1       1. Below 24 Month            0.279489   1. Collectable below 100%
#
#       _merge        Tag
# 1  left_only  left_only
