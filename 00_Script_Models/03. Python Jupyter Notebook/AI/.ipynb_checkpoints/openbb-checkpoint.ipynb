# %%
from openbb import obb

# %%
obb.account.login(pat="<PAT>")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# File ~\AppData\Local\anaconda3\Lib\site-packages\jose\jws.py:176, in _load(jwt)
#     175 try:
# --> 176     signing_input, crypto_segment = jwt.rsplit(b".", 1)
#     177     header_segment, claims_segment = signing_input.split(b".", 1)
#
# ValueError: not enough values to unpack (expected 2, got 1)
#
# During handling of the above exception, another exception occurred:
#
# JWSError                                  Traceback (most recent call last)
# File ~\AppData\Local\anaconda3\Lib\site-packages\jose\jwt.py:183, in get_unverified_header(token)
#     182 try:
# --> 183     headers = jws.get_unverified_headers(token)
#     184 except Exception:
#
# File ~\AppData\Local\anaconda3\Lib\site-packages\jose\jws.py:109, in get_unverified_headers(token)
#      95 """Returns the decoded headers without verification of any kind.
#      96
# ...

# %%
obb.equity.price.historical("AAPL").to_df()
# Out:
# ---------------------------------------------------------------------------
# OpenBBError                               Traceback (most recent call last)
# File ~\AppData\Local\anaconda3\Lib\site-packages\openbb_core\app\command_runner.py:310, in StaticCommandRunner._execute_func(cls, route, args, execution_context, func, kwargs)
#     309 try:
# --> 310     obbject = await cls._command(
#     311         func=func,
#     312         kwargs=kwargs,
#     313     )
#     315     if chart and obbject.results:
#
# File ~\AppData\Local\anaconda3\Lib\site-packages\openbb_core\app\command_runner.py:243, in StaticCommandRunner._command(cls, func, kwargs)
#     242 with context_manager as warning_list:
# --> 243     obbject = await maybe_coroutine(func, **kwargs)
#     245     obbject.provider = getattr(
#     246         kwargs.get("provider_choices", None), "provider", None
#     247     )
#
# ...
