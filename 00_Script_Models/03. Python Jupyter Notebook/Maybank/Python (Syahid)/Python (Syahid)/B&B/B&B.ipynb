# %%
import numpy as np
import pandas as pd
import pandasql
import sqlite3

pd.set_option("display.max_columns", None) 
pd.set_option("display.max_colwidth", 1000) #huruf dlm column
pd.set_option("display.max_rows", 100)
pd.set_option("display.precision", 2) #2 titik perpuluhan

# %%
BB = pd.read_excel(r"T:\MIB Risk Management\Credit Risk Analytics - Historical\01_Reporting\01_Monthly_Reporting\20.0_Bullet and Balloon\BB\2022\BB Loans Reporting Template Sep'22 (Master compiled)_MIB portion.xlsm",sheet_name='Details', header=3)
GB = pd.read_excel(r"T:\MIB Risk Management\Credit Risk Analytics - Historical\01_Reporting\01_Monthly_Reporting\20.0_Bullet and Balloon\GB\BULLET_BALLOON_DETAILS_TEMPLATE_FINAL_Sep_22.xlsm",sheet_name='Details', header=3)

# %%
BB.columns = BB.columns.str.replace(" ",'_')
GB.columns = GB.columns.str.replace(" ",'_')

# %%
BB1 = BB.iloc[np.where((BB.Business_Segment=="Business Banking, Malaysia"))]

# %%
BB1
# Out:
#       No  Booking_Expired         Booking_Date    Booking_Number  \
# 0    1.0              NaN  2019-07-16 00:00:00  -- Key in Data--
# 1    3.0              NaN                  NaN  -- Key in Data--
# 2    2.0              NaN  2020-05-27 00:00:00  -- Key in Data--
# 3    4.0              NaN  2022-03-28 00:00:00  -- Key in Data--
# 4    4.0              NaN  2016-03-01 00:00:00  -- Key in Data--
# 5    5.0              NaN  2019-05-15 00:00:00  -- Key in Data--
# 6    6.0              NaN  2018-11-27 00:00:00  -- Key in Data--
# 7    7.0              NaN           For Noting  -- Key in Data--
# 8    8.0              NaN  2018-01-24 00:00:00  -- Key in Data--
# 9    9.0              NaN  2018-01-29 00:00:00  -- Key in Data--
# 10  10.0              NaN  2017-10-31 00:00:00  -- Key in Data--
#
#                     Requesting_Officer  Contact_No Name_of_Country  \
# 0           Nazirulwati / Noor Hafizza  04-7304811        Malaysia
# ...

# %%
GB.shape
