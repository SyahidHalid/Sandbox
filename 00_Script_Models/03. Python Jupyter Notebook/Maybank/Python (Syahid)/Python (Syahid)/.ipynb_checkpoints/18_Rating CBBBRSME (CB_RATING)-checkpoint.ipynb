# %%
import numpy as np
import pandas as pd
import pandasql
import sqlite3

pd.set_option("display.max_columns", None) 
pd.set_option("display.max_colwidth", 1000) #huruf dlm column
pd.set_option("display.max_rows", 100)
pd.set_option("display.precision", 2) #2 titik perpuluhan

# %%
date = '20210331'
#jgn lupa rename nme file

# %%
GB = pd.read_excel(r'T:\MIB Risk Management\Credit Risk Analytics - Historical\02_Data_Source\01_Corporate_Financing\01_Portfolio\\'+date+'\Copy of GB Monthly Loan Outstanding as at 31-Mar-2021_v1-refined.xls', sheet_name='cb os by mkt seg') 
#sheet_name='cb os by mkt seg 2'
#sheet_name='SourceCM'
                   
description = pd.read_excel(r"T:\MIB Risk Management\Credit Risk Analytics - Historical\01_Reporting\01_Monthly_Reporting\Python\User defined\description.xlsx", sheet_name='description')


Report_Corp_CRDM = pd.read_excel(r'T:\MIB Risk Management\Credit Risk Analytics - Historical\02_Data_Source\11_CRRS\\'+date[:4]+'\\'+date+'\Report_Corp_CRDM_'+date+'.xlsx')

# %%
CRWA = pd.read_excel(r'T:\MIB Risk Management\Credit Risk Analytics - Historical\02_Data_Source\12_RDMS\\'+date+'\CRWA Mar 2021 Final (Domestic - All except Retail).xlsx', sheet_name='Context Id=139')

#Context Id=139
#sheet_name='Context Id=162'

# %%
List = pd.read_excel(r'T:\MIB Risk Management\Credit Risk Analytics - Historical\02_Data_Source\12_RDMS\\'+date+'\List Master Listing '+date+'.xlsx')
#, sheet_name='Sheet2'

# %%
GB.head(1)
# Out:
#        Month  M Cus No                Name        Description      State Desc  \
# 0 2021-03-31   92090.0  GARY CHIAM WEI HAN  KUALA LUMPUR MAIN  FED. TERRITORY
#
#    Branch Code  Cust Class Cd Nature Of Business Economic Sector Cd  \
# 0       1401.0          500.0                NaN               0310
#
#     M Npl Date  M Sub Market Segment Cd  M Market Segment Cd Npl Flg  \
# 0  01-JAN-1900                      3.0                  1.0       N
#
#   M Partial Woff Flg   Description.1  M Customer Type M Full Writeoff Flg  \
# 0                NaN  Consumer Loans            102.0                   N
#
#   M Financing Type Cd Iso Currency Cd  M Account No M New Npl Flg  \
# 0                   I             MYR  820010000069             N
#
#    M Interest Code M Source Prod Type Cd Facility  M Bnm Balance SUM 1  \
# 0             46.0                 HZK01      RTO            901223.02
#
#    Authorised Limit SUM  M Approved Limit SUM  Cur Book Bal SUM M Msic Code  \
# 0                   0.0             881736.65         901223.02       97000
#
#   Maturity Date Origination Date  Avg Book Bal SUM  Common Coa Id  \
# 0   22-OCT-2049      02-JAN-2019         898712.92        12000.0
#
#     Issue Date  M Stock Code M Folder Name M New Id Number REMARKS AO/AM   AD  \
# 0  30-JAN-2019           NaN           NaN    820120136011     NaN   TBD  TBD
#
#    DIR   SD BIZ SEG GROUP
# 0  TBD  TBD     TBD   TBD

# %%
GB.columns = GB.columns.str.strip()
GB.columns = GB.columns.str.upper()
GB.columns = GB.columns.str.replace(" ","_")

GB.M_FINANCING_TYPE_CD = GB.M_FINANCING_TYPE_CD.str.strip()
GB.M_FINANCING_TYPE_CD = GB.M_FINANCING_TYPE_CD.str.upper()

GB.FACILITY = GB.FACILITY.str.strip()
GB.FACILITY = GB.FACILITY.str.upper()

#case 20211231,20220331,20210930 nme M_BNM_BALANCE_SUM_1
GB['M_BNM_BALANCE_SUM']=GB['M_BNM_BALANCE_SUM_1']

#M_BNM_BALANCE_SUM 20220731
GB.M_BNM_BALANCE_SUM.fillna(0, inplace=True)

GB1 = GB.iloc[np.where((GB.M_FINANCING_TYPE_CD=='I')&(GB.FACILITY!='RTO'))]

# %%
#case 20211231
#check M_MSIC_CODE kat excel n let type as general sbb klau x dia jd time value

GB1=GB1[['M_CUS_NO','NAME','M_MSIC_CODE','M_BNM_BALANCE_SUM']]

GB1 = GB1.fillna(0).groupby(['M_CUS_NO','NAME','M_MSIC_CODE'])[['M_BNM_BALANCE_SUM']].sum().reset_index().sort_values(by='M_BNM_BALANCE_SUM', ascending=False)


description.columns = description.columns.str.strip()
description.columns = description.columns.str.replace(" ", "_")
description.columns = description.columns.str.upper()

description.ISC_NOB = description.ISC_NOB.map(str)
description.ISC_NOB = description.ISC_NOB.str.strip()
description.ISC_NOB = description.ISC_NOB.str.upper()

GB1.M_MSIC_CODE = GB1.M_MSIC_CODE.map(str)
GB1.M_MSIC_CODE = GB1.M_MSIC_CODE.str.strip()
GB1.M_MSIC_CODE = GB1.M_MSIC_CODE.str.upper()

join_A = GB1.merge(description[['ISC_NOB','INDUSTRIAL_SECTOR_CODE_(ISC_DESC)2','ISC_PARENT']].drop_duplicates().rename(columns = {'ISC_NOB':'M_MSIC_CODE'}), on='M_MSIC_CODE', how='left').drop('M_BNM_BALANCE_SUM', axis=1)

# %%
Report_Corp_CRDM.columns = Report_Corp_CRDM.columns.str.strip()
Report_Corp_CRDM.columns = Report_Corp_CRDM.columns.str.upper()
Report_Corp_CRDM.columns = Report_Corp_CRDM.columns.str.replace(" ","_")

Report_Corp_CRDM1 = Report_Corp_CRDM[['GCIF_NUM','RDMS_ADJ_BRR']]

Report_Corp_CRDM1.GCIF_NUM = Report_Corp_CRDM1.GCIF_NUM.map(str)
Report_Corp_CRDM1.GCIF_NUM = Report_Corp_CRDM1.GCIF_NUM.str.strip()
Report_Corp_CRDM1.GCIF_NUM = Report_Corp_CRDM1.GCIF_NUM.str.upper()

join_A.M_CUS_NO = join_A.M_CUS_NO.map(str)
join_A.M_CUS_NO = join_A.M_CUS_NO.str.strip()
join_A.M_CUS_NO = join_A.M_CUS_NO.str.upper()
#case 20210630
join_A['M_CUS_NO'] = join_A['M_CUS_NO'].str[:-2]
join_B = join_A.merge(Report_Corp_CRDM1.rename(columns = {'GCIF_NUM':'M_CUS_NO'}).drop_duplicates(), on='M_CUS_NO', how='left')
# Out:
# D:\anaconda3\lib\site-packages\pandas\core\generic.py:5303: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[name] = value

# %%
CRWA.columns = CRWA.columns.str.strip()
CRWA.columns = CRWA.columns.str.upper()
CRWA.columns = CRWA.columns.str.replace(" ","_")

CRWA1 = CRWA[['COUNTERPARTY_ORIGINAL','CUSTOMER_FIELD19','INTERNAL_RATING_ORIGINAL']]

CRWA1.COUNTERPARTY_ORIGINAL = CRWA1.COUNTERPARTY_ORIGINAL.map(str)
CRWA1.COUNTERPARTY_ORIGINAL = CRWA1.COUNTERPARTY_ORIGINAL.str.strip()
CRWA1.COUNTERPARTY_ORIGINAL = CRWA1.COUNTERPARTY_ORIGINAL.str.upper()

join_C = join_B.merge(CRWA1.rename(columns = {'COUNTERPARTY_ORIGINAL':'M_CUS_NO'}).drop_duplicates('M_CUS_NO'), on='M_CUS_NO', how='left').drop_duplicates()


def PSE_SOV(CUSTOMER_FIELD19):
    if CUSTOMER_FIELD19 == 'PSE(SA)':
        return "PSE"
    elif CUSTOMER_FIELD19 == 'SOV(SA)':
        return "SOV"
#    else:
#        return "Unrated"
join_C['PSE/SOV'] = join_C.CUSTOMER_FIELD19.apply(PSE_SOV)

List.columns = List.columns.str.strip()
List.columns = List.columns.str.upper()
List.columns = List.columns.str.replace(" ","_")

List.GCIF_CHILD = List.GCIF_CHILD.map(str)
List.GCIF_CHILD = List.GCIF_CHILD.str.strip()
List.GCIF_CHILD = List.GCIF_CHILD.str.upper()

join_D = join_C.merge(List.rename(columns={"GCIF_CHILD":"M_CUS_NO"}).drop_duplicates(), on='M_CUS_NO', how='left').drop_duplicates()


#join_D.GCIF_PARENTS = join_D.GCIF_PARENTS.apply(lambda x: f'{x:.0f}')
join_D.GCIF_PARENTS = join_D.GCIF_PARENTS.astype(str)
join_D.GCIF_PARENTS = join_D.GCIF_PARENTS.str.strip()
join_D.GCIF_PARENTS = join_D.GCIF_PARENTS.str.upper()

join_D['GCIF_PARENTS1'] = join_D.GCIF_PARENTS.str[:-2]


join_E = join_D.merge(join_D[['M_CUS_NO','INTERNAL_RATING_ORIGINAL']].rename(columns={'M_CUS_NO':'GCIF_PARENTS1','INTERNAL_RATING_ORIGINAL':'3RD_PARTY'}), on='GCIF_PARENTS1', how='left')


join_E1 = join_E.merge(CRWA1.rename(columns = {'COUNTERPARTY_ORIGINAL':'GCIF_PARENTS1'}).drop_duplicates('GCIF_PARENTS1'), on='GCIF_PARENTS1', how='left',suffixes=('', '_y')).drop_duplicates()

join_E1['CUSTOMER_FIELD19'] = join_E1.CUSTOMER_FIELD19
join_E1.loc[join_E1['CUSTOMER_FIELD19'].isnull(),'CUSTOMER_FIELD19'] = join_E1.CUSTOMER_FIELD19_y


join_E1['3RD_PARTY'] = join_E1['3RD_PARTY']
join_E1.loc[join_E1['3RD_PARTY'].isnull(),'3RD_PARTY'] = join_E1.INTERNAL_RATING_ORIGINAL_y


join_E2 = join_E1.merge(Report_Corp_CRDM1.rename(columns = {'GCIF_NUM':'GCIF_PARENTS1'}).drop_duplicates('GCIF_PARENTS1'), on='GCIF_PARENTS1', how='left',suffixes=('', '_y')).drop_duplicates()

join_E2['3RD_PARTY'] = join_E2['3RD_PARTY']
join_E2.loc[join_E2['3RD_PARTY'].isnull(),'3RD_PARTY'] = join_E2.RDMS_ADJ_BRR_y


join_E2['FINAL_RATING'] = join_E2['INTERNAL_RATING_ORIGINAL']
join_E2.loc[join_E2['FINAL_RATING'].isnull(),'FINAL_RATING'] = join_E2.RDMS_ADJ_BRR
join_E2.loc[join_E2['FINAL_RATING'].isnull(),'FINAL_RATING'] = join_E2['3RD_PARTY']
join_E2.loc[join_E2['FINAL_RATING'].isnull(),'FINAL_RATING'] = join_E2['PSE/SOV']
join_E2.loc[join_E2['FINAL_RATING'].isnull(),'FINAL_RATING'] = "Unrated"


join_E2.rename(columns={'M_MSIC_CODE':'BNM_SECTOR_CD',\
                       'INDUSTRIAL_SECTOR_CODE_(ISC_DESC)2':'SECTOR_DESC',\
                      'ISC_PARENT':'SECTOR_PARENT',\
                      'RDMS_ADJ_BRR':'CRRS',\
                      'INTERNAL_RATING_ORIGINAL':'RDMS',\
                      'GCIF_PARENTS1':'3RD_PARTY_PARENT'},inplace=True)

join_E2['SEGMENT'] = '01. CB'

join_E2 = join_E2[['M_CUS_NO',\
                'NAME',\
                'BNM_SECTOR_CD',\
                'SECTOR_DESC',\
                'SECTOR_PARENT',\
                'SEGMENT',\
                'RDMS',\
                'CUSTOMER_FIELD19',\
                'PSE/SOV',\
                'CRRS',\
                '3RD_PARTY_PARENT',\
                '3RD_PARTY',\
                'FINAL_RATING']]
# Out:
# D:\anaconda3\lib\site-packages\pandas\core\generic.py:5303: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[name] = value

# %%
writer2 = pd.ExcelWriter(r'T:\MIB Risk Management\Credit Risk Analytics - Historical\01_Reporting\01_Monthly_Reporting\18_Rating_CBBBRSME\BRR_CBBBRSME_'+date[:6]+'(python).xlsx',engine='xlsxwriter')

join_E2.to_excel(writer2, index = False)

writer2.save()

# %%
join_E2.head(1)
# Out:
#    M_CUS_NO                                      NAME BNM_SECTOR_CD  \
# 0  23549043  LEMBAGA PEMBIAYAAN PERUMAHAN SEKTOR AWAM         64999
#
#                                                                                SECTOR_DESC  \
# 0  OTHER FINANCIAL SERVICE ACTIVITIES, EXCEPT INSURANCE/TAKAFUL AND PENSION FUNDING N.E.C.
#
#                                      SECTOR_PARENT SEGMENT RDMS  \
# 0  11. FINANCIAL AND INSURANCE/ TAKAFUL ACTIVITIES  01. CB    2
#
#   CUSTOMER_FIELD19 PSE/SOV CRRS 3RD_PARTY_PARENT 3RD_PARTY FINAL_RATING
# 0        PSE(FIRB)    None    2                N       NaN            2

# %%
=='Unrated' !='N'

# %%
join_E2.iloc[np.where(join_E2['FINAL_RATING']=='Unrated')]
# Out:
#      M_CUS_NO                                      NAME BNM_SECTOR_CD  \
# 81   27282547  SHARJAH ELECTRICITY WATER AND GAS AUTHOR        3510XB
# 84   18902204        JCORP CAPITAL EXCELLENCE SDN. BHD.         72105
# 228   7768664              AMANAH SAHAM NASIONAL BERHAD         64999
# 341  13291327               ETIQA FAMILY TAKAFUL BERHAD         651XX
# 380  16812493            ZURICH TAKAFUL MALAYSIA BERHAD         651XX
# 406  21725108                       LANGSAT OSC SDN BHD        429XXC
# 421  25197224              ETIQA GENERAL TAKAFUL BERHAD         651XX
# 437  22356725    BOARDROOM OUTSOURCE SERVICES SDN. BHD.         70209
# 453  25992791              ASIA PACIFIC NET (M) SDN BHD         63990
# 460   7888346                        ZECON LAND SDN BHD        41001C
# 483  27303539                    KLIA AEROPOLIS SDN BHD         821XX
# 487   7185822                       PJB CAPITAL SDN BHD         74XXX
# 489  22329461                 PR1MA DEVELOPMENT SDN BHD         41009
# 494  19068406                       TIRAM FRESH SDN BHD         0113X
# 495  19438995      MY PREMIER TRUSTEE (MALAYSIA) BERHAD         70209
# 496   4540342                KAA TRAVEL & TOURS SDN BHD          7210
# 501  27083105  ASIA PACIFIC WENJING FINANCIAL GROUP LTD         64200
# 502  27305432                SAMTRADE CUSTODIAN SDN BHD         620XX
# 505  25481096            KEMENTERIAN KESIHATAN MALAYSIA         861XX
# 507  27305454                     SAM CUSTODIAN SDN BHD         620XX
# 508  27410692              SENANG4U AUTOMOBIL SDN. BHD.         64200
# 509   1567313             MAJLIS DAERAH DALAT DAN MUKAH         841XX
# 510  20922293                 PERMODALAN FELCRA SDN BHD         70209
# 517  11903470       PERBADANAN URUS AIR SELANGOR BERHAD         3530X
# 519  17234402                       INGRESS CES SDN BHD         1010X
# 520   9725727   AKAUN PANJAR PERKHIDMATAN MRSM LENGGONG         852XX
# 524  18793188         DEUTSCHE TRUSTEES MALAYSIA BERHAD         66199
# 525  19130107            TEMASYA DEVELOPMENT CO SDN BHD        4210XG
# 530  21477639                                ASN SARA 1         66199
# 533   5927264          P.P.IKAN LKIM LTAB (A/K IMPREST)         74XXX
# 534  22586926                  ATLAN TECHNOLOGY SDN BHD         74XXX
# 535  22644107               TH HOTEL TERENGGANU SDN BHD        55101B
# 536  22645463               TH HOTEL ALOR SETAR SDN BHD        55101B
# 539  24289342   JABATAN AKAUNTAN NEGARA M CAW PUTRAJAYA         66199
# 541   3834049          PERBADANAN PEMBANGUNAN PERUMAHAN        41001H
# 543  27412248           MARCHSTONE PLANTATION SDN. BHD.         0240X
#
#                                                                                  SECTOR_DESC  \
# 81                              ELECTRICITY POWER GENERATION - NATURAL GAS FIRED POWER PLANT
# 84                                         RESEARCH AND DEVELOPMENT ON AGRICULTURAL SCIENCES
# 228  OTHER FINANCIAL SERVICE ACTIVITIES, EXCEPT INSURANCE/TAKAFUL AND PENSION FUNDING N.E.C.
# 341                                                                        INSURANCE/TAKAFUL
# 380                                                                        INSURANCE/TAKAFUL
# 406                                        CONSTRUCTION OF OTHER ENGINEERING PROJECTS N.E.C.
# 421                                                                        INSURANCE/TAKAFUL
# 437                                           OTHER MANAGEMENT CONSULTANCY ACTIVITIES N.E.C.
# 453                                              OTHER INFORMATION SERVICE ACTIVITIES N.E.C.
# 460               DEVELOPER - AFFORDABLE HOUSING SCHEME (AS APPROVED BY GOVERNMENT) FOR SALE
# 483                                             OFFICE ADMINISTRATIVE AND SUPPORT ACTIVITIES
# 487                                  OTHER PROFESSIONAL, SCIENTIFIC AND TECHNICAL ACTIVITIES
# 489                                                         CONSTRUCTION OF BUILDINGS N.E.C.
# 494                                       GROWING OF VEGETABLES AND MELONS, ROOTS AND TUBERS
# 495                                           OTHER MANAGEMENT CONSULTANCY ACTIVITIES N.E.C.
# 496                                                       MINING OF URANIUM AND THORIUM ORES
# 501                                                          ACTIVITIES OF HOLDING COMPANIES
# 502                                 COMPUTER PROGRAMMING, CONSULTANCY AND RELATED ACTIVITIES
# 505                                                                      HOSPITAL ACTIVITIES
# 507                                 COMPUTER PROGRAMMING, CONSULTANCY AND RELATED ACTIVITIES
# 508                                                          ACTIVITIES OF HOLDING COMPANIES
# 509          ADMINISTRATION OF THE STATE AND THE ECONOMIC AND SOCIAL POLICY OF THE COMMUNITY
# 510                                           OTHER MANAGEMENT CONSULTANCY ACTIVITIES N.E.C.
# 517                                                        STEAM AND AIR CONDITIONING SUPPLY
# 519                                                        PROCESSING AND PRESERVING OF MEAT
# 520                                                                      SECONDARY EDUCATION
# 524                                                   ACTIVITIES AUXILIARY TO FINANCE N.E.C.
# 525                                                CONSTRUCTION OF ROADS AND RAILWAYS N.E.C.
# 530                                                   ACTIVITIES AUXILIARY TO FINANCE N.E.C.
# 533                                  OTHER PROFESSIONAL, SCIENTIFIC AND TECHNICAL ACTIVITIES
# 534                                  OTHER PROFESSIONAL, SCIENTIFIC AND TECHNICAL ACTIVITIES
# 535                                                      HOTEL AND RESORT RATINGS: 3-4 STARS
# 536                                                      HOTEL AND RESORT RATINGS: 3-4 STARS
# 539                                                   ACTIVITIES AUXILIARY TO FINANCE N.E.C.
# 541                                                 CONTRACTOR - OTHER RESIDENTIAL BUILDINGS
# 543                                                              SUPPORT SERVICE TO FORESTRY
#
#                                                          SECTOR_PARENT  \
# 81             04. ELECTRICITY, GAS, STEAM AND AIR CONDITIONING SUPPLY
# 84               13. PROFESSIONAL, SCIENTIFIC AND TECHNICAL ACTIVITIES
# 228                    11. FINANCIAL AND INSURANCE/ TAKAFUL ACTIVITIES
# 341                    11. FINANCIAL AND INSURANCE/ TAKAFUL ACTIVITIES
# 380                    11. FINANCIAL AND INSURANCE/ TAKAFUL ACTIVITIES
# 406                                                   06. CONSTRUCTION
# 421                    11. FINANCIAL AND INSURANCE/ TAKAFUL ACTIVITIES
# 437              13. PROFESSIONAL, SCIENTIFIC AND TECHNICAL ACTIVITIES
# 453                                  10. INFORMATION AND COMMUNICATION
# 460                                                   06. CONSTRUCTION
# 483                  14. ADMINISTRATIVE AND SUPPORT SERVICE ACTIVITIES
# 487              13. PROFESSIONAL, SCIENTIFIC AND TECHNICAL ACTIVITIES
# 489                                                   06. CONSTRUCTION
# 494                              01. AGRICULTURE, FORESTRY AND FISHING
# 495              13. PROFESSIONAL, SCIENTIFIC AND TECHNICAL ACTIVITIES
# 496                                           02. MINING AND QUARRYING
# 501                    11. FINANCIAL AND INSURANCE/ TAKAFUL ACTIVITIES
# 502                                  10. INFORMATION AND COMMUNICATION
# 505                        17. HUMAN HEALTH AND SOCIAL WORK ACTIVITIES
# 507                                  10. INFORMATION AND COMMUNICATION
# 508                    11. FINANCIAL AND INSURANCE/ TAKAFUL ACTIVITIES
# 509  15. PUBLIC ADMINISTRATION AND DEFENCE; COMPULSORY SOCIAL SECURITY
# 510              13. PROFESSIONAL, SCIENTIFIC AND TECHNICAL ACTIVITIES
# 517            04. ELECTRICITY, GAS, STEAM AND AIR CONDITIONING SUPPLY
# 519                                                  03. MANUFACTURING
# 520                                                      16. EDUCATION
# 524                    11. FINANCIAL AND INSURANCE/ TAKAFUL ACTIVITIES
# 525                                                   06. CONSTRUCTION
# 530                    11. FINANCIAL AND INSURANCE/ TAKAFUL ACTIVITIES
# 533              13. PROFESSIONAL, SCIENTIFIC AND TECHNICAL ACTIVITIES
# 534              13. PROFESSIONAL, SCIENTIFIC AND TECHNICAL ACTIVITIES
# 535                      09. ACCOMMODATION AND FOOD SERVICE ACTIVITIES
# 536                      09. ACCOMMODATION AND FOOD SERVICE ACTIVITIES
# 539                    11. FINANCIAL AND INSURANCE/ TAKAFUL ACTIVITIES
# 541                                                   06. CONSTRUCTION
# 543                              01. AGRICULTURE, FORESTRY AND FISHING
#
#     SEGMENT RDMS CUSTOMER_FIELD19 PSE/SOV CRRS 3RD_PARTY_PARENT 3RD_PARTY  \
# 81   01. CB  NaN         CORP(SA)    None  NaN                N       NaN
# 84   01. CB  NaN         CORP(SA)    None  NaN                N       NaN
# 228  01. CB  NaN         CORP(SA)    None  NaN                N       NaN
# 341  01. CB  NaN         CORP(SA)    None  NaN                N       NaN
# 380  01. CB  NaN         CORP(SA)    None  NaN                N       NaN
# 406  01. CB  NaN         CORP(SA)    None  NaN                N       NaN
# 421  01. CB  NaN         CORP(SA)    None  NaN                N       NaN
# 437  01. CB  NaN         CORP(SA)    None  NaN                N       NaN
# 453  01. CB  NaN         CORP(SA)    None  NaN                N       NaN
# 460  01. CB  NaN         CORP(SA)    None  NaN                N       NaN
# 483  01. CB  NaN         CORP(SA)    None  NaN                N       NaN
# 487  01. CB  NaN         CORP(SA)    None  NaN                N       NaN
# 489  01. CB  NaN         CORP(SA)    None  NaN                N       NaN
# 494  01. CB  NaN         CORP(SA)    None  NaN                N       NaN
# 495  01. CB  NaN         CORP(SA)    None  NaN                N       NaN
# 496  01. CB  NaN         CORP(SA)    None  NaN                N       NaN
# 501  01. CB  NaN         CORP(SA)    None  NaN                N       NaN
# 502  01. CB  NaN              NaN    None  NaN                N       NaN
# 505  01. CB  NaN              NaN    None  NaN                N       NaN
# 507  01. CB  NaN              NaN    None  NaN                N       NaN
# 508  01. CB  NaN              NaN    None  NaN                N       NaN
# 509  01. CB  NaN              NaN    None  NaN                N       NaN
# 510  01. CB  NaN              NaN    None  NaN                N       NaN
# 517  01. CB  NaN              NaN    None  NaN                N       NaN
# 519  01. CB  NaN              NaN    None  NaN                N       NaN
# 520  01. CB  NaN              NaN    None  NaN                N       NaN
# 524  01. CB  NaN              NaN    None  NaN                N       NaN
# 525  01. CB  NaN              NaN    None  NaN                N       NaN
# 530  01. CB  NaN              NaN    None  NaN                N       NaN
# 533  01. CB  NaN              NaN    None  NaN                N       NaN
# 534  01. CB  NaN              NaN    None  NaN                N       NaN
# 535  01. CB  NaN              NaN    None  NaN                N       NaN
# 536  01. CB  NaN              NaN    None  NaN                N       NaN
# 539  01. CB  NaN              NaN    None  NaN                N       NaN
# 541  01. CB  NaN              NaN    None  NaN                N       NaN
# 543  01. CB  NaN              NaN    None  NaN                N       NaN
#
#     FINAL_RATING
# 81       Unrated
# 84       Unrated
# 228      Unrated
# 341      Unrated
# 380      Unrated
# 406      Unrated
# 421      Unrated
# 437      Unrated
# 453      Unrated
# 460      Unrated
# 483      Unrated
# 487      Unrated
# 489      Unrated
# 494      Unrated
# 495      Unrated
# 496      Unrated
# 501      Unrated
# 502      Unrated
# 505      Unrated
# 507      Unrated
# 508      Unrated
# 509      Unrated
# 510      Unrated
# 517      Unrated
# 519      Unrated
# 520      Unrated
# 524      Unrated
# 525      Unrated
# 530      Unrated
# 533      Unrated
# 534      Unrated
# 535      Unrated
# 536      Unrated
# 539      Unrated
# 541      Unrated
# 543      Unrated

# %% [markdown]
# # FIX SECTION

# %%
Nisa = pd.read_excel(r'T:\MIB Risk Management\Credit Risk Analytics - Historical\01_Reporting\01_Monthly_Reporting\18_Rating_CBBBRSME\BRR_CBBBRSME_202207.xlsx', sheet_name='Sheet1', header=1)

Nisa.columns = Nisa.columns.str.replace(" ","_").str.upper()
Nisa1 = Nisa.iloc[np.where(Nisa.SEGMENT=='01. CB')][['M_CUS_NO','FINAL_RATING']]

# %%
Nisa1.shape, join_E.shape
# Out:
# ((569, 2), (569, 13))

# %%
Syahid1 = join_E[['M_CUS_NO','FINAL_RATING']]

# %%
Nisa1.M_CUS_NO = Nisa1.M_CUS_NO.astype(str)
a = Nisa1.merge(Syahid1,on='M_CUS_NO',how='left',indicator=True)

# %%
a._merge.value_counts()
# Out:
# both          569
# right_only      0
# left_only       0
# Name: _merge, dtype: int64

# %%
a.head(1)
# Out:
#    M_CUS_NO FINAL_RATING_x FINAL_RATING_y _merge
# 0  23549043              2              2   both

# %%
a.FINAL_RATING_x = a.FINAL_RATING_x.astype(str)
a.FINAL_RATING_y = a.FINAL_RATING_y.astype(str)

b = a.iloc[np.where(a.FINAL_RATING_x!=a.FINAL_RATING_y)]

# %%
b
# Out:
#      M_CUS_NO FINAL_RATING_x FINAL_RATING_y _merge
# 31    7051644              4        Unrated   both
# 189  24165522             11        Unrated   both
# 233  16892620             10        Unrated   both
# 257  25804659             10        Unrated   both
# 402  10042966             10        Unrated   both
# 418   2532566             10        Unrated   both
# 439   5151161             10        Unrated   both
# 463   1484158             10        Unrated   both
# 464  21516161             11        Unrated   both
# 471   6015582             11        Unrated   both

# %%
#MASALAH THIRD PARTY SBB AMIK KAT PATCHING JE BUKAN KAT MASTER SKALI

# %%
join_E.iloc[np.where(join_E.M_CUS_NO=='24165522')]
# Out:
#      M_CUS_NO                                NAME BNM_SECTOR_CD  \
# 189  24165522  MSM SUGAR REFINERY (JOHOR) SDN BHD         107XX
#
#                             SECTOR_DESC      SECTOR_PARENT SEGMENT RDMS  \
# 189  MANUFACTURE OF OTHER FOOD PRODUCTS  03. MANUFACTURING  01. CB  NaN
#
#     CUSTOMER_FIELD19 PSE/SOV CRRS 3RD_PARTY_PARENT 3RD_PARTY FINAL_RATING
# 189              NaN    None  NaN                N       NaN      Unrated

# %%
List.GCIF_PARENTS
# Out:
#    GCIF_CHILD  GCIF_PARENTS
# 0    15413822      14615137
# 1    15413822      14615137
# 2    21855848      17199004
# 3    21955312      11363084
# 4     3071566       6736153
# 5     3071566       6736153
# 6     3925505      17199004
# 7     7065393      11363084
# 8     7460731      14615137
# 9     7460731      14615137
# 10    7558005      10156133
# 11    7558005      10156133
# 12   25150972      27659960
# 13    7065393      11363084
# 14    7065393      11363084
# 15   25150972      27659960
# 16    7065393      11363084
# 17    7065393      11363084
# 18    7618283       7617660
# 19    4073287      17199004
# 20   21574445      10156133
# 21    4073287      17199004
# 22   21729247      17199004
# 23   21729247      17199004
# 24    3327800      17199004
# 25    3327800      17199004
# 26    7626638      17199004
# 27    7626638      17199004
# 28    1156008      17199004
# 29    7626638      17199004
# 30    7626638      17199004
# 31   10975488      17199004
# 32    7626638      17199004
# 33   16082499      17199004
# 34    6262525       7932284
# 35   10975488      17199004
# 36    1380498      21288986
# 37    1380498      21288986
# 38    7626638      17199004
# 39    7626638      17199004
# 40    7626638      17199004
# 41   23034947      17199004
# 42    7626638      17199004
# 43    1649467      15111175
# 44    7626638      17199004
# 45    7626638      17199004
# 46   15614845      15111175
# 47    7626638      17199004
# 48    8952144      17199004
# 49   11128882      17199004
# 50   21729247      17199004
# 51   22424167      22328959
# 52   22424167      22328959
# 53    3071566       6736153
# 54    3071566       6736153
# 55    3925505      17199004
# 56    5766724       4323334
# 57    7558005      10156133
# 58    1156008      17199004
# 59    1578219      17199004
# 60   15912384      10156133
# 61   16271033      10156133
# 62   17209936      22797296
# 63   18777527      10156133
# 64   18841985      24215425
# 65   18946731       4253213
# 66   21574445      10156133
# 67   23034947      17199004
# 68   23339073      12932286
# 69   23613871      16082009
# 70   25233630      10156133
# 71   26745126      17541202
# 72    3327800      17199004
# 73    4073287      17199004
# 74    4874192       1517877
# 75    7558005      10156133

# %%
join_d = pd.concat([join_c.merge(CRWA1.rename(columns={'COUNTERPARTY_ORIGINAL':'GCIF_CHILD'}), on='GCIF_CHILD'),\
                    join_c.merge(CRWA1.rename(columns={'COUNTERPARTY_ORIGINAL':'GCIF_PARENTS'}), on='GCIF_PARENTS')]).drop_duplicates()
