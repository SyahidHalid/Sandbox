# %%
get_column_letter(114) #DJ is jun
# Out:
# 'DJ'

# %%
column = 113 #-----------------DJ=114
date = 20220531

import numpy as np
import pandas as pd
import pandasql
import sqlite3
from openpyxl import Workbook, load_workbook
from openpyxl.utils import get_column_letter

pd.set_option("display.max_columns", None) 
pd.set_option("display.max_colwidth", 1000) #huruf dlm column
pd.set_option("display.max_rows", 100)
pd.set_option("display.precision", 2) #2 titik perpuluhan

WB = load_workbook(r'T:\MIB Risk Management\Credit Risk Analytics - Historical\01_Reporting\01_Monthly_Reporting\02_Business_Financing\Maybank_Islamic_Business_Financing_'+str(date)+'(python).xlsx')
BB2 = load_workbook(r'T:\MIB Risk Management\Credit Risk Analytics - Historical\02_Data_Source\02_Business_Financing\01_Portfolio\\'+str(date)+'\BB2_SUMMARY_'+str(date)+'(python).xlsx')

# %%
EWSBASE_df = pd.read_excel(r'T:\MIB Risk Management\Credit Risk Analytics - Historical\02_Data_Source\02_Business_Financing\01_Portfolio\\'+str(date)+'\BB2_SUMMARY_'+str(date)+'(python).xlsx', sheet_name='EWSBASE')

WLBASE_df = pd.read_excel(r'T:\MIB Risk Management\Credit Risk Analytics - Historical\02_Data_Source\02_Business_Financing\01_Portfolio\\'+str(date)+'\BB2_SUMMARY_'+str(date)+'(python).xlsx', sheet_name='WLBASE')

SMABASE_df = pd.read_excel(r'T:\MIB Risk Management\Credit Risk Analytics - Historical\02_Data_Source\02_Business_Financing\01_Portfolio\\'+str(date)+'\BB2_SUMMARY_'+str(date)+'(python).xlsx', sheet_name='SMABASE')

GILBASE_df = pd.read_excel(r'T:\MIB Risk Management\Credit Risk Analytics - Historical\02_Data_Source\02_Business_Financing\01_Portfolio\\'+str(date)+'\BB2_SUMMARY_'+str(date)+'(python).xlsx', sheet_name='GILBASE')

RESTRUCTURED_df = pd.read_excel(r'T:\MIB Risk Management\Credit Risk Analytics - Historical\02_Data_Source\02_Business_Financing\01_Portfolio\\'+str(date)+'\BB2_SUMMARY_'+str(date)+'(python).xlsx', sheet_name='RESTRUCTURED')

RESCHEDULED_df = pd.read_excel(r'T:\MIB Risk Management\Credit Risk Analytics - Historical\02_Data_Source\02_Business_Financing\01_Portfolio\\'+str(date)+'\BB2_SUMMARY_'+str(date)+'(python).xlsx', sheet_name='RESCHEDULED')

# %%
#----------------------------------------------Total(RM Mil)--------------------------------

Sheet_A = WB['Total(RM Mil)']

#%MERGE(RISKCAT,BB.Summ_risk_cat&&RDATE,RISKCAT1,RISK_CAT);
#%MERGE(COLLATERAL,BB.Summ_collateral_type&&RDATE, COLLATERAL1, COLLATERAL_TYPE);
#%MERGE(REGION, BB.Summ_region&&RDATE, REGION1, REGION);
#%MERGE(BC, BB.Summ_bc&&RDATE, BC1, BC);
#%MERGE(SC, BB.Summ_sector_code&&RDATE, SC1, SECTOR_CODE);
#%MERGE(ISC, BB.Summ_isc_parent&&RDATE, ISC1, ISC_PARENT);

RISK_CAT = BB2['RISK_CAT']
COLLATERAL_TYPE = BB2['COLLATERAL_TYPE']
REGION = BB2['REGION']
BC = BB2['BC']
SECTOR_CODE = BB2['SECTOR_CODE']
ISC_PARENT = BB2['ISC_PARENT']

#%MULTIVAR(CUS_OSM,10,15,&COL,Total(RM Mil),RISKCAT1);
#%MULTIVAR(CUS_OSM,19,21,&COL,Total(RM Mil),COLLATERAL1);
#%MULTIVAR(CUS_OSM,25,32,&COL,Total(RM Mil),REGION1);
#%MULTIVAR(CUS_OSM,36,68,&COL,Total(RM Mil),BC1);
#%MULTIVAR(CUS_OSM,72,81,&COL,Total(RM Mil),SC1);
#%MULTIVAR(CUS_OSM,85,107,&COL,Total(RM Mil),ISC1);

for row in range(10,16): #extra kn satu 
    for col in range(column,column+1): #extra kn satu 
        char = get_column_letter(col)
        Sheet_A[char + str(row)] = RISK_CAT.cell(row=row-8, column=3).value
        
for row in range(19,22):
    for col in range(column,column+1):
        char=get_column_letter(col)
        Sheet_A[char+str(row)] = COLLATERAL_TYPE.cell(row=row-17, column=3).value

for row in range(25,33):
    for col in range(column,column+1):
        char=get_column_letter(col)
        Sheet_A[char+str(row)] = REGION.cell(row=row-23, column=3).value

for row in range(36,69):
    for col in range(column,column+1):
        char=get_column_letter(col)
        Sheet_A[char+str(row)] = BC.cell(row=row-34, column=3).value
    
for row in range(72,82):
    for col in range(column,column+1):
        char=get_column_letter(col)
        Sheet_A[char+str(row)] = SECTOR_CODE.cell(row=row-70, column=3).value
    
for row in range(85,108):
    for col in range(column,column+1):
        char=get_column_letter(col)
        Sheet_A[char+str(row)] = ISC_PARENT.cell(row=row-83, column=3).value

# %%
#----------------------------------------------Total(# Cust)--------------------------------

Sheet_B = WB['Total(# Cust)']

#%MULTIVAR(NOC,10,15,&COL,Total(# Cust),RISKCAT1);
#%MULTIVAR(NOC,19,21,&COL,Total(# Cust),COLLATERAL1);
#%MULTIVAR(NOC,25,32,&COL,Total(# Cust),REGION1);
#%MULTIVAR(NOC,36,68,&COL,Total(# Cust),BC1);
#%MULTIVAR(NOC,72,81,&COL,Total(# Cust),SC1);
#%MULTIVAR(NOC,85,107,&COL,Total(# Cust),ISC1);

for row in range(10,16): #extra kn satu 
    for col in range(column,column+1): #extra kn satu 
        char = get_column_letter(col)
        Sheet_B[char + str(row)] = RISK_CAT.cell(row=row-8, column=2).value

for row in range(19,22):
    for col in range(column,column+1):
        char=get_column_letter(col)
        Sheet_B[char+str(row)] = COLLATERAL_TYPE.cell(row=row-17, column=2).value

for row in range(25,33):
    for col in range(column,column+1):
        char=get_column_letter(col)
        Sheet_B[char+str(row)] = REGION.cell(row=row-23, column=2).value

for row in range(36,69):
    for col in range(column,column+1):
        char=get_column_letter(col)
        Sheet_B[char+str(row)] = BC.cell(row=row-34, column=2).value

for row in range(72,82):
    for col in range(column,column+1):
        char=get_column_letter(col)
        Sheet_B[char+str(row)] = SECTOR_CODE.cell(row=row-70, column=2).value

for row in range(85,108):
    for col in range(column,column+1):
        char=get_column_letter(col)
        Sheet_B[char+str(row)] = ISC_PARENT.cell(row=row-83, column=2).value

# %%
#----------------------------------------------Top30(RM Mil)--------------------------------

Sheet_C = WB['Top30(RM Mil)']

#%MERGE(RISKCAT,BB.T30Summ_risk_cat&&RDATE, RISK_CAT30, RISK_CAT);
#%MERGE(COLLATERAL,BB.T30Summ_collateral_type&&RDATE, COLLATERAL30, COLLATERAL_TYPE);
#%MERGE(REGION, BB.T30Summ_region&&RDATE, REGION30, REGION);
#%MERGE(BC, BB.T30Summ_bc&&RDATE, BC30, BC);
#%MERGE(SC, BB.T30Summ_sector_code&&RDATE, SC30, SECTOR_CODE);
#%MERGE(ISC, BB.T30Summ_isc_parent&&RDATE, ISC30, ISC_PARENT);

TOP30RISK_CAT = BB2['TOP30RISK_CAT']
TOP30COLLATERAL_TYPE = BB2['TOP30COLLATERAL_TYPE']

#%MULTIVAR(CUS_OSM_TOP30,10,15,&COL,Top30(RM Mil),RISK_CAT30);
#%MULTIVAR(CUS_OSM_TOP30,19,21,&COL,Top30(RM Mil),COLLATERAL30);
#%MULTIVAR(GIL_OSM_TOP30,26,28,&COL,Top30(RM Mil),COLLATERAL30);

for row in range(10,16): #extra kn satu 
    for col in range(column,column+1): #extra kn satu 
        char = get_column_letter(col)
        Sheet_C[char + str(row)] = TOP30RISK_CAT.cell(row=row-8, column=5).value
        

for row in range(19,22):
    for col in range(column,column+1):
        char=get_column_letter(col)
        Sheet_C[char+str(row)] = TOP30COLLATERAL_TYPE.cell(row=row-17, column=5).value

for row in range(26,29):
    for col in range(column,column+1):
        char=get_column_letter(col)
        Sheet_C[char+str(row)] = TOP30COLLATERAL_TYPE.cell(row=row-24, column=7).value

# %%
#----------------------------------------------Top30(# Cust)--------------------------------

#%MULTIVAR(NOC_TOP30,10,15,&COL,Top30(# Cust),RISK_CAT30);
#%MULTIVAR(NOC_TOP30,19,21,&COL,Top30(# Cust),COLLATERAL30);
#%MULTIVAR(NOC_GIL_TOP30,26,28,&COL,Top30(# Cust),COLLATERAL30);

Sheet_D = WB['Top30(# Cust)']

for row in range(10,16): #extra kn satu 
    for col in range(column,column+1): #extra kn satu 
        char = get_column_letter(col)
        Sheet_D[char + str(row)] = TOP30RISK_CAT.cell(row=row-8, column=4).value
        
for row in range(19,22):
    for col in range(column,column+1):
        char=get_column_letter(col)
        Sheet_D[char+str(row)] = TOP30COLLATERAL_TYPE.cell(row=row-17, column=4).value

for row in range(26,29):
    for col in range(column,column+1):
        char=get_column_letter(col)
        Sheet_D[char+str(row)] = TOP30COLLATERAL_TYPE.cell(row=row-24, column=6).value

# %%
#----------------------------------------------AQ(RM Mil)--------------------------------

#%MULTIVAR(CUS_OSM,9,9,&COL,AQ(RM Mil),TOTAL_EWS);/*just added on 19 Aug 21*/
#%MULTIVAR(CUS_OSM,10,10,&COL,AQ(RM Mil),TOTAL_WATCHLIST);
#%MULTIVAR(OSM,11,11,&COL,AQ(RM Mil),TOTAL_SMA);
#/*%MULTIVAR(CUS_OSM,10,10,&COL,AQ(RM Mil),TOTAL_SMA);*/
#%MULTIVAR(OSM,14,14,&COL,AQ(RM Mil),TOTAL_RESTRUCTURED);
#%MULTIVAR(OSM,15,15,&COL,AQ(RM Mil),TOTAL_RESCHEDULED);
#%MULTIVAR(CUS_OSM,13,13,&COL,AQ(RM Mil),TOTAL_IMPAIRED);
#%MULTIVAR(CUS_OSM,19,21,&COL,AQ(RM Mil),COLLATERAL_IF);
#%MULTIVAR(CUS_OSM,25,32,&COL,AQ(RM Mil),REGION_IF);
#%MULTIVAR(CUS_OSM,36,68,&COL,AQ(RM Mil),BC_IF);
#%MULTIVAR(CUS_OSM,72,81,&COL,AQ(RM Mil),SC_IF);
#%MULTIVAR(CUS_OSM,85,107,&COL,AQ(RM Mil),ISC_IF);

Sheet_E = WB['AQ(RM Mil)']

#AQ - Early Warning Signal
for row in range(9,10): #extra kn satu 
    for col in range(column,column+1): #extra kn satu 
        char = get_column_letter(col)
        Sheet_E[char + str(row)] = sum(EWSBASE_df.CUS_OSM)

#AQ - Watchlist
for row in range(10,11): #extra kn satu 
    for col in range(column,column+1): #extra kn satu 
        char = get_column_letter(col)
        Sheet_E[char + str(row)] = sum(WLBASE_df.CUS_OSM)
        
#AQ - Special Mention Accounts
for row in range(11,12): #extra kn satu 
    for col in range(column,column+1): #extra kn satu 
        char = get_column_letter(col)
        Sheet_E[char + str(row)] = sum(SMABASE_df.OSM)
        
#AQ - NCIF blom ad lg value, tunggu nawar. note at 4/8/2022
#for row in range(12,13): #extra kn satu 
#    for col in range(column,column+1): #extra kn satu 
#        char = get_column_letter(col)
#        Sheet_E[char + str(row)] = sum(GILBASE_df.CUS_OSM)
        
#AQ - GILBASE/ Impaired Financing
for row in range(13,14): #extra kn satu 
    for col in range(column,column+1): #extra kn satu 
        char = get_column_letter(col)
        Sheet_E[char + str(row)] = sum(GILBASE_df.CUS_OSM)
        
#AQ - RESTRUCTURED
for row in range(14,15): #extra kn satu 
    for col in range(column,column+1): #extra kn satu 
        char = get_column_letter(col)
        Sheet_E[char + str(row)] = sum(RESTRUCTURED_df.OSM)
        
#AQ - RESCHEDULED
for row in range(15,16): #extra kn satu 
    for col in range(column,column+1): #extra kn satu 
        char = get_column_letter(col)
        Sheet_E[char + str(row)] = sum(RESCHEDULED_df.OSM)
        
               
GILCOLLATERAL_TYPE = BB2['GILCOLLATERAL_TYPE']

for row in range(19,22):
    for col in range(column,column+1):
        char=get_column_letter(col)
        Sheet_E[char+str(row)] = GILCOLLATERAL_TYPE.cell(row=row-17, column=3).value
               
GILREGION = BB2['GILREGION']

for row in range(25,33):
    for col in range(column,column+1):
        char=get_column_letter(col)
        Sheet_E[char+str(row)] = GILREGION.cell(row=row-23, column=3).value
               
GILBC = BB2['GILBC']

for row in range(36,69):
    for col in range(column,column+1):
        char=get_column_letter(col)
        Sheet_E[char+str(row)] = GILBC.cell(row=row-34, column=3).value
                       
GILSECTOR_CODE = BB2['GILSECTOR_CODE']

for row in range(72,82):
    for col in range(column,column+1):
        char=get_column_letter(col)
        Sheet_E[char+str(row)] = GILSECTOR_CODE.cell(row=row-70, column=3).value

                               
GILISC_PARENT = BB2['GILISC_PARENT']

for row in range(85,108):
    for col in range(column,column+1):
        char=get_column_letter(col)
        Sheet_E[char+str(row)] = GILISC_PARENT.cell(row=row-83, column=3).value

# %%
#----------------------------------------------AQ(# Cust)--------------------------------

#%MULTIVAR(NOA,9,9,&COL,AQ(# Cust),TOTAL_EWS);/*just added on 19 Aug 21*/
#%MULTIVAR(NOA,10,10,&COL,AQ(# Cust),TOTAL_WATCHLIST);
#%MULTIVAR(NOA,11,11,&COL,AQ(# Cust),TOTAL_SMA);
#%MULTIVAR(NOA,15,15,&COL,AQ(# Cust),TOTAL_RESCHEDULED);
#%MULTIVAR(NOA,14,14,&COL,AQ(# Cust),TOTAL_RESTRUCTURED);
#%MULTIVAR(NOC,13,13,&COL,AQ(# Cust),TOTAL_IMPAIRED);
#%MULTIVAR(NOC,19,21,&COL,AQ(# Cust),COLLATERAL_IF);
#%MULTIVAR(NOC,25,32,&COL,AQ(# Cust),REGION_IF);
#%MULTIVAR(NOC,36,68,&COL,AQ(# Cust),BC_IF);
#%MULTIVAR(NOC,72,81,&COL,AQ(# Cust),SC_IF);
#%MULTIVAR(NOC,85,107,&COL,AQ(# Cust),ISC_IF);

Sheet_F = WB['AQ(# Cust)']

#EWSBASE = BB2['EWSBASE']

#AQ - Early Warning Signal
for row in range(9,10): #extra kn satu 
    for col in range(column,column+1): #extra kn satu 
        char = get_column_letter(col)
        Sheet_F[char + str(row)] = len(EWSBASE_df.index)

#AQ - Watchlist
for row in range(10,11): #extra kn satu 
    for col in range(column,column+1): #extra kn satu 
        char = get_column_letter(col)
        Sheet_F[char + str(row)] = len(WLBASE_df.index)
        
#AQ - Special Mention Accounts
for row in range(11,12): #extra kn satu 
    for col in range(column,column+1): #extra kn satu 
        char = get_column_letter(col)
        Sheet_F[char + str(row)] = len(SMABASE_df.index)
        
#AQ - NCIF blom ad lg value, tunggu nawar. note at 4/8/2022
#for row in range(12,13): #extra kn satu 
#    for col in range(column,column+1): #extra kn satu 
#        char = get_column_letter(col)
#        Sheet_F[char + str(row)] = len(GILBASE_df.index)
        
#AQ - GILBASE/ Impaired Financing
for row in range(13,14): #extra kn satu 
    for col in range(column,column+1): #extra kn satu 
        char = get_column_letter(col)
        Sheet_F[char + str(row)] = len(GILBASE_df.index)
        
#AQ - RESTRUCTURED
for row in range(14,15): #extra kn satu 
    for col in range(column,column+1): #extra kn satu 
        char = get_column_letter(col)
        Sheet_F[char + str(row)] = len(RESTRUCTURED_df.index)
        
#AQ - RESCHEDULED
for row in range(15,16): #extra kn satu 
    for col in range(column,column+1): #extra kn satu 
        char = get_column_letter(col)
        Sheet_F[char + str(row)] = len(RESCHEDULED_df.index)
        
            
for row in range(19,22):
    for col in range(column,column+1):
        char=get_column_letter(col)
        Sheet_F[char+str(row)] = GILCOLLATERAL_TYPE.cell(row=row-17, column=2).value
               
for row in range(25,33):
    for col in range(column,column+1):
        char=get_column_letter(col)
        Sheet_F[char+str(row)] = GILREGION.cell(row=row-23, column=2).value

for row in range(36,69):
    for col in range(column,column+1):
        char=get_column_letter(col)
        Sheet_F[char+str(row)] = GILBC.cell(row=row-34, column=2).value

for row in range(72,82):
    for col in range(column,column+1):
        char=get_column_letter(col)
        Sheet_F[char+str(row)] = GILSECTOR_CODE.cell(row=row-70, column=2).value
                            
for row in range(85,108):
    for col in range(column,column+1):
        char=get_column_letter(col)
        Sheet_F[char+str(row)] = GILISC_PARENT.cell(row=row-83, column=2).value

# %%
#----------------------------------------------NewlyApproved(RM Mil)--------------------------------

#%MULTIVAR(RM__MIL,10,15,&COL,NewlyApproved(RM Mil),RISKCAT_NA);
#%MULTIVAR(RM__MIL,19,21,&COL,NewlyApproved(RM Mil),COLLATERAL_NA);
#%MULTIVAR(RM__MIL,25,33,&COL,NewlyApproved(RM Mil),REGION_NA);
#%MULTIVAR(RM__MIL,37,71,&COL,NewlyApproved(RM Mil),BC_NA);
#%MULTIVAR(RM__MIL,75,84,&COL,NewlyApproved(RM Mil),SC_NA);
#%MULTIVAR(RM__MIL,88,110,&COL,NewlyApproved(RM Mil),ISC_NA);

Sheet_G = WB['NewlyApproved(RM Mil)']

NARISK_CAT = BB2['NARISK_CAT']

for row in range(10,16):
    for col in range(column,column+1):
        char=get_column_letter(col)
        Sheet_G[char+str(row)] = NARISK_CAT.cell(row=row-8, column=3).value
               
NACOLLATERAL_TYPE = BB2['NACOLLATERAL_TYPE']

for row in range(19,22):
    for col in range(column,column+1):
        char=get_column_letter(col)
        Sheet_G[char+str(row)] = NACOLLATERAL_TYPE.cell(row=row-17, column=3).value
               
NARegion__LOS_ = BB2['NARegion__LOS_']

for row in range(25,34):
    for col in range(column,column+1):
        char=get_column_letter(col)
        Sheet_G[char+str(row)] = NARegion__LOS_.cell(row=row-23, column=3).value
                       
NABC_Subspoke = BB2['NABC_Subspoke']

for row in range(37,72):
    for col in range(column,column+1):
        char=get_column_letter(col)
        Sheet_G[char+str(row)] = NABC_Subspoke.cell(row=row-35, column=3).value

                               
NAISC_PARENT = BB2['NAISC_PARENT']

for row in range(88,111):
    for col in range(column,column+1):
        char=get_column_letter(col)
        Sheet_G[char+str(row)] = NAISC_PARENT.cell(row=row-86, column=3).value

# %%
#----------------------------------------------NewlyApproved(# Cust)--------------------------------

#%MULTIVAR(NOA,10,15,&COL,NewlyApproved(# Cust),RISKCAT_NA);
#%MULTIVAR(NOA,19,21,&COL,NewlyApproved(# Cust),COLLATERAL_NA);
#%MULTIVAR(NOA,25,33,&COL,NewlyApproved(# Cust),REGION_NA);
#%MULTIVAR(NOA,37,71,&COL,NewlyApproved(# Cust),BC_NA);
#%MULTIVAR(NOA,75,84,&COL,NewlyApproved(# Cust),SC_NA);
#%MULTIVAR(NOA,88,110,&COL,NewlyApproved(# Cust),ISC_NA);

Sheet_H = WB['NewlyApproved(# Cust)']


for row in range(10,16):
    for col in range(column,column+1):
        char=get_column_letter(col)
        Sheet_H[char+str(row)] = NARISK_CAT.cell(row=row-8, column=2).value
               

for row in range(19,22):
    for col in range(column,column+1):
        char=get_column_letter(col)
        Sheet_H[char+str(row)] = NACOLLATERAL_TYPE.cell(row=row-17, column=2).value
               

for row in range(25,34):
    for col in range(column,column+1):
        char=get_column_letter(col)
        Sheet_H[char+str(row)] = NARegion__LOS_.cell(row=row-23, column=2).value
                       

for row in range(37,72):
    for col in range(column,column+1):
        char=get_column_letter(col)
        Sheet_H[char+str(row)] = NABC_Subspoke.cell(row=row-35, column=2).value

                               
for row in range(88,111):
    for col in range(column,column+1):
        char=get_column_letter(col)
        Sheet_H[char+str(row)] = NAISC_PARENT.cell(row=row-86, column=2).value

# %%
#----------------------------------------------TOP30_INDIVIDUAL--------------------------------

#hold dlu sbb dataset xde
#%MULTIVAR(Borrower_name,8,37,2,Listing_Top30Individual,TOP30_INDIVIDUAL);
#%MULTIVAR(CUS_OSM,8,37,3,Listing_Top30Individual,TOP30_INDIVIDUAL);
#%MULTIVAR(EAD,8,37,4,Listing_Top30Individual,TOP30_INDIVIDUAL);
#%MULTIVAR(RWA,8,37,5,Listing_Top30Individual,TOP30_INDIVIDUAL);
#%MULTIVAR(RATING,8,37,8,Listing_Top30Individual,TOP30_INDIVIDUAL);
#%MULTIVAR(FRR,8,37,9,Listing_Top30Individual,TOP30_INDIVIDUAL);
#%MULTIVAR(REGION,8,37,10,Listing_Top30Individual,TOP30_INDIVIDUAL);

# %%
#----------------------------------------------Listing_Top10Watchlist--------------------------------

#%MULTIVAR(BORROWER1,8,17,2,Listing_Top10Watchlist,TOP10_WATCHLIST);
#%MULTIVAR(CUS_OSM,8,17,3,Listing_Top10Watchlist,TOP10_WATCHLIST);
#%MULTIVAR(RATING,8,17,5,Listing_Top10Watchlist,TOP10_WATCHLIST);
#%MULTIVAR(FRR,8,17,6,Listing_Top10Watchlist,TOP10_WATCHLIST);
#%MULTIVAR(BROAD_SECTOR1,8,17,7,Listing_Top10Watchlist,TOP10_WATCHLIST);
#%MULTIVAR(REASON,8,17,8,Listing_Top10Watchlist,TOP10_WATCHLIST);

Sheet_I = WB['Listing_Top10Watchlist']

WLTOP10 = BB2['WLTOP10']

#borrower name
for row in range(8,18):
    for col in range(column,column+1):
        char= 'B' #get_column_letter(col)
        Sheet_I[char+str(row)] = WLTOP10.cell(row=row-6, column=2).value

        
##outstanding
for row in range(8,18):
    for col in range(column,column+1):
        char= 'C' #get_column_letter(col)
        Sheet_I[char+str(row)] = WLTOP10.cell(row=row-6, column=7).value

#rating/BRR
for row in range(8,18):
    for col in range(column,column+1):
        char= 'E' #get_column_letter(col)
        Sheet_I[char+str(row)] = WLTOP10.cell(row=row-6, column=6).value

#FRR
for row in range(8,18):
    for col in range(column,column+1):
        char= 'F' #get_column_letter(col)
        Sheet_I[char+str(row)] = WLTOP10.cell(row=row-6, column=8).value

#FRR industry/broad sector
for row in range(8,18):
    for col in range(column,column+1):
        char= 'G' #get_column_letter(col)
        Sheet_I[char+str(row)] = WLTOP10.cell(row=row-6, column=8).value

# %%
#----------------------------------------------SMATOP10--------------------------------

#%MULTIVAR(BORROWER1,8,17,2,Listing_Top10SMA,TOP10_SMA);
#%MULTIVAR(OSM,8,17,3,Listing_Top10SMA,TOP10_SMA);
#%MULTIVAR(FINAL_RATING,8,17,5,Listing_Top10SMA,TOP10_SMA);
#%MULTIVAR(FRR,8,17,6,Listing_Top10SMA,TOP10_SMA);
#%MULTIVAR(BROAD_SECTOR1,8,17,7,Listing_Top10SMA,TOP10_SMA);
#%MULTIVAR(REASON,8,17,8,Listing_Top10SMA,TOP10_SMA);

Sheet_J = WB['Listing_Top10SMA']

SMATOP10 = BB2['SMATOP10']

#borrower name
for row in range(8,18):
    for col in range(column,column+1):
        char= 'B' #get_column_letter(col)
        Sheet_J[char+str(row)] = SMATOP10.cell(row=row-6, column=2).value

        
##outstanding
for row in range(8,18):
    for col in range(column,column+1):
        char= 'C' #get_column_letter(col)
        Sheet_J[char+str(row)] = SMATOP10.cell(row=row-6, column=9).value

#rating/BRR
for row in range(8,18):
    for col in range(column,column+1):
        char= 'E' #get_column_letter(col)
        Sheet_J[char+str(row)] = SMATOP10.cell(row=row-6, column=3).value

#FRR
for row in range(8,18):
    for col in range(column,column+1):
        char= 'F' #get_column_letter(col)
        Sheet_J[char+str(row)] = SMATOP10.cell(row=row-6, column=4).value

#FRR industry/broad sector
for row in range(8,18):
    for col in range(column,column+1):
        char= 'G' #get_column_letter(col)
        Sheet_J[char+str(row)] = SMATOP10.cell(row=row-6, column=5).value

# %%
#----------------------------------------------Listing_Top10Impaired--------------------------------

#%MULTIVAR(Borrower_name,8,17,2,Listing_Top10Impaired,TOP10_IF);
#%MULTIVAR(CUS_OSM,8,17,3,Listing_Top10Impaired,TOP10_IF);
#%MULTIVAR(REGION,8,17,5,Listing_Top10Impaired,TOP10_IF);
#%MULTIVAR(ISC_PARENT,8,17,6,Listing_Top10Impaired,TOP10_IF);



Sheet_J = WB['Listing_Top10Impaired']

IMPAIREDTOP10 = BB2['IMPAIREDTOP10']

#borrower name
for row in range(8,18):
    for col in range(column,column+1):
        char= 'B' #get_column_letter(col)
        Sheet_J[char+str(row)] = IMPAIREDTOP10.cell(row=row-6, column=3).value

        
##outstanding
for row in range(8,18):
    for col in range(column,column+1):
        char= 'C' #get_column_letter(col)
        Sheet_J[char+str(row)] = IMPAIREDTOP10.cell(row=row-6, column=17).value

#REGION
for row in range(8,18):
    for col in range(column,column+1):
        char= 'E' #get_column_letter(col)
        Sheet_J[char+str(row)] = IMPAIREDTOP10.cell(row=row-6, column=10).value

#Industry
for row in range(8,18):
    for col in range(column,column+1):
        char= 'F' #get_column_letter(col)
        Sheet_J[char+str(row)] = IMPAIREDTOP10.cell(row=row-6, column=7).value

# %%
#----------------------------------------------Listing_Top10NewlyApproved--------------------------------

#%MULTIVAR(NAME_OF_CUSTOMER,8,17,2,Listing_Top10NewlyApproved,TOP10_NA);
#%MULTIVAR(RM__mil,8,17,3,Listing_Top10NewlyApproved,TOP10_NA);
#%MULTIVAR(BRR,8,17,5,Listing_Top10NewlyApproved,TOP10_NA);
#%MULTIVAR(FRR,8,17,6,Listing_Top10NewlyApproved,TOP10_NA);
#%MULTIVAR(Region__LOS_,8,17,7,Listing_Top10NewlyApproved,TOP10_NA);
#%MULTIVAR(BROAD_Sector,8,17,8,Listing_Top10NewlyApproved,TOP10_NA);



Sheet_K = WB['Listing_Top10NewlyApproved']

NATOP10 = BB2['NATOP10']

#name
for row in range(8,18):
    for col in range(column,column+1):
        char= 'B' #get_column_letter(col)
        Sheet_K[char+str(row)] = NATOP10.cell(row=row-6, column=1).value

        
##Limit
for row in range(8,18):
    for col in range(column,column+1):
        char= 'C' #get_column_letter(col)
        Sheet_K[char+str(row)] = NATOP10.cell(row=row-6, column=8).value

#BRR
for row in range(8,18):
    for col in range(column,column+1):
        char= 'E' #get_column_letter(col)
        Sheet_K[char+str(row)] = NATOP10.cell(row=row-6, column=7).value

#FRR
for row in range(8,18):
    for col in range(column,column+1):
        char= 'F' #get_column_letter(col)
        Sheet_K[char+str(row)] = NATOP10.cell(row=row-6, column=6).value

#REGION
for row in range(8,18):
    for col in range(column,column+1):
        char= 'G' #get_column_letter(col)
        Sheet_K[char+str(row)] = NATOP10.cell(row=row-6, column=3).value

# %%
#----------------------------------------------RESCHEDULED--------------------------------

Sheet_L = WB['Listing_Rescheduled']

RESCHEDULED = BB2['RESCHEDULED']

#name
for row in range(8,14):
    for col in range(column,column+1):
        char= 'B' #get_column_letter(col)
        Sheet_L[char+str(row)] = RESCHEDULED.cell(row=row-6, column=1).value

#limit
for row in range(8,14):
    for col in range(column,column+1):
        char= 'C' #get_column_letter(col)
        Sheet_L[char+str(row)] = RESCHEDULED.cell(row=row-6, column=2).value

#OSM
for row in range(8,14):
    for col in range(column,column+1):
        char= 'D' #get_column_letter(col)
        Sheet_L[char+str(row)] = RESCHEDULED.cell(row=row-6, column=3).value

#Risk category/Final_rating
for row in range(8,14):
    for col in range(column,column+1):
        char= 'E' #get_column_letter(col)
        Sheet_L[char+str(row)] = RESCHEDULED.cell(row=row-6, column=4).value

#FRR
for row in range(8,14):
    for col in range(column,column+1):
        char= 'F' #get_column_letter(col)
        Sheet_L[char+str(row)] = RESCHEDULED.cell(row=row-6, column=5).value

#Frequency
for row in range(8,14):
    for col in range(column,column+1):
        char= 'G' #get_column_letter(col)
        Sheet_L[char+str(row)] = RESCHEDULED.cell(row=row-6, column=6).value

#Remark
for row in range(8,14):
    for col in range(column,column+1):
        char= 'H' #get_column_letter(col)
        Sheet_L[char+str(row)] = RESCHEDULED.cell(row=row-6, column=7).value

# %%
#----------------------------------------------RESTRUCTURED--------------------------------

Sheet_M = WB['Listing_Restructured']

RESTRUCTURED = BB2['RESTRUCTURED']

#name
for row in range(8,14):
    for col in range(column,column+1):
        char= 'B' #get_column_letter(col)
        Sheet_M[char+str(row)] = RESTRUCTURED.cell(row=row-6, column=1).value

#limit
for row in range(8,14):
    for col in range(column,column+1):
        char= 'C' #get_column_letter(col)
        Sheet_M[char+str(row)] = RESTRUCTURED.cell(row=row-6, column=2).value

#OSM
for row in range(8,14):
    for col in range(column,column+1):
        char= 'D' #get_column_letter(col)
        Sheet_M[char+str(row)] = RESTRUCTURED.cell(row=row-6, column=3).value

#Risk category/Final_rating
for row in range(8,14):
    for col in range(column,column+1):
        char= 'E' #get_column_letter(col)
        Sheet_M[char+str(row)] = RESTRUCTURED.cell(row=row-6, column=4).value

#FRR
for row in range(8,14):
    for col in range(column,column+1):
        char= 'F' #get_column_letter(col)
        Sheet_M[char+str(row)] = RESTRUCTURED.cell(row=row-6, column=5).value

#Frequency
for row in range(8,14):
    for col in range(column,column+1):
        char= 'G' #get_column_letter(col)
        Sheet_M[char+str(row)] = RESTRUCTURED.cell(row=row-6, column=6).value

#Remark
for row in range(8,14):
    for col in range(column,column+1):
        char= 'H' #get_column_letter(col)
        Sheet_M[char+str(row)] = RESTRUCTURED.cell(row=row-6, column=7).value

# %%
WB.save(filename=r'T:\MIB Risk Management\Credit Risk Analytics - Historical\01_Reporting\01_Monthly_Reporting\02_Business_Financing\Maybank_Islamic_Business_Financing_'+str(date)+'(python).xlsx')

# %% [markdown]
# # TRY

# %%
from openpyxl import Workbook, load_workbook
from openpyxl.utils import get_column_letter

wb = load_workbook(r'C:\Users\80005701\Python\Coding\20220430 FIX\Maybank_Islamic_Business_Financing_20220131.xlsx')
ws = wb['Total(RM Mil)']

for row in range(1,11):
    for col in range(0,5):
        #char = chr(65 + col) 65 tu col A1
        char = get_column_letter(col)
        #print(ws[char + str(row)].value)

        
wb.save(r'C:\Users\80005701\Python\Coding\20220430 FIX\Maybank_Islamic_Business_Financing_20220131.xlsx')
#tutup excel bru save

#ws = wb.active
#ws.title = "DATA"
#ws.append(['tim','is','great']) nnti buat column
#ws['A1'] =   nnti dia create kat A1 excel
#wb.save(r'C:\Users\80005701\Python\Coding\20220430 FIX\Maybank_Islamic_Business_Financing_20220131.xlsx')
#wb.create_sheet("test") dia buat sheet kat excel n lepas save bru ada

# %%
# %MACRO MERGE(DATA1, DATA2, DATA3, VAR);
PROC SORT DATA=&DATA1; BY &VAR; RUN;
PROC SORT DATA=&DATA2; BY &VAR; RUN;

DATA &DATA3;
MERGE &DATA1(IN=A) &DATA2(IN=B);
BY &VAR;
IF A;

IF NOC= .           THEN NOC=0;
IF CUS_OSM= .       THEN CUS_OSM=0;
IF NOC_TOP30= .     THEN NOC_TOP30=0;
IF CUS_OSM_TOP30= . THEN CUS_OSM_TOP30=0;
IF GIL_OSM_TOP30= . THEN GIL_OSM_TOP30=0;
IF CUS_EAD= .       THEN CUS_EAD=0;
IF CUS_RWA= .       THEN CUS_RWA=0;
IF CUS_EL= .        THEN CUS_EL=0;

IF A AND NOT B THEN DO;
NOC=0;
CUS_OSM=0;
NOC_TOP30=0;
CUS_OSM_TOP30=0;
NOC_GIL_TOP30=0;
GIL_OSM_TOP30=0;
CUS_EAD=0;
CUS_RWA=0;
CUS_EL=0;
END;
RUN;
# %MEND;

# %%
/*FOR IMPAIRED FINANCING*/
# %MACRO MERGE1(DATA1, DATA2, DATA3, VAR);
PROC SORT DATA=&DATA1; BY &VAR; RUN;
PROC SORT DATA=&DATA2; BY &VAR; RUN;

DATA &DATA3;
MERGE &DATA1(IN=A) &DATA2(IN=B);
BY &VAR;
IF A;

IF NOC= .           THEN NOC=0;
IF CUS_OSM= .       THEN CUS_OSM=0;
IF NOC_TOP30= .     THEN NOC_TOP30=0;
IF CUS_OSM_TOP30= . THEN CUS_OSM_TOP30=0;
IF NOC_GIL_TOP30=.  THEN NOC_GIL_TOP30=0;
IF GIL_OSM_TOP30= . THEN GIL_OSM_TOP30=0;

IF A AND NOT B THEN DO;
NOC= 0;
CUS_OSM= 0;
NOC_TOP30= 0;
CUS_OSM_TOP30=0;
NOC_GIL_TOP30=0;
GIL_OSM_TOP30=0;
END;
RUN;
# %MEND;

# %%
/*FOR NEWLY APPROVED*/
# %MACRO MERGE2(DATA1, DATA2, DATA3, VAR);
PROC SORT DATA=&DATA1; BY &VAR; RUN;
PROC SORT DATA=&DATA2; BY &VAR; RUN;

DATA &DATA3;
MERGE &DATA1(IN=A) &DATA2(IN=B);
BY &VAR;
IF A;

IF NOA= .           THEN NOA=0;
IF RM_MIL= .        THEN RM_MIL=0;

IF A AND NOT B THEN DO;
NOA=0;
RM_MIL=0;
END;
RUN;
# %MEND;

# %%
# %MACRO MULTIVAR(VARNAME, ROW1, ROW2, COL1, SHEET, DATA); 
FILENAME MYFILE DDE "Excel|\\filestor\maybank-my\MIB Risk Management\Credit Risk Analytics - Historical\02_Data_Source\02_Business_Financing\01_Portfolio\&RDATE\[Maybank_Islamic_Business_Financing_&RDATE..xlsx]&SHEET!R&ROW1.C&COL.:R&ROW2.C&COL1." NOTAB; 

DATA _NULL_; 
FILE MYFILE; 
SET &DATA; 
PUT &VARNAME; 
RUN; 
# %MEND;

# %%
from openpyxl import Workbook, load_workbook
from openpyxl.utils import get_column_letter
from openpyxl.styles import Font
data = {
"Joe": {
"math": 65,
"science": 78,
"english": 98,
"gym": 89
},
"Bill": {
"math": 55,
"science": 72,
"english": 87,
"gym": 95
},
"Tim": {
"math": 100,
"science": 45,
"english": 75,
"gym": 92
},
"Sally": {
"math": 30,
"science": 25,
"english": 45,
"gym": 100
},
"Jane": {
"math": 100,
"science": 100,
"english": 100,
"gym": 60
}
}
wb = Workbook()
ws = wb.active
ws.title = "Grades"
headings = ['Name'] + list(data['Joe'].keys())
ws.append(headings)
for person in data:
grades = list(data[person].values())
ws.append([person] + grades)
for col in range(2, len(data['Joe']) + 2):
char = get_column_letter(col)
ws[char + "7"] = f"=SUM({char + '2'}:{char + '6'})/{len(data)}"
for col in range(1, 6):
ws[get_column_letter(col) + '1'].font = Font(bold=True, color="0099CCFF")
wb.save("NewGrades.xlsx")

# %%
I am trying to simplify some code, and wondered whether I would be able to use an If statement to set a different open workbook variable, depending on a few conditions of a defined range.

basically something like

dim ws as worksheet: set ws = Thisworkbook.worksheet("worksheet name")
dim r as range: set range = ws.range("A cell which has an if statement in it to display a number based on another cells contents")
dim wb as workbook
this is where I want to vary the actual workbook set as wb

if r.value = 1 then
set wb = Open a workbook
elseif r.value = 2 then
set wb = Open another workbook

# %%
location_import = r'C:\Users\80005701\Python\Coding\20220430 FIX\BB2_SUMMARY_20220131.xlsx'

BB_RISK1 = pd.read_excel(location_import, sheet_name = 'RISK_CAT')
BB_RISK2 = pd.read_excel(location_import, sheet_name = 'GILRISK_CAT')
BB_RISK3 = pd.read_excel(location_import, sheet_name = 'TOP30RISK_CAT')
BB_COLLATERAL_TYPE1 = pd.read_excel(location_import, sheet_name = 'COLLATERAL_TYPE')
BB_COLLATERAL_TYPE2 = pd.read_excel(location_import, sheet_name = 'GILCOLLATERAL_TYPE')
BB_COLLATERAL_TYPE3 = pd.read_excel(location_import, sheet_name = 'TOP30COLLATERAL_TYPE')
BB_REGION1 = pd.read_excel(location_import, sheet_name = 'REGION')
BB_REGION2 = pd.read_excel(location_import, sheet_name = 'GILREGION')
BB_REGION3 = pd.read_excel(location_import, sheet_name = 'TOP30REGION')
BB_BC1 = pd.read_excel(location_import, sheet_name = 'BC')
BB_BC2 = pd.read_excel(location_import, sheet_name = 'GILBC')
BB_BC3 = pd.read_excel(location_import, sheet_name = 'TOP30BC')
BB_SECTOR_CODE1 = pd.read_excel(location_import, sheet_name = 'SECTOR_CODE')
BB_SECTOR_CODE2 = pd.read_excel(location_import, sheet_name = 'GILSECTOR_CODE')
BB_SECTOR_CODE3 = pd.read_excel(location_import, sheet_name = 'TOP30SECTOR_CODE')
BB_ISC_PARENT1 = pd.read_excel(location_import, sheet_name = 'ISC_PARENT')
BB_ISC_PARENT2 = pd.read_excel(location_import, sheet_name = 'GILISC_PARENT')
BB_ISC_PARENT3 = pd.read_excel(location_import, sheet_name = 'TOP30ISC_PARENT')

BB_RISK1.fillna(0, inplace =True)
BB_RISK2.fillna(0, inplace =True)
BB_RISK3.fillna(0, inplace =True)
BB_COLLATERAL_TYPE1.fillna(0, inplace =True)
BB_COLLATERAL_TYPE2.fillna(0, inplace =True)
BB_COLLATERAL_TYPE3.fillna(0, inplace =True)
BB_REGION1.fillna(0, inplace =True)
BB_REGION2.fillna(0, inplace =True)
BB_REGION3.fillna(0, inplace =True)
BB_BC1.fillna(0, inplace =True)
BB_BC2.fillna(0, inplace =True)
BB_BC3.fillna(0, inplace =True)
BB_SECTOR_CODE1.fillna(0, inplace =True)
BB_SECTOR_CODE2.fillna(0, inplace =True)
BB_SECTOR_CODE3.fillna(0, inplace =True)
BB_ISC_PARENT1.fillna(0, inplace =True)
BB_ISC_PARENT2.fillna(0, inplace =True)
BB_ISC_PARENT3.fillna(0, inplace =True)

#----------------------------------------------Total(RM Mil)--------------------------------

Sheet_A = WB['Total(RM Mil)']

Sheet_A['DF10'] =

# %%
#----------------------------------------------Total(RM Mil)--------------------------------

Sheet_A = WB['Total(RM Mil)']

RISK_CAT = BB2['RISK_CAT']

char=get_column_letter(column)





if(Sheet_A['A10'].value  == '        Very Low Risk')&( RISK_CAT['A2'].value == '01.Very Low Risk'):
    Sheet_A[char+'10'] = RISK_CAT.cell(row=2, column=3).value
#elif(Sheet_A['A11'].value  == '        Very Low Risk')&( RISK_CAT['A2'].value == '01.Very Low Risk'):
#    Sheet_A[char+'10'] = RISK_CAT.cell(row=2, column=3).value
    
    
#Sheet_A[char+'11'] = RISK_CAT.cell(row=3, column=3).value
#Sheet_A[char+'12'] = RISK_CAT.cell(row=4, column=3).value
#Sheet_A[char+'13'] = RISK_CAT.cell(row=5, column=3).value
#Sheet_A[char+'14'] = RISK_CAT.cell(row=6, column=3).value
#Sheet_A[char+'15'] = RISK_CAT.cell(row=7, column=3).value

# %%
RISK_CAT = BB2['RISK_CAT']
RISK_CAT['A2'].value
# Out:
# '01.Very Low Risk'
