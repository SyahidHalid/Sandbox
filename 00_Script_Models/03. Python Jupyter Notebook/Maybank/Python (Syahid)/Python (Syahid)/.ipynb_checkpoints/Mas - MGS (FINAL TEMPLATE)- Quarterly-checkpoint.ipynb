# %%
import numpy as np
import pandas as pd
import pandasql
import sqlite3

pd.set_option("display.max_columns", None) 
pd.set_option("display.max_colwidth", 1000) #huruf dlm column
pd.set_option("display.max_rows", 100)
pd.set_option("display.precision", 2) #2 titik perpuluhan

# %%
D = 'Jun 2021'
D3 = 'Sep 2021'
D6 = 'Dec 2021'
D9 = 'Mar 2022'
D12 = 'Jun 2022'

D_1 = pd.read_excel(r"T:\MIB Risk Management\Credit Risk Analytics - Historical\01_Reporting\01_Monthly_Reporting\19_Sectoral MGS\\"+D+"\MGSL_"+D+"(python).xlsx",sheet_name='MGS no RPSIA')
D3_1 = pd.read_excel(r"T:\MIB Risk Management\Credit Risk Analytics - Historical\01_Reporting\01_Monthly_Reporting\19_Sectoral MGS\\"+D3+"\MGSL_"+D3+"(python).xlsx",sheet_name='MGS no RPSIA')
D6_1 = pd.read_excel(r"T:\MIB Risk Management\Credit Risk Analytics - Historical\01_Reporting\01_Monthly_Reporting\19_Sectoral MGS\\"+D6+"\MGSL_"+D6+"(python).xlsx",sheet_name='MGS no RPSIA')
D9_1 = pd.read_excel(r"T:\MIB Risk Management\Credit Risk Analytics - Historical\01_Reporting\01_Monthly_Reporting\19_Sectoral MGS\\"+D9+"\MGSL_"+D9+"(python).xlsx",sheet_name='MGS no RPSIA')
D12_1 = pd.read_excel(r"T:\MIB Risk Management\Credit Risk Analytics - Historical\01_Reporting\01_Monthly_Reporting\19_Sectoral MGS\\"+D12+"\MGSL_"+D12+"(python).xlsx",sheet_name='MGS no RPSIA')

D12_CBBB = pd.read_excel(r"T:\MIB Risk Management\Credit Risk Analytics - Historical\01_Reporting\01_Monthly_Reporting\19_Sectoral MGS\\"+D12+"\MGSL_"+D12+"(python).xlsx",sheet_name='rating CB BB no RPSIA')
D12_SME = pd.read_excel(r"T:\MIB Risk Management\Credit Risk Analytics - Historical\01_Reporting\01_Monthly_Reporting\19_Sectoral MGS\\"+D12+"\MGSL_"+D12+"(python).xlsx",sheet_name='rating sme no RPSIA')

# %%
D12_1['Quarter'] = 4
D9_1['Quarter'] = 3
D6_1['Quarter'] = 2
D3_1['Quarter'] = 1
D_1['Quarter'] = 0

MGSL = pd.concat([D12_1,D9_1,D6_1,D3_1,D_1], axis=0, ignore_index=True)

# %%
writer2 = pd.ExcelWriter(r"T:\MIB Risk Management\CRM\10.0_MGS Sectoral\Syahid\MGSL "+D12+"_"+D+"(python).xlsx", engine='xlsxwriter')

MGSL.to_excel(writer2, sheet_name='MGSL'+D12+"_"+D, index = False)
D12_CBBB.to_excel(writer2, sheet_name='rating CB BB no RPSIA '+D12, index = False)
D12_SME.to_excel(writer2, sheet_name='rating sme no RPSIA '+D12, index = False)

writer2.save()

# %%
CB = pd.read_excel(r"T:\MIB Risk Management\Credit Risk Analytics - Historical\01_Reporting\01_Monthly_Reporting\18_Rating_CBBBRSME\BRR_CBBBRSME_202206(python).xlsx")

# %%
MGSL.head(1)
# Out:
#   COUNTRY_TYPE COUNTRY/SECTOR LOANS/FIS  TYPE_OF_MGSL      GCIF  \
# 0     Malaysia             BB     Loans  Construction  10499872
#
#        NAME_OF_BORROWER/ISSUER BRR(CURRENT) ENTITY_(IMPORTANT:_MUST_KEY-IN)  \
# 0  A.E.W. CONSTRUCTION SDN BHD           12                    Conventional
#
#   STATUS_OF_ACCOUNT(IMPORTANT:_MUST_KEY-IN)  LIMIT_(RM_'MIL)  \
# 0                                       EWS              0.6
#
#    ACTUAL_OUTSTANDING_AS_AT_MONTH_END_(RM_'MIL)  \
# 0                                          0.58
#
#   STAGE_(IMPORTANT:_MUST_KEY-IN) TYPE_OF_LIMIT_(1)(IMPORTANT:_MUST_KEY-IN)  \
# 0           Completed / Emplaced                                 Revolving
#
#   FACILITY_TYPE GROUP_NAME STATUS_OF_ACCOUNT(CURRENT)     _merge    MFRS9  \
# 0            OD        NaN                        EWS  left_only  Stage 1
#
#    Quarter
# 0        4

# %%
MGSL.GCIF = MGSL.GCIF.astype(str)
MGSL.GCIF = MGSL.GCIF.str.strip()
MGSL.GCIF = MGSL.GCIF.str.upper()

CB.M_CUS_NO = CB.M_CUS_NO.astype(str)
CB.M_CUS_NO = CB.M_CUS_NO.str.strip()
CB.M_CUS_NO = CB.M_CUS_NO.str.upper()

CB1 = CB[['M_CUS_NO','FINAL_RATING']].rename(columns={'M_CUS_NO':'GCIF'})

a = MGSL.merge(CB1, on='GCIF', how='left', indicator='exist')

# %%
a.exist.value_counts()
# Out:
# left_only     42219
# both            971
# right_only        0
# Name: exist, dtype: int64

# %%
b = a.iloc[np.where(a.exist=='both')]

# %%
b['BRR(CURRENT)'].value_counts()
b.shape
# Out:
# (971, 21)

# %%
c = b.iloc[np.where(b['BRR(CURRENT)']=='Unrated')]
c.FINAL_RATING.value_counts()
# Out:
# 21    57
# 11    28
# 9     25
# 6     19
# 20    17
# 15     9
# 21     7
# 16     4
# 10     2
# Name: FINAL_RATING, dtype: int64

# %%
D = 'Jun 2021'
D3 = 'Sep 2021'
D6 = 'Dec 2021'
D9 = 'Mar 2022'
D12 = 'Jun 2022'


BB = pd.read_excel(r"D:\Users\80005701\Documents\MGSL\\"+D+"\MGS BB Template "+D+".xlsx",sheet_name='FINAL_TEMPLATE', header=2)
BBHP = pd.read_excel(r"D:\Users\80005701\Documents\MGSL\\"+D+"\MGS Template "+D[:3]+"'"+D[-2:]+"_BBHP.xlsx",sheet_name='FINAL_TEMPLATE', header=2)
SME = pd.read_excel(r"D:\Users\80005701\Documents\MGSL\\"+D+"\MGS Template "+D[:3]+"'"+D[-2:]+"_SME.xlsx",sheet_name='FINAL_TEMPLATE', header=2)
GB = pd.read_excel(r"D:\Users\80005701\Documents\MGSL\\"+D+"\MGSL_Template_FINAL_GB_"+D[:3]+" "+D[-2:]+".xlsm",sheet_name='FINAL_TEMPLATE', header=2)


BB3 = pd.read_excel(r"D:\Users\80005701\Documents\MGSL\\"+D3+"\MGS BB Template "+D3+".xlsx",sheet_name='FINAL_TEMPLATE', header=2)
BBHP3 = pd.read_excel(r"D:\Users\80005701\Documents\MGSL\\"+D3+"\MGS Template "+D3[:3]+"'"+D3[-2:]+"_BBHP.xlsx",sheet_name='FINAL_TEMPLATE', header=2)
SME3 = pd.read_excel(r"D:\Users\80005701\Documents\MGSL\\"+D3+"\MGS Template "+D3[:3]+"'"+D3[-2:]+"_SME.xlsx",sheet_name='FINAL_TEMPLATE', header=2)
GB3 = pd.read_excel(r"D:\Users\80005701\Documents\MGSL\\"+D3+"\MGSL_Template_FINAL_GB_"+D3[:3]+" "+D3[-2:]+".xlsm",sheet_name='FINAL_TEMPLATE', header=2)


BB6 = pd.read_excel(r"D:\Users\80005701\Documents\MGSL\\"+D6+"\MGS BB Template "+D6+".xlsx",sheet_name='FINAL_TEMPLATE', header=2)
BBHP6 = pd.read_excel(r"D:\Users\80005701\Documents\MGSL\\"+D6+"\MGS Template "+D6[:3]+"'"+D6[-2:]+"_BBHP.xlsx",sheet_name='FINAL_TEMPLATE', header=2)
SME6 = pd.read_excel(r"D:\Users\80005701\Documents\MGSL\\"+D6+"\MGS Template "+D6[:3]+"'"+D6[-2:]+"_SME.xlsx",sheet_name='FINAL_TEMPLATE', header=2)
GB6 = pd.read_excel(r"D:\Users\80005701\Documents\MGSL\\"+D6+"\MGSL_Template_FINAL_GB_"+D6[:3]+" "+D6[-2:]+".xlsm",sheet_name='FINAL_TEMPLATE', header=2)


BB9 = pd.read_excel(r"D:\Users\80005701\Documents\MGSL\\"+D9+"\MGS BB Template "+D9+".xlsx",sheet_name='FINAL_TEMPLATE', header=2)
BBHP9 = pd.read_excel(r"D:\Users\80005701\Documents\MGSL\\"+D9+"\MGS Template "+D9[:3]+"'"+D9[-2:]+"_BBHP.xlsx",sheet_name='FINAL_TEMPLATE', header=2)
SME9 = pd.read_excel(r"D:\Users\80005701\Documents\MGSL\\"+D9+"\MGS Template "+D9[:3]+"'"+D9[-2:]+"_SME.xlsx",sheet_name='FINAL_TEMPLATE', header=2)
GB9 = pd.read_excel(r"D:\Users\80005701\Documents\MGSL\\"+D9+"\MGSL_Template_FINAL_GB_"+D9[:3]+" "+D9[-2:]+".xlsm",sheet_name='FINAL_TEMPLATE', header=2)


BB12 = pd.read_excel(r"D:\Users\80005701\Documents\MGSL\\"+D12+"\MGS BB Template "+D12+".xlsx",sheet_name='FINAL_TEMPLATE', header=2)
BBHP12 = pd.read_excel(r"D:\Users\80005701\Documents\MGSL\\"+D12+"\MGS Template "+D12[:3]+"'"+D12[-2:]+"_BBHP.xlsx",sheet_name='FINAL_TEMPLATE', header=2)
SME12 = pd.read_excel(r"D:\Users\80005701\Documents\MGSL\\"+D12+"\MGS Template "+D12[:3]+"'"+D12[-2:]+"_SME.xlsx",sheet_name='FINAL_TEMPLATE', header=2)
GB12 = pd.read_excel(r"D:\Users\80005701\Documents\MGSL\\"+D12+"\MGSL_Template_FINAL_GB_"+D12[:3]+" "+D12[-2:]+".xlsm",sheet_name='FINAL_TEMPLATE', header=2)


BB.columns = BB.columns.str.upper()
BB.columns = BB.columns.str.strip()
BB.columns = BB.columns.str.replace("\n","").str.replace(" ","_")

BBHP.columns = BBHP.columns.str.upper()
BBHP.columns = BBHP.columns.str.strip()
BBHP.columns = BBHP.columns.str.replace("\n","").str.replace(" ","_")

SME.columns = SME.columns.str.upper()
SME.columns = SME.columns.str.strip()
SME.columns = SME.columns.str.replace("\n","").str.replace(" ","_")

GB.columns = GB.columns.str.upper()
GB.columns = GB.columns.str.strip()
GB.columns = GB.columns.str.replace("\n","").str.replace(" ","_")


BB3.columns = BB3.columns.str.upper()
BB3.columns = BB3.columns.str.strip()
BB3.columns = BB3.columns.str.replace("\n","").str.replace(" ","_")

BBHP3.columns = BBHP3.columns.str.upper()
BBHP3.columns = BBHP3.columns.str.strip()
BBHP3.columns = BBHP3.columns.str.replace("\n","").str.replace(" ","_")

SME3.columns = SME3.columns.str.upper()
SME3.columns = SME3.columns.str.strip()
SME3.columns = SME3.columns.str.replace("\n","").str.replace(" ","_")

GB3.columns = GB3.columns.str.upper()
GB3.columns = GB3.columns.str.strip()
GB3.columns = GB3.columns.str.replace("\n","").str.replace(" ","_")


BB6.columns = BB6.columns.str.upper()
BB6.columns = BB6.columns.str.strip()
BB6.columns = BB6.columns.str.replace("\n","").str.replace(" ","_")

BBHP6.columns = BBHP6.columns.str.upper()
BBHP6.columns = BBHP6.columns.str.strip()
BBHP6.columns = BBHP6.columns.str.replace("\n","").str.replace(" ","_")

SME6.columns = SME6.columns.str.upper()
SME6.columns = SME6.columns.str.strip()
SME6.columns = SME6.columns.str.replace("\n","").str.replace(" ","_")

GB6.columns = GB6.columns.str.upper()
GB6.columns = GB6.columns.str.strip()
GB6.columns = GB6.columns.str.replace("\n","").str.replace(" ","_")


BB9.columns = BB9.columns.str.upper()
BB9.columns = BB9.columns.str.strip()
BB9.columns = BB9.columns.str.replace("\n","").str.replace(" ","_")

BBHP9.columns = BBHP9.columns.str.upper()
BBHP9.columns = BBHP9.columns.str.strip()
BBHP9.columns = BBHP9.columns.str.replace("\n","").str.replace(" ","_")

SME9.columns = SME9.columns.str.upper()
SME9.columns = SME9.columns.str.strip()
SME9.columns = SME9.columns.str.replace("\n","").str.replace(" ","_")

GB9.columns = GB9.columns.str.upper()
GB9.columns = GB9.columns.str.strip()
GB9.columns = GB9.columns.str.replace("\n","").str.replace(" ","_")


BB12.columns = BB12.columns.str.upper()
BB12.columns = BB12.columns.str.strip()
BB12.columns = BB12.columns.str.replace("\n","").str.replace(" ","_")

BBHP12.columns = BBHP12.columns.str.upper()
BBHP12.columns = BBHP12.columns.str.strip()
BBHP12.columns = BBHP12.columns.str.replace("\n","").str.replace(" ","_")

SME12.columns = SME12.columns.str.upper()
SME12.columns = SME12.columns.str.strip()
SME12.columns = SME12.columns.str.replace("\n","").str.replace(" ","_")

GB12.columns = GB12.columns.str.upper()
GB12.columns = GB12.columns.str.strip()
GB12.columns = GB12.columns.str.replace("\n","").str.replace(" ","_")


BB12_1=BB12[["COUNTRY_TYPE","COUNTRY/SECTOR","LOANS/FIS","TYPE_OF_MGSL","GCIF","NAME_OF_BORROWER/ISSUER","BRR(CURRENT)","ENTITY_(IMPORTANT:_MUST_KEY-IN)","STATUS_OF_ACCOUNT(IMPORTANT:_MUST_KEY-IN)","LIMIT_(RM_'MIL)","ACTUAL_OUTSTANDING_AS_AT_MONTH_END_(RM_'MIL)","STAGE_(IMPORTANT:_MUST_KEY-IN)","TYPE_OF_LIMIT_(1)(IMPORTANT:_MUST_KEY-IN)"]]

BBHP12_1=BBHP12[["COUNTRY_TYPE","COUNTRY/SECTOR","LOANS/FIS","TYPE_OF_MGSL","GCIF","NAME_OF_BORROWER/ISSUER","BRR(CURRENT)","ENTITY_(IMPORTANT:_MUST_KEY-IN)","STATUS_OF_ACCOUNT(IMPORTANT:_MUST_KEY-IN)","LIMIT_(RM_'MIL)","ACTUAL_OUTSTANDING_AS_AT_MONTH_END_(RM_'MIL)","STAGE_(IMPORTANT:_MUST_KEY-IN)","TYPE_OF_LIMIT_(1)(IMPORTANT:_MUST_KEY-IN)"]]

SME12_1=SME12[["COUNTRY_TYPE","COUNTRY/SECTOR","LOANS/FIS","TYPE_OF_MGSL","GCIF","NAME_OF_BORROWER/ISSUER","BRR(CURRENT)","ENTITY_(IMPORTANT:_MUST_KEY-IN)","STATUS_OF_ACCOUNT(IMPORTANT:_MUST_KEY-IN)","LIMIT_(RM_'MIL)","ACTUAL_OUTSTANDING_AS_AT_MONTH_END_(RM_'MIL)","STAGE_(IMPORTANT:_MUST_KEY-IN)","TYPE_OF_LIMIT_(1)(IMPORTANT:_MUST_KEY-IN)"]]

GB12_1=GB12[["COUNTRY_TYPE","COUNTRY/SECTOR","LOANS/FIS","TYPE_OF_MGSL","GCIF","NAME_OF_BORROWER/ISSUER","BRR(CURRENT)","ENTITY_(IMPORTANT:_MUST_KEY-IN)","STATUS_OF_ACCOUNT(CURRENT)","LIMIT_(RM_'MIL)","ACTUAL_OUTSTANDING_AS_AT_MONTH_END_(RM_'MIL)","STAGE_(IMPORTANT:_MUST_KEY-IN)","TYPE_OF_LIMIT_(1)(IMPORTANT:_MUST_KEY-IN)"]].rename(columns={'STATUS_OF_ACCOUNT_(CURRENT)':'STATUS_OF_ACCOUNT_(IMPORTANT:_MUST_KEY-IN)'})


BB9_1=BB9[["COUNTRY_TYPE","COUNTRY/SECTOR","LOANS/FIS","TYPE_OF_MGSL","GCIF","NAME_OF_BORROWER/ISSUER","BRR(CURRENT)","ENTITY_(IMPORTANT:_MUST_KEY-IN)","STATUS_OF_ACCOUNT(IMPORTANT:_MUST_KEY-IN)","LIMIT_(RM_'MIL)","ACTUAL_OUTSTANDING_AS_AT_MONTH_END_(RM_'MIL)","STAGE_(IMPORTANT:_MUST_KEY-IN)","TYPE_OF_LIMIT_(1)(IMPORTANT:_MUST_KEY-IN)"]]

BBHP9_1=BBHP9[["COUNTRY_TYPE","COUNTRY/SECTOR","LOANS/FIS","TYPE_OF_MGSL","GCIF","NAME_OF_BORROWER/ISSUER","BRR(CURRENT)","ENTITY_(IMPORTANT:_MUST_KEY-IN)","STATUS_OF_ACCOUNT(IMPORTANT:_MUST_KEY-IN)","LIMIT_(RM_'MIL)","ACTUAL_OUTSTANDING_AS_AT_MONTH_END_(RM_'MIL)","STAGE_(IMPORTANT:_MUST_KEY-IN)","TYPE_OF_LIMIT_(1)(IMPORTANT:_MUST_KEY-IN)"]]

SME9_1=SME9[["COUNTRY_TYPE","COUNTRY/SECTOR","LOANS/FIS","TYPE_OF_MGSL","GCIF","NAME_OF_BORROWER/ISSUER","BRR(CURRENT)","ENTITY_(IMPORTANT:_MUST_KEY-IN)","STATUS_OF_ACCOUNT(IMPORTANT:_MUST_KEY-IN)","LIMIT_(RM_'MIL)","ACTUAL_OUTSTANDING_AS_AT_MONTH_END_(RM_'MIL)","STAGE_(IMPORTANT:_MUST_KEY-IN)","TYPE_OF_LIMIT_(1)(IMPORTANT:_MUST_KEY-IN)"]]

GB9_1=GB9[["COUNTRY_TYPE","COUNTRY/SECTOR","LOANS/FIS","TYPE_OF_MGSL","GCIF","NAME_OF_BORROWER/ISSUER","BRR(CURRENT)","ENTITY_(IMPORTANT:_MUST_KEY-IN)","STATUS_OF_ACCOUNT(CURRENT)","LIMIT_(RM_'MIL)","ACTUAL_OUTSTANDING_AS_AT_MONTH_END_(RM_'MIL)","STAGE_(IMPORTANT:_MUST_KEY-IN)","TYPE_OF_LIMIT_(1)(IMPORTANT:_MUST_KEY-IN)"]].rename(columns={'STATUS_OF_ACCOUNT_(CURRENT)':'STATUS_OF_ACCOUNT_(IMPORTANT:_MUST_KEY-IN)'})


BB6_1=BB6[["COUNTRY_TYPE","COUNTRY/SECTOR","LOANS/FIS","TYPE_OF_MGSL","GCIF","NAME_OF_BORROWER/ISSUER","BRR(CURRENT)","ENTITY_(IMPORTANT:_MUST_KEY-IN)","STATUS_OF_ACCOUNT(IMPORTANT:_MUST_KEY-IN)","LIMIT_(RM_'MIL)","ACTUAL_OUTSTANDING_AS_AT_MONTH_END_(RM_'MIL)","STAGE_(IMPORTANT:_MUST_KEY-IN)","TYPE_OF_LIMIT_(1)(IMPORTANT:_MUST_KEY-IN)"]]

BBHP6_1=BBHP6[["COUNTRY_TYPE","COUNTRY/SECTOR","LOANS/FIS","TYPE_OF_MGSL","GCIF","NAME_OF_BORROWER/ISSUER","BRR(CURRENT)","ENTITY_(IMPORTANT:_MUST_KEY-IN)","STATUS_OF_ACCOUNT(IMPORTANT:_MUST_KEY-IN)","LIMIT_(RM_'MIL)","ACTUAL_OUTSTANDING_AS_AT_MONTH_END_(RM_'MIL)","STAGE_(IMPORTANT:_MUST_KEY-IN)","TYPE_OF_LIMIT_(1)(IMPORTANT:_MUST_KEY-IN)"]]

SME6_1=SME6[["COUNTRY_TYPE","COUNTRY/SECTOR","LOANS/FIS","TYPE_OF_MGSL","GCIF","NAME_OF_BORROWER/ISSUER","BRR(CURRENT)","ENTITY_(IMPORTANT:_MUST_KEY-IN)","STATUS_OF_ACCOUNT(IMPORTANT:_MUST_KEY-IN)","LIMIT_(RM_'MIL)","ACTUAL_OUTSTANDING_AS_AT_MONTH_END_(RM_'MIL)","STAGE_(IMPORTANT:_MUST_KEY-IN)","TYPE_OF_LIMIT_(1)(IMPORTANT:_MUST_KEY-IN)"]]

GB6_1=GB6[["COUNTRY_TYPE","COUNTRY/SECTOR","LOANS/FIS","TYPE_OF_MGSL","GCIF","NAME_OF_BORROWER/ISSUER","BRR(CURRENT)","ENTITY_(IMPORTANT:_MUST_KEY-IN)","STATUS_OF_ACCOUNT(CURRENT)","LIMIT_(RM_'MIL)","ACTUAL_OUTSTANDING_AS_AT_MONTH_END_(RM_'MIL)","STAGE_(IMPORTANT:_MUST_KEY-IN)","TYPE_OF_LIMIT_(1)(IMPORTANT:_MUST_KEY-IN)"]].rename(columns={'STATUS_OF_ACCOUNT_(CURRENT)':'STATUS_OF_ACCOUNT_(IMPORTANT:_MUST_KEY-IN)'})


BB3_1=BB3[["COUNTRY_TYPE","COUNTRY/SECTOR","LOANS/FIS","TYPE_OF_MGSL","GCIF","NAME_OF_BORROWER/ISSUER","BRR(CURRENT)","ENTITY_(IMPORTANT:_MUST_KEY-IN)","STATUS_OF_ACCOUNT(IMPORTANT:_MUST_KEY-IN)","LIMIT_(RM_'MIL)","ACTUAL_OUTSTANDING_AS_AT_MONTH_END_(RM_'MIL)","STAGE_(IMPORTANT:_MUST_KEY-IN)","TYPE_OF_LIMIT_(1)(IMPORTANT:_MUST_KEY-IN)"]]

BBHP3_1=BBHP3[["COUNTRY_TYPE","COUNTRY/SECTOR","LOANS/FIS","TYPE_OF_MGSL","GCIF","NAME_OF_BORROWER/ISSUER","BRR(CURRENT)","ENTITY_(IMPORTANT:_MUST_KEY-IN)","STATUS_OF_ACCOUNT(IMPORTANT:_MUST_KEY-IN)","LIMIT_(RM_'MIL)","ACTUAL_OUTSTANDING_AS_AT_MONTH_END_(RM_'MIL)","STAGE_(IMPORTANT:_MUST_KEY-IN)","TYPE_OF_LIMIT_(1)(IMPORTANT:_MUST_KEY-IN)"]]

SME3_1=SME3[["COUNTRY_TYPE","COUNTRY/SECTOR","LOANS/FIS","TYPE_OF_MGSL","GCIF","NAME_OF_BORROWER/ISSUER","BRR(CURRENT)","ENTITY_(IMPORTANT:_MUST_KEY-IN)","STATUS_OF_ACCOUNT(IMPORTANT:_MUST_KEY-IN)","LIMIT_(RM_'MIL)","ACTUAL_OUTSTANDING_AS_AT_MONTH_END_(RM_'MIL)","STAGE_(IMPORTANT:_MUST_KEY-IN)","TYPE_OF_LIMIT_(1)(IMPORTANT:_MUST_KEY-IN)"]]

GB3_1=GB3[["COUNTRY_TYPE","COUNTRY/SECTOR","LOANS/FIS","TYPE_OF_MGSL","GCIF","NAME_OF_BORROWER/ISSUER","BRR(CURRENT)","ENTITY_(IMPORTANT:_MUST_KEY-IN)","STATUS_OF_ACCOUNT(CURRENT)","LIMIT_(RM_'MIL)","ACTUAL_OUTSTANDING_AS_AT_MONTH_END_(RM_'MIL)","STAGE_(IMPORTANT:_MUST_KEY-IN)","TYPE_OF_LIMIT_(1)(IMPORTANT:_MUST_KEY-IN)"]].rename(columns={'STATUS_OF_ACCOUNT_(CURRENT)':'STATUS_OF_ACCOUNT_(IMPORTANT:_MUST_KEY-IN)'})


BB_1=BB[["COUNTRY_TYPE","COUNTRY/SECTOR","LOANS/FIS","TYPE_OF_MGSL","GCIF","NAME_OF_BORROWER/ISSUER","BRR(CURRENT)","ENTITY_(IMPORTANT:_MUST_KEY-IN)","STATUS_OF_ACCOUNT(IMPORTANT:_MUST_KEY-IN)","LIMIT_(RM_'MIL)","ACTUAL_OUTSTANDING_AS_AT_MONTH_END_(RM_'MIL)","STAGE_(IMPORTANT:_MUST_KEY-IN)","TYPE_OF_LIMIT_(1)(IMPORTANT:_MUST_KEY-IN)"]]

BBHP_1=BBHP[["COUNTRY_TYPE","COUNTRY/SECTOR","LOANS/FIS","TYPE_OF_MGSL","GCIF","NAME_OF_BORROWER/ISSUER","BRR(CURRENT)","ENTITY_(IMPORTANT:_MUST_KEY-IN)","STATUS_OF_ACCOUNT(IMPORTANT:_MUST_KEY-IN)","LIMIT_(RM_'MIL)","ACTUAL_OUTSTANDING_AS_AT_MONTH_END_(RM_'MIL)","STAGE_(IMPORTANT:_MUST_KEY-IN)","TYPE_OF_LIMIT_(1)(IMPORTANT:_MUST_KEY-IN)"]]

SME_1=SME[["COUNTRY_TYPE","COUNTRY/SECTOR","LOANS/FIS","TYPE_OF_MGSL","GCIF","NAME_OF_BORROWER/ISSUER","BRR(CURRENT)","ENTITY_(IMPORTANT:_MUST_KEY-IN)","STATUS_OF_ACCOUNT(IMPORTANT:_MUST_KEY-IN)","LIMIT_(RM_'MIL)","ACTUAL_OUTSTANDING_AS_AT_MONTH_END_(RM_'MIL)","STAGE_(IMPORTANT:_MUST_KEY-IN)","TYPE_OF_LIMIT_(1)(IMPORTANT:_MUST_KEY-IN)"]]

GB_1=GB[["COUNTRY_TYPE","COUNTRY/SECTOR","LOANS/FIS","TYPE_OF_MGSL","GCIF","NAME_OF_BORROWER/ISSUER","BRR(CURRENT)","ENTITY_(IMPORTANT:_MUST_KEY-IN)","STATUS_OF_ACCOUNT(CURRENT)","LIMIT_(RM_'MIL)","ACTUAL_OUTSTANDING_AS_AT_MONTH_END_(RM_'MIL)","STAGE_(IMPORTANT:_MUST_KEY-IN)","TYPE_OF_LIMIT_(1)(IMPORTANT:_MUST_KEY-IN)"]].rename(columns={'STATUS_OF_ACCOUNT_(CURRENT)':'STATUS_OF_ACCOUNT_(IMPORTANT:_MUST_KEY-IN)'})


DF12 = pd.concat([BB12_1,BBHP12_1,SME12_1,GB12_1], axis=0, ignore_index=True)

DF9 = pd.concat([BB9_1,BBHP9_1,SME9_1,GB9_1], axis=0, ignore_index=True)

DF6 = pd.concat([BB6_1,BBHP6_1,SME6_1,GB6_1], axis=0, ignore_index=True)

DF3 = pd.concat([BB3_1,BBHP3_1,SME3_1,GB3_1], axis=0, ignore_index=True)

DF = pd.concat([BB_1,BBHP_1,SME_1,GB_1], axis=0, ignore_index=True)

DF12_1 = DF12.iloc[np.where((DF12["COUNTRY_TYPE"]=='Malaysia')&\
                            (DF12['STAGE_(IMPORTANT:_MUST_KEY-IN)'].isin(['Completed / Emplaced','Approved by Sectoral Limit Controller','Facilities Pending Emplacement','Approved by Management & Pending Acceptance','Approved by Management / Amount Enforced','Partial Release','Pre-approved Line'])))]

DF12_1['STATUS_OF_ACCOUNT(CURRENT)'].fillna(DF12_1['STATUS_OF_ACCOUNT(IMPORTANT:_MUST_KEY-IN)'],inplace=True)

DF12_1.loc[(DF12_1['LOANS/FIS']=='FIS'),"ACTUAL_OUTSTANDING_AS_AT_MONTH_END_(RM_'MIL)"] = DF12_1["LIMIT_(RM_'MIL)"]

DF9_1 = DF9.iloc[np.where((DF9["COUNTRY_TYPE"]=='Malaysia')&\
                            (DF9['STAGE_(IMPORTANT:_MUST_KEY-IN)'].isin(['Completed / Emplaced','Approved by Sectoral Limit Controller','Facilities Pending Emplacement','Approved by Management & Pending Acceptance','Approved by Management / Amount Enforced','Partial Release','Pre-approved Line'])))]

DF9_1['STATUS_OF_ACCOUNT(CURRENT)'].fillna(DF9_1['STATUS_OF_ACCOUNT(IMPORTANT:_MUST_KEY-IN)'],inplace=True)

DF9_1.loc[(DF9_1['LOANS/FIS']=='FIS'),"ACTUAL_OUTSTANDING_AS_AT_MONTH_END_(RM_'MIL)"] = DF9_1["LIMIT_(RM_'MIL)"]

DF6_1 = DF6.iloc[np.where((DF6["COUNTRY_TYPE"]=='Malaysia')&\
                            (DF6['STAGE_(IMPORTANT:_MUST_KEY-IN)'].isin(['Completed / Emplaced','Approved by Sectoral Limit Controller','Facilities Pending Emplacement','Approved by Management & Pending Acceptance','Approved by Management / Amount Enforced','Partial Release','Pre-approved Line'])))]

DF6_1['STATUS_OF_ACCOUNT(CURRENT)'].fillna(DF6_1['STATUS_OF_ACCOUNT(IMPORTANT:_MUST_KEY-IN)'],inplace=True)

DF6_1.loc[(DF6_1['LOANS/FIS']=='FIS'),"ACTUAL_OUTSTANDING_AS_AT_MONTH_END_(RM_'MIL)"] = DF6_1["LIMIT_(RM_'MIL)"]

DF3_1 = DF3.iloc[np.where((DF3["COUNTRY_TYPE"]=='Malaysia')&\
                            (DF3['STAGE_(IMPORTANT:_MUST_KEY-IN)'].isin(['Completed / Emplaced','Approved by Sectoral Limit Controller','Facilities Pending Emplacement','Approved by Management & Pending Acceptance','Approved by Management / Amount Enforced','Partial Release','Pre-approved Line'])))]

DF3_1['STATUS_OF_ACCOUNT(CURRENT)'].fillna(DF3_1['STATUS_OF_ACCOUNT(IMPORTANT:_MUST_KEY-IN)'],inplace=True)

DF3_1.loc[(DF3_1['LOANS/FIS']=='FIS'),"ACTUAL_OUTSTANDING_AS_AT_MONTH_END_(RM_'MIL)"] = DF3_1["LIMIT_(RM_'MIL)"]

DF_1 = DF.iloc[np.where((DF["COUNTRY_TYPE"]=='Malaysia')&\
                            (DF['STAGE_(IMPORTANT:_MUST_KEY-IN)'].isin(['Completed / Emplaced','Approved by Sectoral Limit Controller','Facilities Pending Emplacement','Approved by Management & Pending Acceptance','Approved by Management / Amount Enforced','Partial Release','Pre-approved Line'])))]

DF_1['STATUS_OF_ACCOUNT(CURRENT)'].fillna(DF_1['STATUS_OF_ACCOUNT(IMPORTANT:_MUST_KEY-IN)'],inplace=True)

DF_1.loc[(DF_1['LOANS/FIS']=='FIS'),"ACTUAL_OUTSTANDING_AS_AT_MONTH_END_(RM_'MIL)"] = DF_1["LIMIT_(RM_'MIL)"]

DF12_1['Quarter'] = 4
DF9_1['Quarter'] = 3
DF6_1['Quarter'] = 2
DF3_1['Quarter'] = 1
DF_1['Quarter'] = 0

MGSL = pd.concat([DF12_1,DF9_1,DF6_1,DF3_1,DF_1], axis=0, ignore_index=True)

RPSIA = pd.read_excel(r"D:\Users\80005701\Documents\MGSL\RPSIA_202206(python).xlsx")


RPSIA1 = RPSIA.rename(columns={'CUSTOMER_ID':'GCIF'})


RPSIA1.GCIF = RPSIA1.GCIF.astype(str)
RPSIA1.GCIF = RPSIA1.GCIF.str.strip()
RPSIA1.GCIF = RPSIA1.GCIF.str.upper()

MGSL.GCIF = MGSL.GCIF.astype(str)
MGSL.GCIF = MGSL.GCIF.str.strip()
MGSL.GCIF = MGSL.GCIF.str.upper()

merge_a = MGSL.merge(RPSIA1[['GCIF']], on='GCIF', how='left', indicator=True)

woRP = merge_a.iloc[np.where(merge_a._merge=='left_only')]
RPonly = merge_a.iloc[np.where(merge_a._merge=='both')]

writer2 = pd.ExcelWriter(r"D:\Users\80005701\Desktop\Work\Kerja\Txt\MGSL Quater.xlsx",engine='xlsxwriter')

merge_a.to_excel(writer2, sheet_name='BASE', index=False)
woRP.to_excel(writer2, sheet_name='excluded RPSIA', index=False)
RPonly.to_excel(writer2, sheet_name='RPSIA only', index=False)

writer2.save()

# %%
a = merge_a.iloc[np.where(merge_a._merge=='both')]
a._merge.value_counts()
# Out:
# both          673
# right_only      0
# left_only       0
# Name: _merge, dtype: int64

# %%
a.head(1)
# Out:
#      COUNTRY_TYPE COUNTRY/SECTOR LOANS/FIS TYPE_OF_MGSL      GCIF  \
# 7492     Malaysia             GB     Loans     Oil_Palm  15499781
#
#         NAME_OF_BORROWER/ISSUER BRR(CURRENT) ENTITY_(IMPORTANT:_MUST_KEY-IN)  \
# 7492  SIME DARBY PLANTATION BHD            8                    Conventional
#
#      STATUS_OF_ACCOUNT(IMPORTANT:_MUST_KEY-IN)  LIMIT_(RM_'MIL)  \
# 7492                                       NaN            100.0
#
#       ACTUAL_OUTSTANDING_AS_AT_MONTH_END_(RM_'MIL)  \
# 7492                                           NaN
#
#      STAGE_(IMPORTANT:_MUST_KEY-IN) TYPE_OF_LIMIT_(1)(IMPORTANT:_MUST_KEY-IN)  \
# 7492           Completed / Emplaced                        Revolving (Eg: OD)
#
#      STATUS_OF_ACCOUNT(CURRENT)  Quarter _merge
# 7492                        EWS        4   both

# %% [markdown]
# # GB

# %%
c1 = DF12_1.iloc[np.where((DF12_1['ENTITY_(IMPORTANT:_MUST_KEY-IN)']!='Islamic')&(DF12_1["LOANS/FIS"]=='Loans')&(DF12_1["COUNTRY/SECTOR"]=='GB'))].fillna(0).groupby(['TYPE_OF_MGSL'])[["LIMIT_(RM_'MIL)","ACTUAL_OUTSTANDING_AS_AT_MONTH_END_(RM_'MIL)"]].sum().reset_index().sort_values(by='TYPE_OF_MGSL',ascending=False)
c1
#,'COUNTRY/SECTOR','LOANS/FIS'
# Out:
#    TYPE_OF_MGSL  LIMIT_(RM_'MIL)  ACTUAL_OUTSTANDING_AS_AT_MONTH_END_(RM_'MIL)
# 3      Shipping          1082.51                                        348.52
# 2      Oil_Palm          6327.29                                       2005.68
# 1       Oil_Gas         18718.26                                      10662.22
# 0  Construction          3637.81                                       1180.58

# %%
c2 = DF12_1.iloc[np.where((DF12_1['ENTITY_(IMPORTANT:_MUST_KEY-IN)']!='Islamic')&(DF12_1["LOANS/FIS"]!='Loans')&(DF12_1["COUNTRY/SECTOR"]=='GB'))].fillna(0).groupby(['TYPE_OF_MGSL'])[["LIMIT_(RM_'MIL)","ACTUAL_OUTSTANDING_AS_AT_MONTH_END_(RM_'MIL)"]].sum().reset_index().sort_values(by='TYPE_OF_MGSL',ascending=False)
c2
#,'COUNTRY/SECTOR','LOANS/FIS'
# Out:
#    TYPE_OF_MGSL  LIMIT_(RM_'MIL)  ACTUAL_OUTSTANDING_AS_AT_MONTH_END_(RM_'MIL)
# 2      Oil_Palm            495.0                                         495.0
# 1       Oil_Gas           2347.8                                        2347.8
# 0  Construction             50.0                                          50.0

# %%
i1 = DF12_1.iloc[np.where((DF12_1['ENTITY_(IMPORTANT:_MUST_KEY-IN)']=='Islamic')&(DF12_1["LOANS/FIS"]=='Loans')&(DF12_1["COUNTRY/SECTOR"]=='GB'))].fillna(0).groupby(['TYPE_OF_MGSL'])[["LIMIT_(RM_'MIL)","ACTUAL_OUTSTANDING_AS_AT_MONTH_END_(RM_'MIL)"]].sum().reset_index().sort_values(by='TYPE_OF_MGSL',ascending=False)
i1
#,'COUNTRY/SECTOR','LOANS/FIS'
# Out:
#    TYPE_OF_MGSL  LIMIT_(RM_'MIL)  ACTUAL_OUTSTANDING_AS_AT_MONTH_END_(RM_'MIL)
# 3      Shipping            78.43                                         47.54
# 2      Oil_Palm         11795.04                                       5141.38
# 1       Oil_Gas          8192.55                                       1714.85
# 0  Construction          2016.11                                        625.84

# %%
i2 = DF12_1.iloc[np.where((DF12_1['ENTITY_(IMPORTANT:_MUST_KEY-IN)']=='Islamic')&(DF12_1["LOANS/FIS"]!='Loans')&(DF12_1["COUNTRY/SECTOR"]=='GB'))].fillna(0).groupby(['TYPE_OF_MGSL'])[["LIMIT_(RM_'MIL)","ACTUAL_OUTSTANDING_AS_AT_MONTH_END_(RM_'MIL)"]].sum().reset_index().sort_values(by='TYPE_OF_MGSL',ascending=False)
i2
#,'COUNTRY/SECTOR','LOANS/FIS'
# Out:
#   TYPE_OF_MGSL  LIMIT_(RM_'MIL)  ACTUAL_OUTSTANDING_AS_AT_MONTH_END_(RM_'MIL)
# 1     Oil_Palm            105.0                                         105.0
# 0      Oil_Gas            500.0                                         500.0

# %% [markdown]
# # SME

# %%
sme_c1 = DF12_1.iloc[np.where((DF12_1['ENTITY_(IMPORTANT:_MUST_KEY-IN)']!='Islamic')&(DF12_1["LOANS/FIS"]=='Loans')&(DF12_1["COUNTRY/SECTOR"]=='SME'))].fillna(0).groupby(['TYPE_OF_MGSL'])[["LIMIT_(RM_'MIL)","ACTUAL_OUTSTANDING_AS_AT_MONTH_END_(RM_'MIL)"]].sum().reset_index().sort_values(by='TYPE_OF_MGSL',ascending=False)
sme_c1
#,'COUNTRY/SECTOR','LOANS/FIS'
# Out:
#    TYPE_OF_MGSL  LIMIT_(RM_'MIL)  ACTUAL_OUTSTANDING_AS_AT_MONTH_END_(RM_'MIL)
# 3      Shipping             1.78                                          0.91
# 2      Oil_Palm            44.49                                         36.44
# 1       Oil_Gas            22.62                                         15.78
# 0  Construction           450.55                                        288.87

# %%
sme_c2 = DF12_1.iloc[np.where((DF12_1['ENTITY_(IMPORTANT:_MUST_KEY-IN)']!='Islamic')&(DF12_1["LOANS/FIS"]!='Loans')&(DF12_1["COUNTRY/SECTOR"]=='SME'))].fillna(0).groupby(['TYPE_OF_MGSL'])[["LIMIT_(RM_'MIL)","ACTUAL_OUTSTANDING_AS_AT_MONTH_END_(RM_'MIL)"]].sum().reset_index().sort_values(by='TYPE_OF_MGSL',ascending=False)
sme_c2
#,'COUNTRY/SECTOR','LOANS/FIS'
# Out:
# Empty DataFrame
# Columns: [TYPE_OF_MGSL, LIMIT_(RM_'MIL), ACTUAL_OUTSTANDING_AS_AT_MONTH_END_(RM_'MIL)]
# Index: []

# %%
sme_i1 = DF12_1.iloc[np.where((DF12_1['ENTITY_(IMPORTANT:_MUST_KEY-IN)']=='Islamic')&(DF12_1["LOANS/FIS"]=='Loans')&(DF12_1["COUNTRY/SECTOR"]=='SME'))].fillna(0).groupby(['TYPE_OF_MGSL'])[["LIMIT_(RM_'MIL)","ACTUAL_OUTSTANDING_AS_AT_MONTH_END_(RM_'MIL)"]].sum().reset_index().sort_values(by='TYPE_OF_MGSL',ascending=False)
sme_i1
#,'COUNTRY/SECTOR','LOANS/FIS'
# Out:
#    TYPE_OF_MGSL  LIMIT_(RM_'MIL)  ACTUAL_OUTSTANDING_AS_AT_MONTH_END_(RM_'MIL)
# 3      Shipping            18.80                                         13.12
# 2      Oil_Palm           230.23                                        140.54
# 1       Oil_Gas            32.61                                         24.67
# 0  Construction          1046.54                                        755.49

# %%
sme_i2 = DF12_1.iloc[np.where((DF12_1['ENTITY_(IMPORTANT:_MUST_KEY-IN)']=='Islamic')&(DF12_1["LOANS/FIS"]!='Loans')&(DF12_1["COUNTRY/SECTOR"]=='SME'))].fillna(0).groupby(['TYPE_OF_MGSL'])[["LIMIT_(RM_'MIL)","ACTUAL_OUTSTANDING_AS_AT_MONTH_END_(RM_'MIL)"]].sum().reset_index().sort_values(by='TYPE_OF_MGSL',ascending=False)
sme_i2
#,'COUNTRY/SECTOR','LOANS/FIS'
# Out:
# Empty DataFrame
# Columns: [TYPE_OF_MGSL, LIMIT_(RM_'MIL), ACTUAL_OUTSTANDING_AS_AT_MONTH_END_(RM_'MIL)]
# Index: []

# %% [markdown]
# # BB

# %%
bb = DF12_1.iloc[np.where((DF12_1["COUNTRY/SECTOR"]=='BB')&(DF12_1["LOANS/FIS"]=='Loans'))].fillna(0).groupby(['TYPE_OF_MGSL'])[["LIMIT_(RM_'MIL)","ACTUAL_OUTSTANDING_AS_AT_MONTH_END_(RM_'MIL)"]].sum().reset_index()#.sort_values(by='TYPE_OF_MGSL',ascending=False)
bb
#,'COUNTRY/SECTOR','LOANS/FIS'
#(DF12_1['ENTITY_(IMPORTANT:_MUST_KEY-IN)']=='Islamic')&
# Out:
#    TYPE_OF_MGSL  LIMIT_(RM_'MIL)  ACTUAL_OUTSTANDING_AS_AT_MONTH_END_(RM_'MIL)
# 0  Construction          6301.41                                       1552.34
# 1       Oil_Gas           261.60                                         52.70
# 2      Oil_Palm          2095.80                                        628.86
# 3      Shipping           152.62                                         17.42

# %%
sum(bb["LIMIT_(RM_'MIL)"]), sum(bb["ACTUAL_OUTSTANDING_AS_AT_MONTH_END_(RM_'MIL)"])
# Out:
# (8811.434729162507, 2251.319528859998)

# %%
sum(a["ACTUAL_OUTSTANDING_AS_AT_MONTH_END_(RM_'MIL)"])+sum(BBHP12_1["ACTUAL_OUTSTANDING_AS_AT_MONTH_END_(RM_'MIL)"])
# Out:
# 2251.3195288599973

# %%
sum(BBHP12_1["LIMIT_(RM_'MIL)"])+sum(a["LIMIT_(RM_'MIL)"])
# Out:
# 8811.434729162518

# %%
DF12_1
# Out:
#      COUNTRY_TYPE COUNTRY/SECTOR LOANS/FIS  TYPE_OF_MGSL      GCIF  \
# 1        Malaysia             BB     Loans  Construction  10499872
# 2        Malaysia             BB     Loans  Construction  10499872
# 3        Malaysia             BB     Loans      Oil_Palm  20202168
# 4        Malaysia             BB     Loans  Construction   9256090
# 5        Malaysia             BB     Loans  Construction   6288425
# ...           ...            ...       ...           ...       ...
# 9466     Malaysia             GB       FIS       Oil_Gas       NaN
# 9467     Malaysia             GB     Loans       Oil_Gas  27050248
# 9468     Malaysia             GB     Loans       Oil_Gas  27050248
# 9469     Malaysia             GB     Loans       Oil_Gas  26051342
# 9470     Malaysia             GB     Loans  Construction   8046172
#
#                                  NAME_OF_BORROWER/ISSUER BRR(CURRENT)  \
# 1                            A.E.W. CONSTRUCTION SDN BHD           12
# 2                            A.E.W. CONSTRUCTION SDN BHD           12
# 3                                       AB MALEK SDN BHD           17
# 4                                      ABADI RIA SDN BHD           21
# 5                                  ABH TEKNOKRAT SDN BHD           19
# ...                                                  ...          ...
# 9466                       MISC Capital Two (Labuan) Ltd          NaN
# 9467                                 Petrosniaga Sdn Bhd      Unrated
# 9468                                 Petrosniaga Sdn Bhd      Unrated
# 9469  Petroleum Sarawak Exploration & Production Sdn Bhd           12
# 9470                            AHMAD ZAKI RESOURCES BHD           18
#
#      ENTITY_(IMPORTANT:_MUST_KEY-IN)  \
# 1                       Conventional
# 2                       Conventional
# 3                       Conventional
# 4                       Conventional
# 5                       Conventional
# ...                              ...
# 9466                    Conventional
# 9467                         Islamic
# 9468                         Islamic
# 9469                         Islamic
# 9470                         Islamic
#
#      STATUS_OF_ACCOUNT(IMPORTANT:_MUST_KEY-IN)  LIMIT_(RM_'MIL)  \
# 1                                          EWS         6.00e-01
# 2                                          EWS         3.20e-01
# 3                                    Watchlist         0.00e+00
# 4                                Good / Normal         7.81e-03
# 5                                Good / Normal         9.05e-01
# ...                                        ...              ...
# 9466                                       NaN         6.00e+02
# 9467                                       NaN         8.00e+01
# 9468                                       NaN         4.00e+01
# 9469                                       NaN         5.00e+02
# 9470                                       NaN         9.00e+01
#
#       ACTUAL_OUTSTANDING_AS_AT_MONTH_END_(RM_'MIL)  \
# 1                                             0.58
# 2                                             0.32
# 3                                             0.00
# 4                                             0.00
# 5                                             0.75
# ...                                            ...
# 9466                                        600.00
# 9467                                           NaN
# 9468                                           NaN
# 9469                                        394.77
# 9470                                        170.53
#
#                 STAGE_(IMPORTANT:_MUST_KEY-IN)  \
# 1                         Completed / Emplaced
# 2                         Completed / Emplaced
# 3                         Completed / Emplaced
# 4                         Completed / Emplaced
# 5                         Completed / Emplaced
# ...                                        ...
# 9466  Approved by Management / Amount Enforced
# 9467     Approved by Sectoral Limit Controller
# 9468     Approved by Sectoral Limit Controller
# 9469     Approved by Sectoral Limit Controller
# 9470     Approved by Sectoral Limit Controller
#
#      TYPE_OF_LIMIT_(1)(IMPORTANT:_MUST_KEY-IN) STATUS_OF_ACCOUNT(CURRENT)
# 1                                    Revolving                        EWS
# 2                                Non_Revolving                        EWS
# 3                                Non_Revolving                  Watchlist
# 4                                Non_Revolving              Good / Normal
# 5                                    Revolving              Good / Normal
# ...                                        ...                        ...
# 9466                         --Please Select--              Good / Normal
# 9467                         --Please Select--              Good / Normal
# 9468                         --Please Select--              Good / Normal
# 9469                         --Please Select--              Good / Normal
# 9470                         --Please Select--                         WL
#
# [8122 rows x 14 columns]

# %%
DF12["TYPE_OF_LIMIT_(1)(IMPORTANT:_MUST_KEY-IN)"].value_counts()
# Out:
# Non_Revolving             4600
# Revolving                 3791
# Revolving (Eg: OD)         541
# --Please Select--          322
# Non-Revolving (Eg: TL)     148
# Not_Applicable              35
# Name: TYPE_OF_LIMIT_(1)(IMPORTANT:_MUST_KEY-IN), dtype: int64

# %%
DF12_1["TYPE_OF_LIMIT_(1)(IMPORTANT:_MUST_KEY-IN)"].value_counts()
# Out:
# Non_Revolving             4296
# Revolving                 3394
# Revolving (Eg: OD)         315
# Non-Revolving (Eg: TL)      51
# --Please Select--           40
# Not_Applicable              22
# Name: TYPE_OF_LIMIT_(1)(IMPORTANT:_MUST_KEY-IN), dtype: int64

# %%
DF12_1["STATUS_OF_ACCOUNT(IMPORTANT:_MUST_KEY-IN)"].value_counts()
# Out:
# Good / Normal                     6685
# Watchlist                          311
# Impaired Non-Performing Loans      190
# EWS                                181
# Impaired Performing Loans           32
# SMA                                 19
# Name: STATUS_OF_ACCOUNT(IMPORTANT:_MUST_KEY-IN), dtype: int64

# %% [markdown]
# # RPSIA

# %%
merge_a._merge.value_counts()
# Out:
# left_only     8100
# both            22
# right_only       0
# Name: _merge, dtype: int64

# %%
merge_a["NAME_OF_BORROWER/ISSUER"].value_counts()
# Out:
# SARADU PLANTATION SDN BHD              56
# ACRE WORKS SDN BHD                     46
# WOODMAN KUALA BARAM ESTATE SDN BHD     44
# PEMBINAAN TETAP TEGUH SDN. BHD.        39
# TRANS RESOURCES CORPORATION SDN BHD    39
#                                        ..
# REKA HALUS SB                           1
# HO TEIK SWEE CONSTRUCTION SDN BHD       1
# CRSC PROPERTY SDN BHD                   1
# ACACIA CONCEPTS SDN. BHD.               1
# PERNIAGAAN HAJJAH RUSLINAH HAMID        1
# Name: NAME_OF_BORROWER/ISSUER, Length: 4362, dtype: int64

# %%
GB12.GCIF.dtypes, RPSIA1.dtypes
# Out:
# (dtype('O'),
#  GCIF             int64
#  Outstanding    float64
#  dtype: object)

# %%
sum(a["ACTUAL_OUTSTANDING_AS_AT_MONTH_END__(RM_'MIL)"])
# Out:
# 5350.49955599

# %%
a = GB12.iloc[np.where(GB12.GCIF==20924517)].fillna(0)
a
# Out:
#           NO COUNTRY_TYPE COUNTRY/SECTOR  BUSINESS_DIVISION LOANS/FIS  \
# 566    566.0     Malaysia             GB    Client Coverage     Loans
# 567    567.0     Malaysia             GB    Client Coverage     Loans
# 568    568.0     Malaysia             GB  Corporate Banking     Loans
# 614    614.0     Malaysia             GB  Corporate Banking     Loans
# 615    615.0     Malaysia             GB  Corporate Banking     Loans
# 670    670.0     Malaysia             GB  Corporate Banking     Loans
# 688    688.0     Malaysia             GB  Corporate Banking     Loans
# 689    689.0     Malaysia             GB  Corporate Banking     Loans
# 722    722.0     Malaysia             GB  Corporate Banking       FIS
# 1039  1041.0     Malaysia             GB   Leverage Finance     Loans
# 1040  1042.0     Malaysia             GB   Leverage Finance     Loans
# 1078  1080.0     Malaysia             GB   Leverage Finance     Loans
# 1079  1081.0     Malaysia             GB   Leverage Finance     Loans
# 1138  1143.0     Malaysia             GB   Leverage Finance     Loans
# 1139  1144.0     Malaysia             GB   Leverage Finance     Loans
# 1140  1145.0     Malaysia             GB   Leverage Finance     Loans
# 1164  1169.0     Malaysia             GB   Leverage Finance     Loans
# 1193  1199.0     Malaysia             GB  Corporate Banking     Loans
#
#      TYPE_OF_MGSL  \
# 566       Oil_Gas
# 567       Oil_Gas
# 568       Oil_Gas
# 614       Oil_Gas
# 615       Oil_Gas
# 670       Oil_Gas
# 688       Oil_Gas
# 689       Oil_Gas
# 722       Oil_Gas
# 1039      Oil_Gas
# 1040      Oil_Gas
# 1078      Oil_Gas
# 1079      Oil_Gas
# 1138      Oil_Gas
# 1139      Oil_Gas
# 1140      Oil_Gas
# 1164      Oil_Gas
# 1193      Oil_Gas
#
#                                                                SUB-SECTORS__(IMPORTANT:_MUST_KEY-IN)  \
# 566                                  0910Xg Other support activities for oil & gas extraction n.e.c.
# 567   2220 Service activities incidental to crude oil and natural gas extraction excluding surveying
# 568   2220 Service activities incidental to crude oil and natural gas extraction excluding surveying
# 614                                  0910Xg Other support activities for oil & gas extraction n.e.c.
# 615                                  0910Xg Other support activities for oil & gas extraction n.e.c.
# 670                                  0910Xg Other support activities for oil & gas extraction n.e.c.
# 688                                  0910Xg Other support activities for oil & gas extraction n.e.c.
# 689                                  0910Xg Other support activities for oil & gas extraction n.e.c.
# 722                                  0910Xg Other support activities for oil & gas extraction n.e.c.
# 1039                                 0910Xg Other support activities for oil & gas extraction n.e.c.
# 1040                                 0910Xg Other support activities for oil & gas extraction n.e.c.
# 1078                                 0910Xg Other support activities for oil & gas extraction n.e.c.
# 1079                                 0910Xg Other support activities for oil & gas extraction n.e.c.
# 1138                                 0910Xg Other support activities for oil & gas extraction n.e.c.
# 1139                                 0910Xg Other support activities for oil & gas extraction n.e.c.
# 1140                                 0910Xg Other support activities for oil & gas extraction n.e.c.
# 1164                                 0910Xg Other support activities for oil & gas extraction n.e.c.
# 1193                                 0910Xg Other support activities for oil & gas extraction n.e.c.
#
#       BOOKING_EXPIRED BOOKINGNUMBER BOOKING_RECEIVED_DATE  \
# 566                 0    OG_OLD_005   2014-12-02 00:00:00
# 567                 0    OG_OLD_006   2014-12-02 00:00:00
# 568                 0    OG_OLD_007   2015-08-14 00:00:00
# 614                 0    OG_OLD_159   2014-10-10 00:00:00
# 615                 0    OG_OLD_049   2014-06-11 00:00:00
# 670                 0    OG_OLD_102   2016-10-17 00:00:00
# 688                 0    OG_OLD_115                     0
# 689                 0    OG_OLD_116                     0
# 722                 0    OG_OLD_142                     0
# 1039                0     OG010719A   2019-07-25 00:00:00
# 1040                0     OG010719B   2019-07-25 00:00:00
# 1078                0     OG011219A   2019-12-17 00:00:00
# 1079                0     OG011219B   2019-12-17 00:00:00
# 1138                0     OG030720A   2020-07-30 00:00:00
# 1139                0     OG030720B   2020-07-30 00:00:00
# 1140                0     OG030720C   2020-07-30 00:00:00
# 1164                0      OG021120   2020-11-19 00:00:00
# 1193                0      OG010521   2021-05-20 00:00:00
#
#      BOOKING_APPROVED_DATE   LOANS_APPROVED_DATE LOANS_APPROVED_BY  \
# 566    2014-12-02 00:00:00   2013-12-11 00:00:00          GMCC/CRC
# 567    2014-12-02 00:00:00                     0                 0
# 568    2015-08-14 00:00:00   2013-12-11 00:00:00          GMCC/CRC
# 614    2014-10-10 00:00:00   2018-05-20 00:00:00          GMCC/CRC
# 615    2014-06-11 00:00:00   2013-12-11 00:00:00          GMCC/CRC
# 670    2016-10-18 00:00:00   2013-12-11 00:00:00          GMCC/CRC
# 688                      0   2013-12-11 00:00:00          GMCC/CRC
# 689                      0   2013-12-11 00:00:00          GMCC/CRC
# 722                      0   2013-12-11 00:00:00         GMCC/CRC
# 1039   2019-07-25 00:00:00   2019-08-13 00:00:00              GMCC
# 1040   2019-07-25 00:00:00   2019-08-13 00:00:00              GMCC
# 1078   2020-01-03 00:00:00  21/1/2020\n22/1/2020         GMCC\nCRC
# 1079   2020-01-03 00:00:00  21/1/2020\n22/1/2020         GMCC\nCRC
# 1138                     0                     0                 0
# 1139                     0                     0                 0
# 1140                     0                     0                 0
# 1164                     0                     0                 0
# 1193   2021-06-16 00:00:00                     0                 0
#
#        REQUESTOR'S_NAME DIRECTOR REQUESTOR_CONTACT      GCIF  ACCOUNT_NUMBER  \
# 566   NOR HAFEZA HAMZAH      FUA              5232  20924517    414897560251
# 567          Salahuddin      FUA                 0  20924517               0
# 568   NOR HAFEZA HAMZAH      FUA              5232  20924517    414897560251
# 614   NOR HAFEZA HAMZAH      FUA              5232  20924517    514897055676
# 615   NOR HAFEZA HAMZAH      FUA              5232  20924517    514897054700
# 670   NOR HAFEZA HAMZAH      FUA              5232  20924517    514897054700
# 688   NOR HAFEZA HAMZAH      FUA              5232  20924517    514897054700
# 689   NOR HAFEZA HAMZAH      FUA              5232  20924517    514897054700
# 722   NOR HAFEZA HAMZAH      FUA              5232  20924517    514897054700
# 1039      JULIAN CHEONG      FUA          20591819  20924517               0
# 1040      JULIAN CHEONG      FUA          20591819  20924517               0
# 1078     LUEI JUN SIANG      FUA          20591503  20924517               0
# 1079     LUEI JUN SIANG      FUA          20591503  20924517               0
# 1138      JULIAN CHEONG      FUA          20591819  20924517               0
# 1139      JULIAN CHEONG      FUA          20591819  20924517               0
# 1140      JULIAN CHEONG      FUA          20591819  20924517               0
# 1164      JULIAN CHEONG      FUA      03-2059 1819  20924517               0
# 1193      JULIAN CHEONG      FUA      03-2059 1819  20924517               0
#
#      GROUP_NAME                   NAME_OF_BORROWER/ISSUER  \
# 566      SAPURA  SAPURA TMC SB (FKA SAPURAKENCANA TMC SB)
# 567      SAPURA  SAPURA TMC SB (FKA SAPURAKENCANA TMC SB)
# 568      SAPURA  SAPURA TMC SB (FKA SAPURAKENCANA TMC SB)
# 614      SAPURA                             SAPURA TMC SB
# 615      SAPURA  SAPURA TMC SB (FKA SAPURAKENCANA TMC SB)
# 670      SAPURA  SAPURA TMC SB (FKA SAPURAKENCANA TMC SB)
# 688      SAPURA  SAPURA TMC SB (FKA SAPURAKENCANA TMC SB)
# 689      SAPURA  SAPURA TMC SB (FKA SAPURAKENCANA TMC SB)
# 722      SAPURA                             SAPURA TMC SB
# 1039     SAPURA  SAPURA TMC SB (FKA SAPURAKENCANA TMC SB)
# 1040     SAPURA  SAPURA TMC SB (FKA SAPURAKENCANA TMC SB)
# 1078     SAPURA                             SAPURA TMC SB
# 1079     SAPURA                             SAPURA TMC SB
# 1138     SAPURA                             SAPURA TMC SB
# 1139     SAPURA                             SAPURA TMC SB
# 1140     SAPURA                             SAPURA TMC SB
# 1164     SAPURA                             SAPURA TMC SB
# 1193     SAPURA                             SAPURA TMC SB
#
#      BRR__(AT_POINT_OF_ORIGINATION) BRR_(CURRENT) CURRENT_BRR_CATEGORY  \
# 566                               0            22                  R&R
# 567                               0            22                  R&R
# 568                               0            22                  R&R
# 614                               0            22                  R&R
# 615                               0            22                  R&R
# 670                               0            22                  R&R
# 688                               0            22                  R&R
# 689                               0            22                  R&R
# 722                               0            22                  R&R
# 1039                              8            22                  R&R
# 1040                              8            22                  R&R
# 1078                              8            22                  R&R
# 1079                              8            22                  R&R
# 1138                             12            22                  R&R
# 1139                             12            22                  R&R
# 1140                             12            22                  R&R
# 1164                             16            22                  R&R
# 1193                             16            22                  R&R
#
#                STAGE__(IMPORTANT:_MUST_KEY-IN)  \
# 566                                  Cancelled
# 567                                  Cancelled
# 568                              Fully Settled
# 614                       Completed / Emplaced
# 615                                  Cancelled
# 670                                  Cancelled
# 688                                  Cancelled
# 689                                  Cancelled
# 722   Approved by Management / Amount Enforced
# 1039                                 Cancelled
# 1040                                 Cancelled
# 1078                      Completed / Emplaced
# 1079                                 Cancelled
# 1138                      Completed / Emplaced
# 1139                      Completed / Emplaced
# 1140                                 Cancelled
# 1164                                 Cancelled
# 1193                                 Cancelled
#
#      PDS_PRE-APPROVED_LIMIT_/_PDS_CREDIT_MEMO__(IMPORTANT:_MUST_KEY-IN)  \
# 566                                                                   0
# 567                                                                   0
# 568                                                                   0
# 614                                                                   0
# 615                                                                   0
# 670                                                                   0
# 688                                                                   0
# 689                                                                   0
# 722                                               PDS_PreApproved_Limit
# 1039                                                                  0
# 1040                                                                  0
# 1078                                                                  0
# 1079                                                                  0
# 1138                                                                  0
# 1139                                                                  0
# 1140                                                                  0
# 1164                                                                  0
# 1193                                                                  0
#
#               FACILITY_TYPE                    FACILITY_TYPE_2 LOAN_PARKED  \
# 566                      TL                               TL-I    Domestic
# 567                      TL      USDTL-1 (MiLL) USD93.93m @4.4        MILL
# 568                      TL     USDTL-2 (MiLL) USD174.68m @4.4        MILL
# 614       Funded tradebills                              TB(F)    Domestic
# 615                    STRC                               STRC    Domestic
# 670   Non Funded Tradebills                                 DV    Domestic
# 688           Unrated bonds                Bonds-unrated (RM)     Domestic
# 689           Unrated bonds                Bonds-unrated (RM)     Domestic
# 722                   Bonds                                  0    Domestic
# 1039                   STRC                        RC FACILITY    Domestic
# 1040  Non Funded Tradebills                CROSS CURRENCY SWAP    Domestic
# 1078                     TL     UNRATED BOND (Buyout Exercise)    Domestic
# 1079                   STRC                               STRC    Domestic
# 1138                     TL  UNRATED BOND (Global Refinancing)    Domestic
# 1139                   STRC                    STRC Project RC    Domestic
# 1140  Non Funded Tradebills                            DV line    Domestic
# 1164                     TL                       UNRATED BOND    Domestic
# 1193                     TL                                 DV    Domestic
#
#      ENTITY__(IMPORTANT:_MUST_KEY-IN)  \
# 566                           Islamic
# 567                      Conventional
# 568                      Conventional
# 614                      Conventional
# 615                      Conventional
# 670                           Islamic
# 688                      Conventional
# 689                           Islamic
# 722                      Conventional
# 1039                     Conventional
# 1040                     Conventional
# 1078                          Islamic
# 1079                     Conventional
# 1138                          Islamic
# 1139                     Conventional
# 1140                          Islamic
# 1164                     Conventional
# 1193                     Conventional
#
#      TYPE_OF_LIMIT_(1)_(IMPORTANT:_MUST_KEY-IN)  \
# 566                      Non-Revolving (Eg: TL)
# 567                      Non-Revolving (Eg: TL)
# 568                      Non-Revolving (Eg: TL)
# 614                          Revolving (Eg: OD)
# 615                          Revolving (Eg: OD)
# 670                          Revolving (Eg: OD)
# 688                          Revolving (Eg: OD)
# 689                          Revolving (Eg: OD)
# 722                              Not_Applicable
# 1039                                  Revolving
# 1040                              Non_Revolving
# 1078                              Non_Revolving
# 1079                              Non_Revolving
# 1138                              Non_Revolving
# 1139                                  Revolving
# 1140                              Non_Revolving
# 1164                              Non_Revolving
# 1193                          --Please Select--
#
#      TYPE_OF_LIMIT_(2)_(IMPORTANT:_MUST_KEY-IN)  \
# 566       Fully Drawdown (Capped at Latest O/S)
# 567       Fully Drawdown (Capped at Latest O/S)
# 568       Fully Drawdown (Capped at Latest O/S)
# 614                             Capped at Limit
# 615                             Capped at Limit
# 670                             Capped at Limit
# 688                             Capped at Limit
# 689                             Capped at Limit
# 722                                           0
# 1039                            Capped at Limit
# 1040      Fully Drawdown (Capped at Latest O/S)
# 1078      Fully Drawdown (Capped at Latest O/S)
# 1079      Fully Drawdown (Capped at Latest O/S)
# 1138      Fully Drawdown (Capped at Latest O/S)
# 1139                            Capped at Limit
# 1140      Fully Drawdown (Capped at Latest O/S)
# 1164      Fully Drawdown (Capped at Latest O/S)
# 1193                          --Please Select--
#
#      STATUS_OF_ACCOUNT_(AT_POINT_OF_ORIGINATION) STATUS_OF_ACCOUNT_(CURRENT)  \
# 566                                    Watchlist                         GIL
# 567                                    Watchlist                         GIL
# 568                                    Watchlist                         GIL
# 614                                    Watchlist                         GIL
# 615                                    Watchlist                         GIL
# 670                                    Watchlist                         GIL
# 688                                    Watchlist                         GIL
# 689                                    Watchlist                         GIL
# 722                                    Watchlist                         GIL
# 1039                                          WL                         GIL
# 1040                                          WL                         GIL
# 1078                                         EWS                         GIL
# 1079                                         EWS                         GIL
# 1138                                          WL                         GIL
# 1139                                          WL                         GIL
# 1140                                          WL                         GIL
# 1164                                          WL                         GIL
# 1193                                          WL                         GIL
#
#      CURRENCY  LIMIT__(ORIGINAL_CURRENCY_'MIL)  \
# 566       MYR                            75.36
# 567       MYR                           403.04
# 568       USD                           174.68
# 614       MYR                           493.18
# 615       MYR                           500.00
# 670       MYR                           300.00
# 688       USD                           200.00
# 689       MYR                          1413.40
# 722       USD                           200.00
# 1039      MYR                           700.00
# 1040      MYR                           140.00
# 1078      MYR                          1479.23
# 1079      USD                           200.00
# 1138      MYR                          2819.00
# 1139      MYR                           700.00
# 1140      MYR                           440.00
# 1164      USD                            60.00
# 1193      MYR                           148.00
#
#       ACTUAL_OUTSTANDING_AS_AT_MONTH_END__(ORIGINAL_CURRENCY)  \
# 566                                                    617.03
# 567                                                      0.00
# 568                                                    269.42
# 614                                                      0.00
# 615                                                    500.00
# 670                                                      0.00
# 688                                                      0.00
# 689                                                      0.00
# 722                                                      0.00
# 1039                                                     0.00
# 1040                                                     0.00
# 1078                                                     0.00
# 1079                                                     0.00
# 1138                                                     0.00
# 1139                                                     0.00
# 1140                                                     0.00
# 1164                                                     0.00
# 1193                                                     0.00
#
#       LIMIT__(RM_'MIL)  ACTUAL_OUTSTANDING_AS_AT_MONTH_END__(RM_'MIL)  \
# 566              75.36                                            0.0
# 567             403.04                                            0.0
# 568             698.72                                            0.0
# 614             493.18                                            0.0
# 615             500.00                                            0.0
# 670             300.00                                            0.0
# 688             800.00                                            0.0
# 689            1413.40                                            0.0
# 722             800.00                                            0.0
# 1039            700.00                                            0.0
# 1040            140.00                                            0.0
# 1078           1479.23                                            0.0
# 1079            800.00                                            0.0
# 1138           2819.00                                            0.0
# 1139            700.00                                         5350.5
# 1140            440.00                                            0.0
# 1164            240.00                                            0.0
# 1193            148.00                                            0.0
#
#       INDICATOR  \
# 566         0.0
# 567         0.0
# 568         0.0
# 614         0.0
# 615         0.0
# 670         0.0
# 688         0.0
# 689         0.0
# 722         0.0
# 1039        0.0
# 1040        0.0
# 1078        0.0
# 1079        0.0
# 1138        0.0
# 1139        0.0
# 1140        0.0
# 1164        0.0
# 1193        0.0
#
#                                                                                                                                                                                                                            REMARKS  \
# 566                                                                                                                               [NZ, 13/3/19] - Hafeza confirmed limit reduced in Feb19.\n[NZ, 30/7/2020] - Limit was refinanced
# 567                                                                                                                                                                                                                              0
# 568                                                                                                                        29/6/2018 - Updated O/S to RM768.59m\n[NZ, 13/3/19] - Hafeza confirmed Facility fully settled in Feb19.
# 614                                                                                                                                          [24/6/22] - Updated per May 22 Top Group Reporting\n29/6/2018 - Updated O/S to RM550m
# 615                                                                                                                                                                                         [NZ, 30/7/2020] - Limit was refinanced
# 670                                                                                                                                26/6/2018 - Hafeza confirm Emplaced account is islamic \n[NZ, 30/7/2020] - Limit was refinanced
# 688   29/6/2018 - Limit increase from RM359.94 to RM808.00 . O/S updated to RM802.00. \nConfirmed by Hafeza, the facility is conventional.\n10/10/2019 - Hafeza confirmed limit in USD200m\n[NZ, 30/7/2020] - Limit was refinanced
# 689                                                                                                26/6/2018 - Limit increase from RM1,017.80 to RM1,413.40. O/S updated to RM1,413.40. \n[NZ, 30/7/2020] - Limit was refinanced\n
# 722                                                                                                                                                                                                                              0
# 1039                                                                                                                                                                                        [NZ, 30/7/2020] - Limit was refinanced
# 1040                                                                                                                                                                                        [NZ, 30/7/2020] - Limit was refinanced
# 1078                                                                                                   [24/6/22] - Updated per May 22 Top Group Reporting\n[NZ,4/2/2020] - Julian confirmed client accepted lower amount of RM1.6b
# 1079                                                                                                                                                       [NZ,4/2/2020] - Julian confirmed client accepted lower amount of RM1.6b
# 1138                                                                                                                                                                            [24/6/22] - Updated per May 22 Top Group Reporting
# 1139                                                                                                                                                                            [24/6/22] - Updated per May 22 Top Group Reporting
# 1140                                                                                    [11/3/22] Limit has been cancelled on 28.02.22 as updated by Business (Hafeza)\n[NZ, 16/4/2021] - Update per Top Group Mar21 (Global Refi)
# 1164                                                                                                                                                                                                                             0
# 1193                                                 [11/3/22] Limit has been cancelled on 28.02.22 as updated by Business (Hafeza)\n[9/3/22] Limit reduced from RM300mil to RM148mil based on 20% over approved limit (RM740mil).
#
#                                  BORROWER_NAME  TOTAL_LIMIT_(RM'MIL)  \
# 566   SAPURA TMC SB (FKA SAPURAKENCANA TMC SB)              12949.92
# 567   SAPURA TMC SB (FKA SAPURAKENCANA TMC SB)              12949.92
# 568   SAPURA TMC SB (FKA SAPURAKENCANA TMC SB)              12949.92
# 614                              SAPURA TMC SB              12949.92
# 615   SAPURA TMC SB (FKA SAPURAKENCANA TMC SB)              12949.92
# 670   SAPURA TMC SB (FKA SAPURAKENCANA TMC SB)              12949.92
# 688   SAPURA TMC SB (FKA SAPURAKENCANA TMC SB)              12949.92
# 689   SAPURA TMC SB (FKA SAPURAKENCANA TMC SB)              12949.92
# 722                              SAPURA TMC SB              12949.92
# 1039  SAPURA TMC SB (FKA SAPURAKENCANA TMC SB)              12949.92
# 1040  SAPURA TMC SB (FKA SAPURAKENCANA TMC SB)              12949.92
# 1078                             SAPURA TMC SB              12949.92
# 1079                             SAPURA TMC SB              12949.92
# 1138                             SAPURA TMC SB              12949.92
# 1139                             SAPURA TMC SB              12949.92
# 1140                             SAPURA TMC SB              12949.92
# 1164                             SAPURA TMC SB              12949.92
# 1193                             SAPURA TMC SB              12949.92
#
#      BULLET/BALLOON_REPAYMENT  PEAT_FINANCING_TAGGING_(YES/NO)  \
# 566                         0                                0
# 567                         0                                0
# 568                         0                                0
# 614                         0                                0
# 615                         0                                0
# 670                         0                                0
# 688                         0                                0
# 689                         0                                0
# 722                         0                                0
# 1039                        0                                0
# 1040                        0                                0
# 1078                   Bullet                                0
# 1079                   Bullet                                0
# 1138                   Bullet                                0
# 1139                   Bullet                                0
# 1140                        0                                0
# 1164                   Bullet                                0
# 1193                        0                                0
#
#       PEAT_FINANCING_AMOUNT__(TYPE_OF_FACILITY_-_RM'M)  \
# 566                                                0.0
# 567                                                0.0
# 568                                                0.0
# 614                                                0.0
# 615                                                0.0
# 670                                                0.0
# 688                                                0.0
# 689                                                0.0
# 722                                                0.0
# 1039                                               0.0
# 1040                                               0.0
# 1078                                               0.0
# 1079                                               0.0
# 1138                                               0.0
# 1139                                               0.0
# 1140                                               0.0
# 1164                                               0.0
# 1193                                               0.0
#
#       PEAT_LAND_COMPOSITION_(%)  PER_LIMIT_FILE
# 566                         0.0               0
# 567                         0.0               0
# 568                         0.0               0
# 614                         0.0               0
# 615                         0.0               0
# 670                         0.0               0
# 688                         0.0               0
# 689                         0.0               0
# 722                         0.0               0
# 1039                        0.0               0
# 1040                        0.0               0
# 1078                        0.0               0
# 1079                        0.0               0
# 1138                        0.0               0
# 1139                        0.0               0
# 1140                        0.0               0
# 1164                        0.0               0
# 1193                        0.0               0

# %%
a.BORROWER_NAME.value_counts()
# Out:
# SAPURA TMC SB                               9
# SAPURA TMC SB (FKA SAPURAKENCANA TMC SB)    9
# Name: BORROWER_NAME, dtype: int64

# %%
GB12.shape
# Out:
# (1480, 47)

# %%
t = ['Total', 'Bilateral Loan', 'Bilateral Loan', 'Bilateral Loan', 'Bilateral Loan','Total', 'Fixed Income Secrurities (FIS)', 'Fixed Income Secrurities (FIS)', 'Fixed Income Secrurities (FIS)', 'Fixed Income Secrurities (FIS)','Total']

# %%
#_D

BB1_D = BB[["Unnamed: 0","Bookings \n(RM 'mil)","Total Exposure\n (RM 'mil)","Outstanding \n(RM 'mil)"]].rename(columns={'Unnamed: 0':'Entity'})
BB1_D.columns = BB1_D.columns.str.replace("\n", "_")
BB2_D = BB1_D.iloc[np.where(~(BB1_D.Entity.isnull()))]
BB2_D = BB2_D.assign(Entity1=t)
BB2_D['Class'] = 'BB'


BBHP1_D = BBHP[["Unnamed: 0","Bookings \n(RM 'mil)","Total Exposure\n (RM 'mil)","Outstanding \n(RM 'mil)"]].rename(columns={'Unnamed: 0':'Entity'})
BBHP1_D.columns = BBHP1_D.columns.str.replace("\n", "_")
BBHP2_D = BBHP1_D.iloc[np.where(~(BBHP1_D.Entity.isnull()))]
BBHP2_D = BBHP2_D.assign(Entity1=t)
BBHP2_D['Class'] = 'BB'


SME1_D = SME[["Unnamed: 0","Bookings \n(RM 'mil)","Total Exposure\n (RM 'mil)","Outstanding \n(RM 'mil)"]].rename(columns={'Unnamed: 0':'Entity'})
SME1_D.columns = SME1_D.columns.str.replace("\n", "_")
SME2_D = SME1_D.iloc[np.where(~(SME1_D.Entity.isnull()))]
SME2_D = SME2_D.assign(Entity1=t)
SME2_D['Class'] = 'SME'


GB1_D = GB[["Unnamed: 0","Bookings \n(RM 'mil)","Total Exposure\n (RM 'mil)","Outstanding \n(RM 'mil)"]].rename(columns={'Unnamed: 0':'Entity'})
GB1_D.columns = GB1_D.columns.str.replace("\n", "_")
GB2_D = GB1_D.iloc[np.where(~(GB1_D.Entity.isnull()))]
GB2_D = GB2_D.assign(Entity1=t)
GB2_D['Class'] = 'CB/GB'


frames_D = [ BB2_D, BBHP2_D, SME2_D, GB2_D] 
MGS_D = pd.concat(frames_D)

MGS1_D = MGS_D.groupby(['Class','Entity1','Entity']).sum().reset_index().sort_values(by=['Entity1'], ascending=[False])

MGS1_D['Total Exposures w/o Bookings'] = MGS1_D["Total Exposure_ (RM 'mil)"]-MGS1_D["Bookings _(RM 'mil)"]

MGS1_D['Date'] = D

MGS1_D.Entity = MGS1_D.Entity.str.strip()

def utilization(Entity):
    if Entity == 'Construction':
        return 31700 
    elif Entity == 'Oil & Gas':
        return 37490 
    elif Entity == 'Oil Palm':
        return 30700
    elif Entity == 'Shipping':
        return 10110
    else:
        return 31700+37490+30700+10110
        
MGS1_D['Limit/Threshold'] = MGS1_D['Entity'].apply(utilization)
MGS1_D['Utilization Exposures w/o bookings'] = MGS1_D['Total Exposures w/o Bookings']/MGS1_D['Limit/Threshold']
MGS1_D['Utilization Exposures'] = MGS1_D["Total Exposure_ (RM 'mil)"]/MGS1_D['Limit/Threshold']

MGS2_D = MGS1_D.iloc[np.where(MGS1_D.Entity1!='Total')].sort_values(by=['Class','Entity1','Entity'],ascending=[True,True,True])

# %%
MGS2_D
# Out:
#     Class                         Entity1        Entity  Bookings _(RM 'mil)  \
# 0      BB                  Bilateral Loan  Construction                72.35
# 1      BB                  Bilateral Loan     Oil & Gas                18.85
# 2      BB                  Bilateral Loan      Oil Palm               173.82
# 3      BB                  Bilateral Loan      Shipping                 0.00
# 4      BB  Fixed Income Secrurities (FIS)  Construction                 0.00
# 5      BB  Fixed Income Secrurities (FIS)     Oil & Gas                 0.00
# 6      BB  Fixed Income Secrurities (FIS)      Oil Palm                 0.00
# 7      BB  Fixed Income Secrurities (FIS)      Shipping                 0.00
# 11  CB/GB                  Bilateral Loan  Construction                 0.00
# 12  CB/GB                  Bilateral Loan     Oil & Gas                 0.00
# 13  CB/GB                  Bilateral Loan      Oil Palm               600.00
# 14  CB/GB                  Bilateral Loan      Shipping                 0.00
# 15  CB/GB  Fixed Income Secrurities (FIS)  Construction                 0.00
# 16  CB/GB  Fixed Income Secrurities (FIS)     Oil & Gas                 0.00
# 17  CB/GB  Fixed Income Secrurities (FIS)      Oil Palm                 0.00
# 18  CB/GB  Fixed Income Secrurities (FIS)      Shipping                 0.00
# 22    SME                  Bilateral Loan  Construction               139.90
# 23    SME                  Bilateral Loan     Oil & Gas                 1.00
# 24    SME                  Bilateral Loan      Oil Palm                30.57
# 25    SME                  Bilateral Loan      Shipping                 5.65
# 26    SME  Fixed Income Secrurities (FIS)  Construction                 0.00
# 27    SME  Fixed Income Secrurities (FIS)     Oil & Gas                 0.00
# 28    SME  Fixed Income Secrurities (FIS)      Oil Palm                 0.00
# 29    SME  Fixed Income Secrurities (FIS)      Shipping                 0.00
#
#     Total Exposure_ (RM 'mil)  Outstanding _(RM 'mil)  \
# 0                     1754.25                  481.39
# 1                      172.02                   39.25
# 2                     1102.03                  398.05
# 3                       29.99                    9.17
# 4                        0.00                    0.00
# 5                        0.00                    0.00
# 6                        0.00                    0.00
# 7                        0.00                    0.00
# 11                    1826.11                  819.88
# 12                    6576.44                 1906.28
# 13                   11032.63                 6079.60
# 14                     217.08                   66.81
# 15                       0.00                    0.00
# 16                     160.00                  160.00
# 17                     105.00                  105.00
# 18                       0.00                    0.00
# 22                    1047.78                  728.07
# 23                      34.56                   25.78
# 24                     143.99                   98.48
# 25                      24.12                   13.20
# 26                       0.00                    0.00
# 27                       0.00                    0.00
# 28                       0.00                    0.00
# 29                       0.00                    0.00
#
#     Total Exposures w/o Bookings      Date  Limit/Threshold  \
# 0                        1681.90  Jun 2021            31700
# 1                         153.17  Jun 2021            37490
# 2                         928.20  Jun 2021            30700
# 3                          29.99  Jun 2021            10110
# 4                           0.00  Jun 2021            31700
# 5                           0.00  Jun 2021            37490
# 6                           0.00  Jun 2021            30700
# 7                           0.00  Jun 2021            10110
# 11                       1826.11  Jun 2021            31700
# 12                       6576.44  Jun 2021            37490
# 13                      10432.63  Jun 2021            30700
# 14                        217.08  Jun 2021            10110
# 15                          0.00  Jun 2021            31700
# 16                        160.00  Jun 2021            37490
# 17                        105.00  Jun 2021            30700
# 18                          0.00  Jun 2021            10110
# 22                        907.88  Jun 2021            31700
# 23                         33.56  Jun 2021            37490
# 24                        113.42  Jun 2021            30700
# 25                         18.47  Jun 2021            10110
# 26                          0.00  Jun 2021            31700
# 27                          0.00  Jun 2021            37490
# 28                          0.00  Jun 2021            30700
# 29                          0.00  Jun 2021            10110
#
#     Utilization Exposures w/o bookings  Utilization Exposures
# 0                             5.31e-02               5.53e-02
# 1                             4.09e-03               4.59e-03
# 2                             3.02e-02               3.59e-02
# 3                             2.97e-03               2.97e-03
# 4                             0.00e+00               0.00e+00
# 5                             0.00e+00               0.00e+00
# 6                             0.00e+00               0.00e+00
# 7                             0.00e+00               0.00e+00
# 11                            5.76e-02               5.76e-02
# 12                            1.75e-01               1.75e-01
# 13                            3.40e-01               3.59e-01
# 14                            2.15e-02               2.15e-02
# 15                            0.00e+00               0.00e+00
# 16                            4.27e-03               4.27e-03
# 17                            3.42e-03               3.42e-03
# 18                            0.00e+00               0.00e+00
# 22                            2.86e-02               3.31e-02
# 23                            8.95e-04               9.22e-04
# 24                            3.69e-03               4.69e-03
# 25                            1.83e-03               2.39e-03
# 26                            0.00e+00               0.00e+00
# 27                            0.00e+00               0.00e+00
# 28                            0.00e+00               0.00e+00
# 29                            0.00e+00               0.00e+00

# %%
#_D1

BB1_D1 = BB1[["Unnamed: 0","Bookings \n(RM 'mil)","Total Exposure\n (RM 'mil)","Outstanding \n(RM 'mil)"]].rename(columns={'Unnamed: 0':'Entity'})
BB1_D1.columns = BB1_D1.columns.str.replace("\n", "_")
BB2_D1 = BB1_D1.iloc[np.where(~(BB1_D1.Entity.isnull()))]
BB2_D1 = BB2_D1.assign(Entity1=t)
BB2_D1['Class'] = 'BB'


BBHP1_D1 = BBHP1[["Unnamed: 0","Bookings \n(RM 'mil)","Total Exposure\n (RM 'mil)","Outstanding \n(RM 'mil)"]].rename(columns={'Unnamed: 0':'Entity'})
BBHP1_D1.columns = BBHP1_D1.columns.str.replace("\n", "_")
BBHP2_D1 = BBHP1_D1.iloc[np.where(~(BBHP1_D1.Entity.isnull()))]
BBHP2_D1 = BBHP2_D1.assign(Entity1=t)
BBHP2_D1['Class'] = 'BB'


SME1_D1 = SME1[["Unnamed: 0","Bookings \n(RM 'mil)","Total Exposure\n (RM 'mil)","Outstanding \n(RM 'mil)"]].rename(columns={'Unnamed: 0':'Entity'})
SME1_D1.columns = SME1_D1.columns.str.replace("\n", "_")
SME2_D1 = SME1_D1.iloc[np.where(~(SME1_D1.Entity.isnull()))]
SME2_D1 = SME2_D1.assign(Entity1=t)
SME2_D1['Class'] = 'SME'


GB1_D1 = GB1[["Unnamed: 0","Bookings \n(RM 'mil)","Total Exposure\n (RM 'mil)","Outstanding \n(RM 'mil)"]].rename(columns={'Unnamed: 0':'Entity'})
GB1_D1.columns = GB1_D1.columns.str.replace("\n", "_")
GB2_D1 = GB1_D1.iloc[np.where(~(GB1_D1.Entity.isnull()))]
GB2_D1 = GB2_D1.assign(Entity1=t)
GB2_D1['Class'] = 'CB/GB'


frames_D1 = [ BB2_D1, BBHP2_D1, SME2_D1, GB2_D1] 
MGS_D1 = pd.concat(frames_D1)

MGS1_D1 = MGS_D1.groupby(['Class','Entity1','Entity']).sum().reset_index().sort_values(by=['Entity1'], ascending=[False])

MGS1_D1['Total Exposures w/o Bookings'] = MGS1_D1["Total Exposure_ (RM 'mil)"]-MGS1_D1["Bookings _(RM 'mil)"]

MGS1_D1['D1ate'] = D1

MGS1_D1.Entity = MGS1_D1.Entity.str.strip()

def utilization(Entity):
    if Entity == 'Construction':
        return 31700 
    elif Entity == 'Oil & Gas':
        return 37490 
    elif Entity == 'Oil Palm':
        return 30700
    elif Entity == 'Shipping':
        return 10110
    else:
        return 31700+37490+30700+10110
        
MGS1_D1['Limit/ThresholD1'] = MGS1_D1['Entity'].apply(utilization)
MGS1_D1['Utilization Exposures w/o bookings'] = MGS1_D1['Total Exposures w/o Bookings']/MGS1_D1['Limit/ThresholD1']
MGS1_D1['Utilization Exposures'] = MGS1_D1["Total Exposure_ (RM 'mil)"]/MGS1_D1['Limit/ThresholD1']

MGS2_D1 = MGS1_D1.iloc[np.where(MGS1_D1.Entity1!='Total')].sort_values(by=['Class','Entity1','Entity'],ascending=[True,True,True])

# %%
MGS2_D1
# Out:
#     Class                         Entity1        Entity  Bookings _(RM 'mil)  \
# 0      BB                  Bilateral Loan  Construction               126.31
# 1      BB                  Bilateral Loan     Oil & Gas                10.85
# 2      BB                  Bilateral Loan      Oil Palm               140.60
# 3      BB                  Bilateral Loan      Shipping                 0.00
# 4      BB  Fixed Income Secrurities (FIS)  Construction                 0.00
# 5      BB  Fixed Income Secrurities (FIS)     Oil & Gas                 0.00
# 6      BB  Fixed Income Secrurities (FIS)      Oil Palm                 0.00
# 7      BB  Fixed Income Secrurities (FIS)      Shipping                 0.00
# 11  CB/GB                  Bilateral Loan  Construction                 0.00
# 12  CB/GB                  Bilateral Loan     Oil & Gas                 0.00
# 13  CB/GB                  Bilateral Loan      Oil Palm               600.00
# 14  CB/GB                  Bilateral Loan      Shipping                 0.00
# 15  CB/GB  Fixed Income Secrurities (FIS)  Construction                 0.00
# 16  CB/GB  Fixed Income Secrurities (FIS)     Oil & Gas                 0.00
# 17  CB/GB  Fixed Income Secrurities (FIS)      Oil Palm                 0.00
# 18  CB/GB  Fixed Income Secrurities (FIS)      Shipping                 0.00
# 22    SME                  Bilateral Loan  Construction               149.33
# 23    SME                  Bilateral Loan     Oil & Gas                 1.40
# 24    SME                  Bilateral Loan      Oil Palm                31.56
# 25    SME                  Bilateral Loan      Shipping                 5.65
# 26    SME  Fixed Income Secrurities (FIS)  Construction                 0.00
# 27    SME  Fixed Income Secrurities (FIS)     Oil & Gas                 0.00
# 28    SME  Fixed Income Secrurities (FIS)      Oil Palm                 0.00
# 29    SME  Fixed Income Secrurities (FIS)      Shipping                 0.00
#
#     Total Exposure_ (RM 'mil)  Outstanding _(RM 'mil)  \
# 0                     1807.70                  445.26
# 1                      158.77                   36.48
# 2                     1078.05                  415.93
# 3                       29.98                    9.16
# 4                        0.00                    0.00
# 5                        0.00                    0.00
# 6                        0.00                    0.00
# 7                        0.00                    0.00
# 11                    1826.11                  835.49
# 12                    6576.44                 1922.40
# 13                   11032.63                 6114.75
# 14                     217.08                   66.86
# 15                       0.00                    0.00
# 16                       0.00                    0.00
# 17                     105.00                  105.00
# 18                       0.00                    0.00
# 22                    1093.98                  763.86
# 23                      35.46                   26.28
# 24                     144.98                   99.22
# 25                      24.25                   12.92
# 26                       0.00                    0.00
# 27                       0.00                    0.00
# 28                       0.00                    0.00
# 29                       0.00                    0.00
#
#     Total Exposures w/o Bookings     D1ate  Limit/ThresholD1  \
# 0                        1681.38  Jul 2021             31700
# 1                         147.92  Jul 2021             37490
# 2                         937.45  Jul 2021             30700
# 3                          29.98  Jul 2021             10110
# 4                           0.00  Jul 2021             31700
# 5                           0.00  Jul 2021             37490
# 6                           0.00  Jul 2021             30700
# 7                           0.00  Jul 2021             10110
# 11                       1826.11  Jul 2021             31700
# 12                       6576.44  Jul 2021             37490
# 13                      10432.63  Jul 2021             30700
# 14                        217.08  Jul 2021             10110
# 15                          0.00  Jul 2021             31700
# 16                          0.00  Jul 2021             37490
# 17                        105.00  Jul 2021             30700
# 18                          0.00  Jul 2021             10110
# 22                        944.65  Jul 2021             31700
# 23                         34.06  Jul 2021             37490
# 24                        113.42  Jul 2021             30700
# 25                         18.60  Jul 2021             10110
# 26                          0.00  Jul 2021             31700
# 27                          0.00  Jul 2021             37490
# 28                          0.00  Jul 2021             30700
# 29                          0.00  Jul 2021             10110
#
#     Utilization Exposures w/o bookings  Utilization Exposures
# 0                             5.30e-02               5.70e-02
# 1                             3.95e-03               4.23e-03
# 2                             3.05e-02               3.51e-02
# 3                             2.97e-03               2.97e-03
# 4                             0.00e+00               0.00e+00
# 5                             0.00e+00               0.00e+00
# 6                             0.00e+00               0.00e+00
# 7                             0.00e+00               0.00e+00
# 11                            5.76e-02               5.76e-02
# 12                            1.75e-01               1.75e-01
# 13                            3.40e-01               3.59e-01
# 14                            2.15e-02               2.15e-02
# 15                            0.00e+00               0.00e+00
# 16                            0.00e+00               0.00e+00
# 17                            3.42e-03               3.42e-03
# 18                            0.00e+00               0.00e+00
# 22                            2.98e-02               3.45e-02
# 23                            9.09e-04               9.46e-04
# 24                            3.69e-03               4.72e-03
# 25                            1.84e-03               2.40e-03
# 26                            0.00e+00               0.00e+00
# 27                            0.00e+00               0.00e+00
# 28                            0.00e+00               0.00e+00
# 29                            0.00e+00               0.00e+00

# %%
#_D2

BB1_D2 = BB2[["Unnamed: 0","Bookings \n(RM 'mil)","Total Exposure\n (RM 'mil)","Outstanding \n(RM 'mil)"]].rename(columns={'Unnamed: 0':'Entity'})
BB1_D2.columns = BB1_D2.columns.str.replace("\n", "_")
BB2_D2 = BB1_D2.iloc[np.where(~(BB1_D2.Entity.isnull()))]
BB2_D2 = BB2_D2.assign(Entity1=t)
BB2_D2['Class'] = 'BB'


BBHP1_D2 = BBHP2[["Unnamed: 0","Bookings \n(RM 'mil)","Total Exposure\n (RM 'mil)","Outstanding \n(RM 'mil)"]].rename(columns={'Unnamed: 0':'Entity'})
BBHP1_D2.columns = BBHP1_D2.columns.str.replace("\n", "_")
BBHP2_D2 = BBHP1_D2.iloc[np.where(~(BBHP1_D2.Entity.isnull()))]
BBHP2_D2 = BBHP2_D2.assign(Entity1=t)
BBHP2_D2['Class'] = 'BB'


SME1_D2 = SME2[["Unnamed: 0","Bookings \n(RM 'mil)","Total Exposure\n (RM 'mil)","Outstanding \n(RM 'mil)"]].rename(columns={'Unnamed: 0':'Entity'})
SME1_D2.columns = SME1_D2.columns.str.replace("\n", "_")
SME2_D2 = SME1_D2.iloc[np.where(~(SME1_D2.Entity.isnull()))]
SME2_D2 = SME2_D2.assign(Entity1=t)
SME2_D2['Class'] = 'SME'


GB1_D2 = GB2[["Unnamed: 0","Bookings \n(RM 'mil)","Total Exposure\n (RM 'mil)","Outstanding \n(RM 'mil)"]].rename(columns={'Unnamed: 0':'Entity'})
GB1_D2.columns = GB1_D2.columns.str.replace("\n", "_")
GB2_D2 = GB1_D2.iloc[np.where(~(GB1_D2.Entity.isnull()))]
GB2_D2 = GB2_D2.assign(Entity1=t)
GB2_D2['Class'] = 'CB/GB'


frames_D2 = [ BB2_D2, BBHP2_D2, SME2_D2, GB2_D2] 
MGS_D2 = pd.concat(frames_D2)

MGS1_D2 = MGS_D2.groupby(['Class','Entity1','Entity']).sum().reset_index().sort_values(by=['Entity1'], ascending=[False])

MGS1_D2['Total Exposures w/o Bookings'] = MGS1_D2["Total Exposure_ (RM 'mil)"]-MGS1_D2["Bookings _(RM 'mil)"]

MGS1_D2['D2ate'] = D2

MGS1_D2.Entity = MGS1_D2.Entity.str.strip()

def utilization(Entity):
    if Entity == 'Construction':
        return 31700 
    elif Entity == 'Oil & Gas':
        return 37490 
    elif Entity == 'Oil Palm':
        return 30700
    elif Entity == 'Shipping':
        return 10110
    else:
        return 31700+37490+30700+10110
        
MGS1_D2['Limit/ThresholD2'] = MGS1_D2['Entity'].apply(utilization)
MGS1_D2['Utilization Exposures w/o bookings'] = MGS1_D2['Total Exposures w/o Bookings']/MGS1_D2['Limit/ThresholD2']
MGS1_D2['Utilization Exposures'] = MGS1_D2["Total Exposure_ (RM 'mil)"]/MGS1_D2['Limit/ThresholD2']

MGS2_D2 = MGS1_D2.iloc[np.where(MGS1_D2.Entity1!='Total')].sort_values(by=['Class','Entity1','Entity'],ascending=[True,True,True])

# %%
MGS2_D2
# Out:
#     Class                         Entity1        Entity  Bookings _(RM 'mil)  \
# 0      BB                  Bilateral Loan  Construction               157.03
# 1      BB                  Bilateral Loan     Oil & Gas                10.85
# 2      BB                  Bilateral Loan      Oil Palm               141.01
# 3      BB                  Bilateral Loan      Shipping                 0.00
# 4      BB  Fixed Income Secrurities (FIS)  Construction                 0.00
# 5      BB  Fixed Income Secrurities (FIS)     Oil & Gas                 0.00
# 6      BB  Fixed Income Secrurities (FIS)      Oil Palm                 0.00
# 7      BB  Fixed Income Secrurities (FIS)      Shipping                 0.00
# 11  CB/GB                  Bilateral Loan  Construction                 0.00
# 12  CB/GB                  Bilateral Loan     Oil & Gas                 0.00
# 13  CB/GB                  Bilateral Loan      Oil Palm               315.00
# 14  CB/GB                  Bilateral Loan      Shipping                 0.00
# 15  CB/GB  Fixed Income Secrurities (FIS)  Construction                 0.00
# 16  CB/GB  Fixed Income Secrurities (FIS)     Oil & Gas                 0.00
# 17  CB/GB  Fixed Income Secrurities (FIS)      Oil Palm                 0.00
# 18  CB/GB  Fixed Income Secrurities (FIS)      Shipping                 0.00
# 22    SME                  Bilateral Loan  Construction               201.83
# 23    SME                  Bilateral Loan     Oil & Gas                 2.00
# 24    SME                  Bilateral Loan      Oil Palm                37.48
# 25    SME                  Bilateral Loan      Shipping                 5.65
# 26    SME  Fixed Income Secrurities (FIS)  Construction                 0.00
# 27    SME  Fixed Income Secrurities (FIS)     Oil & Gas                 0.00
# 28    SME  Fixed Income Secrurities (FIS)      Oil Palm                 0.00
# 29    SME  Fixed Income Secrurities (FIS)      Shipping                 0.00
#
#     Total Exposure_ (RM 'mil)  Outstanding _(RM 'mil)  \
# 0                     1838.36                  353.05
# 1                      158.75                   35.33
# 2                     1077.06                  407.82
# 3                       29.97                    9.15
# 4                        0.00                    0.00
# 5                        0.00                    0.00
# 6                        0.00                    0.00
# 7                        0.00                    0.00
# 11                    1826.11                  810.03
# 12                    6576.44                 1906.89
# 13                   11207.63                 6865.20
# 14                     184.14                   67.06
# 15                       0.00                    0.00
# 16                       0.00                    0.00
# 17                     105.00                  105.00
# 18                       0.00                    0.00
# 22                    1146.47                  763.86
# 23                      36.06                   26.28
# 24                     152.03                   99.22
# 25                      24.25                   12.92
# 26                       0.00                    0.00
# 27                       0.00                    0.00
# 28                       0.00                    0.00
# 29                       0.00                    0.00
#
#     Total Exposures w/o Bookings     D2ate  Limit/ThresholD2  \
# 0                        1681.33  Aug 2021             31700
# 1                         147.90  Aug 2021             37490
# 2                         936.04  Aug 2021             30700
# 3                          29.97  Aug 2021             10110
# 4                           0.00  Aug 2021             31700
# 5                           0.00  Aug 2021             37490
# 6                           0.00  Aug 2021             30700
# 7                           0.00  Aug 2021             10110
# 11                       1826.11  Aug 2021             31700
# 12                       6576.44  Aug 2021             37490
# 13                      10892.63  Aug 2021             30700
# 14                        184.14  Aug 2021             10110
# 15                          0.00  Aug 2021             31700
# 16                          0.00  Aug 2021             37490
# 17                        105.00  Aug 2021             30700
# 18                          0.00  Aug 2021             10110
# 22                        944.65  Aug 2021             31700
# 23                         34.06  Aug 2021             37490
# 24                        114.55  Aug 2021             30700
# 25                         18.60  Aug 2021             10110
# 26                          0.00  Aug 2021             31700
# 27                          0.00  Aug 2021             37490
# 28                          0.00  Aug 2021             30700
# 29                          0.00  Aug 2021             10110
#
#     Utilization Exposures w/o bookings  Utilization Exposures
# 0                             5.30e-02               5.80e-02
# 1                             3.95e-03               4.23e-03
# 2                             3.05e-02               3.51e-02
# 3                             2.96e-03               2.96e-03
# 4                             0.00e+00               0.00e+00
# 5                             0.00e+00               0.00e+00
# 6                             0.00e+00               0.00e+00
# 7                             0.00e+00               0.00e+00
# 11                            5.76e-02               5.76e-02
# 12                            1.75e-01               1.75e-01
# 13                            3.55e-01               3.65e-01
# 14                            1.82e-02               1.82e-02
# 15                            0.00e+00               0.00e+00
# 16                            0.00e+00               0.00e+00
# 17                            3.42e-03               3.42e-03
# 18                            0.00e+00               0.00e+00
# 22                            2.98e-02               3.62e-02
# 23                            9.09e-04               9.62e-04
# 24                            3.73e-03               4.95e-03
# 25                            1.84e-03               2.40e-03
# 26                            0.00e+00               0.00e+00
# 27                            0.00e+00               0.00e+00
# 28                            0.00e+00               0.00e+00
# 29                            0.00e+00               0.00e+00

# %%
#_D3

BB1_D3 = BB3[["Unnamed: 0","Bookings \n(RM 'mil)","Total Exposure\n (RM 'mil)","Outstanding \n(RM 'mil)"]].rename(columns={'Unnamed: 0':'Entity'})
BB1_D3.columns = BB1_D3.columns.str.replace("\n", "_")
BB2_D3 = BB1_D3.iloc[np.where(~(BB1_D3.Entity.isnull()))]
BB2_D3 = BB2_D3.assign(Entity1=t)
BB2_D3['Class'] = 'BB'


BBHP1_D3 = BBHP3[["Unnamed: 0","Bookings \n(RM 'mil)","Total Exposure\n (RM 'mil)","Outstanding \n(RM 'mil)"]].rename(columns={'Unnamed: 0':'Entity'})
BBHP1_D3.columns = BBHP1_D3.columns.str.replace("\n", "_")
BBHP2_D3 = BBHP1_D3.iloc[np.where(~(BBHP1_D3.Entity.isnull()))]
BBHP2_D3 = BBHP2_D3.assign(Entity1=t)
BBHP2_D3['Class'] = 'BB'


SME1_D3 = SME3[["Unnamed: 0","Bookings \n(RM 'mil)","Total Exposure\n (RM 'mil)","Outstanding \n(RM 'mil)"]].rename(columns={'Unnamed: 0':'Entity'})
SME1_D3.columns = SME1_D3.columns.str.replace("\n", "_")
SME2_D3 = SME1_D3.iloc[np.where(~(SME1_D3.Entity.isnull()))]
SME2_D3 = SME2_D3.assign(Entity1=t)
SME2_D3['Class'] = 'SME'


GB1_D3 = GB3[["Unnamed: 0","Bookings \n(RM 'mil)","Total Exposure\n (RM 'mil)","Outstanding \n(RM 'mil)"]].rename(columns={'Unnamed: 0':'Entity'})
GB1_D3.columns = GB1_D3.columns.str.replace("\n", "_")
GB2_D3 = GB1_D3.iloc[np.where(~(GB1_D3.Entity.isnull()))]
GB2_D3 = GB2_D3.assign(Entity1=t)
GB2_D3['Class'] = 'CB/GB'


frames_D3 = [ BB2_D3, BBHP2_D3, SME2_D3, GB2_D3] 
MGS_D3 = pd.concat(frames_D3)

MGS1_D3 = MGS_D3.groupby(['Class','Entity1','Entity']).sum().reset_index().sort_values(by=['Entity1'], ascending=[False])

MGS1_D3['Total Exposures w/o Bookings'] = MGS1_D3["Total Exposure_ (RM 'mil)"]-MGS1_D3["Bookings _(RM 'mil)"]

MGS1_D3['D3ate'] = D3

MGS1_D3.Entity = MGS1_D3.Entity.str.strip()

def utilization(Entity):
    if Entity == 'Construction':
        return 31700 
    elif Entity == 'Oil & Gas':
        return 37490 
    elif Entity == 'Oil Palm':
        return 30700
    elif Entity == 'Shipping':
        return 10110
    else:
        return 31700+37490+30700+10110
        
MGS1_D3['Limit/ThresholD3'] = MGS1_D3['Entity'].apply(utilization)
MGS1_D3['Utilization Exposures w/o bookings'] = MGS1_D3['Total Exposures w/o Bookings']/MGS1_D3['Limit/ThresholD3']
MGS1_D3['Utilization Exposures'] = MGS1_D3["Total Exposure_ (RM 'mil)"]/MGS1_D3['Limit/ThresholD3']

MGS2_D3 = MGS1_D3.iloc[np.where(MGS1_D3.Entity1!='Total')].sort_values(by=['Class','Entity1','Entity'],ascending=[True,True,True])

# %%
MGS2_D3
# Out:
#     Class                         Entity1        Entity  Bookings _(RM 'mil)  \
# 0      BB                  Bilateral Loan  Construction               183.10
# 1      BB                  Bilateral Loan     Oil & Gas                10.85
# 2      BB                  Bilateral Loan      Oil Palm               136.19
# 3      BB                  Bilateral Loan      Shipping                 0.00
# 4      BB  Fixed Income Secrurities (FIS)  Construction                 0.00
# 5      BB  Fixed Income Secrurities (FIS)     Oil & Gas                 0.00
# 6      BB  Fixed Income Secrurities (FIS)      Oil Palm                 0.00
# 7      BB  Fixed Income Secrurities (FIS)      Shipping                 0.00
# 11  CB/GB                  Bilateral Loan  Construction                 0.00
# 12  CB/GB                  Bilateral Loan     Oil & Gas                 0.00
# 13  CB/GB                  Bilateral Loan      Oil Palm               315.00
# 14  CB/GB                  Bilateral Loan      Shipping                 0.00
# 15  CB/GB  Fixed Income Secrurities (FIS)  Construction                 0.00
# 16  CB/GB  Fixed Income Secrurities (FIS)     Oil & Gas                 0.00
# 17  CB/GB  Fixed Income Secrurities (FIS)      Oil Palm                 0.00
# 18  CB/GB  Fixed Income Secrurities (FIS)      Shipping                 0.00
# 22    SME                  Bilateral Loan  Construction               209.71
# 23    SME                  Bilateral Loan     Oil & Gas                 2.30
# 24    SME                  Bilateral Loan      Oil Palm                45.29
# 25    SME                  Bilateral Loan      Shipping                 5.65
# 26    SME  Fixed Income Secrurities (FIS)  Construction                 0.00
# 27    SME  Fixed Income Secrurities (FIS)     Oil & Gas                 0.00
# 28    SME  Fixed Income Secrurities (FIS)      Oil Palm                 0.00
# 29    SME  Fixed Income Secrurities (FIS)      Shipping                 0.00
#
#     Total Exposure_ (RM 'mil)  Outstanding _(RM 'mil)  \
# 0                     1859.68                  432.36
# 1                      158.70                   41.57
# 2                     1081.46                  403.93
# 3                       29.96                    9.14
# 4                        0.00                    0.00
# 5                        0.00                    0.00
# 6                        0.00                    0.00
# 7                        0.00                    0.00
# 11                    1826.11                  760.29
# 12                    6576.44                 1903.46
# 13                   11207.63                 6862.86
# 14                     184.14                   67.27
# 15                       0.00                    0.00
# 16                       0.00                    0.00
# 17                     105.00                  105.00
# 18                       0.00                    0.00
# 22                    1154.36                  763.86
# 23                      36.36                   26.28
# 24                     159.84                   99.22
# 25                      24.25                   12.92
# 26                       0.00                    0.00
# 27                       0.00                    0.00
# 28                       0.00                    0.00
# 29                       0.00                    0.00
#
#     Total Exposures w/o Bookings     D3ate  Limit/ThresholD3  \
# 0                        1676.58  Sep 2021             31700
# 1                         147.85  Sep 2021             37490
# 2                         945.26  Sep 2021             30700
# 3                          29.96  Sep 2021             10110
# 4                           0.00  Sep 2021             31700
# 5                           0.00  Sep 2021             37490
# 6                           0.00  Sep 2021             30700
# 7                           0.00  Sep 2021             10110
# 11                       1826.11  Sep 2021             31700
# 12                       6576.44  Sep 2021             37490
# 13                      10892.63  Sep 2021             30700
# 14                        184.14  Sep 2021             10110
# 15                          0.00  Sep 2021             31700
# 16                          0.00  Sep 2021             37490
# 17                        105.00  Sep 2021             30700
# 18                          0.00  Sep 2021             10110
# 22                        944.65  Sep 2021             31700
# 23                         34.06  Sep 2021             37490
# 24                        114.55  Sep 2021             30700
# 25                         18.60  Sep 2021             10110
# 26                          0.00  Sep 2021             31700
# 27                          0.00  Sep 2021             37490
# 28                          0.00  Sep 2021             30700
# 29                          0.00  Sep 2021             10110
#
#     Utilization Exposures w/o bookings  Utilization Exposures
# 0                             5.29e-02               5.87e-02
# 1                             3.94e-03               4.23e-03
# 2                             3.08e-02               3.52e-02
# 3                             2.96e-03               2.96e-03
# 4                             0.00e+00               0.00e+00
# 5                             0.00e+00               0.00e+00
# 6                             0.00e+00               0.00e+00
# 7                             0.00e+00               0.00e+00
# 11                            5.76e-02               5.76e-02
# 12                            1.75e-01               1.75e-01
# 13                            3.55e-01               3.65e-01
# 14                            1.82e-02               1.82e-02
# 15                            0.00e+00               0.00e+00
# 16                            0.00e+00               0.00e+00
# 17                            3.42e-03               3.42e-03
# 18                            0.00e+00               0.00e+00
# 22                            2.98e-02               3.64e-02
# 23                            9.09e-04               9.70e-04
# 24                            3.73e-03               5.21e-03
# 25                            1.84e-03               2.40e-03
# 26                            0.00e+00               0.00e+00
# 27                            0.00e+00               0.00e+00
# 28                            0.00e+00               0.00e+00
# 29                            0.00e+00               0.00e+00

# %%
#_D4

BB1_D4 = BB4[["Unnamed: 0","Bookings \n(RM 'mil)","Total Exposure\n (RM 'mil)","Outstanding \n(RM 'mil)"]].rename(columns={'Unnamed: 0':'Entity'})
BB1_D4.columns = BB1_D4.columns.str.replace("\n", "_")
BB2_D4 = BB1_D4.iloc[np.where(~(BB1_D4.Entity.isnull()))]
BB2_D4 = BB2_D4.assign(Entity1=t)
BB2_D4['Class'] = 'BB'


BBHP1_D4 = BBHP4[["Unnamed: 0","Bookings \n(RM 'mil)","Total Exposure\n (RM 'mil)","Outstanding \n(RM 'mil)"]].rename(columns={'Unnamed: 0':'Entity'})
BBHP1_D4.columns = BBHP1_D4.columns.str.replace("\n", "_")
BBHP2_D4 = BBHP1_D4.iloc[np.where(~(BBHP1_D4.Entity.isnull()))]
BBHP2_D4 = BBHP2_D4.assign(Entity1=t)
BBHP2_D4['Class'] = 'BB'


SME1_D4 = SME4[["Unnamed: 0","Bookings \n(RM 'mil)","Total Exposure\n (RM 'mil)","Outstanding \n(RM 'mil)"]].rename(columns={'Unnamed: 0':'Entity'})
SME1_D4.columns = SME1_D4.columns.str.replace("\n", "_")
SME2_D4 = SME1_D4.iloc[np.where(~(SME1_D4.Entity.isnull()))]
SME2_D4 = SME2_D4.assign(Entity1=t)
SME2_D4['Class'] = 'SME'


GB1_D4 = GB4[["Unnamed: 0","Bookings \n(RM 'mil)","Total Exposure\n (RM 'mil)","Outstanding \n(RM 'mil)"]].rename(columns={'Unnamed: 0':'Entity'})
GB1_D4.columns = GB1_D4.columns.str.replace("\n", "_")
GB2_D4 = GB1_D4.iloc[np.where(~(GB1_D4.Entity.isnull()))]
GB2_D4 = GB2_D4.assign(Entity1=t)
GB2_D4['Class'] = 'CB/GB'


frames_D4 = [ BB2_D4, BBHP2_D4, SME2_D4, GB2_D4] 
MGS_D4 = pd.concat(frames_D4)

MGS1_D4 = MGS_D4.groupby(['Class','Entity1','Entity']).sum().reset_index().sort_values(by=['Entity1'], ascending=[False])

MGS1_D4['Total Exposures w/o Bookings'] = MGS1_D4["Total Exposure_ (RM 'mil)"]-MGS1_D4["Bookings _(RM 'mil)"]

MGS1_D4['D4ate'] = D4

MGS1_D4.Entity = MGS1_D4.Entity.str.strip()

def utilization(Entity):
    if Entity == 'Construction':
        return 31700 
    elif Entity == 'Oil & Gas':
        return 37490 
    elif Entity == 'Oil Palm':
        return 30700
    elif Entity == 'Shipping':
        return 10110
    else:
        return 31700+37490+30700+10110
        
MGS1_D4['Limit/ThresholD4'] = MGS1_D4['Entity'].apply(utilization)
MGS1_D4['Utilization Exposures w/o bookings'] = MGS1_D4['Total Exposures w/o Bookings']/MGS1_D4['Limit/ThresholD4']
MGS1_D4['Utilization Exposures'] = MGS1_D4["Total Exposure_ (RM 'mil)"]/MGS1_D4['Limit/ThresholD4']

MGS2_D4 = MGS1_D4.iloc[np.where(MGS1_D4.Entity1!='Total')].sort_values(by=['Class','Entity1','Entity'],ascending=[True,True,True])

# %%
MGS2_D4
# Out:
#     Class                         Entity1        Entity  Bookings _(RM 'mil)  \
# 0      BB                  Bilateral Loan  Construction               222.12
# 1      BB                  Bilateral Loan     Oil & Gas                10.85
# 2      BB                  Bilateral Loan      Oil Palm               137.35
# 3      BB                  Bilateral Loan      Shipping                 0.00
# 4      BB  Fixed Income Secrurities (FIS)  Construction                 0.00
# 5      BB  Fixed Income Secrurities (FIS)     Oil & Gas                 0.00
# 6      BB  Fixed Income Secrurities (FIS)      Oil Palm                 0.00
# 7      BB  Fixed Income Secrurities (FIS)      Shipping                 0.00
# 11  CB/GB                  Bilateral Loan  Construction               100.00
# 12  CB/GB                  Bilateral Loan     Oil & Gas                 0.00
# 13  CB/GB                  Bilateral Loan      Oil Palm               516.00
# 14  CB/GB                  Bilateral Loan      Shipping                 0.00
# 15  CB/GB  Fixed Income Secrurities (FIS)  Construction                 0.00
# 16  CB/GB  Fixed Income Secrurities (FIS)     Oil & Gas                 0.00
# 17  CB/GB  Fixed Income Secrurities (FIS)      Oil Palm                 0.00
# 18  CB/GB  Fixed Income Secrurities (FIS)      Shipping                 0.00
# 22    SME                  Bilateral Loan  Construction               216.87
# 23    SME                  Bilateral Loan     Oil & Gas                 2.30
# 24    SME                  Bilateral Loan      Oil Palm                52.54
# 25    SME                  Bilateral Loan      Shipping                 5.76
# 26    SME  Fixed Income Secrurities (FIS)  Construction                 0.00
# 27    SME  Fixed Income Secrurities (FIS)     Oil & Gas                 0.00
# 28    SME  Fixed Income Secrurities (FIS)      Oil Palm                 0.00
# 29    SME  Fixed Income Secrurities (FIS)      Shipping                 0.00
#
#     Total Exposure_ (RM 'mil)  Outstanding _(RM 'mil)  \
# 0                     1898.70                  251.01
# 1                      158.64                   36.93
# 2                     1082.62                  386.99
# 3                       29.96                    9.12
# 4                        0.00                    0.00
# 5                        0.00                    0.00
# 6                        0.00                    0.00
# 7                        0.00                    0.00
# 11                    1926.11                  774.64
# 12                    6316.12                 1625.16
# 13                   11408.63                 6600.89
# 14                     184.14                   67.32
# 15                       0.00                    0.00
# 16                       0.00                    0.00
# 17                     105.00                  105.00
# 18                       0.00                    0.00
# 22                    1161.52                  763.86
# 23                      36.36                   26.28
# 24                     167.09                   99.22
# 25                      24.36                   12.92
# 26                       0.00                    0.00
# 27                       0.00                    0.00
# 28                       0.00                    0.00
# 29                       0.00                    0.00
#
#     Total Exposures w/o Bookings     D4ate  Limit/ThresholD4  \
# 0                        1676.58  Oct 2021             31700
# 1                         147.79  Oct 2021             37490
# 2                         945.26  Oct 2021             30700
# 3                          29.96  Oct 2021             10110
# 4                           0.00  Oct 2021             31700
# 5                           0.00  Oct 2021             37490
# 6                           0.00  Oct 2021             30700
# 7                           0.00  Oct 2021             10110
# 11                       1826.11  Oct 2021             31700
# 12                       6316.12  Oct 2021             37490
# 13                      10892.63  Oct 2021             30700
# 14                        184.14  Oct 2021             10110
# 15                          0.00  Oct 2021             31700
# 16                          0.00  Oct 2021             37490
# 17                        105.00  Oct 2021             30700
# 18                          0.00  Oct 2021             10110
# 22                        944.65  Oct 2021             31700
# 23                         34.06  Oct 2021             37490
# 24                        114.55  Oct 2021             30700
# 25                         18.60  Oct 2021             10110
# 26                          0.00  Oct 2021             31700
# 27                          0.00  Oct 2021             37490
# 28                          0.00  Oct 2021             30700
# 29                          0.00  Oct 2021             10110
#
#     Utilization Exposures w/o bookings  Utilization Exposures
# 0                             5.29e-02               5.99e-02
# 1                             3.94e-03               4.23e-03
# 2                             3.08e-02               3.53e-02
# 3                             2.96e-03               2.96e-03
# 4                             0.00e+00               0.00e+00
# 5                             0.00e+00               0.00e+00
# 6                             0.00e+00               0.00e+00
# 7                             0.00e+00               0.00e+00
# 11                            5.76e-02               6.08e-02
# 12                            1.68e-01               1.68e-01
# 13                            3.55e-01               3.72e-01
# 14                            1.82e-02               1.82e-02
# 15                            0.00e+00               0.00e+00
# 16                            0.00e+00               0.00e+00
# 17                            3.42e-03               3.42e-03
# 18                            0.00e+00               0.00e+00
# 22                            2.98e-02               3.66e-02
# 23                            9.09e-04               9.70e-04
# 24                            3.73e-03               5.44e-03
# 25                            1.84e-03               2.41e-03
# 26                            0.00e+00               0.00e+00
# 27                            0.00e+00               0.00e+00
# 28                            0.00e+00               0.00e+00
# 29                            0.00e+00               0.00e+00

# %%
#_D5

BB1_D5 = BB5[["Unnamed: 0","Bookings \n(RM 'mil)","Total Exposure\n (RM 'mil)","Outstanding \n(RM 'mil)"]].rename(columns={'Unnamed: 0':'Entity'})
BB1_D5.columns = BB1_D5.columns.str.replace("\n", "_")
BB2_D5 = BB1_D5.iloc[np.where(~(BB1_D5.Entity.isnull()))]
BB2_D5 = BB2_D5.assign(Entity1=t)
BB2_D5['Class'] = 'BB'


BBHP1_D5 = BBHP5[["Unnamed: 0","Bookings \n(RM 'mil)","Total Exposure\n (RM 'mil)","Outstanding \n(RM 'mil)"]].rename(columns={'Unnamed: 0':'Entity'})
BBHP1_D5.columns = BBHP1_D5.columns.str.replace("\n", "_")
BBHP2_D5 = BBHP1_D5.iloc[np.where(~(BBHP1_D5.Entity.isnull()))]
BBHP2_D5 = BBHP2_D5.assign(Entity1=t)
BBHP2_D5['Class'] = 'BB'


SME1_D5 = SME5[["Unnamed: 0","Bookings \n(RM 'mil)","Total Exposure\n (RM 'mil)","Outstanding \n(RM 'mil)"]].rename(columns={'Unnamed: 0':'Entity'})
SME1_D5.columns = SME1_D5.columns.str.replace("\n", "_")
SME2_D5 = SME1_D5.iloc[np.where(~(SME1_D5.Entity.isnull()))]
SME2_D5 = SME2_D5.assign(Entity1=t)
SME2_D5['Class'] = 'SME'


GB1_D5 = GB5[["Unnamed: 0","Bookings \n(RM 'mil)","Total Exposure\n (RM 'mil)","Outstanding \n(RM 'mil)"]].rename(columns={'Unnamed: 0':'Entity'})
GB1_D5.columns = GB1_D5.columns.str.replace("\n", "_")
GB2_D5 = GB1_D5.iloc[np.where(~(GB1_D5.Entity.isnull()))]
GB2_D5 = GB2_D5.assign(Entity1=t)
GB2_D5['Class'] = 'CB/GB'


frames_D5 = [ BB2_D5, BBHP2_D5, SME2_D5, GB2_D5] 
MGS_D5 = pd.concat(frames_D5)

MGS1_D5 = MGS_D5.groupby(['Class','Entity1','Entity']).sum().reset_index().sort_values(by=['Entity1'], ascending=[False])

MGS1_D5['Total Exposures w/o Bookings'] = MGS1_D5["Total Exposure_ (RM 'mil)"]-MGS1_D5["Bookings _(RM 'mil)"]

MGS1_D5['D5ate'] = D5

MGS1_D5.Entity = MGS1_D5.Entity.str.strip()

def utilization(Entity):
    if Entity == 'Construction':
        return 31700 
    elif Entity == 'Oil & Gas':
        return 37490 
    elif Entity == 'Oil Palm':
        return 30700
    elif Entity == 'Shipping':
        return 10110
    else:
        return 31700+37490+30700+10110
        
MGS1_D5['Limit/ThresholD5'] = MGS1_D5['Entity'].apply(utilization)
MGS1_D5['Utilization Exposures w/o bookings'] = MGS1_D5['Total Exposures w/o Bookings']/MGS1_D5['Limit/ThresholD5']
MGS1_D5['Utilization Exposures'] = MGS1_D5["Total Exposure_ (RM 'mil)"]/MGS1_D5['Limit/ThresholD5']

MGS2_D5 = MGS1_D5.iloc[np.where(MGS1_D5.Entity1!='Total')].sort_values(by=['Class','Entity1','Entity'],ascending=[True,True,True])

# %%
MGS2_D5
# Out:
#     Class                         Entity1        Entity  Bookings _(RM 'mil)  \
# 0      BB                  Bilateral Loan  Construction               258.47
# 1      BB                  Bilateral Loan     Oil & Gas                10.85
# 2      BB                  Bilateral Loan      Oil Palm               138.04
# 3      BB                  Bilateral Loan      Shipping                 0.00
# 4      BB  Fixed Income Secrurities (FIS)  Construction                 0.00
# 5      BB  Fixed Income Secrurities (FIS)     Oil & Gas                 0.00
# 6      BB  Fixed Income Secrurities (FIS)      Oil Palm                 0.00
# 7      BB  Fixed Income Secrurities (FIS)      Shipping                 0.00
# 11  CB/GB                  Bilateral Loan  Construction               100.00
# 12  CB/GB                  Bilateral Loan     Oil & Gas                 0.00
# 13  CB/GB                  Bilateral Loan      Oil Palm               516.00
# 14  CB/GB                  Bilateral Loan      Shipping                 0.00
# 15  CB/GB  Fixed Income Secrurities (FIS)  Construction                 0.00
# 16  CB/GB  Fixed Income Secrurities (FIS)     Oil & Gas                 0.00
# 17  CB/GB  Fixed Income Secrurities (FIS)      Oil Palm                 0.00
# 18  CB/GB  Fixed Income Secrurities (FIS)      Shipping                 0.00
# 22    SME                  Bilateral Loan  Construction               220.41
# 23    SME                  Bilateral Loan     Oil & Gas                 2.66
# 24    SME                  Bilateral Loan      Oil Palm                63.42
# 25    SME                  Bilateral Loan      Shipping                 5.76
# 26    SME  Fixed Income Secrurities (FIS)  Construction                 0.00
# 27    SME  Fixed Income Secrurities (FIS)     Oil & Gas                 0.00
# 28    SME  Fixed Income Secrurities (FIS)      Oil Palm                 0.00
# 29    SME  Fixed Income Secrurities (FIS)      Shipping                 0.00
#
#     Total Exposure_ (RM 'mil)  Outstanding _(RM 'mil)  \
# 0                     1934.74                  391.04
# 1                      158.50                   41.66
# 2                     1078.77                  394.37
# 3                       29.96                    8.87
# 4                        0.00                    0.00
# 5                        0.00                    0.00
# 6                        0.00                    0.00
# 7                        0.00                    0.00
# 11                    1926.11                  723.47
# 12                    6316.12                 1405.00
# 13                   11408.63                 6765.76
# 14                     184.14                   67.21
# 15                       0.00                    0.00
# 16                       0.00                    0.00
# 17                     105.00                  105.00
# 18                       0.00                    0.00
# 22                    1165.06                  763.86
# 23                      36.72                   26.28
# 24                     177.97                   99.22
# 25                      24.36                   12.92
# 26                       0.00                    0.00
# 27                       0.00                    0.00
# 28                       0.00                    0.00
# 29                       0.00                    0.00
#
#     Total Exposures w/o Bookings     D5ate  Limit/ThresholD5  \
# 0                        1676.27  Nov 2021             31700
# 1                         147.65  Nov 2021             37490
# 2                         940.72  Nov 2021             30700
# 3                          29.96  Nov 2021             10110
# 4                           0.00  Nov 2021             31700
# 5                           0.00  Nov 2021             37490
# 6                           0.00  Nov 2021             30700
# 7                           0.00  Nov 2021             10110
# 11                       1826.11  Nov 2021             31700
# 12                       6316.12  Nov 2021             37490
# 13                      10892.63  Nov 2021             30700
# 14                        184.14  Nov 2021             10110
# 15                          0.00  Nov 2021             31700
# 16                          0.00  Nov 2021             37490
# 17                        105.00  Nov 2021             30700
# 18                          0.00  Nov 2021             10110
# 22                        944.65  Nov 2021             31700
# 23                         34.06  Nov 2021             37490
# 24                        114.55  Nov 2021             30700
# 25                         18.60  Nov 2021             10110
# 26                          0.00  Nov 2021             31700
# 27                          0.00  Nov 2021             37490
# 28                          0.00  Nov 2021             30700
# 29                          0.00  Nov 2021             10110
#
#     Utilization Exposures w/o bookings  Utilization Exposures
# 0                             5.29e-02               6.10e-02
# 1                             3.94e-03               4.23e-03
# 2                             3.06e-02               3.51e-02
# 3                             2.96e-03               2.96e-03
# 4                             0.00e+00               0.00e+00
# 5                             0.00e+00               0.00e+00
# 6                             0.00e+00               0.00e+00
# 7                             0.00e+00               0.00e+00
# 11                            5.76e-02               6.08e-02
# 12                            1.68e-01               1.68e-01
# 13                            3.55e-01               3.72e-01
# 14                            1.82e-02               1.82e-02
# 15                            0.00e+00               0.00e+00
# 16                            0.00e+00               0.00e+00
# 17                            3.42e-03               3.42e-03
# 18                            0.00e+00               0.00e+00
# 22                            2.98e-02               3.68e-02
# 23                            9.09e-04               9.80e-04
# 24                            3.73e-03               5.80e-03
# 25                            1.84e-03               2.41e-03
# 26                            0.00e+00               0.00e+00
# 27                            0.00e+00               0.00e+00
# 28                            0.00e+00               0.00e+00
# 29                            0.00e+00               0.00e+00

# %%
#_D6

BB1_D6 = BB6[["Unnamed: 0","Bookings \n(RM 'mil)","Total Exposure\n (RM 'mil)","Outstanding \n(RM 'mil)"]].rename(columns={'Unnamed: 0':'Entity'})
BB1_D6.columns = BB1_D6.columns.str.replace("\n", "_")
BB2_D6 = BB1_D6.iloc[np.where(~(BB1_D6.Entity.isnull()))]
BB2_D6 = BB2_D6.assign(Entity1=t)
BB2_D6['Class'] = 'BB'


BBHP1_D6 = BBHP6[["Unnamed: 0","Bookings \n(RM 'mil)","Total Exposure\n (RM 'mil)","Outstanding \n(RM 'mil)"]].rename(columns={'Unnamed: 0':'Entity'})
BBHP1_D6.columns = BBHP1_D6.columns.str.replace("\n", "_")
BBHP2_D6 = BBHP1_D6.iloc[np.where(~(BBHP1_D6.Entity.isnull()))]
BBHP2_D6 = BBHP2_D6.assign(Entity1=t)
BBHP2_D6['Class'] = 'BB'


SME1_D6 = SME6[["Unnamed: 0","Bookings \n(RM 'mil)","Total Exposure\n (RM 'mil)","Outstanding \n(RM 'mil)"]].rename(columns={'Unnamed: 0':'Entity'})
SME1_D6.columns = SME1_D6.columns.str.replace("\n", "_")
SME2_D6 = SME1_D6.iloc[np.where(~(SME1_D6.Entity.isnull()))]
SME2_D6 = SME2_D6.assign(Entity1=t)
SME2_D6['Class'] = 'SME'


GB1_D6 = GB6[["Unnamed: 0","Bookings \n(RM 'mil)","Total Exposure\n (RM 'mil)","Outstanding \n(RM 'mil)"]].rename(columns={'Unnamed: 0':'Entity'})
GB1_D6.columns = GB1_D6.columns.str.replace("\n", "_")
GB2_D6 = GB1_D6.iloc[np.where(~(GB1_D6.Entity.isnull()))]
GB2_D6 = GB2_D6.assign(Entity1=t)
GB2_D6['Class'] = 'CB/GB'


frames_D6 = [ BB2_D6, BBHP2_D6, SME2_D6, GB2_D6] 
MGS_D6 = pd.concat(frames_D6)

MGS1_D6 = MGS_D6.groupby(['Class','Entity1','Entity']).sum().reset_index().sort_values(by=['Entity1'], ascending=[False])

MGS1_D6['Total Exposures w/o Bookings'] = MGS1_D6["Total Exposure_ (RM 'mil)"]-MGS1_D6["Bookings _(RM 'mil)"]

MGS1_D6['D6ate'] = D6

MGS1_D6.Entity = MGS1_D6.Entity.str.strip()

def utilization(Entity):
    if Entity == 'Construction':
        return 31700 
    elif Entity == 'Oil & Gas':
        return 37490 
    elif Entity == 'Oil Palm':
        return 30700
    elif Entity == 'Shipping':
        return 10110
    else:
        return 31700+37490+30700+10110
        
MGS1_D6['Limit/ThresholD6'] = MGS1_D6['Entity'].apply(utilization)
MGS1_D6['Utilization Exposures w/o bookings'] = MGS1_D6['Total Exposures w/o Bookings']/MGS1_D6['Limit/ThresholD6']
MGS1_D6['Utilization Exposures'] = MGS1_D6["Total Exposure_ (RM 'mil)"]/MGS1_D6['Limit/ThresholD6']

MGS2_D6 = MGS1_D6.iloc[np.where(MGS1_D6.Entity1!='Total')].sort_values(by=['Class','Entity1','Entity'],ascending=[True,True,True])

# %%
MGS2_D6
# Out:
#     Class                         Entity1        Entity  Bookings _(RM 'mil)  \
# 0      BB                  Bilateral Loan  Construction               278.28
# 1      BB                  Bilateral Loan     Oil & Gas                10.85
# 2      BB                  Bilateral Loan      Oil Palm               167.92
# 3      BB                  Bilateral Loan      Shipping                 0.00
# 4      BB  Fixed Income Secrurities (FIS)  Construction                 0.00
# 5      BB  Fixed Income Secrurities (FIS)     Oil & Gas                 0.00
# 6      BB  Fixed Income Secrurities (FIS)      Oil Palm                 0.00
# 7      BB  Fixed Income Secrurities (FIS)      Shipping                 0.00
# 11  CB/GB                  Bilateral Loan  Construction               100.00
# 12  CB/GB                  Bilateral Loan     Oil & Gas                 0.00
# 13  CB/GB                  Bilateral Loan      Oil Palm               516.00
# 14  CB/GB                  Bilateral Loan      Shipping                 0.00
# 15  CB/GB  Fixed Income Secrurities (FIS)  Construction                 0.00
# 16  CB/GB  Fixed Income Secrurities (FIS)     Oil & Gas                 0.00
# 17  CB/GB  Fixed Income Secrurities (FIS)      Oil Palm                 0.00
# 18  CB/GB  Fixed Income Secrurities (FIS)      Shipping                 0.00
# 22    SME                  Bilateral Loan  Construction               188.32
# 23    SME                  Bilateral Loan     Oil & Gas                 2.21
# 24    SME                  Bilateral Loan      Oil Palm                72.42
# 25    SME                  Bilateral Loan      Shipping                 0.30
# 26    SME  Fixed Income Secrurities (FIS)  Construction                 0.00
# 27    SME  Fixed Income Secrurities (FIS)     Oil & Gas                 0.00
# 28    SME  Fixed Income Secrurities (FIS)      Oil Palm                 0.00
# 29    SME  Fixed Income Secrurities (FIS)      Shipping                 0.00
#
#     Total Exposure_ (RM 'mil)  Outstanding _(RM 'mil)  \
# 0                     1954.85                  250.48
# 1                      158.64                   37.39
# 2                     1113.93                  350.11
# 3                       29.96                    8.63
# 4                        0.00                    0.00
# 5                        0.00                    0.00
# 6                        0.00                    0.00
# 7                        0.00                    0.00
# 11                    1926.11                  697.08
# 12                    6316.12                 1660.35
# 13                   11408.63                 5973.61
# 14                      79.28                   67.09
# 15                       0.00                    0.00
# 16                       0.00                    0.00
# 17                     105.00                  105.00
# 18                       0.00                    0.00
# 22                    1134.64                  764.39
# 23                      37.20                   27.20
# 24                     188.40                   99.51
# 25                      18.90                   13.22
# 26                       0.00                    0.00
# 27                       0.00                    0.00
# 28                       0.00                    0.00
# 29                       0.00                    0.00
#
#     Total Exposures w/o Bookings     D6ate  Limit/ThresholD6  \
# 0                        1676.58  Dec 2021             31700
# 1                         147.79  Dec 2021             37490
# 2                         946.00  Dec 2021             30700
# 3                          29.96  Dec 2021             10110
# 4                           0.00  Dec 2021             31700
# 5                           0.00  Dec 2021             37490
# 6                           0.00  Dec 2021             30700
# 7                           0.00  Dec 2021             10110
# 11                       1826.11  Dec 2021             31700
# 12                       6316.12  Dec 2021             37490
# 13                      10892.63  Dec 2021             30700
# 14                         79.28  Dec 2021             10110
# 15                          0.00  Dec 2021             31700
# 16                          0.00  Dec 2021             37490
# 17                        105.00  Dec 2021             30700
# 18                          0.00  Dec 2021             10110
# 22                        946.33  Dec 2021             31700
# 23                         34.99  Dec 2021             37490
# 24                        115.98  Dec 2021             30700
# 25                         18.60  Dec 2021             10110
# 26                          0.00  Dec 2021             31700
# 27                          0.00  Dec 2021             37490
# 28                          0.00  Dec 2021             30700
# 29                          0.00  Dec 2021             10110
#
#     Utilization Exposures w/o bookings  Utilization Exposures
# 0                             5.29e-02               6.17e-02
# 1                             3.94e-03               4.23e-03
# 2                             3.08e-02               3.63e-02
# 3                             2.96e-03               2.96e-03
# 4                             0.00e+00               0.00e+00
# 5                             0.00e+00               0.00e+00
# 6                             0.00e+00               0.00e+00
# 7                             0.00e+00               0.00e+00
# 11                            5.76e-02               6.08e-02
# 12                            1.68e-01               1.68e-01
# 13                            3.55e-01               3.72e-01
# 14                            7.84e-03               7.84e-03
# 15                            0.00e+00               0.00e+00
# 16                            0.00e+00               0.00e+00
# 17                            3.42e-03               3.42e-03
# 18                            0.00e+00               0.00e+00
# 22                            2.99e-02               3.58e-02
# 23                            9.33e-04               9.92e-04
# 24                            3.78e-03               6.14e-03
# 25                            1.84e-03               1.87e-03
# 26                            0.00e+00               0.00e+00
# 27                            0.00e+00               0.00e+00
# 28                            0.00e+00               0.00e+00
# 29                            0.00e+00               0.00e+00

# %%
#_D7

BB1_D7 = BB7[["Unnamed: 0","Bookings \n(RM 'mil)","Total Exposure\n (RM 'mil)","Outstanding \n(RM 'mil)"]].rename(columns={'Unnamed: 0':'Entity'})
BB1_D7.columns = BB1_D7.columns.str.replace("\n", "_")
BB2_D7 = BB1_D7.iloc[np.where(~(BB1_D7.Entity.isnull()))]
BB2_D7 = BB2_D7.assign(Entity1=t)
BB2_D7['Class'] = 'BB'


BBHP1_D7 = BBHP7[["Unnamed: 0","Bookings \n(RM 'mil)","Total Exposure\n (RM 'mil)","Outstanding \n(RM 'mil)"]].rename(columns={'Unnamed: 0':'Entity'})
BBHP1_D7.columns = BBHP1_D7.columns.str.replace("\n", "_")
BBHP2_D7 = BBHP1_D7.iloc[np.where(~(BBHP1_D7.Entity.isnull()))]
BBHP2_D7 = BBHP2_D7.assign(Entity1=t)
BBHP2_D7['Class'] = 'BB'


SME1_D7 = SME7[["Unnamed: 0","Bookings \n(RM 'mil)","Total Exposure\n (RM 'mil)","Outstanding \n(RM 'mil)"]].rename(columns={'Unnamed: 0':'Entity'})
SME1_D7.columns = SME1_D7.columns.str.replace("\n", "_")
SME2_D7 = SME1_D7.iloc[np.where(~(SME1_D7.Entity.isnull()))]
SME2_D7 = SME2_D7.assign(Entity1=t)
SME2_D7['Class'] = 'SME'


GB1_D7 = GB7[["Unnamed: 0","Bookings \n(RM 'mil)","Total Exposure\n (RM 'mil)","Outstanding \n(RM 'mil)"]].rename(columns={'Unnamed: 0':'Entity'})
GB1_D7.columns = GB1_D7.columns.str.replace("\n", "_")
GB2_D7 = GB1_D7.iloc[np.where(~(GB1_D7.Entity.isnull()))]
GB2_D7 = GB2_D7.assign(Entity1=t)
GB2_D7['Class'] = 'CB/GB'


frames_D7 = [ BB2_D7, BBHP2_D7, SME2_D7, GB2_D7] 
MGS_D7 = pd.concat(frames_D7)

MGS1_D7 = MGS_D7.groupby(['Class','Entity1','Entity']).sum().reset_index().sort_values(by=['Entity1'], ascending=[False])

MGS1_D7['Total Exposures w/o Bookings'] = MGS1_D7["Total Exposure_ (RM 'mil)"]-MGS1_D7["Bookings _(RM 'mil)"]

MGS1_D7['D7ate'] = D7

MGS1_D7.Entity = MGS1_D7.Entity.str.strip()

def utilization(Entity):
    if Entity == 'Construction':
        return 31700 
    elif Entity == 'Oil & Gas':
        return 37490 
    elif Entity == 'Oil Palm':
        return 30700
    elif Entity == 'Shipping':
        return 10110
    else:
        return 31700+37490+30700+10110
        
MGS1_D7['Limit/ThresholD7'] = MGS1_D7['Entity'].apply(utilization)
MGS1_D7['Utilization Exposures w/o bookings'] = MGS1_D7['Total Exposures w/o Bookings']/MGS1_D7['Limit/ThresholD7']
MGS1_D7['Utilization Exposures'] = MGS1_D7["Total Exposure_ (RM 'mil)"]/MGS1_D7['Limit/ThresholD7']

MGS2_D7 = MGS1_D7.iloc[np.where(MGS1_D7.Entity1!='Total')].sort_values(by=['Class','Entity1','Entity'],ascending=[True,True,True])

# %%
MGS2_D7
# Out:
#     Class                         Entity1        Entity  Bookings _(RM 'mil)  \
# 0      BB                  Bilateral Loan  Construction               296.47
# 1      BB                  Bilateral Loan     Oil & Gas                 0.85
# 2      BB                  Bilateral Loan      Oil Palm               111.46
# 3      BB                  Bilateral Loan      Shipping                 0.00
# 4      BB  Fixed Income Secrurities (FIS)  Construction                 0.00
# 5      BB  Fixed Income Secrurities (FIS)     Oil & Gas                 0.00
# 6      BB  Fixed Income Secrurities (FIS)      Oil Palm                 0.00
# 7      BB  Fixed Income Secrurities (FIS)      Shipping                 0.00
# 11  CB/GB                  Bilateral Loan  Construction               100.00
# 12  CB/GB                  Bilateral Loan     Oil & Gas                 0.00
# 13  CB/GB                  Bilateral Loan      Oil Palm               516.00
# 14  CB/GB                  Bilateral Loan      Shipping                 0.00
# 15  CB/GB  Fixed Income Secrurities (FIS)  Construction                 0.00
# 16  CB/GB  Fixed Income Secrurities (FIS)     Oil & Gas                 0.00
# 17  CB/GB  Fixed Income Secrurities (FIS)      Oil Palm                 0.00
# 18  CB/GB  Fixed Income Secrurities (FIS)      Shipping                 0.00
# 22    SME                  Bilateral Loan  Construction               200.18
# 23    SME                  Bilateral Loan     Oil & Gas                 2.21
# 24    SME                  Bilateral Loan      Oil Palm                85.20
# 25    SME                  Bilateral Loan      Shipping                 0.30
# 26    SME  Fixed Income Secrurities (FIS)  Construction                 0.00
# 27    SME  Fixed Income Secrurities (FIS)     Oil & Gas                 0.00
# 28    SME  Fixed Income Secrurities (FIS)      Oil Palm                 0.00
# 29    SME  Fixed Income Secrurities (FIS)      Shipping                 0.00
#
#     Total Exposure_ (RM 'mil)  Outstanding _(RM 'mil)  \
# 0                     1971.96                  392.17
# 1                      148.15                   41.44
# 2                     1035.16                  371.97
# 3                       29.20                    8.38
# 4                        0.00                    0.00
# 5                        0.00                    0.00
# 6                        0.00                    0.00
# 7                        0.00                    0.00
# 11                    1926.11                  690.04
# 12                    6316.12                 1650.15
# 13                   11408.63                 5899.21
# 14                      79.28                   66.72
# 15                       0.00                    0.00
# 16                       0.00                    0.00
# 17                     105.00                  105.00
# 18                       0.00                    0.00
# 22                    1146.50                  764.39
# 23                      37.20                   27.20
# 24                     201.18                   99.51
# 25                      18.90                   13.22
# 26                       0.00                    0.00
# 27                       0.00                    0.00
# 28                       0.00                    0.00
# 29                       0.00                    0.00
#
#     Total Exposures w/o Bookings     D7ate  Limit/ThresholD7  \
# 0                        1675.49  Jan 2022             31700
# 1                         147.30  Jan 2022             37490
# 2                         923.70  Jan 2022             30700
# 3                          29.20  Jan 2022             10110
# 4                           0.00  Jan 2022             31700
# 5                           0.00  Jan 2022             37490
# 6                           0.00  Jan 2022             30700
# 7                           0.00  Jan 2022             10110
# 11                       1826.11  Jan 2022             31700
# 12                       6316.12  Jan 2022             37490
# 13                      10892.63  Jan 2022             30700
# 14                         79.28  Jan 2022             10110
# 15                          0.00  Jan 2022             31700
# 16                          0.00  Jan 2022             37490
# 17                        105.00  Jan 2022             30700
# 18                          0.00  Jan 2022             10110
# 22                        946.33  Jan 2022             31700
# 23                         34.99  Jan 2022             37490
# 24                        115.98  Jan 2022             30700
# 25                         18.60  Jan 2022             10110
# 26                          0.00  Jan 2022             31700
# 27                          0.00  Jan 2022             37490
# 28                          0.00  Jan 2022             30700
# 29                          0.00  Jan 2022             10110
#
#     Utilization Exposures w/o bookings  Utilization Exposures
# 0                             5.29e-02               6.22e-02
# 1                             3.93e-03               3.95e-03
# 2                             3.01e-02               3.37e-02
# 3                             2.89e-03               2.89e-03
# 4                             0.00e+00               0.00e+00
# 5                             0.00e+00               0.00e+00
# 6                             0.00e+00               0.00e+00
# 7                             0.00e+00               0.00e+00
# 11                            5.76e-02               6.08e-02
# 12                            1.68e-01               1.68e-01
# 13                            3.55e-01               3.72e-01
# 14                            7.84e-03               7.84e-03
# 15                            0.00e+00               0.00e+00
# 16                            0.00e+00               0.00e+00
# 17                            3.42e-03               3.42e-03
# 18                            0.00e+00               0.00e+00
# 22                            2.99e-02               3.62e-02
# 23                            9.33e-04               9.92e-04
# 24                            3.78e-03               6.55e-03
# 25                            1.84e-03               1.87e-03
# 26                            0.00e+00               0.00e+00
# 27                            0.00e+00               0.00e+00
# 28                            0.00e+00               0.00e+00
# 29                            0.00e+00               0.00e+00

# %%
#_D8

BB1_D8 = BB8[["Unnamed: 0","Bookings \n(RM 'mil)","Total Exposure\n (RM 'mil)","Outstanding \n(RM 'mil)"]].rename(columns={'Unnamed: 0':'Entity'})
BB1_D8.columns = BB1_D8.columns.str.replace("\n", "_")
BB2_D8 = BB1_D8.iloc[np.where(~(BB1_D8.Entity.isnull()))]
BB2_D8 = BB2_D8.assign(Entity1=t)
BB2_D8['Class'] = 'BB'


BBHP1_D8 = BBHP8[["Unnamed: 0","Bookings \n(RM 'mil)","Total Exposure\n (RM 'mil)","Outstanding \n(RM 'mil)"]].rename(columns={'Unnamed: 0':'Entity'})
BBHP1_D8.columns = BBHP1_D8.columns.str.replace("\n", "_")
BBHP2_D8 = BBHP1_D8.iloc[np.where(~(BBHP1_D8.Entity.isnull()))]
BBHP2_D8 = BBHP2_D8.assign(Entity1=t)
BBHP2_D8['Class'] = 'BB'


SME1_D8 = SME8[["Unnamed: 0","Bookings \n(RM 'mil)","Total Exposure\n (RM 'mil)","Outstanding \n(RM 'mil)"]].rename(columns={'Unnamed: 0':'Entity'})
SME1_D8.columns = SME1_D8.columns.str.replace("\n", "_")
SME2_D8 = SME1_D8.iloc[np.where(~(SME1_D8.Entity.isnull()))]
SME2_D8 = SME2_D8.assign(Entity1=t)
SME2_D8['Class'] = 'SME'


GB1_D8 = GB8[["Unnamed: 0","Bookings \n(RM 'mil)","Total Exposure\n (RM 'mil)","Outstanding \n(RM 'mil)"]].rename(columns={'Unnamed: 0':'Entity'})
GB1_D8.columns = GB1_D8.columns.str.replace("\n", "_")
GB2_D8 = GB1_D8.iloc[np.where(~(GB1_D8.Entity.isnull()))]
GB2_D8 = GB2_D8.assign(Entity1=t)
GB2_D8['Class'] = 'CB/GB'


frames_D8 = [ BB2_D8, BBHP2_D8, SME2_D8, GB2_D8] 
MGS_D8 = pd.concat(frames_D8)

MGS1_D8 = MGS_D8.groupby(['Class','Entity1','Entity']).sum().reset_index().sort_values(by=['Entity1'], ascending=[False])

MGS1_D8['Total Exposures w/o Bookings'] = MGS1_D8["Total Exposure_ (RM 'mil)"]-MGS1_D8["Bookings _(RM 'mil)"]

MGS1_D8['D8ate'] = D8

MGS1_D8.Entity = MGS1_D8.Entity.str.strip()

def utilization(Entity):
    if Entity == 'Construction':
        return 31700 
    elif Entity == 'Oil & Gas':
        return 37490 
    elif Entity == 'Oil Palm':
        return 30700
    elif Entity == 'Shipping':
        return 10110
    else:
        return 31700+37490+30700+10110
        
MGS1_D8['Limit/ThresholD8'] = MGS1_D8['Entity'].apply(utilization)
MGS1_D8['Utilization Exposures w/o bookings'] = MGS1_D8['Total Exposures w/o Bookings']/MGS1_D8['Limit/ThresholD8']
MGS1_D8['Utilization Exposures'] = MGS1_D8["Total Exposure_ (RM 'mil)"]/MGS1_D8['Limit/ThresholD8']

MGS2_D8 = MGS1_D8.iloc[np.where(MGS1_D8.Entity1!='Total')].sort_values(by=['Class','Entity1','Entity'],ascending=[True,True,True])

# %%
MGS2_D8
# Out:
#     Class                         Entity1        Entity  Bookings _(RM 'mil)  \
# 0      BB                  Bilateral Loan  Construction               297.49
# 1      BB                  Bilateral Loan     Oil & Gas                 0.85
# 2      BB                  Bilateral Loan      Oil Palm               113.62
# 3      BB                  Bilateral Loan      Shipping                 0.00
# 4      BB  Fixed Income Secrurities (FIS)  Construction                 0.00
# 5      BB  Fixed Income Secrurities (FIS)     Oil & Gas                 0.00
# 6      BB  Fixed Income Secrurities (FIS)      Oil Palm                 0.00
# 7      BB  Fixed Income Secrurities (FIS)      Shipping                 0.00
# 11  CB/GB                  Bilateral Loan  Construction               100.00
# 12  CB/GB                  Bilateral Loan     Oil & Gas               192.00
# 13  CB/GB                  Bilateral Loan      Oil Palm               516.00
# 14  CB/GB                  Bilateral Loan      Shipping                 0.00
# 15  CB/GB  Fixed Income Secrurities (FIS)  Construction                 0.00
# 16  CB/GB  Fixed Income Secrurities (FIS)     Oil & Gas                 0.00
# 17  CB/GB  Fixed Income Secrurities (FIS)      Oil Palm                 0.00
# 18  CB/GB  Fixed Income Secrurities (FIS)      Shipping                 0.00
# 22    SME                  Bilateral Loan  Construction               212.04
# 23    SME                  Bilateral Loan     Oil & Gas                 2.21
# 24    SME                  Bilateral Loan      Oil Palm                86.70
# 25    SME                  Bilateral Loan      Shipping                 0.30
# 26    SME  Fixed Income Secrurities (FIS)  Construction                 0.00
# 27    SME  Fixed Income Secrurities (FIS)     Oil & Gas                 0.00
# 28    SME  Fixed Income Secrurities (FIS)      Oil Palm                 0.00
# 29    SME  Fixed Income Secrurities (FIS)      Shipping                 0.00
#
#     Total Exposure_ (RM 'mil)  Outstanding _(RM 'mil)  \
# 0                     1974.13                  244.69
# 1                      148.15                   36.25
# 2                     1037.31                  348.39
# 3                       29.20                    8.13
# 4                        0.00                    0.00
# 5                        0.00                    0.00
# 6                        0.00                    0.00
# 7                        0.00                    0.00
# 11                    1926.11                  695.70
# 12                    6094.66                 1663.39
# 13                   11408.63                 5935.87
# 14                      79.28                   66.34
# 15                       0.00                    0.00
# 16                     500.00                  500.00
# 17                     105.00                  105.00
# 18                       0.00                    0.00
# 22                    1158.36                  764.39
# 23                      37.20                   27.20
# 24                     202.68                   99.51
# 25                      18.90                   13.22
# 26                       0.00                    0.00
# 27                       0.00                    0.00
# 28                       0.00                    0.00
# 29                       0.00                    0.00
#
#     Total Exposures w/o Bookings     D8ate  Limit/ThresholD8  \
# 0                        1676.64  Feb 2022             31700
# 1                         147.30  Feb 2022             37490
# 2                         923.70  Feb 2022             30700
# 3                          29.20  Feb 2022             10110
# 4                           0.00  Feb 2022             31700
# 5                           0.00  Feb 2022             37490
# 6                           0.00  Feb 2022             30700
# 7                           0.00  Feb 2022             10110
# 11                       1826.11  Feb 2022             31700
# 12                       5902.66  Feb 2022             37490
# 13                      10892.63  Feb 2022             30700
# 14                         79.28  Feb 2022             10110
# 15                          0.00  Feb 2022             31700
# 16                        500.00  Feb 2022             37490
# 17                        105.00  Feb 2022             30700
# 18                          0.00  Feb 2022             10110
# 22                        946.33  Feb 2022             31700
# 23                         34.99  Feb 2022             37490
# 24                        115.98  Feb 2022             30700
# 25                         18.60  Feb 2022             10110
# 26                          0.00  Feb 2022             31700
# 27                          0.00  Feb 2022             37490
# 28                          0.00  Feb 2022             30700
# 29                          0.00  Feb 2022             10110
#
#     Utilization Exposures w/o bookings  Utilization Exposures
# 0                             5.29e-02               6.23e-02
# 1                             3.93e-03               3.95e-03
# 2                             3.01e-02               3.38e-02
# 3                             2.89e-03               2.89e-03
# 4                             0.00e+00               0.00e+00
# 5                             0.00e+00               0.00e+00
# 6                             0.00e+00               0.00e+00
# 7                             0.00e+00               0.00e+00
# 11                            5.76e-02               6.08e-02
# 12                            1.57e-01               1.63e-01
# 13                            3.55e-01               3.72e-01
# 14                            7.84e-03               7.84e-03
# 15                            0.00e+00               0.00e+00
# 16                            1.33e-02               1.33e-02
# 17                            3.42e-03               3.42e-03
# 18                            0.00e+00               0.00e+00
# 22                            2.99e-02               3.65e-02
# 23                            9.33e-04               9.92e-04
# 24                            3.78e-03               6.60e-03
# 25                            1.84e-03               1.87e-03
# 26                            0.00e+00               0.00e+00
# 27                            0.00e+00               0.00e+00
# 28                            0.00e+00               0.00e+00
# 29                            0.00e+00               0.00e+00

# %%
#_D9

BB1_D9 = BB9[["Unnamed: 0","Bookings \n(RM 'mil)","Total Exposure\n (RM 'mil)","Outstanding \n(RM 'mil)"]].rename(columns={'Unnamed: 0':'Entity'})
BB1_D9.columns = BB1_D9.columns.str.replace("\n", "_")
BB2_D9 = BB1_D9.iloc[np.where(~(BB1_D9.Entity.isnull()))]
BB2_D9 = BB2_D9.assign(Entity1=t)
BB2_D9['Class'] = 'BB'


BBHP1_D9 = BBHP9[["Unnamed: 0","Bookings \n(RM 'mil)","Total Exposure\n (RM 'mil)","Outstanding \n(RM 'mil)"]].rename(columns={'Unnamed: 0':'Entity'})
BBHP1_D9.columns = BBHP1_D9.columns.str.replace("\n", "_")
BBHP2_D9 = BBHP1_D9.iloc[np.where(~(BBHP1_D9.Entity.isnull()))]
BBHP2_D9 = BBHP2_D9.assign(Entity1=t)
BBHP2_D9['Class'] = 'BB'


SME1_D9 = SME9[["Unnamed: 0","Bookings \n(RM 'mil)","Total Exposure\n (RM 'mil)","Outstanding \n(RM 'mil)"]].rename(columns={'Unnamed: 0':'Entity'})
SME1_D9.columns = SME1_D9.columns.str.replace("\n", "_")
SME2_D9 = SME1_D9.iloc[np.where(~(SME1_D9.Entity.isnull()))]
SME2_D9 = SME2_D9.assign(Entity1=t)
SME2_D9['Class'] = 'SME'


GB1_D9 = GB9[["Unnamed: 0","Bookings \n(RM 'mil)","Total Exposure\n (RM 'mil)","Outstanding \n(RM 'mil)"]].rename(columns={'Unnamed: 0':'Entity'})
GB1_D9.columns = GB1_D9.columns.str.replace("\n", "_")
GB2_D9 = GB1_D9.iloc[np.where(~(GB1_D9.Entity.isnull()))]
GB2_D9 = GB2_D9.assign(Entity1=t)
GB2_D9['Class'] = 'CB/GB'


frames_D9 = [ BB2_D9, BBHP2_D9, SME2_D9, GB2_D9] 
MGS_D9 = pd.concat(frames_D9)

MGS1_D9 = MGS_D9.groupby(['Class','Entity1','Entity']).sum().reset_index().sort_values(by=['Entity1'], ascending=[False])

MGS1_D9['Total Exposures w/o Bookings'] = MGS1_D9["Total Exposure_ (RM 'mil)"]-MGS1_D9["Bookings _(RM 'mil)"]

MGS1_D9['D9ate'] = D9

MGS1_D9.Entity = MGS1_D9.Entity.str.strip()

def utilization(Entity):
    if Entity == 'Construction':
        return 31700 
    elif Entity == 'Oil & Gas':
        return 37490 
    elif Entity == 'Oil Palm':
        return 30700
    elif Entity == 'Shipping':
        return 10110
    else:
        return 31700+37490+30700+10110
        
MGS1_D9['Limit/ThresholD9'] = MGS1_D9['Entity'].apply(utilization)
MGS1_D9['Utilization Exposures w/o bookings'] = MGS1_D9['Total Exposures w/o Bookings']/MGS1_D9['Limit/ThresholD9']
MGS1_D9['Utilization Exposures'] = MGS1_D9["Total Exposure_ (RM 'mil)"]/MGS1_D9['Limit/ThresholD9']

MGS2_D9 = MGS1_D9.iloc[np.where(MGS1_D9.Entity1!='Total')].sort_values(by=['Class','Entity1','Entity'],ascending=[True,True,True])

# %%
MGS2_D9
# Out:
#     Class                         Entity1        Entity  Bookings _(RM 'mil)  \
# 0      BB                  Bilateral Loan  Construction               315.28
# 1      BB                  Bilateral Loan     Oil & Gas                 0.85
# 2      BB                  Bilateral Loan      Oil Palm               115.85
# 3      BB                  Bilateral Loan      Shipping                 0.00
# 4      BB  Fixed Income Secrurities (FIS)  Construction                 0.00
# 5      BB  Fixed Income Secrurities (FIS)     Oil & Gas                 0.00
# 6      BB  Fixed Income Secrurities (FIS)      Oil Palm                 0.00
# 7      BB  Fixed Income Secrurities (FIS)      Shipping                 0.00
# 11  CB/GB                  Bilateral Loan  Construction               100.00
# 12  CB/GB                  Bilateral Loan     Oil & Gas               192.00
# 13  CB/GB                  Bilateral Loan      Oil Palm               516.00
# 14  CB/GB                  Bilateral Loan      Shipping                 0.00
# 15  CB/GB  Fixed Income Secrurities (FIS)  Construction                 0.00
# 16  CB/GB  Fixed Income Secrurities (FIS)     Oil & Gas                 0.00
# 17  CB/GB  Fixed Income Secrurities (FIS)      Oil Palm                 0.00
# 18  CB/GB  Fixed Income Secrurities (FIS)      Shipping                 0.00
# 22    SME                  Bilateral Loan  Construction               227.62
# 23    SME                  Bilateral Loan     Oil & Gas                 4.71
# 24    SME                  Bilateral Loan      Oil Palm                93.15
# 25    SME                  Bilateral Loan      Shipping                 0.30
# 26    SME  Fixed Income Secrurities (FIS)  Construction                 0.00
# 27    SME  Fixed Income Secrurities (FIS)     Oil & Gas                 0.00
# 28    SME  Fixed Income Secrurities (FIS)      Oil Palm                 0.00
# 29    SME  Fixed Income Secrurities (FIS)      Shipping                 0.00
#
#     Total Exposure_ (RM 'mil)  Outstanding _(RM 'mil)  \
# 0                     1991.79                  260.15
# 1                      148.06                   36.46
# 2                     1031.39                  346.31
# 3                       28.86                    8.04
# 4                        0.00                    0.00
# 5                        0.00                    0.00
# 6                        0.00                    0.00
# 7                        0.00                    0.00
# 11                    1926.11                  726.25
# 12                    6094.66                 1644.61
# 13                   11235.04                 5907.65
# 14                      79.28                   65.97
# 15                       0.00                    0.00
# 16                     500.00                  500.00
# 17                     105.00                  105.00
# 18                       0.00                    0.00
# 22                    1173.94                  764.39
# 23                      39.70                   27.20
# 24                     209.13                   99.51
# 25                      18.90                   13.22
# 26                       0.00                    0.00
# 27                       0.00                    0.00
# 28                       0.00                    0.00
# 29                       0.00                    0.00
#
#     Total Exposures w/o Bookings     D9ate  Limit/ThresholD9  \
# 0                        1676.51  Mar 2022             31700
# 1                         147.21  Mar 2022             37490
# 2                         915.54  Mar 2022             30700
# 3                          28.86  Mar 2022             10110
# 4                           0.00  Mar 2022             31700
# 5                           0.00  Mar 2022             37490
# 6                           0.00  Mar 2022             30700
# 7                           0.00  Mar 2022             10110
# 11                       1826.11  Mar 2022             31700
# 12                       5902.66  Mar 2022             37490
# 13                      10719.04  Mar 2022             30700
# 14                         79.28  Mar 2022             10110
# 15                          0.00  Mar 2022             31700
# 16                        500.00  Mar 2022             37490
# 17                        105.00  Mar 2022             30700
# 18                          0.00  Mar 2022             10110
# 22                        946.33  Mar 2022             31700
# 23                         34.99  Mar 2022             37490
# 24                        115.98  Mar 2022             30700
# 25                         18.60  Mar 2022             10110
# 26                          0.00  Mar 2022             31700
# 27                          0.00  Mar 2022             37490
# 28                          0.00  Mar 2022             30700
# 29                          0.00  Mar 2022             10110
#
#     Utilization Exposures w/o bookings  Utilization Exposures
# 0                             5.29e-02               6.28e-02
# 1                             3.93e-03               3.95e-03
# 2                             2.98e-02               3.36e-02
# 3                             2.85e-03               2.85e-03
# 4                             0.00e+00               0.00e+00
# 5                             0.00e+00               0.00e+00
# 6                             0.00e+00               0.00e+00
# 7                             0.00e+00               0.00e+00
# 11                            5.76e-02               6.08e-02
# 12                            1.57e-01               1.63e-01
# 13                            3.49e-01               3.66e-01
# 14                            7.84e-03               7.84e-03
# 15                            0.00e+00               0.00e+00
# 16                            1.33e-02               1.33e-02
# 17                            3.42e-03               3.42e-03
# 18                            0.00e+00               0.00e+00
# 22                            2.99e-02               3.70e-02
# 23                            9.33e-04               1.06e-03
# 24                            3.78e-03               6.81e-03
# 25                            1.84e-03               1.87e-03
# 26                            0.00e+00               0.00e+00
# 27                            0.00e+00               0.00e+00
# 28                            0.00e+00               0.00e+00
# 29                            0.00e+00               0.00e+00

# %%
#_D10

BB1_D10 = BB10[["Unnamed: 0","Bookings \n(RM 'mil)","Total Exposure\n (RM 'mil)","Outstanding \n(RM 'mil)"]].rename(columns={'Unnamed: 0':'Entity'})
BB1_D10.columns = BB1_D10.columns.str.replace("\n", "_")
BB2_D10 = BB1_D10.iloc[np.where(~(BB1_D10.Entity.isnull()))]
BB2_D10 = BB2_D10.assign(Entity1=t)
BB2_D10['Class'] = 'BB'


BBHP1_D10 = BBHP10[["Unnamed: 0","Bookings \n(RM 'mil)","Total Exposure\n (RM 'mil)","Outstanding \n(RM 'mil)"]].rename(columns={'Unnamed: 0':'Entity'})
BBHP1_D10.columns = BBHP1_D10.columns.str.replace("\n", "_")
BBHP2_D10 = BBHP1_D10.iloc[np.where(~(BBHP1_D10.Entity.isnull()))]
BBHP2_D10 = BBHP2_D10.assign(Entity1=t)
BBHP2_D10['Class'] = 'BB'


SME1_D10 = SME10[["Unnamed: 0","Bookings \n(RM 'mil)","Total Exposure\n (RM 'mil)","Outstanding \n(RM 'mil)"]].rename(columns={'Unnamed: 0':'Entity'})
SME1_D10.columns = SME1_D10.columns.str.replace("\n", "_")
SME2_D10 = SME1_D10.iloc[np.where(~(SME1_D10.Entity.isnull()))]
SME2_D10 = SME2_D10.assign(Entity1=t)
SME2_D10['Class'] = 'SME'


GB1_D10 = GB10[["Unnamed: 0","Bookings \n(RM 'mil)","Total Exposure\n (RM 'mil)","Outstanding \n(RM 'mil)"]].rename(columns={'Unnamed: 0':'Entity'})
GB1_D10.columns = GB1_D10.columns.str.replace("\n", "_")
GB2_D10 = GB1_D10.iloc[np.where(~(GB1_D10.Entity.isnull()))]
GB2_D10 = GB2_D10.assign(Entity1=t)
GB2_D10['Class'] = 'CB/GB'


frames_D10 = [ BB2_D10, BBHP2_D10, SME2_D10, GB2_D10] 
MGS_D10 = pd.concat(frames_D10)

MGS1_D10 = MGS_D10.groupby(['Class','Entity1','Entity']).sum().reset_index().sort_values(by=['Entity1'], ascending=[False])

MGS1_D10['Total Exposures w/o Bookings'] = MGS1_D10["Total Exposure_ (RM 'mil)"]-MGS1_D10["Bookings _(RM 'mil)"]

MGS1_D10['D10ate'] = D10

MGS1_D10.Entity = MGS1_D10.Entity.str.strip()

def utilization(Entity):
    if Entity == 'Construction':
        return 31700 
    elif Entity == 'Oil & Gas':
        return 37490 
    elif Entity == 'Oil Palm':
        return 30700
    elif Entity == 'Shipping':
        return 10110
    else:
        return 31700+37490+30700+10110
        
MGS1_D10['Limit/ThresholD10'] = MGS1_D10['Entity'].apply(utilization)
MGS1_D10['Utilization Exposures w/o bookings'] = MGS1_D10['Total Exposures w/o Bookings']/MGS1_D10['Limit/ThresholD10']
MGS1_D10['Utilization Exposures'] = MGS1_D10["Total Exposure_ (RM 'mil)"]/MGS1_D10['Limit/ThresholD10']

MGS2_D10 = MGS1_D10.iloc[np.where(MGS1_D10.Entity1!='Total')].sort_values(by=['Class','Entity1','Entity'],ascending=[True,True,True])

# %%
MGS2_D10
# Out:
#     Class                         Entity1        Entity  Bookings _(RM 'mil)  \
# 0      BB                  Bilateral Loan  Construction                69.32
# 1      BB                  Bilateral Loan     Oil & Gas                 0.00
# 2      BB                  Bilateral Loan      Oil Palm                83.67
# 3      BB                  Bilateral Loan      Shipping                 0.00
# 4      BB  Fixed Income Secrurities (FIS)  Construction                 0.00
# 5      BB  Fixed Income Secrurities (FIS)     Oil & Gas                 0.00
# 6      BB  Fixed Income Secrurities (FIS)      Oil Palm                 0.00
# 7      BB  Fixed Income Secrurities (FIS)      Shipping                 0.00
# 11  CB/GB                  Bilateral Loan  Construction               100.00
# 12  CB/GB                  Bilateral Loan     Oil & Gas               192.00
# 13  CB/GB                  Bilateral Loan      Oil Palm              1296.00
# 14  CB/GB                  Bilateral Loan      Shipping                 0.00
# 15  CB/GB  Fixed Income Secrurities (FIS)  Construction                 0.00
# 16  CB/GB  Fixed Income Secrurities (FIS)     Oil & Gas                 0.00
# 17  CB/GB  Fixed Income Secrurities (FIS)      Oil Palm                 0.00
# 18  CB/GB  Fixed Income Secrurities (FIS)      Shipping                 0.00
# 22    SME                  Bilateral Loan  Construction                86.67
# 23    SME                  Bilateral Loan     Oil & Gas                 0.00
# 24    SME                  Bilateral Loan      Oil Palm                31.03
# 25    SME                  Bilateral Loan      Shipping                 0.30
# 26    SME  Fixed Income Secrurities (FIS)  Construction                 0.00
# 27    SME  Fixed Income Secrurities (FIS)     Oil & Gas                 0.00
# 28    SME  Fixed Income Secrurities (FIS)      Oil Palm                 0.00
# 29    SME  Fixed Income Secrurities (FIS)      Shipping                 0.00
#
#     Total Exposure_ (RM 'mil)  Outstanding _(RM 'mil)  \
# 0                     1973.83                  420.37
# 1                      146.94                   35.14
# 2                     1023.36                  348.77
# 3                       28.72                    7.90
# 4                        0.00                    0.00
# 5                        0.00                    0.00
# 6                        0.00                    0.00
# 7                        0.00                    0.00
# 11                    1926.11                  713.40
# 12                    6093.32                 1658.96
# 13                   12015.04                 5939.51
# 14                      78.43                   49.14
# 15                       0.00                    0.00
# 16                     500.00                  500.00
# 17                     105.00                  105.00
# 18                       0.00                    0.00
# 22                    1029.05                  760.01
# 23                      32.82                   25.40
# 24                     203.34                  140.54
# 25                      18.80                   13.12
# 26                       0.00                    0.00
# 27                       0.00                    0.00
# 28                       0.00                    0.00
# 29                       0.00                    0.00
#
#     Total Exposures w/o Bookings    D10ate  Limit/ThresholD10  \
# 0                        1904.51  Apr 2022              31700
# 1                         146.94  Apr 2022              37490
# 2                         939.68  Apr 2022              30700
# 3                          28.72  Apr 2022              10110
# 4                           0.00  Apr 2022              31700
# 5                           0.00  Apr 2022              37490
# 6                           0.00  Apr 2022              30700
# 7                           0.00  Apr 2022              10110
# 11                       1826.11  Apr 2022              31700
# 12                       5901.32  Apr 2022              37490
# 13                      10719.04  Apr 2022              30700
# 14                         78.43  Apr 2022              10110
# 15                          0.00  Apr 2022              31700
# 16                        500.00  Apr 2022              37490
# 17                        105.00  Apr 2022              30700
# 18                          0.00  Apr 2022              10110
# 22                        942.38  Apr 2022              31700
# 23                         32.82  Apr 2022              37490
# 24                        172.31  Apr 2022              30700
# 25                         18.49  Apr 2022              10110
# 26                          0.00  Apr 2022              31700
# 27                          0.00  Apr 2022              37490
# 28                          0.00  Apr 2022              30700
# 29                          0.00  Apr 2022              10110
#
#     Utilization Exposures w/o bookings  Utilization Exposures
# 0                             6.01e-02               6.23e-02
# 1                             3.92e-03               3.92e-03
# 2                             3.06e-02               3.33e-02
# 3                             2.84e-03               2.84e-03
# 4                             0.00e+00               0.00e+00
# 5                             0.00e+00               0.00e+00
# 6                             0.00e+00               0.00e+00
# 7                             0.00e+00               0.00e+00
# 11                            5.76e-02               6.08e-02
# 12                            1.57e-01               1.63e-01
# 13                            3.49e-01               3.91e-01
# 14                            7.76e-03               7.76e-03
# 15                            0.00e+00               0.00e+00
# 16                            1.33e-02               1.33e-02
# 17                            3.42e-03               3.42e-03
# 18                            0.00e+00               0.00e+00
# 22                            2.97e-02               3.25e-02
# 23                            8.75e-04               8.75e-04
# 24                            5.61e-03               6.62e-03
# 25                            1.83e-03               1.86e-03
# 26                            0.00e+00               0.00e+00
# 27                            0.00e+00               0.00e+00
# 28                            0.00e+00               0.00e+00
# 29                            0.00e+00               0.00e+00

# %%
#_D11

BB1_D11 = BB11[["Unnamed: 0","Bookings \n(RM 'mil)","Total Exposure\n (RM 'mil)","Outstanding \n(RM 'mil)"]].rename(columns={'Unnamed: 0':'Entity'})
BB1_D11.columns = BB1_D11.columns.str.replace("\n", "_")
BB2_D11 = BB1_D11.iloc[np.where(~(BB1_D11.Entity.isnull()))]
BB2_D11 = BB2_D11.assign(Entity1=t)
BB2_D11['Class'] = 'BB'


BBHP1_D11 = BBHP11[["Unnamed: 0","Bookings \n(RM 'mil)","Total Exposure\n (RM 'mil)","Outstanding \n(RM 'mil)"]].rename(columns={'Unnamed: 0':'Entity'})
BBHP1_D11.columns = BBHP1_D11.columns.str.replace("\n", "_")
BBHP2_D11 = BBHP1_D11.iloc[np.where(~(BBHP1_D11.Entity.isnull()))]
BBHP2_D11 = BBHP2_D11.assign(Entity1=t)
BBHP2_D11['Class'] = 'BB'


SME1_D11 = SME11[["Unnamed: 0","Bookings \n(RM 'mil)","Total Exposure\n (RM 'mil)","Outstanding \n(RM 'mil)"]].rename(columns={'Unnamed: 0':'Entity'})
SME1_D11.columns = SME1_D11.columns.str.replace("\n", "_")
SME2_D11 = SME1_D11.iloc[np.where(~(SME1_D11.Entity.isnull()))]
SME2_D11 = SME2_D11.assign(Entity1=t)
SME2_D11['Class'] = 'SME'


GB1_D11 = GB11[["Unnamed: 0","Bookings \n(RM 'mil)","Total Exposure\n (RM 'mil)","Outstanding \n(RM 'mil)"]].rename(columns={'Unnamed: 0':'Entity'})
GB1_D11.columns = GB1_D11.columns.str.replace("\n", "_")
GB2_D11 = GB1_D11.iloc[np.where(~(GB1_D11.Entity.isnull()))]
GB2_D11 = GB2_D11.assign(Entity1=t)
GB2_D11['Class'] = 'CB/GB'


frames_D11 = [ BB2_D11, BBHP2_D11, SME2_D11, GB2_D11] 
MGS_D11 = pd.concat(frames_D11)

MGS1_D11 = MGS_D11.groupby(['Class','Entity1','Entity']).sum().reset_index().sort_values(by=['Entity1'], ascending=[False])

MGS1_D11['Total Exposures w/o Bookings'] = MGS1_D11["Total Exposure_ (RM 'mil)"]-MGS1_D11["Bookings _(RM 'mil)"]

MGS1_D11['D11ate'] = D11

MGS1_D11.Entity = MGS1_D11.Entity.str.strip()

def utilization(Entity):
    if Entity == 'Construction':
        return 31700 
    elif Entity == 'Oil & Gas':
        return 37490 
    elif Entity == 'Oil Palm':
        return 30700
    elif Entity == 'Shipping':
        return 10110
    else:
        return 31700+37490+30700+10110
        
MGS1_D11['Limit/ThresholD11'] = MGS1_D11['Entity'].apply(utilization)
MGS1_D11['Utilization Exposures w/o bookings'] = MGS1_D11['Total Exposures w/o Bookings']/MGS1_D11['Limit/ThresholD11']
MGS1_D11['Utilization Exposures'] = MGS1_D11["Total Exposure_ (RM 'mil)"]/MGS1_D11['Limit/ThresholD11']

MGS2_D11 = MGS1_D11.iloc[np.where(MGS1_D11.Entity1!='Total')].sort_values(by=['Class','Entity1','Entity'],ascending=[True,True,True])

# %%
MGS2_D11
# Out:
#     Class                         Entity1        Entity  Bookings _(RM 'mil)  \
# 0      BB                  Bilateral Loan  Construction               135.31
# 1      BB                  Bilateral Loan     Oil & Gas                 0.00
# 2      BB                  Bilateral Loan      Oil Palm                90.44
# 3      BB                  Bilateral Loan      Shipping                 0.00
# 4      BB  Fixed Income Secrurities (FIS)  Construction                 0.00
# 5      BB  Fixed Income Secrurities (FIS)     Oil & Gas                 0.00
# 6      BB  Fixed Income Secrurities (FIS)      Oil Palm                 0.00
# 7      BB  Fixed Income Secrurities (FIS)      Shipping                 0.00
# 11  CB/GB                  Bilateral Loan  Construction               100.00
# 12  CB/GB                  Bilateral Loan     Oil & Gas               312.00
# 13  CB/GB                  Bilateral Loan      Oil Palm              1076.00
# 14  CB/GB                  Bilateral Loan      Shipping                 0.00
# 15  CB/GB  Fixed Income Secrurities (FIS)  Construction                 0.00
# 16  CB/GB  Fixed Income Secrurities (FIS)     Oil & Gas                 0.00
# 17  CB/GB  Fixed Income Secrurities (FIS)      Oil Palm                 0.00
# 18  CB/GB  Fixed Income Secrurities (FIS)      Shipping                 0.00
# 22    SME                  Bilateral Loan  Construction                96.10
# 23    SME                  Bilateral Loan     Oil & Gas                 0.50
# 24    SME                  Bilateral Loan      Oil Palm                44.60
# 25    SME                  Bilateral Loan      Shipping                 0.30
# 26    SME  Fixed Income Secrurities (FIS)  Construction                 0.00
# 27    SME  Fixed Income Secrurities (FIS)     Oil & Gas                 0.00
# 28    SME  Fixed Income Secrurities (FIS)      Oil Palm                 0.00
# 29    SME  Fixed Income Secrurities (FIS)      Shipping                 0.00
#
#     Total Exposure_ (RM 'mil)  Outstanding _(RM 'mil)  \
# 0                     2046.09                  165.04
# 1                      146.94                   31.28
# 2                     1041.28                  322.53
# 3                       28.72                    7.64
# 4                        0.00                    0.00
# 5                        0.00                    0.00
# 6                        0.00                    0.00
# 7                        0.00                    0.00
# 11                    1926.11                  665.45
# 12                    6213.32                 1653.67
# 13                   11795.04                 6184.92
# 14                      78.43                   48.50
# 15                       0.00                    0.00
# 16                     500.00                  500.00
# 17                     105.00                  105.00
# 18                       0.00                    0.00
# 22                    1032.95                  755.49
# 23                      32.43                   24.67
# 24                     216.91                  140.54
# 25                      18.80                   13.12
# 26                       0.00                    0.00
# 27                       0.00                    0.00
# 28                       0.00                    0.00
# 29                       0.00                    0.00
#
#     Total Exposures w/o Bookings    D11ate  Limit/ThresholD11  \
# 0                        1910.78  May 2022              31700
# 1                         146.94  May 2022              37490
# 2                         950.83  May 2022              30700
# 3                          28.72  May 2022              10110
# 4                           0.00  May 2022              31700
# 5                           0.00  May 2022              37490
# 6                           0.00  May 2022              30700
# 7                           0.00  May 2022              10110
# 11                       1826.11  May 2022              31700
# 12                       5901.32  May 2022              37490
# 13                      10719.04  May 2022              30700
# 14                         78.43  May 2022              10110
# 15                          0.00  May 2022              31700
# 16                        500.00  May 2022              37490
# 17                        105.00  May 2022              30700
# 18                          0.00  May 2022              10110
# 22                        936.84  May 2022              31700
# 23                         31.93  May 2022              37490
# 24                        172.31  May 2022              30700
# 25                         18.49  May 2022              10110
# 26                          0.00  May 2022              31700
# 27                          0.00  May 2022              37490
# 28                          0.00  May 2022              30700
# 29                          0.00  May 2022              10110
#
#     Utilization Exposures w/o bookings  Utilization Exposures
# 0                             6.03e-02               6.45e-02
# 1                             3.92e-03               3.92e-03
# 2                             3.10e-02               3.39e-02
# 3                             2.84e-03               2.84e-03
# 4                             0.00e+00               0.00e+00
# 5                             0.00e+00               0.00e+00
# 6                             0.00e+00               0.00e+00
# 7                             0.00e+00               0.00e+00
# 11                            5.76e-02               6.08e-02
# 12                            1.57e-01               1.66e-01
# 13                            3.49e-01               3.84e-01
# 14                            7.76e-03               7.76e-03
# 15                            0.00e+00               0.00e+00
# 16                            1.33e-02               1.33e-02
# 17                            3.42e-03               3.42e-03
# 18                            0.00e+00               0.00e+00
# 22                            2.96e-02               3.26e-02
# 23                            8.52e-04               8.65e-04
# 24                            5.61e-03               7.07e-03
# 25                            1.83e-03               1.86e-03
# 26                            0.00e+00               0.00e+00
# 27                            0.00e+00               0.00e+00
# 28                            0.00e+00               0.00e+00
# 29                            0.00e+00               0.00e+00

# %%
#_D12

BB1_D12 = BB12[["Unnamed: 0","Bookings \n(RM 'mil)","Total Exposure\n (RM 'mil)","Outstanding \n(RM 'mil)"]].rename(columns={'Unnamed: 0':'Entity'})
BB1_D12.columns = BB1_D12.columns.str.replace("\n", "_")
BB2_D12 = BB1_D12.iloc[np.where(~(BB1_D12.Entity.isnull()))]
BB2_D12 = BB2_D12.assign(Entity1=t)
BB2_D12['Class'] = 'BB'


BBHP1_D12 = BBHP12[["Unnamed: 0","Bookings \n(RM 'mil)","Total Exposure\n (RM 'mil)","Outstanding \n(RM 'mil)"]].rename(columns={'Unnamed: 0':'Entity'})
BBHP1_D12.columns = BBHP1_D12.columns.str.replace("\n", "_")
BBHP2_D12 = BBHP1_D12.iloc[np.where(~(BBHP1_D12.Entity.isnull()))]
BBHP2_D12 = BBHP2_D12.assign(Entity1=t)
BBHP2_D12['Class'] = 'BB'


SME1_D12 = SME12[["Unnamed: 0","Bookings \n(RM 'mil)","Total Exposure\n (RM 'mil)","Outstanding \n(RM 'mil)"]].rename(columns={'Unnamed: 0':'Entity'})
SME1_D12.columns = SME1_D12.columns.str.replace("\n", "_")
SME2_D12 = SME1_D12.iloc[np.where(~(SME1_D12.Entity.isnull()))]
SME2_D12 = SME2_D12.assign(Entity1=t)
SME2_D12['Class'] = 'SME'


GB1_D12 = GB12[["Unnamed: 0","Bookings \n(RM 'mil)","Total Exposure\n (RM 'mil)","Outstanding \n(RM 'mil)"]].rename(columns={'Unnamed: 0':'Entity'})
GB1_D12.columns = GB1_D12.columns.str.replace("\n", "_")
GB2_D12 = GB1_D12.iloc[np.where(~(GB1_D12.Entity.isnull()))]
GB2_D12 = GB2_D12.assign(Entity1=t)
GB2_D12['Class'] = 'CB/GB'


frames_D12 = [ BB2_D12, BBHP2_D12, SME2_D12, GB2_D12] 
MGS_D12 = pd.concat(frames_D12)

MGS1_D12 = MGS_D12.groupby(['Class','Entity1','Entity']).sum().reset_index().sort_values(by=['Entity1'], ascending=[False])

MGS1_D12['Total Exposures w/o Bookings'] = MGS1_D12["Total Exposure_ (RM 'mil)"]-MGS1_D12["Bookings _(RM 'mil)"]

MGS1_D12['D12ate'] = D12

MGS1_D12.Entity = MGS1_D12.Entity.str.strip()

def utilization(Entity):
    if Entity == 'Construction':
        return 31700 
    elif Entity == 'Oil & Gas':
        return 37490 
    elif Entity == 'Oil Palm':
        return 30700
    elif Entity == 'Shipping':
        return 10110
    else:
        return 31700+37490+30700+10110
        
MGS1_D12['Limit/ThresholD12'] = MGS1_D12['Entity'].apply(utilization)
MGS1_D12['Utilization Exposures w/o bookings'] = MGS1_D12['Total Exposures w/o Bookings']/MGS1_D12['Limit/ThresholD12']
MGS1_D12['Utilization Exposures'] = MGS1_D12["Total Exposure_ (RM 'mil)"]/MGS1_D12['Limit/ThresholD12']

MGS2_D12 = MGS1_D12.iloc[np.where(MGS1_D12.Entity1!='Total')].sort_values(by=['Class','Entity1','Entity'],ascending=[True,True,True])

# %%
MGS2_D12
# Out:
#     Class                         Entity1        Entity  Bookings _(RM 'mil)  \
# 0      BB                  Bilateral Loan  Construction               172.41
# 1      BB                  Bilateral Loan     Oil & Gas                 0.00
# 2      BB                  Bilateral Loan      Oil Palm                65.57
# 3      BB                  Bilateral Loan      Shipping                 0.00
# 4      BB  Fixed Income Secrurities (FIS)  Construction                 0.00
# 5      BB  Fixed Income Secrurities (FIS)     Oil & Gas                 0.00
# 6      BB  Fixed Income Secrurities (FIS)      Oil Palm                 0.00
# 7      BB  Fixed Income Secrurities (FIS)      Shipping                 0.00
# 11  CB/GB                  Bilateral Loan  Construction               190.00
# 12  CB/GB                  Bilateral Loan     Oil & Gas               812.00
# 13  CB/GB                  Bilateral Loan      Oil Palm              1076.00
# 14  CB/GB                  Bilateral Loan      Shipping                 0.00
# 15  CB/GB  Fixed Income Secrurities (FIS)  Construction                 0.00
# 16  CB/GB  Fixed Income Secrurities (FIS)     Oil & Gas                 0.00
# 17  CB/GB  Fixed Income Secrurities (FIS)      Oil Palm                 0.00
# 18  CB/GB  Fixed Income Secrurities (FIS)      Shipping                 0.00
# 22    SME                  Bilateral Loan  Construction               109.70
# 23    SME                  Bilateral Loan     Oil & Gas                 0.68
# 24    SME                  Bilateral Loan      Oil Palm                57.92
# 25    SME                  Bilateral Loan      Shipping                 0.30
# 26    SME  Fixed Income Secrurities (FIS)  Construction                 0.00
# 27    SME  Fixed Income Secrurities (FIS)     Oil & Gas                 0.00
# 28    SME  Fixed Income Secrurities (FIS)      Oil Palm                 0.00
# 29    SME  Fixed Income Secrurities (FIS)      Shipping                 0.00
#
#     Total Exposure_ (RM 'mil)  Outstanding _(RM 'mil)  \
# 0                     2082.01                  417.73
# 1                      146.64                   39.31
# 2                     1045.03                  365.60
# 3                       28.22                    7.40
# 4                        0.00                    0.00
# 5                        0.00                    0.00
# 6                        0.00                    0.00
# 7                        0.00                    0.00
# 11                    2016.11                  625.84
# 12                    8192.55                 1714.85
# 13                   11795.04                 5141.38
# 14                      78.43                   47.54
# 15                       0.00                    0.00
# 16                     500.00                  500.00
# 17                     105.00                  105.00
# 18                       0.00                    0.00
# 22                    1046.54                  755.49
# 23                      32.61                   24.67
# 24                     230.23                  140.54
# 25                      18.80                   13.12
# 26                       0.00                    0.00
# 27                       0.00                    0.00
# 28                       0.00                    0.00
# 29                       0.00                    0.00
#
#     Total Exposures w/o Bookings    D12ate  Limit/ThresholD12  \
# 0                        1909.60  Jun 2022              31700
# 1                         146.64  Jun 2022              37490
# 2                         979.46  Jun 2022              30700
# 3                          28.22  Jun 2022              10110
# 4                           0.00  Jun 2022              31700
# 5                           0.00  Jun 2022              37490
# 6                           0.00  Jun 2022              30700
# 7                           0.00  Jun 2022              10110
# 11                       1826.11  Jun 2022              31700
# 12                       7380.55  Jun 2022              37490
# 13                      10719.04  Jun 2022              30700
# 14                         78.43  Jun 2022              10110
# 15                          0.00  Jun 2022              31700
# 16                        500.00  Jun 2022              37490
# 17                        105.00  Jun 2022              30700
# 18                          0.00  Jun 2022              10110
# 22                        936.84  Jun 2022              31700
# 23                         31.93  Jun 2022              37490
# 24                        172.31  Jun 2022              30700
# 25                         18.49  Jun 2022              10110
# 26                          0.00  Jun 2022              31700
# 27                          0.00  Jun 2022              37490
# 28                          0.00  Jun 2022              30700
# 29                          0.00  Jun 2022              10110
#
#     Utilization Exposures w/o bookings  Utilization Exposures
# 0                             6.02e-02               6.57e-02
# 1                             3.91e-03               3.91e-03
# 2                             3.19e-02               3.40e-02
# 3                             2.79e-03               2.79e-03
# 4                             0.00e+00               0.00e+00
# 5                             0.00e+00               0.00e+00
# 6                             0.00e+00               0.00e+00
# 7                             0.00e+00               0.00e+00
# 11                            5.76e-02               6.36e-02
# 12                            1.97e-01               2.19e-01
# 13                            3.49e-01               3.84e-01
# 14                            7.76e-03               7.76e-03
# 15                            0.00e+00               0.00e+00
# 16                            1.33e-02               1.33e-02
# 17                            3.42e-03               3.42e-03
# 18                            0.00e+00               0.00e+00
# 22                            2.96e-02               3.30e-02
# 23                            8.52e-04               8.70e-04
# 24                            5.61e-03               7.50e-03
# 25                            1.83e-03               1.86e-03
# 26                            0.00e+00               0.00e+00
# 27                            0.00e+00               0.00e+00
# 28                            0.00e+00               0.00e+00
# 29                            0.00e+00               0.00e+00

# %%
MGS2_D.columns = MGS2_D1.columns = MGS2_D2.columns = MGS2_D3.columns = MGS2_D4.columns = MGS2_D5.columns = MGS2_D6.columns = MGS2_D7.columns = MGS2_D8.columns = MGS2_D9.columns = MGS2_D10.columns = MGS2_D11.columns = MGS2_D12.columns

frames_yearly = [MGS2_D,MGS2_D1,MGS2_D2,MGS2_D3,MGS2_D4,MGS2_D5,MGS2_D6,MGS2_D7,MGS2_D8,MGS2_D9,MGS2_D10,MGS2_D11,MGS2_D12] 
MGS__yearly = pd.concat(frames_yearly)

# %%
MGS__yearly.rename(columns= {'D12ate':'Date','Limit/ThresholD12':'Limit/Threshold'}, inplace=True)
MGS__yearly['date_time'] = pd.to_datetime(MGS__yearly['Date'], format='%b %Y')

# %%
MGS__yearly.Entity = MGS__yearly.Entity.str.strip()

Construction = MGS__yearly.iloc[np.where((MGS__yearly.Entity=='Construction')&(MGS__yearly.Date==D12))].groupby(['Class'])[["Total Exposure_ (RM 'mil)","Outstanding _(RM 'mil)","Bookings _(RM 'mil)"]].sum().reset_index()
Construction1 = MGS__yearly.iloc[np.where((MGS__yearly.Entity=='Oil Palm')&(MGS__yearly.Date==D12))].groupby(['Class'])[["Total Exposure_ (RM 'mil)","Outstanding _(RM 'mil)","Bookings _(RM 'mil)"]].sum().reset_index()
Construction2 = MGS__yearly.iloc[np.where((MGS__yearly.Entity=='Oil & Gas')&(MGS__yearly.Date==D12))].groupby(['Class'])[["Total Exposure_ (RM 'mil)","Outstanding _(RM 'mil)","Bookings _(RM 'mil)"]].sum().reset_index()
Construction3 = MGS__yearly.iloc[np.where((MGS__yearly.Entity=='Shipping')&(MGS__yearly.Date==D12))].groupby(['Class'])[["Total Exposure_ (RM 'mil)","Outstanding _(RM 'mil)","Bookings _(RM 'mil)"]].sum().reset_index()
Total = MGS__yearly.groupby(['date_time'])[["Bookings _(RM 'mil)","Total Exposure_ (RM 'mil)","Outstanding _(RM 'mil)","Total Exposures w/o Bookings","Utilization Exposures w/o bookings","Utilization Exposures"]].sum().reset_index().sort_values(by=['date_time'], ascending=[True])

# %%
Total1 = MGS__yearly.groupby(['date_time','Entity'])[["Bookings _(RM 'mil)","Total Exposure_ (RM 'mil)","Outstanding _(RM 'mil)","Total Exposures w/o Bookings","Utilization Exposures w/o bookings","Utilization Exposures"]].sum().reset_index().sort_values(by=['date_time'], ascending=[True])

# %%
Exposure_EN = Total1.pivot(index='Entity', columns='date_time', values="Total Exposure_ (RM 'mil)")

# %%
Exposure_EN
# Out:
# date_time     2021-06-01  2021-07-01  2021-08-01  2021-09-01  2021-10-01  \
# Entity
# Construction     4628.14     4727.79     4810.95     4840.15     4986.33
# Oil & Gas        6943.03     6770.68     6771.26     6771.51     6511.12
# Oil Palm        12383.64    12360.66    12541.72    12553.93    12763.34
# Shipping          271.19      271.31      238.36      238.34      238.45
#
# date_time     2021-11-01  2021-12-01  2022-01-01  2022-02-01  2022-03-01  \
# Entity
# Construction     5025.91     5015.61     5044.58     5058.61     5091.84
# Oil & Gas        6511.35     6511.95     6501.47     6780.01     6782.43
# Oil Palm        12770.37    12815.95    12749.96    12753.62    12580.56
# Shipping          238.45      128.14      127.38      127.38      127.04
#
# date_time     2022-04-01  2022-05-01  2022-06-01
# Entity
# Construction     4928.99     5005.14     5144.67
# Oil & Gas        6773.08     6892.69     8871.80
# Oil Palm        13346.74    13158.23    13175.30
# Shipping          125.95      125.95      125.44

# %%
Total2 = MGS__yearly.groupby(['date_time','Class'])[["Bookings _(RM 'mil)","Total Exposure_ (RM 'mil)","Outstanding _(RM 'mil)","Total Exposures w/o Bookings","Utilization Exposures w/o bookings","Utilization Exposures"]].sum().reset_index().sort_values(by=['date_time'], ascending=[True])

# %%
Class_EN = Total2.pivot(index='Class', columns='date_time', values="Total Exposure_ (RM 'mil)")
Class_EN
# Out:
# date_time  2021-06-01  2021-07-01  2021-08-01  2021-09-01  2021-10-01  \
# Class
# BB            3058.29     3074.50     3104.14     3129.80     3169.91
# CB/GB        19917.26    19757.26    19899.32    19899.32    19940.00
# SME           1250.45     1298.67     1358.82     1374.81     1389.33
#
# date_time  2021-11-01  2021-12-01  2022-01-01  2022-02-01  2022-03-01  \
# Class
# BB            3201.97     3257.37     3184.47     3188.79     3200.11
# CB/GB        19940.00    19835.14    19835.14    20113.68    19940.09
# SME           1404.11     1379.14     1403.78     1417.14     1441.67
#
# date_time  2022-04-01  2022-05-01  2022-06-01
# Class
# BB            3172.85     3263.02     3301.90
# CB/GB        20717.90    20617.90    22687.13
# SME           1284.01     1301.09     1328.18

# %%
writer = pd.ExcelWriter(r'T:\MIB Risk Management\CRM\23.0_MGS Sectoral\MGS_yearly('+D+'-'+D12+').xlsx', engine='xlsxwriter')

MGS__yearly.to_excel(writer, sheet_name='MGS listing', index = False)
Construction.to_excel(writer, sheet_name='Construction', index = False)
Construction1.to_excel(writer, sheet_name='Oil Palm', index = False)
Construction2.to_excel(writer, sheet_name='Oil & Gas', index = False)
Construction3.to_excel(writer, sheet_name='Shipping', index = False) 
Total.to_excel(writer, sheet_name='Total', index = False)

writer.save()

# %%
MGS__yearly.Entity = MGS__yearly.Entity.str.strip()

construction = MGS__yearly.iloc[np.where(MGS__yearly.Entity=='Total')].groupby(['Date']).sum().reset_index()
construction1 = MGS__yearly.iloc[np.where(MGS__yearly.Entity=='Bilateral Loan')].groupby(['Date']).sum().reset_index()
construction2 = MGS__yearly.iloc[np.where(MGS__yearly.Entity=='Fixed Income Secrurities (FIS)')].groupby(['Date']).sum().reset_index()
construction3 = MGS__yearly.iloc[np.where(MGS__yearly.Entity=='Oil & Gas')].groupby(['Date']).sum().reset_index()
construction4 = MGS__yearly.iloc[np.where(MGS__yearly.Entity=='Shipping')].groupby(['Date']).sum().reset_index()
construction5 = MGS__yearly.iloc[np.where(MGS__yearly.Entity=='Construction')].groupby(['Date']).sum().reset_index()
construction6 = MGS__yearly.iloc[np.where(MGS__yearly.Entity=='Oil Palm')].groupby(['Date']).sum().reset_index()

# %%
# bar_chart_legend.py

import matplotlib.pyplot as plt

def bar_chart(numbers, labels, pos):
    plt.bar(pos, [4, 5, 6, 3], color='green')
    plt.bar(pos, numbers, color='blue')
    plt.xticks(ticks=pos, labels=labels)
    plt.xlabel('Vehicle Types')
    plt.ylabel('Number of Vehicles')
    plt.legend(['First Label', 'Second Label'], loc='upper left')
    plt.show()

if __name__ == '__main__':
    numbers = [2, 1, 4, 6]
    labels = ['Electric', 'Solar', 'Diesel', 'Unleaded']
    pos = list(range(4))
    bar_chart(numbers, labels, pos)
