# %%
import numpy as np
import pandas as pd
import pandasql
import sqlite3

pd.set_option("display.max_columns", None) 
pd.set_option("display.max_colwidth", 1000) #huruf dlm column
pd.set_option("display.max_rows", 100)
pd.set_option("display.precision", 2) #2 titik perpuluhan

# %%
CB = pd.read_excel(r"T:\MIB Risk Management\Credit Risk Analytics - Historical\01_Reporting\01_Monthly_Reporting\18_Rating_CBBBRSME\BRR_CBBBRSME_202112(python).xlsx")

# %%
CB_source = pd.read_excel(r"T:\MIB Risk Management\Credit Risk Analytics - Historical\02_Data_Source\01_Corporate_Financing\01_Portfolio\20211231\GB Monthly Loan Outstanding as at 31-Dec-2021.xlsx")

# %%
CB_source.columns = CB_source.columns.str.upper()
CB_source.columns = CB_source.columns.str.replace(" ", "_")

# %%
CB_source1 = CB_source.iloc[np.where(CB_source.M_FINANCING_TYPE_CD=='I')].fillna(0).groupby(['M_CUS_NO','M_FINANCING_TYPE_CD'])[['M_BNM_BALANCE_SUM_1']].sum().reset_index()

# %%
CB_1 = CB.merge(CB_source1, on='M_CUS_NO', how='left', indicator=True)

# %%
CB_1.FINAL_RATING = CB_1.FINAL_RATING.str.strip()

CB_1.loc[CB_1.FINAL_RATING == '1', 'RAM'] = 'AAA'
CB_1.loc[CB_1.FINAL_RATING == '2', 'RAM'] = 'AAA'
CB_1.loc[CB_1.FINAL_RATING == '3', 'RAM'] = 'AAA'
CB_1.loc[CB_1.FINAL_RATING == '4', 'RAM'] = 'AA'
CB_1.loc[CB_1.FINAL_RATING == '5', 'RAM'] = 'AA'
CB_1.loc[CB_1.FINAL_RATING == '6', 'RAM'] = 'AA'
CB_1.loc[CB_1.FINAL_RATING == '7', 'RAM'] = 'AA'
CB_1.loc[CB_1.FINAL_RATING == '8', 'RAM'] = 'A'
CB_1.loc[CB_1.FINAL_RATING == '9', 'RAM'] = 'A'
CB_1.loc[CB_1.FINAL_RATING == '10', 'RAM'] = 'A'
CB_1.loc[CB_1.FINAL_RATING == '11', 'RAM'] = 'A'
CB_1.loc[CB_1.FINAL_RATING == '12', 'RAM'] = 'BBB'
CB_1.loc[CB_1.FINAL_RATING == '13', 'RAM'] = 'BBB'
CB_1.loc[CB_1.FINAL_RATING == '14', 'RAM'] = 'BBB'
CB_1.loc[CB_1.FINAL_RATING == '15', 'RAM'] = 'BB'
CB_1.loc[CB_1.FINAL_RATING == '16', 'RAM'] = 'BB'
CB_1.loc[CB_1.FINAL_RATING == '17', 'RAM'] = 'BB'
CB_1.loc[CB_1.FINAL_RATING == '18', 'RAM'] = 'BB'
CB_1.loc[CB_1.FINAL_RATING == '19', 'RAM'] = 'B'
CB_1.loc[CB_1.FINAL_RATING == '20', 'RAM'] = 'B'
CB_1.loc[CB_1.FINAL_RATING == '21', 'RAM'] = 'C'
CB_1.loc[CB_1.FINAL_RATING == '22', 'RAM'] = 'D'
CB_1.loc[CB_1.FINAL_RATING == '23', 'RAM'] = 'D'
CB_1.loc[CB_1.RAM.isna(), 'RAM'] = 'Unrated'

# %%
RPSIA = pd.read_excel(r"T:\MIB Risk Management\Credit Risk Analytics - Historical\01_Reporting\01_Monthly_Reporting\17_Sustainability_ESG high risk sectors\20220331\RPSIA Fikri\RPSIA_Mar22.xlsx", sheet_name='Sheet1')


RPSIA1 = RPSIA.fillna(0)#.groupby(['GCIF'])[['Outstanding']].sum().reset_index()

RPSIA1.GCIF = RPSIA1.GCIF.astype(str)
RPSIA1.GCIF = RPSIA1.GCIF.str.strip()
RPSIA1.GCIF = RPSIA1.GCIF.str.upper()

CB_1.M_CUS_NO = CB_1.M_CUS_NO.astype(str)
CB_1.M_CUS_NO = CB_1.M_CUS_NO.str.strip()
CB_1.M_CUS_NO = CB_1.M_CUS_NO.str.upper()

ex_RPSIA = CB_1.merge(RPSIA1[['GCIF']].drop_duplicates('GCIF').rename(columns={'GCIF':'M_CUS_NO'}), on='M_CUS_NO', how='left', indicator='True')

ex_RPSIA_FINAL = ex_RPSIA.iloc[np.where(ex_RPSIA['True']!='both')]

# %%
CB_2 = ex_RPSIA_FINAL.groupby(['RAM'])[['M_BNM_BALANCE_SUM_1']].sum().reset_index()

# %%
CB_RPSIA = ex_RPSIA.iloc[np.where(ex_RPSIA['True']=='both')]
CB_RPSIA
# Out:
#      M_CUS_NO                                      NAME BNM_SECTOR_CD  \
# 0    23549043  LEMBAGA PEMBIAYAAN PERUMAHAN SEKTOR AWAM         64999
# 1    20924517                      SAPURA TMC SDN. BHD.        0910XG
# 2     6903241                  PERMODALAN NASIONAL BHD.         64309
# 3    17997345  PERBADANAN TABUNG PENDIDIKAN TINGGI NASI         64999
# 4    11852516                          S P SETIA BERHAD        41001B
# 5     1153935                 PADIBERAS NASIONAL BERHAD         106XX
# 6    13251262                    PRASARANA MALAYSIA BHD         4911X
# 7    18174668        LEMBAGA KEMAJUAN TANAH PERSEKUTUAN        01261A
# 8    15499781              SIME DARBY PLANTATION BERHAD        01261B
# 11   24436602              MALAYSIA RAIL LINK SDN. BHD.        4210XC
# 12   22660558                        QSR STORES SDN BHD         56103
# 13   19492758                 TRURICH RESOURCES SDN BHD        01261A
# 15   15868077                    TENAGA NASIONAL BERHAD        3510XG
# 16   20861949                 EDOTCO MALAYSIA SDN. BHD.         6190X
# 17    4346602                          DRB-HICOM BERHAD         64200
# 18   17244961                       AXIATA GROUP BERHAD         6190X
# 21   15890763   PROJEK LINTASAN KOTA HOLDINGS SDN. BHD.         64200
# 24   24996495         PULAU INDAH POWER PLANT SDN. BHD.        3510XC
# 25   21636663                     PJS DAMANSARA SDN BHD         68109
# 26   17199004                       FGV HOLDINGS BERHAD        10401A
# 35    1570868                   PETALING GARDEN SDN BHD        41001B
# 50    1491682            PONTIAN UNITED PLANTATIONS BHD        01261A
# 54   21493946                PR1MA CORPORATION MALAYSIA        41001C
# 100  18277935                   NORTHERN MALL SDN. BHD.        68102D
# 113   4134301      KUMPULAN PERUBATAN (JOHOR) SDN. BHD.         861XX
#
#                                                                                        SECTOR_DESC  \
# 0          OTHER FINANCIAL SERVICE ACTIVITIES, EXCEPT INSURANCE/TAKAFUL AND PENSION FUNDING N.E.C.
# 1                                         OTHER SUPPORT ACTIVITIES FOR OIL & GAS EXTRACTION N.E.C.
# 2                                              TRUSTS, FUNDS AND SIMILAR FINANCIAL ENTITIES N.E.C.
# 3          OTHER FINANCIAL SERVICE ACTIVITIES, EXCEPT INSURANCE/TAKAFUL AND PENSION FUNDING N.E.C.
# 4              DEVELOPER - LANDED RESIDENTIAL UNITS (E.G. LINK, SEMI-D & DETACHED HOUSES) FOR SALE
# 5                                 MANUFACTURE OF GRAIN MILL PRODUCTS, STARCHES AND STARCH PRODUCTS
# 6                                                             PASSENGER RAIL TRANSPORT, INTERURBAN
# 7                                    GROWING OF OIL PALM WITH PLANTATION ESTATES > 10,000 HECTARES
# 8                          GROWING OF OIL PALM WITH PLANTATION ESTATES OF 1,000 TO 10,000 HECTARES
# 11                                                            CONSTRUCTION OF RAILWAYS AND SUBWAYS
# 12                                                                           FAST-FOOD RESTAURANTS
# 13                                   GROWING OF OIL PALM WITH PLANTATION ESTATES > 10,000 HECTARES
# 15                                             TRANSMISSION, DISTRIBUTION AND SALES OF ELECTRICITY
# 16                                                             OTHER TELECOMMUNICATIONS ACTIVITIES
# 17                                                                 ACTIVITIES OF HOLDING COMPANIES
# 18                                                             OTHER TELECOMMUNICATIONS ACTIVITIES
# 21                                                                 ACTIVITIES OF HOLDING COMPANIES
# 24                        OTHER ELECTRICITY POWER GENERATION - NON-RENEWABLE ENERGY/THERMAL N.E.C.
# 25                                       REAL ESTATE ACTIVITIES WITH OWN OR LEASED PROPERTY N.E.C.
# 26                                             INTEGRATED PLAYER FOR MANUFACTURE OF CRUDE PALM OIL
# 35             DEVELOPER - LANDED RESIDENTIAL UNITS (E.G. LINK, SEMI-D & DETACHED HOUSES) FOR SALE
# 50                                   GROWING OF OIL PALM WITH PLANTATION ESTATES > 10,000 HECTARES
# 54                      DEVELOPER - AFFORDABLE HOUSING SCHEME (AS APPROVED BY GOVERNMENT) FOR SALE
# 100  BUYING, SELLING, RENTING AND OPERATING OF SELF-OWNED OR LEASED OF SHOPPING COMPLEXES OR MALLS
# 113                                                                            HOSPITAL ACTIVITIES
#
#                                                SECTOR_PARENT SEGMENT RDMS  \
# 0            11. FINANCIAL AND INSURANCE/ TAKAFUL ACTIVITIES  01. CB    2
# 1                                   02. MINING AND QUARRYING  01. CB   16
# 2            11. FINANCIAL AND INSURANCE/ TAKAFUL ACTIVITIES  01. CB    5
# 3            11. FINANCIAL AND INSURANCE/ TAKAFUL ACTIVITIES  01. CB   11
# 4                                           06. CONSTRUCTION  01. CB    9
# 5                                          03. MANUFACTURING  01. CB   10
# 6                             08. TRANSPORTATION AND STORAGE  01. CB   13
# 7                      01. AGRICULTURE, FORESTRY AND FISHING  01. CB   10
# 8                      01. AGRICULTURE, FORESTRY AND FISHING  01. CB    8
# 11                                          06. CONSTRUCTION  01. CB    3
# 12             09. ACCOMMODATION AND FOOD SERVICE ACTIVITIES  01. CB    6
# 13                     01. AGRICULTURE, FORESTRY AND FISHING  01. CB   23
# 15   04. ELECTRICITY, GAS, STEAM AND AIR CONDITIONING SUPPLY  01. CB    4
# 16                         10. INFORMATION AND COMMUNICATION  01. CB    6
# 17           11. FINANCIAL AND INSURANCE/ TAKAFUL ACTIVITIES  01. CB   13
# 18                         10. INFORMATION AND COMMUNICATION  01. CB   12
# 21           11. FINANCIAL AND INSURANCE/ TAKAFUL ACTIVITIES  01. CB    6
# 24   04. ELECTRICITY, GAS, STEAM AND AIR CONDITIONING SUPPLY  01. CB   11
# 25                                12. REAL ESTATE ACTIVITIES  01. CB   13
# 26                                         03. MANUFACTURING  01. CB   11
# 35                                          06. CONSTRUCTION  01. CB    8
# 50                     01. AGRICULTURE, FORESTRY AND FISHING  01. CB   14
# 54                                          06. CONSTRUCTION  01. CB   13
# 100                               12. REAL ESTATE ACTIVITIES  01. CB   23
# 113              17. HUMAN HEALTH AND SOCIAL WORK ACTIVITIES  01. CB   10
#
#     CUSTOMER_FIELD19 PSE/SOV CRRS 3RD_PARTY_PARENT  3RD_PARTY FINAL_RATING  \
# 0          PSE(FIRB)     NaN    2                N        NaN            2
# 1         CORP(FIRB)     NaN   16                N        NaN           16
# 2         CORP(FIRB)     NaN    5                N        NaN            5
# 3          PSE(FIRB)     NaN   11                N        NaN           11
# 4         CORP(FIRB)     NaN    9                N        NaN            9
# 5         CORP(FIRB)     NaN   10                N        NaN           10
# 6         CORP(FIRB)     NaN   13                N        NaN           13
# 7          PSE(FIRB)     NaN   10                N        NaN           10
# 8         CORP(FIRB)     NaN    8                N        NaN            8
# 11        CORP(FIRB)     NaN    3                N        NaN            3
# 12        CORP(FIRB)     NaN    6                N        NaN            6
# 13        CORP(FIRB)     NaN   23                N        NaN           23
# 15        CORP(FIRB)     NaN    4                N        NaN            4
# 16        CORP(FIRB)     NaN    6                N        NaN            6
# 17        CORP(FIRB)     NaN   13                N        NaN           13
# 18        CORP(FIRB)     NaN   12                N        NaN           12
# 21        CORP(FIRB)     NaN    6                N        NaN            6
# 24    CORP SL (FIRB)     NaN   11                N        NaN           11
# 25        CORP(FIRB)     NaN   13                N        NaN           13
# 26        CORP(FIRB)     NaN   11                N        NaN           11
# 35        CORP(FIRB)     NaN    8                N        NaN            8
# 50        CORP(FIRB)     NaN   14         17199004       11.0           14
# 54         PSE(FIRB)     NaN   13                N        NaN           13
# 100       CORP(FIRB)     NaN   23                N        NaN           23
# 113       CORP(FIRB)     NaN   10                N        NaN           10
#
#     M_FINANCING_TYPE_CD  M_BNM_BALANCE_SUM_1 _merge  RAM  True
# 0                     I             1.02e+10   both  AAA  both
# 1                     I             4.71e+09   both   BB  both
# 2                     I             3.15e+09   both   AA  both
# 3                     I             2.50e+09   both    A  both
# 4                     I             2.29e+09   both    A  both
# 5                     I             2.01e+09   both    A  both
# 6                     I             1.91e+09   both  BBB  both
# 7                     I             1.55e+09   both    A  both
# 8                     I             1.24e+09   both    A  both
# 11                    I             9.60e+08   both  AAA  both
# 12                    I             9.19e+08   both   AA  both
# 13                    I             9.04e+08   both    D  both
# 15                    I             8.27e+08   both   AA  both
# 16                    I             8.24e+08   both   AA  both
# 17                    I             7.22e+08   both  BBB  both
# 18                    I             6.67e+08   both  BBB  both
# 21                    I             5.84e+08   both   AA  both
# 24                    I             5.25e+08   both    A  both
# 25                    I             5.19e+08   both  BBB  both
# 26                    I             5.10e+08   both    A  both
# 35                    I             3.75e+08   both    A  both
# 50                    I             2.56e+08   both  BBB  both
# 54                    I             2.20e+08   both  BBB  both
# 100                   I             1.04e+08   both    D  both
# 113                   I             9.08e+07   both    A  both

# %%
CB_2
# Out:
#        RAM  M_BNM_BALANCE_SUM_1
# 0        A             1.25e+10
# 1       AA             4.59e+09
# 2      AAA             5.24e+07
# 3        B             2.59e+07
# 4       BB             3.33e+09
# 5      BBB             6.09e+09
# 6        C             3.17e+08
# 7        D             8.21e+07
# 8  Unrated             1.14e+09

# %%
RDATE = 20211231

# %%
TOTAL_IMPAIRED_FINAL  = pd.read_csv(r'T:\MIB Risk Management\Credit Risk Analytics - Historical\02_Data_Source\20_CRP\6.0 Impaired Loan\\'+str(RDATE)[:4]+'\\'+str(RDATE)[:6]+'\working\Total_Impaired_Final_'+str(RDATE)+'.txt',sep = ",", header = 0, low_memory = False)
TOTAL_IMPAIRED_FINAL.columns = TOTAL_IMPAIRED_FINAL.columns.str.upper()
TOTAL_IMPAIRED_FINAL.V_ORIGINAL_ACCOUNT_NUMBER = TOTAL_IMPAIRED_FINAL.V_ORIGINAL_ACCOUNT_NUMBER.astype(str)

# %%
TOTAL_IMPAIRED_FINAL1 = TOTAL_IMPAIRED_FINAL.iloc[np.where(TOTAL_IMPAIRED_FINAL.PRODUCT_GROUP=='01.CB')]

# %%
TOTAL_IMPAIRED_FINAL2 = TOTAL_IMPAIRED_FINAL1.fillna(0).groupby(['CUSTOMER_ID'])[['OUTSTANDING_AFTER_EIR_UWI']].sum().reset_index()

# %%
TOTAL_IMPAIRED_FINAL3 = TOTAL_IMPAIRED_FINAL2.merge(CB[['M_CUS_NO','NAME','FINAL_RATING']].rename(columns={'M_CUS_NO':'CUSTOMER_ID'}), on='CUSTOMER_ID',how='left',indicator=True)

# %%
TOTAL_IMPAIRED_FINAL3.FINAL_RATING = TOTAL_IMPAIRED_FINAL3.FINAL_RATING.str.strip()

TOTAL_IMPAIRED_FINAL3.loc[TOTAL_IMPAIRED_FINAL3.FINAL_RATING == '1', 'RAM'] = 'AAA'
TOTAL_IMPAIRED_FINAL3.loc[TOTAL_IMPAIRED_FINAL3.FINAL_RATING == '2', 'RAM'] = 'AAA'
TOTAL_IMPAIRED_FINAL3.loc[TOTAL_IMPAIRED_FINAL3.FINAL_RATING == '3', 'RAM'] = 'AAA'
TOTAL_IMPAIRED_FINAL3.loc[TOTAL_IMPAIRED_FINAL3.FINAL_RATING == '4', 'RAM'] = 'AA'
TOTAL_IMPAIRED_FINAL3.loc[TOTAL_IMPAIRED_FINAL3.FINAL_RATING == '5', 'RAM'] = 'AA'
TOTAL_IMPAIRED_FINAL3.loc[TOTAL_IMPAIRED_FINAL3.FINAL_RATING == '6', 'RAM'] = 'AA'
TOTAL_IMPAIRED_FINAL3.loc[TOTAL_IMPAIRED_FINAL3.FINAL_RATING == '7', 'RAM'] = 'AA'
TOTAL_IMPAIRED_FINAL3.loc[TOTAL_IMPAIRED_FINAL3.FINAL_RATING == '8', 'RAM'] = 'A'
TOTAL_IMPAIRED_FINAL3.loc[TOTAL_IMPAIRED_FINAL3.FINAL_RATING == '9', 'RAM'] = 'A'
TOTAL_IMPAIRED_FINAL3.loc[TOTAL_IMPAIRED_FINAL3.FINAL_RATING == '10', 'RAM'] = 'A'
TOTAL_IMPAIRED_FINAL3.loc[TOTAL_IMPAIRED_FINAL3.FINAL_RATING == '11', 'RAM'] = 'A'
TOTAL_IMPAIRED_FINAL3.loc[TOTAL_IMPAIRED_FINAL3.FINAL_RATING == '12', 'RAM'] = 'BBB'
TOTAL_IMPAIRED_FINAL3.loc[TOTAL_IMPAIRED_FINAL3.FINAL_RATING == '13', 'RAM'] = 'BBB'
TOTAL_IMPAIRED_FINAL3.loc[TOTAL_IMPAIRED_FINAL3.FINAL_RATING == '14', 'RAM'] = 'BBB'
TOTAL_IMPAIRED_FINAL3.loc[TOTAL_IMPAIRED_FINAL3.FINAL_RATING == '15', 'RAM'] = 'BB'
TOTAL_IMPAIRED_FINAL3.loc[TOTAL_IMPAIRED_FINAL3.FINAL_RATING == '16', 'RAM'] = 'BB'
TOTAL_IMPAIRED_FINAL3.loc[TOTAL_IMPAIRED_FINAL3.FINAL_RATING == '17', 'RAM'] = 'BB'
TOTAL_IMPAIRED_FINAL3.loc[TOTAL_IMPAIRED_FINAL3.FINAL_RATING == '18', 'RAM'] = 'BB'
TOTAL_IMPAIRED_FINAL3.loc[TOTAL_IMPAIRED_FINAL3.FINAL_RATING == '19', 'RAM'] = 'B'
TOTAL_IMPAIRED_FINAL3.loc[TOTAL_IMPAIRED_FINAL3.FINAL_RATING == '20', 'RAM'] = 'B'
TOTAL_IMPAIRED_FINAL3.loc[TOTAL_IMPAIRED_FINAL3.FINAL_RATING == '21', 'RAM'] = 'C'
TOTAL_IMPAIRED_FINAL3.loc[TOTAL_IMPAIRED_FINAL3.FINAL_RATING == '22', 'RAM'] = 'D'
TOTAL_IMPAIRED_FINAL3.loc[TOTAL_IMPAIRED_FINAL3.FINAL_RATING == '23', 'RAM'] = 'D'
TOTAL_IMPAIRED_FINAL3.loc[TOTAL_IMPAIRED_FINAL3.RAM.isna(), 'RAM'] = 'Unrated'

# %%
TOTAL_IMPAIRED_FINAL3.CUSTOMER_ID = TOTAL_IMPAIRED_FINAL3.CUSTOMER_ID.astype(str)
TOTAL_IMPAIRED_FINAL3.CUSTOMER_ID = TOTAL_IMPAIRED_FINAL3.CUSTOMER_ID.str.strip()
TOTAL_IMPAIRED_FINAL3.CUSTOMER_ID = TOTAL_IMPAIRED_FINAL3.CUSTOMER_ID.str.upper()

ex_TOTAL_IMPAIRED_FINAL3 = TOTAL_IMPAIRED_FINAL3.merge(RPSIA1[['GCIF']].drop_duplicates('GCIF').rename(columns={'GCIF':'CUSTOMER_ID'}), on='CUSTOMER_ID', how='left', indicator='True')

# %%
IF_RPSIA = ex_TOTAL_IMPAIRED_FINAL3.iloc[np.where(ex_TOTAL_IMPAIRED_FINAL3['True']=='both')]
IF_RPSIA
# Out:
#    CUSTOMER_ID  OUTSTANDING_AFTER_EIR_UWI                       NAME  \
# 13    18277935                   1.03e+08    NORTHERN MALL SDN. BHD.
# 17    19492758                   8.47e+08  TRURICH RESOURCES SDN BHD
#
#    FINAL_RATING _merge RAM  True
# 13           23   both   D  both
# 17           23   both   D  both

# %%
ex_TOTAL_IMPAIRED_FINAL3_FINAL = ex_TOTAL_IMPAIRED_FINAL3.iloc[np.where(ex_TOTAL_IMPAIRED_FINAL3['True']!='both')]

# %%
TOTAL_IMPAIRED_FINAL4 = ex_TOTAL_IMPAIRED_FINAL3_FINAL.groupby(['RAM'])[['OUTSTANDING_AFTER_EIR_UWI']].sum().reset_index()

# %%
writer2 = pd.ExcelWriter(r'T:\MIB Risk Management\Credit Risk Analytics - Historical\01_Reporting\03_Adhoc_Reporting\2022\202208_RAM\Corp & SME Q15 & Q16\RAM_CB - dec 21 (exclude RPSIA).xlsx',engine='xlsxwriter')
CB_RPSIA.to_excel(writer2,sheet_name='CB - RPSIA' ,index = False)
CB_1.to_excel(writer2,sheet_name='CB - base' ,index = False)
CB_2.to_excel(writer2,sheet_name='CB' ,index = False)
TOTAL_IMPAIRED_FINAL4.to_excel(writer2,sheet_name='CB IF' ,index = False)
TOTAL_IMPAIRED_FINAL3.to_excel(writer2,sheet_name='CB IF - base' ,index = False)
IF_RPSIA.to_excel(writer2,sheet_name='CB IF - RPSIA' ,index = False)
writer2.save()
