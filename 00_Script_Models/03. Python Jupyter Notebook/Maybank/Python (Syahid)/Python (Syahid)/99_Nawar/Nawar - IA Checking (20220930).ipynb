# %%
date = '20220930'  #current date

import numpy as np
import pandas as pd
import pandasql
import sqlite3

pd.set_option("display.max_columns", None) 
pd.set_option("display.max_colwidth", 1000) #huruf dlm column
pd.set_option("display.max_rows", 100)
pd.set_option("display.precision", 2) #2 titik perpuluhan

SAS = pd.read_excel(r"T:\MIB Risk Management\Credit Risk Analytics - Historical\01_Reporting\01_Monthly_Reporting\12_Investment_Account\\"+date+"\IA_"+str(date)+".xlsx", sheet_name='IA'+date)

Python = pd.read_excel(r"T:\MIB Risk Management\Credit Risk Analytics - Historical\01_Reporting\01_Monthly_Reporting\12_Investment_Account\\"+date+"\IA_"+str(date)+"(python).xlsx", sheet_name='IA'+date)

# %%
SAS1 = SAS.iloc[np.where(SAS.DATA_SOURCE=='02. OD')]

# %%
Python1 = Python.iloc[np.where(Python.DATA_SOURCE=='02. OD')]

# %%
sum(SAS1.M_BNM_BALANCE_MIL)
# Out:
# 6656.367308050003

# %%
sum(Python1.M_BNM_BALANCE_MIL)
# Out:
# 6656.321301180002

# %%
date = 20220930
nYear = 365

location_OD = r"T:\MIB Risk Management\Credit Risk Analytics - Historical\04_Infocube\99_Data_Source\01_Datawarehouse\01_Credit_Risk_Reporting\05_MIB_OD\\"+str(date)+"\\MIB_OD"+str(date)+".txt"
OD = pd.read_csv(location_OD, sep = "\t", header = 0)
OD.columns = OD.columns.str.replace(" ", "_")
OD.Account_No = OD.Account_No.astype(str)
OD['Account_No'] = OD.Account_No.str[:20]

# %%
sum(OD.M_Bnm_Balance)
# Out:
# 6656321301.180026

# %%
OD_info  = pd.read_excel(r"T:\MIB Risk Management\Credit Risk Analytics - Historical\04_Infocube\02_OD\\"+str(date)+"\\OD"+str(date)+".xlsx")
OD_info.columns = OD_info.columns.str.replace(" ", "_")
OD_info.Account_No = OD_info.Account_No.astype(str)

# %%
sum(OD_info.M_Bnm_Balance)
# Out:
# 6656367308.050018

# %%
OD_info.iloc[np.where(OD_info.Account_No=='501600003891')]
# Out:
#       Account_No    Cus_No  Amrt_Term Amrt_Term_Mult As_Of_Date  Branch_Code  \
# 12  501600003891  25091830         60              M 2022-09-30          160
# 13  501600003891  25091830         60              M 2022-09-30          160
#
#     Common_Coa_Id  Record_Count  Acct_Status_Cd Account_Open_Date  \
# 12          12000             1               1        2017-10-02
# 13          12000             1               1        2017-10-02
#
#    Date_Aa_Approved  Authorised_Limit  Drawing_Limit Source_Prod_Type_Cd  \
# 12       2021-07-12          262500.0       262500.0                 PMA
# 13       2021-07-12          262500.0       262500.0                 PMA
#
#    Special_Mention_Acct_Flg  Interest_Income  Interest_Income_Myr  \
# 12                        N           642.33               642.33
# 13                        N           642.33               642.33
#
#     Non_Interest_Income  Interest_In_Suspense  Specific_Provision  \
# ...
