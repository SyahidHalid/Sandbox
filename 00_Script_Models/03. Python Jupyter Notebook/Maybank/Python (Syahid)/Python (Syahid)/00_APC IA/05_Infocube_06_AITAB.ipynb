# %%
RATE_1 = 20220930
P_DATE = 20220831
nYear = 365
NMONTH = 9
RDAY1 = 273            #jan(31)+feb(28)+Mar(31)+apr(30)+may(31)+june(30)+july(31)+august(31)+september(30)


import numpy as np
import pandas as pd
import pandasql
import sqlite3

pd.set_option("display.max_columns", None) 
pd.set_option("display.max_colwidth", 1000) #huruf dlm column
pd.set_option("display.max_rows", 100)
pd.set_option("display.precision", 2) #2 titik perpuluhan

NII = 0.0004
OE = 0.0077



location_cust = r"T:\MIB Risk Management\Credit Risk Analytics - Historical\04_Infocube\99_Data_Source\02_Teradata\01_Credit_Risk_Reporting\01_Cust\\"+str(RATE_1)+"\\S001_004_ACRM_CUST"+str(RATE_1)+".txt"
location_cust_ind = r"T:\MIB Risk Management\Credit Risk Analytics - Historical\04_Infocube\99_Data_Source\02_Teradata\01_Credit_Risk_Reporting\02_Cust_Ind\\"+str(RATE_1)+"\\S001_028_ACRM_CUST_IND"+str(RATE_1)+".txt"
location_org = r"T:\MIB Risk Management\Credit Risk Analytics - Historical\04_Infocube\99_Data_Source\02_Teradata\01_Credit_Risk_Reporting\04_Organization\\"+str(RATE_1)+"\\T0120_ORGANIZATION"+str(RATE_1)+".txt"

location_HP = r"T:\MIB Risk Management\Credit Risk Analytics - Historical\04_Infocube\99_Data_Source\01_Datawarehouse\01_Credit_Risk_Reporting\09_MIB_HP\\"+str(RATE_1)+"\MIB_HP"+str(RATE_1)+".txt"
location_HPFS = r"T:\MIB Risk Management\Credit Risk Analytics - Historical\04_Infocube\99_Data_Source\01_Datawarehouse\01_Credit_Risk_Reporting\09_MIB_HP\\"+str(RATE_1)+"\MIB_HPFS"+str(RATE_1)+".txt"
location_HPBD = r"T:\MIB Risk Management\Credit Risk Analytics - Historical\04_Infocube\99_Data_Source\01_Datawarehouse\01_Credit_Risk_Reporting\09_MIB_HP\\"+str(RATE_1)+"\MIB_HPBD"+str(RATE_1)+".txt"
location_applicant = r"T:\MIB Risk Management\Credit Risk Analytics - Historical\04_Infocube\99_Data_Source\01_Datawarehouse\01_Credit_Risk_Reporting\09_MIB_HP\\"+str(RATE_1)+"\LOS_HPS_APPLICANT_DETAILS"+str(RATE_1)+".txt"
location_application = r"T:\MIB Risk Management\Credit Risk Analytics - Historical\04_Infocube\99_Data_Source\01_Datawarehouse\01_Credit_Risk_Reporting\09_MIB_HP\\"+str(RATE_1)+"\LOS_HPS_APPLICATION_DETAILS"+str(RATE_1)+".txt"

location_RDMS = r'T:\MIB Risk Management\Credit Risk Analytics - Historical\04_Infocube\99_Data_Source\01_Datawarehouse\01_Credit_Risk_Reporting\04_MIB_Rdms\\'+str(RATE_1)+'\\RDMS_'+str(RATE_1)+'.txt'

#case feb tukar tab delimited klaux seperator sblm ni koma
aitabP = pd.read_csv(r"T:\MIB Risk Management\Credit Risk Analytics - Historical\04_Infocube\06_AITAB\\"+str(P_DATE)+"\\infocube_06_aitab"+str(P_DATE)+".txt", sep = "\t", header = 0)#, low_memory = False
aitabP.columns = aitabP.columns.str.replace(" ", "_")
# Out:
# D:\anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3063: DtypeWarning: Columns (42,49,87) have mixed types.Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
cust = pd.read_csv(location_cust, sep = "|", header = 0, error_bad_lines = False)
cust_ind = pd.read_csv(location_cust_ind, sep = "|", header = 0)
org = pd.read_csv(location_org, sep = "|", header = 0)

HP = pd.read_csv(location_HP, sep = "\t", header = 0)
HPFS = pd.read_csv(location_HPFS, sep = "\t", header = 0)
HPBD = pd.read_csv(location_HPBD, sep = "\t", header = 0)
applicant = pd.read_csv(location_applicant,sep = "\t", header = 0)
application = pd.read_csv(location_application,sep = "\t", header = 0)

RDMS = pd.read_csv(location_RDMS, sep = ",", header = 0, low_memory = False)

#Teradata
cust.columns = cust.columns.str.replace(" ", "_")
cust.M_SUB_SUB_MARKET_SEGMENT.replace({'    ': -9999}, inplace=True)

#Customer Industry
cust_ind.columns = cust_ind.columns.str.replace(" ", "_")

#Organization
org.columns = org.columns.str.replace(" ", "_")
#org.NOB_Cd.replace({'?': -9999}, inplace=True) 

#HP
HP.columns = HP.columns.str.replace(" ", "_")
HP.Account_No = HP.Account_No.astype(str)
HP['Account_No'] = HP.Account_No.str[:20]

#HPFS
HPFS.columns = HPFS.columns.str.replace(" ", "_")
HPFS.Account_No = HPFS.Account_No.astype(str)
HPFS['Account_No'] = HPFS.Account_No.str[:20]

#HPBD
HPBD.columns = HPBD.columns.str.replace(" ", "_")
HPBD.Account_No = HPBD.Account_No.astype(str)
HPBD['Account_No'] = HPBD.Account_No.str[:20]

#HPS Applicant
applicant.columns = applicant.columns.str.replace(" ", "_")

#HPS Application
application.columns = application.columns.str.replace(" ", "_")


#RDMS
RDMS.columns = RDMS.columns.str.replace(" ", "_")
RDMS.Account_No = RDMS.Account_No.astype(str)
RDMS['Account_No'] = RDMS.Account_No.str[:20]
#-----------------------------------------------------USER_DEFINED


Branch_Dsc = pd.read_csv(r"T:\MIB Risk Management\Credit Risk Analytics - Historical\04_Infocube\99_Data_Source\01_Datawarehouse\02_User_Defined\01_Branch_Dsc\Branch_Dsc.txt", sep = "\t", header = 0, low_memory = False)
Branch_Dsc.columns = Branch_Dsc.columns.str.replace(" ", "_")

Product_Hierarchy = pd.read_csv (r"T:\MIB Risk Management\Credit Risk Analytics - Historical\04_Infocube\99_Data_Source\01_Datawarehouse\02_User_Defined\06_Product_Hierarchy\Product_Hierarchy.txt", sep = "\t", header = 0, low_memory = False)
Product_Hierarchy.columns = Product_Hierarchy.columns.str.replace(" ", "_")

PRODUCT_HIERAR = Product_Hierarchy

Econ_Sector_Dsc = pd.read_csv(r"T:\MIB Risk Management\Credit Risk Analytics - Historical\04_Infocube\99_Data_Source\01_Datawarehouse\02_User_Defined\02_Econ_Sector_Dsc\Econ_Sector_Dsc.txt", sep = "\t", header = 0, low_memory = False)
Econ_Sector_Dsc.columns = Econ_Sector_Dsc.columns.str.replace(" ", "_")

Income_Grp_Dsc = pd.read_csv(r"T:\MIB Risk Management\Credit Risk Analytics - Historical\04_Infocube\99_Data_Source\01_Datawarehouse\02_User_Defined\03_Income_Grp_Dsc\Income_Grp_Dsc.txt", sep = "\t", header = 0, low_memory = False)
Income_Grp_Dsc.columns = Income_Grp_Dsc.columns.str.replace(" ", "_")

#Interest_Rate_Cd_Maps = pd.read_csv(r"T:\MIB Risk Management\Credit Risk Analytics - Historical\04_Infocube\99_Data_Source\01_Datawarehouse\02_User_Defined\08_Interest_Rate_Cd_Maps\Interest_Rate_Cd_Maps.txt", sep = "\t", header = 0, low_memory = False)
#Interest_Rate_Cd_Maps.columns = Interest_Rate_Cd_Maps.columns.str.replace(" ", "_")

Occ_Sector_Dsc = pd.read_csv(r"T:\MIB Risk Management\Credit Risk Analytics - Historical\04_Infocube\99_Data_Source\01_Datawarehouse\02_User_Defined\05_Occ_Sector_Dsc\new version\Occ_Sector_Dsc.txt", sep = "\t", header = 0, low_memory = False)
Occ_Sector_Dsc.columns = Occ_Sector_Dsc.columns.str.replace(" ", "_")

Sub_Mkt_Dsc = pd.read_csv(r"T:\MIB Risk Management\Credit Risk Analytics - Historical\04_Infocube\99_Data_Source\01_Datawarehouse\02_User_Defined\07_Sub_Mkt_Dsc\Sub_Mkt_Dsc.txt", sep = "\t", header = 0, low_memory = False)
Sub_Mkt_Dsc.columns = Sub_Mkt_Dsc.columns.str.replace(" ", "_")

R028_NATIONALITY_CODE = pd.read_csv(r"T:\MIB Risk Management\Credit Risk Analytics - Historical\04_Infocube\99_Data_Source\02_Teradata\02_User_Defined\01_Nationality_Code\R028_NATIONALITY_CODE.txt", sep = "\t", header = 0, low_memory = False)
R028_NATIONALITY_CODE.columns = R028_NATIONALITY_CODE.columns.str.replace(" ", "_")


#=====================================================APPEND_AITAB

#append_aitabP = pd.read_csv(r"T:\MIB Risk Management\Credit Risk Analytics - Historical\04_Infocube\99_Data_Source\01_Datawarehouse\01_Credit_Risk_Reporting\12_Append for YTD\\append_aitab"+str(P_DATE)+".txt", sep = ",", header = 0)

#MIBHP_1 = HP[['As_Of_Date','Account_No','Avg_Book_Bal','Interest_Income_Myr', 'Fund_Charge_Myr']]
#MIBHP_1.Account_No = MIBHP_1.Account_No.astype(str)

#MIBHPFS_1 = HPFS[['As_Of_Date','Account_No','Avg_Book_Bal','Interest_Income_Myr','Fund_Charge_Myr']]
#MIBHPFS_1.Account_No = MIBHPFS_1.Account_No.astype(str)

#MIBHPBD_1 = HPBD[['As_Of_Date','Account_No','Avg_Book_Bal','Interest_Income_Myr','Fund_Charge_Myr']]
#MIBHPBD_1.Account_No = MIBHPBD_1.Account_No.astype(str)

#a = append_aitabP.append(MIBHP_1, ignore_index = True)
#b = a.append(MIBHPFS_1, ignore_index = True)
#append_aitab = b.append(MIBHPBD_1, ignore_index = True)

#appendaitab = append_aitab

appendaitab = pd.read_csv(r"T:\MIB Risk Management\Credit Risk Analytics - Historical\04_Infocube\99_Data_Source\01_Datawarehouse\01_Credit_Risk_Reporting\12_Append for YTD\\append_aitab"+str(RATE_1)+".txt", sep = ",", header = 0)

# %%
HP1 = HP.iloc[np.where((HP.Record_Count==1)&(HP.Full_Writeoff_Flg=='N'))]

HP1.columns = HP1.columns.str.upper()

HP1['SOLA_NO'] = 0
HP1['SOLA_STATUS_CD'] = 0
HP1['SOLA_TYPE_CD'] = 0
HP1['DEALER_ACCT_STATUS_CD'] = 0
HP1['DEALER_ALLOW_LIMIT'] = 0
HP1['DEALER_CREDIT_LIMIT'] = 0
HP1['DEALER_UNUTILISED_AMT'] = 0
HP1['DEALER_UTILISED_AMT'] = 0

AITAB1 = HP1[['ACCOUNT_NO'\
,'AA_NUMBER'\
,'CUS_NO'\
,'AS_OF_DATE'\
,'AMRT_TERM'\
,'AMRT_TERM_MULT'\
,'BRANCH_CODE'\
,'COMMON_COA_ID'\
,'CUR_GROSS_RATE'\
,'ISSUE_DATE'\
,'DATE_RELEASED'\
,'RECORD_COUNT'\
,'AVG_BOOK_BAL'\
,'BNM_BALANCE'\
,'DATE_AA_APPROVED'\
,'APPROVED_LIMIT'\
,'FULL_WRITEOFF_FLG'\
,'NEW_NPL_FLG'\
,'NPL_FLG'\
,'NPL_DATE'\
,'MTHS_INSTALLMENT_IN_ARREARS'\
,'RESCHEDULE_FLG'\
,'RESTRUCTURE_FLG'\
,'ECONOMIC_SECTOR_CD'\
,'SOURCE_PROD_TYPE_CD'\
,'PRODUCT_HIERARCHY_CD','M_SUB_MARKET_SEGMENT_CD','M_ENTITY_CD','FUND_CHARGE','INTEREST_INCOME','NON_INTEREST_INCOME','NET_INT_INCOME','FUND_CHARGE_MYR','INTEREST_INCOME_MYR','NET_INT_INCOME_MYR','INT_IN_SUSPENSE','MAINTENANCE_COST','MISC_CHARGES','SPECIFIC_PROVISION','TOTAL_ACTIVITY_COST','ACCT_STATUS_CD'\
,'CIHP_FLG'\
,'FINANCING_CONCEPT','CASH_PRICE','YEAR_OF_VEHICLE','GOODS_STATUS','GOODS_TYPE','FACILITY_NO','MODEL_DESC','SOLA_NO','SOLA_STATUS_CD','SOLA_TYPE_CD','DEALER_ACCT_STATUS_CD','DEALER_ALLOW_LIMIT','DEALER_CREDIT_LIMIT','DEALER_UNUTILISED_AMT','DEALER_UTILISED_AMT','ORG_PAYMENT_AMT','CUR_PAYMENT']]
# Out:
# D:\anaconda3\lib\site-packages\ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """
# D:\anaconda3\lib\site-packages\ipykernel_launcher.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# D:\anaconda3\lib\site-packages\ipykernel_launcher.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# ...

# %%
HPFS1 = HPFS.iloc[np.where(HPFS.Full_Writeoff_Flg=='N')]

HPFS1.columns = HPFS1.columns.str.upper()

HPFS1.loc[(HPFS1.NO_OF_DAYS_PRINCIPAL_PAST_DUE < 30),'MTHS_INSTALLMENT_IN_ARREARS'] = 0
HPFS1.loc[(HPFS1.NO_OF_DAYS_PRINCIPAL_PAST_DUE >= 30)&(HPFS1.NO_OF_DAYS_PRINCIPAL_PAST_DUE < 60),'MTHS_INSTALLMENT_IN_ARREARS'] = 1
HPFS1.loc[(HPFS1.NO_OF_DAYS_PRINCIPAL_PAST_DUE >= 60)&(HPFS1.NO_OF_DAYS_PRINCIPAL_PAST_DUE < 90),'MTHS_INSTALLMENT_IN_ARREARS'] = 2
HPFS1.loc[(HPFS1.NO_OF_DAYS_PRINCIPAL_PAST_DUE >= 90)&(HPFS1.NO_OF_DAYS_PRINCIPAL_PAST_DUE < 120),'MTHS_INSTALLMENT_IN_ARREARS'] = 3
HPFS1.loc[(HPFS1.NO_OF_DAYS_PRINCIPAL_PAST_DUE >= 120)&(HPFS1.NO_OF_DAYS_PRINCIPAL_PAST_DUE < 150),'MTHS_INSTALLMENT_IN_ARREARS'] = 4
HPFS1.loc[(HPFS1.NO_OF_DAYS_PRINCIPAL_PAST_DUE >= 150)&(HPFS1.NO_OF_DAYS_PRINCIPAL_PAST_DUE < 180),'MTHS_INSTALLMENT_IN_ARREARS'] = 5
HPFS1.loc[(HPFS1.NO_OF_DAYS_PRINCIPAL_PAST_DUE >= 180),'MTHS_INSTALLMENT_IN_ARREARS'] = 6

HPFS1['ACCT_STATUS_CD']=0
HPFS1['CIHP_FLG']=0
HPFS1['FINANCING_CONCEPT']=0
HPFS1['CASH_PRICE']=0
HPFS1['YEAR_OF_VEHICLE']=0
HPFS1['GOODS_STATUS']=0
HPFS1['GOODS_TYPE']=0
HPFS1['FACILITY_NO']=0
HPFS1['MODEL_DESC']=0

AITAB2 = HPFS1[['ACCOUNT_NO'\
,'AA_NUMBER'\
,'CUS_NO'\
,'AS_OF_DATE'\
,'AMRT_TERM'\
,'AMRT_TERM_MULT'\
,'BRANCH_CODE'\
,'COMMON_COA_ID'\
,'CUR_GROSS_RATE'\
,'ISSUE_DATE'\
,'DATE_RELEASED'\
,'RECORD_COUNT'\
,'AVG_BOOK_BAL'\
,'BNM_BALANCE'\
,'DATE_AA_APPROVED'\
,'APPROVED_LIMIT'\
,'FULL_WRITEOFF_FLG'\
,'NEW_NPL_FLG'\
,'NPL_FLG'\
,'NPL_DATE'\
,'MTHS_INSTALLMENT_IN_ARREARS'\
,'RESCHEDULE_FLG'\
,'RESTRUCTURE_FLG'\
,'ECONOMIC_SECTOR_CD'\
,'SOURCE_PROD_TYPE_CD'\
,'PRODUCT_HIERARCHY_CD'\
,'M_SUB_MARKET_SEGMENT_CD'\
,'M_ENTITY_CD'\
,'FUND_CHARGE'\
,'INTEREST_INCOME'\
,'NON_INTEREST_INCOME'\
,'NET_INT_INCOME'\
,'FUND_CHARGE_MYR'\
,'INTEREST_INCOME_MYR'\
,'NET_INT_INCOME_MYR'\
,'INT_IN_SUSPENSE'\
,'MAINTENANCE_COST'\
,'MISC_CHARGES'\
,'SPECIFIC_PROVISION'\
,'TOTAL_ACTIVITY_COST'\
,'ACCT_STATUS_CD'\
,'CIHP_FLG'\
,'FINANCING_CONCEPT'\
,'CASH_PRICE'\
,'YEAR_OF_VEHICLE'\
,'GOODS_STATUS'\
,'GOODS_TYPE'\
,'FACILITY_NO'\
,'MODEL_DESC'\
,'SOLA_NO'\
,'SOLA_STATUS_CD'\
,'SOLA_TYPE_CD'\
,'DEALER_ACCT_STATUS_CD'\
,'DEALER_ALLOW_LIMIT'\
,'DEALER_CREDIT_LIMIT'\
,'DEALER_UNUTILISED_AMT'\
,'DEALER_UTILISED_AMT'\
,'ORG_PAYMENT_AMT'\
,'CUR_PAYMENT']]

# %%
HPBD1 =  HPBD.iloc[np.where((HPBD.Dealer_Acct_Status_Cd!=40)&(HPBD.Full_Writeoff_Flg=='N'))]

HPBD1.columns = HPBD1.columns.str.upper()

HPBD1['DATE_RELEASED']=0
HPBD1['ACCT_STATUS_CD']=0
HPBD1['CIHP_FLG']=0
HPBD1['FINANCING_CONCEPT']=0
HPBD1['CASH_PRICE']=0
HPBD1['YEAR_OF_VEHICLE']=0
HPBD1['GOODS_STATUS']=0
HPBD1['GOODS_TYPE']=0
HPBD1['FACILITY_NO']=0
HPBD1['MODEL_DESC']=0
HPBD1['SOLA_NO']=0
HPBD1['SOLA_STATUS_CD']=0
HPBD1['SOLA_TYPE_CD']=0

AITAB3 = HPBD1[['ACCOUNT_NO'\
,'AA_NUMBER'\
,'CUS_NO'\
,'AS_OF_DATE'\
,'AMRT_TERM'\
,'AMRT_TERM_MULT'\
,'BRANCH_CODE'\
,'COMMON_COA_ID'\
,'CUR_GROSS_RATE'\
,'ISSUE_DATE'\
,'DATE_RELEASED'\
,'RECORD_COUNT'\
,'AVG_BOOK_BAL'\
,'BNM_BALANCE'\
,'DATE_AA_APPROVED'\
,'APPROVED_LIMIT'\
,'FULL_WRITEOFF_FLG'\
,'NEW_NPL_FLG'\
,'NPL_FLG'\
,'NPL_DATE'\
,'MTHS_INSTALLMENT_IN_ARREARS'\
,'RESCHEDULE_FLG'\
,'RESTRUCTURE_FLG'\
,'ECONOMIC_SECTOR_CD'\
,'SOURCE_PROD_TYPE_CD'\
,'PRODUCT_HIERARCHY_CD'\
,'M_SUB_MARKET_SEGMENT_CD'\
,'M_ENTITY_CD'\
,'FUND_CHARGE'\
,'INTEREST_INCOME'\
,'NON_INTEREST_INCOME'\
,'NET_INT_INCOME'\
,'FUND_CHARGE_MYR'\
,'INTEREST_INCOME_MYR'\
,'NET_INT_INCOME_MYR'\
,'INT_IN_SUSPENSE'\
,'MAINTENANCE_COST'\
,'MISC_CHARGES'\
,'SPECIFIC_PROVISION'\
,'TOTAL_ACTIVITY_COST'\
,'ACCT_STATUS_CD'\
,'CIHP_FLG'\
,'FINANCING_CONCEPT'\
,'CASH_PRICE'\
,'YEAR_OF_VEHICLE'\
,'GOODS_STATUS'\
,'GOODS_TYPE'\
,'FACILITY_NO'\
,'MODEL_DESC'\
,'SOLA_NO'\
,'SOLA_STATUS_CD'\
,'SOLA_TYPE_CD'\
,'DEALER_ACCT_STATUS_CD'\
,'DEALER_ALLOW_LIMIT'\
,'DEALER_CREDIT_LIMIT'\
,'DEALER_UNUTILISED_AMT'\
,'DEALER_UTILISED_AMT'\
,'ORG_PAYMENT_AMT'\
,'CUR_PAYMENT']]

# %%
AITAB4 = pd.concat([AITAB1, AITAB2, AITAB3])

# %%
#===========================================AITAB5

#AITAB4 = AITAB.fillna(0, inplace=True)

aitabP.columns = aitabP.columns.str.upper()

aitabP_1 = aitabP[['ACCOUNT_NO','MTHS_INSTALLMENT_IN_ARREARS']]
aitabP_1 = aitabP_1.groupby(['ACCOUNT_NO'])[['MTHS_INSTALLMENT_IN_ARREARS']].sum().reset_index()#.drop_duplicates(subset=['Account_No'],keep='last')

aitabP_1.ACCOUNT_NO = aitabP_1.ACCOUNT_NO.astype(str)
AITAB4.ACCOUNT_NO = AITAB4.ACCOUNT_NO.astype(str)

AITAB4_1 = AITAB4.merge(aitabP_1.rename(columns={'MTHS_INSTALLMENT_IN_ARREARS': 'MTHS_INSTALLMENT_IN_ARREARS_P'}),on = 'ACCOUNT_NO', how = 'left')
AITAB4_1 = AITAB4_1.fillna(0)

RDMS_1 = RDMS[['Account_No','Ead_Proportional_Myr','Expected_Loss_Myr','Rwa_After_Risk_Mit_Myr']]

RDMS_1.columns = RDMS_1.columns.str.upper()

RDMS_1 = RDMS_1.groupby(['ACCOUNT_NO'])[['EAD_PROPORTIONAL_MYR','EXPECTED_LOSS_MYR','RWA_AFTER_RISK_MIT_MYR']].sum().reset_index()

AITAB5_1 = AITAB4_1.merge(RDMS_1, on = 'ACCOUNT_NO', how = 'left')
AITAB5_1 = AITAB5_1.fillna(0)

# %%
RDMS_2 = RDMS[['Account_No','Rsme_Rating_Grade','Rating','Pd_Segment_Id']]

RDMS_2.columns = RDMS_2.columns.str.upper()

AITAB5_2 = AITAB5_1.merge(RDMS_2, on = 'ACCOUNT_NO', how = 'left')

AITAB5_2.loc[AITAB5_2.M_SUB_MARKET_SEGMENT_CD.isin([1]), 'PD_SEGMENT'] = AITAB5_2['RSME_RATING_GRADE']
AITAB5_2.loc[AITAB5_2.M_SUB_MARKET_SEGMENT_CD.isin([2,5,6,7,8]), 'PD_SEGMENT'] = AITAB5_2['RATING']
AITAB5_2.loc[~(AITAB5_2.M_SUB_MARKET_SEGMENT_CD.isin([1,2,5,6,7,8])), 'PD_SEGMENT'] = AITAB5_2['PD_SEGMENT_ID']

AITAB5_3 = AITAB5_2.drop(columns=['RSME_RATING_GRADE','RATING','PD_SEGMENT_ID'])
AITAB5_3 = AITAB5_3.fillna(0)

#===========================================AITAB6

PRD_1 = PRODUCT_HIERAR[['Product_Hierarchy_Cd','Level_5','Level_6']]
PRD_2 = PRODUCT_HIERAR[['Source_Prod_Type_Cd','Source_Prod_Type_Dsc']].drop_duplicates(subset=['Source_Prod_Type_Cd'], keep='last')
ECON = Econ_Sector_Dsc[['Econ_Sector_Cd','Econ_Sector']].drop_duplicates(subset=['Econ_Sector_Cd'], keep='last') #rename
BRANCH = Branch_Dsc[['Branch_Cd','Region_Desc','State_Desc','Branch_Desc']] #rename


PRD_1.columns = PRD_1.columns.str.upper()
PRD_2.columns = PRD_2.columns.str.upper()

AITAB5_4 = AITAB5_3.merge(PRD_1, on = 'PRODUCT_HIERARCHY_CD', how = 'left')
AITAB5_5 = AITAB5_4.merge(PRD_2, on = 'SOURCE_PROD_TYPE_CD', how = 'left')

AITAB5_5.ECONOMIC_SECTOR_CD = AITAB5_5.ECONOMIC_SECTOR_CD.astype(int)
AITAB5_5.ECONOMIC_SECTOR_CD = AITAB5_5.ECONOMIC_SECTOR_CD.astype(str)
AITAB5_6 = AITAB5_5.merge(ECON.rename(columns={'Econ_Sector_Cd': 'ECONOMIC_SECTOR_CD'}), on = 'ECONOMIC_SECTOR_CD', how = 'left')
AITAB6 = AITAB5_6.merge(BRANCH.rename(columns={'Branch_Cd': 'BRANCH_CODE'}), on = 'BRANCH_CODE', how = 'left')


#===========================================AITAB7

NATION = R028_NATIONALITY_CODE.rename(columns={'MBB_Nationality_Cd':'M_NATIONALITY_CD'})
OCC = Occ_Sector_Dsc.rename(columns={'Occ_Sector_Cd': 'M_OCC_SECTOR_CD'})
INCOM = Income_Grp_Dsc.rename(columns={'Income_Grp_Cd': 'M_INCOME_GRP_CD'})
SUB_MKT = Sub_Mkt_Dsc.rename(columns={'Code':'M_Sub_Market_Segment_Cd', 'Description':'M_Sub_Market_Segment_Desc'})
#cust_ind_1 = cust_ind.rename(columns={'CUS_NO': 'Cus_No'})
#cust1 = cust.rename(columns={'CUS_NO': 'Cus_No'})



cust_ind_1 = cust_ind[['CUS_NO','M_RACE_CD','SEX','M_NATIONALITY_CD','BTH_DT','M_OCC_SECTOR_CD','M_INCOME_GRP_CD','MARRIED']]
cust_1 = cust[['CUS_NO','CUSTOMER_SEGMENT','M_CUSTOMER_TYPE']]
NATION_1 = NATION[['M_NATIONALITY_CD', 'MBB_Nationality_Desc']]
OCC_1 = OCC[['Occ_Sector', 'M_OCC_SECTOR_CD']]
INCOM_1 = INCOM[['Income_Grp', 'M_INCOME_GRP_CD']]
SUB_MKT_1 = SUB_MKT[['M_Sub_Market_Segment_Desc','M_Sub_Market_Segment_Cd']] 

cust_ind_1.columns = cust_ind_1.columns.str.upper()
cust_1.columns = cust_1.columns.str.upper()
SUB_MKT_1.columns = SUB_MKT_1.columns.str.upper()

AITAB6_1 = pd.merge(AITAB6, cust_ind_1, on="CUS_NO", how="left")
AITAB6_1 = AITAB6_1.fillna(0)
AITAB6_2 = pd.merge(AITAB6_1, cust_1, on="CUS_NO", how="left")
AITAB6_2 = AITAB6_2.fillna(0)
AITAB6_3 = pd.merge(AITAB6_2, NATION_1, on="M_NATIONALITY_CD", how="left")
AITAB6_3 = AITAB6_3.fillna(0)
AITAB6_4 = pd.merge(AITAB6_3, OCC_1, on="M_OCC_SECTOR_CD", how="left")
AITAB6_4 = AITAB6_4.fillna(0)
AITAB6_5 = pd.merge(AITAB6_4, INCOM_1, on="M_INCOME_GRP_CD", how="left")
AITAB6_5 = AITAB6_5.fillna(0)
AITAB7 = pd.merge(AITAB6_5, SUB_MKT_1, on="M_SUB_MARKET_SEGMENT_CD", how="left")
AITAB7 = AITAB7.fillna(0)

def CUSTOMER_SEGMENT_DSC(CUSTOMER_SEGMENT):
    if CUSTOMER_SEGMENT=='004':
        return '01. MASS MARKET'
    elif CUSTOMER_SEGMENT=='003':
        return '02. AFFLUENT'
    elif CUSTOMER_SEGMENT=='002':
        return '03. HNW'
    elif CUSTOMER_SEGMENT=='001':
        return '04. PRIVATE BANKING'
    elif CUSTOMER_SEGMENT=='005':
        return '05. PREMIER'
    elif CUSTOMER_SEGMENT=='006':
        return '06. PREFERRED'
    elif CUSTOMER_SEGMENT=='007':
        return '07. CLASSIC'
    else: 
        return '08. NOT POPULATED' 
AITAB7['CUSTOMER_SEGMENT_DSC'] = AITAB7['CUSTOMER_SEGMENT'].apply(CUSTOMER_SEGMENT_DSC)

appendaitab1 = appendaitab[['Account_No','Interest_Income_Myr','Fund_Charge_Myr','Avg_Book_Bal']]

appendaitab1 = appendaitab1.rename(columns={'Avg_Book_Bal': 'Avg_Book_Bal_Sum',\
                                            'Interest_Income_Myr': 'Interest_Income_Myr_YTD',\
                                            'Fund_Charge_Myr': 'Funds_Charge_Myr_YTD',})
appendaitab1 = appendaitab1.groupby(['Account_No']).sum().reset_index()

appendaitab1.Account_No = appendaitab1.Account_No.astype(str)
appendaitab1.Account_No = appendaitab1.Account_No.str.upper()
appendaitab1.Account_No = appendaitab1.Account_No.str.strip()

appendaitab1.columns = appendaitab1.columns.str.upper()

AITAB7.ACCOUNT_NO = AITAB7.ACCOUNT_NO.astype(str)
AITAB7.ACCOUNT_NO = AITAB7.ACCOUNT_NO.str.upper()
AITAB7.ACCOUNT_NO = AITAB7.ACCOUNT_NO.str.strip()

AITAB8 = AITAB7.merge(appendaitab1, on="ACCOUNT_NO", how="left")
AITAB8 = AITAB8.fillna(0)

# %%
#=========================================AITAB9

AITAB8_1 = AITAB8.merge(org[['NOB_Cd','Org_Party_Id']].rename(columns={'Org_Party_Id':'CUS_NO'}),on='CUS_NO',how='left')

applicant1 = applicant.rename(columns={'Cus_no':'CUS_NO','Aa_number':'AA_NUMBER'})
applicant1['Total_mthly_income_Cust'] = applicant1.Total_mthly_income
applicant1 = applicant1[['CUS_NO','AA_NUMBER','Total_mthly_income','Other_Income','Total_mthly_income_Cust','Debt_ratio']]

AITAB9 = AITAB8_1.merge(applicant1, on=['CUS_NO','AA_NUMBER'],how='left')

VEC_GROUP = AITAB9[['MODEL_DESC']].drop_duplicates()

conn = sqlite3.connect(r'T:\MIB Risk Management\Credit Risk Analytics - Historical\04_Infocube\06_AITAB\\'+str(RATE_1)+'\VEC_GROUP.db')
c = conn.cursor()

c.execute("CREATE TABLE IF NOT EXISTS VEC_GROUP ({})".format(','.join(VEC_GROUP.columns)))

for row in VEC_GROUP.iterrows():
    sql = "INSERT INTO VEC_GROUP({}) VALUES ({})".format(','.join(VEC_GROUP.columns), ','.join(['?']*len(VEC_GROUP.columns)))
    c.execute(sql, tuple(row[1]))

conn.commit()

c.execute("""
create table VEC_GROUP1 as select distinct
a.*
,case
when Model_Desc like '%PROTON%' then '01.PROTON'
when Model_Desc like '%SAGA%' then '01.PROTON'
when Model_Desc like '%PERSONA%' then '01.PROTON'
when Model_Desc like '%PEROSNA%' then '01.PROTON'
when Model_Desc like '%WAJA%' then '01.PROTON'
when Model_Desc like '%WIRA%' then '01.PROTON'
when Model_Desc like '%SATRIA%' then '01.PROTON'
when Model_Desc like '%NEO 1.6%' then '01.PROTON'
when Model_Desc like '%NEO R3%' then '01.PROTON'
when Model_Desc like '%NEO CPS%' then '01.PROTON'
when Model_Desc like '%PREVE%' then '01.PROTON'
when Model_Desc like '%EXORA%' then '01.PROTON'
when Model_Desc like '%EZORA%' then '01.PROTON'
when Model_Desc like '%INSPIRA%' then '01.PROTON'
when Model_Desc like '%ISWARA%' then '01.PROTON'
when Model_Desc like '%PERSONA%' then '01.PROTON'
when Model_Desc like '%PESONA%' then '01.PROTON'
when Model_Desc like '%SAVVY%' then '01.PROTON'
when Model_Desc like '%SAVY%' then '01.PROTON'
when Model_Desc like '%PERDANA%' then '01.PROTON'
when Model_Desc like '%JUARA%' then '01.PROTON'
when Model_Desc like '%GEN 2%' then '01.PROTON'
when Model_Desc like '%GEN-2%' then '01.PROTON'
when Model_Desc like '%GEN.2%' then '01.PROTON'
when Model_Desc like '%GEN2%' then '01.PROTON'
when Model_Desc like '%GEN 1.6%' then '01.PROTON'
when Model_Desc like '%SUPRIMA%' then '01.PROTON'
when Model_Desc like '%SUPREMA%' then '01.PROTON'
when Model_Desc like '%ARENA%' then '01.PROTON'
when Model_Desc like '%IRIZ%' then '01.PROTON'
when Model_Desc like 'BLM 1.3%' then '01.PROTON'

when Model_Desc like '%PERODUA%' then '02.PERODUA'
when Model_Desc like '%MYVI%' then '02.PERODUA'
when Model_Desc like '%MVYI%' then '02.PERODUA'
when Model_Desc like '%MYV1%' then '02.PERODUA'
when Model_Desc like '%MYVVI%' then '02.PERODUA'
when Model_Desc like '%MYVY%' then '02.PERODUA'
when Model_Desc like '%VIVA%' then '02.PERODUA'
when Model_Desc like 'ELITE%' then '02.PERODUA'
when Model_Desc like '%ALZA%' then '02.PERODUA'
when Model_Desc like '%AXIA%' then '02.PERODUA'
when Model_Desc like '%KANCIL%' then '02.PERODUA'
when Model_Desc like '%KENARI%' then '02.PERODUA'
when Model_Desc like '%KELISA%' then '02.PERODUA'
when Model_Desc like '%KEMBARA%' then '02.PERODUA'
when Model_Desc like '%NAUTICA%' then '02.PERODUA'
when Model_Desc like 'RUSA%' then '02.PERODUA'

when Model_Desc like '%TOYOTA%' then '03.TOYOTA'
when Model_Desc like '%VIOS%' then '03.TOYOTA'
when Model_Desc like 'VOIS%' then '03.TOYOTA'
when Model_Desc like '%VELLFIRE%' then '03.TOYOTA'
when Model_Desc like '%VELFIRE%' then '03.TOYOTA'
when Model_Desc like '%VELLFIER%' then '03.TOYOTA'
when Model_Desc like '%AVANZA%' then '03.TOYOTA'
when Model_Desc like '%ESTIMA%' then '03.TOYOTA'
when Model_Desc like '%INNOVA%' then '03.TOYOTA'
when Model_Desc like '%INOVA%' then '03.TOYOTA'
when Model_Desc like '%CAMRY%' then '03.TOYOTA'
when Model_Desc like '%HILUX%' then '03.TOYOTA'
when Model_Desc like '%HI LUX%' then '03.TOYOTA'
when Model_Desc like '%HI-LUX%' then '03.TOYOTA'
when Model_Desc like '%ALTIS%' then '03.TOYOTA'
when Model_Desc like '%RUSH%' then '03.TOYOTA'
when Model_Desc like '%WISH%' then '03.TOYOTA'
when Model_Desc like '%PRIUS%' then '03.TOYOTA'
when Model_Desc like '%FORTUNER%' then '03.TOYOTA'
when Model_Desc like '%FORTUNE%' then '03.TOYOTA'
when Model_Desc like '%ALPHARD%' then '03.TOYOTA'
when Model_Desc like '%ALPAHRD%' then '03.TOYOTA'
when Model_Desc like '%PRADO%' then '03.TOYOTA'
when Model_Desc like '%HIACE%' then '03.TOYOTA'
when Model_Desc like '%HI ACE%' then '03.TOYOTA'
when Model_Desc like '%HAICE%' then '03.TOYOTA'
when Model_Desc like '%HARRIER%' then '03.TOYOTA'
when Model_Desc like '%HARIER%' then '03.TOYOTA'
when Model_Desc like '%UNSER%' then '03.TOYOTA'
when Model_Desc like '%CALDINA%' then '03.TOYOTA'
when Model_Desc like '%PREVIA%' then '03.TOYOTA'
when Model_Desc like '%FJ%CRUISER%' then '03.TOYOTA'
when Model_Desc like '%FJ%CRUSER%' then '03.TOYOTA'
when Model_Desc like '%FJ%CRUSIER%' then '03.TOYOTA'
when Model_Desc like '%FJ%CURSIER%' then '03.TOYOTA'
when Model_Desc like '%LITEACE%' then '03.TOYOTA'
when Model_Desc like 'LY1%' then '03.TOYOTA'
when Model_Desc like 'LY2%' then '03.TOYOTA'
when Model_Desc like 'MARK X%' then '03.TOYOTA'
when Model_Desc like 'MARK-X%' then '03.TOYOTA'
when Model_Desc like 'MATRIX%' then '03.TOYOTA'
when Model_Desc like '%YARIS%' then '03.TOYOTA'
when Model_Desc like '%WALD WW180%' then '03.TOYOTA'
when Model_Desc like '%WALD WW200%' then '03.TOYOTA'
when Model_Desc like 'RAV4%' then '03.TOYOTA'
when Model_Desc like 'RAV 4%' then '03.TOYOTA'
when Model_Desc like '%COROLLA%' then '03.TOYOTA'
when Model_Desc like '%CELICA%' then '03.TOYOTA'
when Model_Desc like 'IPSUM %' then '03.TOYOTA'
when Model_Desc like 'ISIS %' then '03.TOYOTA'
when Model_Desc like '%LAND%CRUISER%' then '03.TOYOTA'
when Model_Desc like '%L/CRUISER%' then '03.TOYOTA'
when Model_Desc like 'L/C%CBA%' then '03.TOYOTA'
when Model_Desc like 'L/C%CYGNUS%' then '03.TOYOTA'
when Model_Desc like 'L/C%CYNUS%' then '03.TOYOTA'
when Model_Desc like 'L/C%HDJ101%' then '03.TOYOTA'
when Model_Desc like 'L/C%UZJ100%' then '03.TOYOTA'
when Model_Desc like 'L/C%UZJ200%' then '03.TOYOTA'
when Model_Desc like 'L/C%URJ202%' then '03.TOYOTA'
when Model_Desc like 'LC%CYGNUS%' then '03.TOYOTA'
when Model_Desc like 'LC%HDJ101%' then '03.TOYOTA'
when Model_Desc like 'LC%UZJ100%' then '03.TOYOTA'
when Model_Desc like 'LC%UZJ200%' then '03.TOYOTA'
when Model_Desc like 'LC%URJ202%' then '03.TOYOTA'
when Model_Desc like '%SOARER%' then '03.TOYOTA'
when Model_Desc like '%VANGUARD%' then '03.TOYOTA'

when Model_Desc like '%HONDA%' then '04.HONDA'
when Model_Desc like '%CRV%' then '04.HONDA'
when Model_Desc like '%CR-V%' then '04.HONDA'
when Model_Desc like '%C-RV%' then '04.HONDA'
when Model_Desc like '%HRV%' then '04.HONDA'
when Model_Desc like '%HR-V%' then '04.HONDA'
when Model_Desc like '%HR V%' then '04.HONDA'
when Model_Desc like '%H-RV%' then '04.HONDA'
when Model_Desc like '%CITY%' then '04.HONDA'
when Model_Desc like '%CIVIC%' then '04.HONDA'
when Model_Desc like '%CIVIV%' then '04.HONDA'
when Model_Desc like '%ACCORD%' then '04.HONDA'
when Model_Desc like '%ACCCORD%' then '04.HONDA'
when Model_Desc like '%ACOORD%' then '04.HONDA'
when Model_Desc like '%JAZZ%' then '04.HONDA'
when Model_Desc like '%STREAM%' then '04.HONDA'
when Model_Desc like '%FREED%' then '04.HONDA'
when Model_Desc like '%INSIGHT%' then '04.HONDA'
when Model_Desc like '%ELYSION%' then '04.HONDA'
when Model_Desc like '%INTEGRA%' then '04.HONDA'
when Model_Desc like '%ODYSSEY%' then '04.HONDA'
when Model_Desc like '%ODDYSSEY%' then '04.HONDA'
when Model_Desc like '%ODESSEY%' then '04.HONDA'
when Model_Desc like '%ODDYSEY%' then '04.HONDA'
when Model_Desc like '%ODEYSSEY%' then '04.HONDA'
when Model_Desc like '%CRZ%' then '04.HONDA'
when Model_Desc like '%CR-Z%' then '04.HONDA'
when Model_Desc like '%STEPWAGON%' then '04.HONDA'
when Model_Desc like '%STEP WAGON%' then '04.HONDA'
when Model_Desc like '%CROSSROAD%' then '04.HONDA'
when Model_Desc like '%CROSS ROAD%' then '04.HONDA'
when Model_Desc like '%GOLDWING%1800%' then '04.HONDA'

when Model_Desc like '%NISSAN%' then '05.NISSAN'
when Model_Desc like '%ALMERA%' then '05.NISSAN'
when Model_Desc like '%ALMEERA%' then '05.NISSAN'
when Model_Desc like '%ALMEARA%' then '05.NISSAN'
when Model_Desc like 'AMERA 1.5%' then '05.NISSAN'
when Model_Desc like '%LIVINA%' then '05.NISSAN'
when Model_Desc like '%GRAND LAVINA%' then '05.NISSAN'
when Model_Desc like '%TEANA%' then '05.NISSAN'
when Model_Desc like '%TEANNA%' then '05.NISSAN'
when Model_Desc like '%SYLPHY%' then '05.NISSAN'
when Model_Desc like '%SLYPHY%' then '05.NISSAN'
when Model_Desc like '%SERENA%' then '05.NISSAN'
when Model_Desc like '%SENTRA%' then '05.NISSAN'
when Model_Desc like '%URVAN%' then '05.NISSAN'
when Model_Desc like '%VANETTE%' then '05.NISSAN'
when Model_Desc like '%VANNETE%' then '05.NISSAN'
when Model_Desc like '%VANNETTE%' then '05.NISSAN'
when Model_Desc like '%NAVARA%' then '05.NISSAN'
when Model_Desc like '%NAVARRA%' then '05.NISSAN'
when Model_Desc like '%LATIO%' then '05.NISSAN'
when Model_Desc like '%FAIRLADY%' then '05.NISSAN'
when Model_Desc like '%FRONTIER%' then '05.NISSAN'
when Model_Desc like '%GTR%' then '05.NISSAN'
when Model_Desc like '%GT-R%' then '05.NISSAN'
when Model_Desc like '%JUKE%' then '05.NISSAN'
when Model_Desc like '%MURANO%' then '05.NISSAN'
when Model_Desc like '%NV200%' then '05.NISSAN'
when Model_Desc like '%NV 200%' then '05.NISSAN'
when Model_Desc like '%YU41H5%' then '05.NISSAN'
when Model_Desc like '%YU41H4%' then '05.NISSAN'
when Model_Desc like '%YU41T5%' then '05.NISSAN'
when Model_Desc like '%X-TRAIL%' then '05.NISSAN'
when Model_Desc like '%X TRAIL%' then '05.NISSAN'
when Model_Desc like '%XTRAIL%' then '05.NISSAN'
when Model_Desc like '%X-GEAR%' then '05.NISSAN'
when Model_Desc like '%X GEAR%' then '05.NISSAN'
when Model_Desc like '%XGEAR%' then '05.NISSAN'
when Model_Desc like '%WINDOW VAN%' then '05.NISSAN'
when Model_Desc like '%SKYLINE%' then '05.NISSAN'
when Model_Desc like '%CEFIRO%' then '05.NISSAN'
when Model_Desc like 'C22 %' then '05.NISSAN'
when Model_Desc like '%ELGRAND%' then '05.NISSAN'
when Model_Desc like 'IMPUL %' then '05.NISSAN'
when Model_Desc like 'PGC 22%' then '05.NISSAN'
when Model_Desc like 'PGC22%' then '05.NISSAN'
when Model_Desc like '%PKD211%' then '05.NISSAN'
when Model_Desc like '%PKD214%' then '05.NISSAN'

when Model_Desc like '%NAZA%' then '06.NAZA/KIA'
when Model_Desc like '%FORTE%' then '06.NAZA/KIA'
when Model_Desc like '%CITRA%' then '06.NAZA/KIA'
when Model_Desc like '%SURIA%' then '06.NAZA/KIA'
when Model_Desc like '%SUTERA%' then '06.NAZA/KIA'
when Model_Desc like '%KIA%' then '06.NAZA/KIA'
when Model_Desc like '%SORENTO%' then '06.NAZA/KIA'
when Model_Desc like '%SPECTRA%' then '06.NAZA/KIA'
when Model_Desc like '%SPORTAGE%' then '06.NAZA/KIA'
when Model_Desc like '%CERATO%' then '06.NAZA/KIA'
when Model_Desc like '%PICANTO%' then '06.NAZA/KIA'
when Model_Desc like '%OPTIMA%' then '06.NAZA/KIA'
when Model_Desc like '%RIO 1.4%' then '06.NAZA/KIA'
when Model_Desc like '%RIO SX%' then '06.NAZA/KIA'
when Model_Desc like '%RIO UB%' then '06.NAZA/KIA'
when Model_Desc like 'RIO %' then '06.NAZA/KIA'
when Model_Desc like '%RONDO%' then '06.NAZA/KIA'
when Model_Desc like '%PREGIO%' then '06.NAZA/KIA'
when Model_Desc like '%CARNIVAL%' then '06.NAZA/KIA'
when Model_Desc like '%CARENS%' then '06.NAZA/KIA'
when Model_Desc like '%BESTARI%' then '06.NAZA/KIA'
when Model_Desc like 'RIA %' then '06.NAZA/KIA'
when Model_Desc like '%FORZA%' then '06.NAZA/KIA'

when Model_Desc like '%MITSUBISHI%' then '07.MITSUBISHI'
when Model_Desc like '%MITSHUBISHI%' then '07.MITSUBISHI'
when Model_Desc like '%TRITON%' then '07.MITSUBISHI'
when Model_Desc like '%PAJERO%' then '07.MITSUBISHI'
when Model_Desc like '%LANCER%' then '07.MITSUBISHI'
when Model_Desc like '%ASX%' then '07.MITSUBISHI'
when Model_Desc like '%MIRAGE%' then '07.MITSUBISHI'
when Model_Desc like '%MIRRAGE%' then '07.MITSUBISHI'
when Model_Desc like '%FUSO%' then '07.MITSUBISHI'
when Model_Desc like '%GRANDIS%' then '07.MITSUBISHI'
when Model_Desc like '%LITE TURBO%' then '07.MITSUBISHI'
when Model_Desc like '%TRITON%' then '07.MITSUBISHI'
when Model_Desc like '%TRITION%' then '07.MITSUBISHI'
when Model_Desc like '%ATTRAGE%' then '07.MITSUBISHI'
when Model_Desc like '%AIRTREK%' then '07.MITSUBISHI'
when Model_Desc like '%FE83PG%' then '07.MITSUBISHI'
when Model_Desc like '%FE637%' then '07.MITSUBISHI'
when Model_Desc like '%FE638%' then '07.MITSUBISHI'
when Model_Desc like '%FE639%' then '07.MITSUBISHI'
when Model_Desc like '%L200 D/CAB%' then '07.MITSUBISHI'
when Model_Desc like '%L200 4X4%' then '07.MITSUBISHI'
when Model_Desc like 'STORM %' then '07.MITSUBISHI'

when Model_Desc like '%MERCEDES%' then '08.MERCEDES BENZ'
when Model_Desc like '%BENZ%' then '08.MERCEDES BENZ'
when Model_Desc like 'A160%' then '08.MERCEDES BENZ'
when Model_Desc like 'A170%' then '08.MERCEDES BENZ'
when Model_Desc like 'A200%' then '08.MERCEDES BENZ'
when Model_Desc like 'A250%' then '08.MERCEDES BENZ'
when Model_Desc like 'A 200%' then '08.MERCEDES BENZ'
when Model_Desc like 'A 250%' then '08.MERCEDES BENZ'
when Model_Desc like 'B170%' then '08.MERCEDES BENZ'
when Model_Desc like 'B180%' then '08.MERCEDES BENZ'
when Model_Desc like 'B200%' then '08.MERCEDES BENZ'
when Model_Desc like 'MB B200%' then '08.MERCEDES BENZ'
when Model_Desc like 'MB CLS%' then '08.MERCEDES BENZ'
when Model_Desc like 'B 170%' then '08.MERCEDES BENZ'
when Model_Desc like 'B 180%' then '08.MERCEDES BENZ'
when Model_Desc like 'B 200%' then '08.MERCEDES BENZ'
when Model_Desc like 'C180%' then '08.MERCEDES BENZ'
when Model_Desc like 'C200%' then '08.MERCEDES BENZ'
when Model_Desc like 'C230%' then '08.MERCEDES BENZ'
when Model_Desc like 'C240%' then '08.MERCEDES BENZ'
when Model_Desc like 'C250%' then '08.MERCEDES BENZ'
when Model_Desc like 'C270%' then '08.MERCEDES BENZ'
when Model_Desc like 'C300%' then '08.MERCEDES BENZ'
when Model_Desc like 'C 180%' then '08.MERCEDES BENZ'
when Model_Desc like 'C 200%' then '08.MERCEDES BENZ'
when Model_Desc like 'C 230%' then '08.MERCEDES BENZ'
when Model_Desc like 'C 240%' then '08.MERCEDES BENZ'
when Model_Desc like 'C 250%' then '08.MERCEDES BENZ'
when Model_Desc like 'C 270%' then '08.MERCEDES BENZ'
when Model_Desc like 'C 300%' then '08.MERCEDES BENZ'
when Model_Desc like 'E200%' then '08.MERCEDES BENZ'
when Model_Desc like 'E220%' then '08.MERCEDES BENZ'
when Model_Desc like 'E230%' then '08.MERCEDES BENZ'
when Model_Desc like 'E240%' then '08.MERCEDES BENZ'
when Model_Desc like 'E250%' then '08.MERCEDES BENZ'
when Model_Desc like 'E270%' then '08.MERCEDES BENZ'
when Model_Desc like 'E280%' then '08.MERCEDES BENZ'
when Model_Desc like 'E300%' then '08.MERCEDES BENZ'
when Model_Desc like 'E320%' then '08.MERCEDES BENZ'
when Model_Desc like 'E350%' then '08.MERCEDES BENZ'
when Model_Desc like 'E400%' then '08.MERCEDES BENZ'
when Model_Desc like 'E 200%' then '08.MERCEDES BENZ'
when Model_Desc like 'E 220%' then '08.MERCEDES BENZ'
when Model_Desc like 'E 230%' then '08.MERCEDES BENZ'
when Model_Desc like 'E 240%' then '08.MERCEDES BENZ'
when Model_Desc like 'E 250%' then '08.MERCEDES BENZ'
when Model_Desc like 'E 270%' then '08.MERCEDES BENZ'
when Model_Desc like 'E 280%' then '08.MERCEDES BENZ'
when Model_Desc like 'E 300%' then '08.MERCEDES BENZ'
when Model_Desc like 'E 320%' then '08.MERCEDES BENZ'
when Model_Desc like 'E 350%' then '08.MERCEDES BENZ'
when Model_Desc like 'E 400%' then '08.MERCEDES BENZ'
when Model_Desc like '%SLK%' then '08.MERCEDES BENZ'
when Model_Desc like '%ML250%' then '08.MERCEDES BENZ'
when Model_Desc like '%ML270%' then '08.MERCEDES BENZ'
when Model_Desc like '%ML280%' then '08.MERCEDES BENZ'
when Model_Desc like '%ML300%' then '08.MERCEDES BENZ'
when Model_Desc like '%ML350%' then '08.MERCEDES BENZ'
when Model_Desc like '%ML 250%' then '08.MERCEDES BENZ'
when Model_Desc like '%ML 270%' then '08.MERCEDES BENZ'
when Model_Desc like '%ML 280%' then '08.MERCEDES BENZ'
when Model_Desc like '%ML 300%' then '08.MERCEDES BENZ'
when Model_Desc like '%ML 350%' then '08.MERCEDES BENZ'
when Model_Desc like '%VITO%' then '08.MERCEDES BENZ'
when Model_Desc like 'S500%' then '08.MERCEDES BENZ'
when Model_Desc like 'S400%' then '08.MERCEDES BENZ'
when Model_Desc like 'S350%' then '08.MERCEDES BENZ'
when Model_Desc like 'S320%' then '08.MERCEDES BENZ'
when Model_Desc like 'S300%' then '08.MERCEDES BENZ'
when Model_Desc like 'S280%' then '08.MERCEDES BENZ'
when Model_Desc like 'S200%' then '08.MERCEDES BENZ'
when Model_Desc like 'S 500%' then '08.MERCEDES BENZ'
when Model_Desc like 'S 400%' then '08.MERCEDES BENZ'
when Model_Desc like 'S 350%' then '08.MERCEDES BENZ'
when Model_Desc like 'S 320%' then '08.MERCEDES BENZ'
when Model_Desc like 'S 300%' then '08.MERCEDES BENZ'
when Model_Desc like 'S 280%' then '08.MERCEDES BENZ'
when Model_Desc like 'S 200%' then '08.MERCEDES BENZ'
when Model_Desc like 'SL350%' then '08.MERCEDES BENZ'
when Model_Desc like 'CLS%' then '08.MERCEDES BENZ'
when Model_Desc like 'CLK%' then '08.MERCEDES BENZ'
when Model_Desc like 'A CLASS%' then '08.MERCEDES BENZ'
when Model_Desc like 'A-CLASS%' then '08.MERCEDES BENZ'
when Model_Desc like 'E CLASS%' then '08.MERCEDES BENZ'
when Model_Desc like 'E-CLASS%' then '08.MERCEDES BENZ'
when Model_Desc like 'A45 AMG%' then '08.MERCEDES BENZ'
when Model_Desc like 'A45AMG%' then '08.MERCEDES BENZ'
when Model_Desc like 'G63 AMG%' then '08.MERCEDES BENZ'
when Model_Desc like 'G63AMG%' then '08.MERCEDES BENZ'
when Model_Desc like 'R280L%' then '08.MERCEDES BENZ'
when Model_Desc like 'R300L%' then '08.MERCEDES BENZ'
when Model_Desc like 'R350L%' then '08.MERCEDES BENZ'

when Model_Desc like '%BMW%' then '09.BMW'
when Model_Desc like '%316I%' then '09.BMW'
when Model_Desc like '%318I%' then '09.BMW'
when Model_Desc like '%320I%' then '09.BMW'
when Model_Desc like '%323I%' then '09.BMW'
when Model_Desc like '%325I%' then '09.BMW'
when Model_Desc like '%328I%' then '09.BMW'
when Model_Desc like '%520I%' then '09.BMW'
when Model_Desc like '%523I%' then '09.BMW'
when Model_Desc like '%525I%' then '09.BMW'
when Model_Desc like '%528I%' then '09.BMW'
when Model_Desc like '%530I%' then '09.BMW'
when Model_Desc like '%630I%' then '09.BMW'
when Model_Desc like '%640I%' then '09.BMW'
when Model_Desc like '%645CI%' then '09.BMW'
when Model_Desc like '%740LI%' then '09.BMW'
when Model_Desc like '%750LI%' then '09.BMW'
when Model_Desc like '316 I%' then '09.BMW'
when Model_Desc like '318 I%' then '09.BMW'
when Model_Desc like '320 I%' then '09.BMW'
when Model_Desc like '323 I%' then '09.BMW'
when Model_Desc like '325 I%' then '09.BMW'
when Model_Desc like '328 I%' then '09.BMW'
when Model_Desc like '520 I%' then '09.BMW'
when Model_Desc like '523 I%' then '09.BMW'
when Model_Desc like '525 I%' then '09.BMW'
when Model_Desc like '528 I%' then '09.BMW'
when Model_Desc like '530 I%' then '09.BMW'
when Model_Desc like '630 I%' then '09.BMW'
when Model_Desc like '640 I%' then '09.BMW'
when Model_Desc like '645 CI%' then '09.BMW'
when Model_Desc like '740 LI%' then '09.BMW'
when Model_Desc like '750 LI%' then '09.BMW'
when Model_Desc like 'Z4%' then '09.BMW'
when Model_Desc like '%X6 XDRIVE%' then '09.BMW'
when Model_Desc like 'X6%' then '09.BMW'
when Model_Desc like 'X5%' then '09.BMW'
when Model_Desc like 'X4%' then '09.BMW'
when Model_Desc like 'X3%' then '09.BMW'
when Model_Desc like 'X1%' then '09.BMW'
when Model_Desc like 'M6 %' then '09.BMW'
when Model_Desc like 'M5 %' then '09.BMW'
when Model_Desc like 'M4 %' then '09.BMW'
when Model_Desc like 'M3 %' then '09.BMW'
when Model_Desc like '116I%' then '09.BMW'
when Model_Desc like '118I%' then '09.BMW'
when Model_Desc like '120I%' then '09.BMW'
when Model_Desc like '220I%' then '09.BMW'
when Model_Desc like '%528 M%SPORT%' then '09.BMW'
when Model_Desc like '%528M SPORT%' then '09.BMW'
when Model_Desc like 'R 1200%' then '09.BMW'
when Model_Desc like 'R1200%' then '09.BMW'
when Model_Desc like 'S 1000%' then '09.BMW'
when Model_Desc like 'S1000%' then '09.BMW'
when Model_Desc like 'K 1300%' then '09.BMW'
when Model_Desc like 'K1300%' then '09.BMW'
when Model_Desc like 'K 1600%' then '09.BMW'
when Model_Desc like 'K1600%' then '09.BMW'
when Model_Desc like 'F 700%' then '09.BMW'
when Model_Desc like 'F700%' then '09.BMW'
when Model_Desc like 'F 800%' then '09.BMW'
when Model_Desc like 'F800%' then '09.BMW'

when Model_Desc like '%FORD%' then '10.FORD'
when Model_Desc like '%RANGER%' then '10.FORD'
when Model_Desc like '%FIESTA%' then '10.FORD'
when Model_Desc like '%ECONOVAN%' then '10.FORD'
when Model_Desc like '%ECOSPORT%' then '10.FORD'
when Model_Desc like '%ECO SPORT%' then '10.FORD'
when Model_Desc like '%FOCUS%' then '10.FORD'
when Model_Desc like '%FUSION%' then '10.FORD'
when Model_Desc like '%MUSTANG%' then '10.FORD'
when Model_Desc like '%ESCAPE%' then '10.FORD'
when Model_Desc like '%EVEREST%' then '10.FORD'
when Model_Desc like '%MONDEO%' then '10.FORD'
when Model_Desc like 'S MAX%' then '10.FORD'
when Model_Desc like 'S-MAX%' then '10.FORD'
when Model_Desc like '%KUGA%' then '10.FORD'
when Model_Desc like '%SPECTRON%' then '10.FORD'

when Model_Desc like '%SUZUKI%' then '11.SUZUKI'
when Model_Desc like '%SWIFT%' then '11.SUZUKI'
when Model_Desc like '%VITARA%' then '11.SUZUKI'
when Model_Desc like '%SX4%' then '11.SUZUKI'
when Model_Desc like 'SX 4%' then '11.SUZUKI'
when Model_Desc like '%JIMNY%' then '11.SUZUKI'
when Model_Desc like '%KIZASHI%' then '11.SUZUKI'
when Model_Desc like '%ALTO %' then '11.SUZUKI'
when Model_Desc like '%IGNIS %' then '11.SUZUKI'

when Model_Desc like '%HYUNDAI%' then '12.HYUNDAI'
when Model_Desc like '%VELLOSTER%' then '12.HYUNDAI'
when Model_Desc like '%SONATA%' then '12.HYUNDAI'
when Model_Desc like '%GETZ%' then '12.HYUNDAI'
when Model_Desc like '%GETS%' then '12.HYUNDAI'
when Model_Desc like '%VELOSTER%' then '12.HYUNDAI'
when Model_Desc like '%ATOS%' then '12.HYUNDAI'
when Model_Desc like '%ELANTRA%' then '12.HYUNDAI'
when Model_Desc like '%ELENTRA%' then '12.HYUNDAI'
when Model_Desc like '%TUCSON%' then '12.HYUNDAI'
when Model_Desc like '%TUSCON%' then '12.HYUNDAI'
when Model_Desc like '%ACCENT%' then '12.HYUNDAI'
when Model_Desc like '%STAREX%' then '12.HYUNDAI'
when Model_Desc like '%SANTA FE%' then '12.HYUNDAI'
when Model_Desc like '%SANTE FE%' then '12.HYUNDAI'
when Model_Desc like '%SANTAFE%' then '12.HYUNDAI'
when Model_Desc like 'I10%' then '12.HYUNDAI'
when Model_Desc like 'I-10%' then '12.HYUNDAI'
when Model_Desc like 'I 10%' then '12.HYUNDAI'
when Model_Desc like 'I30%' then '12.HYUNDAI'
when Model_Desc like 'I40%' then '12.HYUNDAI'
when Model_Desc like '%TRAJET%' then '12.HYUNDAI'
when Model_Desc like '%AVANTE 2.0%' then '12.HYUNDAI'

when Model_Desc like '%VOLKSWAGEN%' then '13.VOLKSWAGEN'
when Model_Desc like '%POLO%SEDAN%' then '13.VOLKSWAGEN'
when Model_Desc like '%GOLF%' then '13.VOLKSWAGEN'
when Model_Desc like '%JETTA%' then '13.VOLKSWAGEN'
when Model_Desc like '%BEETLE%' then '13.VOLKSWAGEN'
when Model_Desc like '%BETTLE%' then '13.VOLKSWAGEN'
when Model_Desc like '%PASSAT%' then '13.VOLKSWAGEN'
when Model_Desc like '%VW POLO%' then '13.VOLKSWAGEN'
when Model_Desc like '%V/WAGEN%' then '13.VOLKSWAGEN'
when Model_Desc like '%TOURAN%' then '13.VOLKSWAGEN'
when Model_Desc like '%TOUAREG%' then '13.VOLKSWAGEN'
when Model_Desc like '%TOUREG%' then '13.VOLKSWAGEN'
when Model_Desc like '%TIGUAN%' then '13.VOLKSWAGEN'
when Model_Desc like '%SCIROCCO%' then '13.VOLKSWAGEN'
when Model_Desc like '%SCIRICCO%' then '13.VOLKSWAGEN'
when Model_Desc like '%SHARAN%' then '13.VOLKSWAGEN'
when Model_Desc like '%POLO%1.2%' then '13.VOLKSWAGEN'
when Model_Desc like '%POLO%1.6%' then '13.VOLKSWAGEN'
when Model_Desc like '%POLO%1.4%' then '13.VOLKSWAGEN'
when Model_Desc like '%POLO HB%' then '13.VOLKSWAGEN'
when Model_Desc like '%POLO H/B%' then '13.VOLKSWAGEN'
when Model_Desc like '%POLO HATCHBACK%' then '13.VOLKSWAGEN'

when Model_Desc like '%POLO NB%' then '13.VOLKSWAGEN'
when Model_Desc like '%POLO%GTI%' then '13.VOLKSWAGEN'
when Model_Desc like '%POLO SPORT%' then '13.VOLKSWAGEN'
when Model_Desc like '%CROSSPOLO%' then '13.VOLKSWAGEN'
when Model_Desc like '%CROSS POLO%' then '13.VOLKSWAGEN'
when Model_Desc like '%CROSS TAURAN%' then '13.VOLKSWAGEN'

when Model_Desc like '%PEUGEOT%' then '14.PEUGEOT'
when Model_Desc like '%3008%' then '14.PEUGEOT'
when Model_Desc like '%5008%' then '14.PEUGEOT'
when Model_Desc like '207%' then '14.PEUGEOT'
when Model_Desc like '208%' then '14.PEUGEOT'
when Model_Desc like '308%' then '14.PEUGEOT'
when Model_Desc like '407%' then '14.PEUGEOT'
when Model_Desc like '408%' then '14.PEUGEOT'
when Model_Desc like '508%' then '14.PEUGEOT'
when Model_Desc like 'RCZ%' then '14.PEUGEOT'
when Model_Desc like '%2008%' then '14.PEUGEOT'

when Model_Desc like '%ISUZU%' then '15.ISUZU'
when Model_Desc like '%D-MAX%' then '15.ISUZU'
when Model_Desc like 'DMAX%' then '15.ISUZU'
when Model_Desc like 'D%MAX%' then '15.ISUZU'
when Model_Desc like '%N-SERIES%' then '15.ISUZU'
when Model_Desc like '%NHR69%' then '15.ISUZU'
when Model_Desc like '%NHR 69%' then '15.ISUZU'
when Model_Desc like '%NKR55%' then '15.ISUZU'
when Model_Desc like '%NKR 55%' then '15.ISUZU'
when Model_Desc like '%NKR66%' then '15.ISUZU'
when Model_Desc like '%NKR 66%' then '15.ISUZU'
when Model_Desc like '%NKS58%' then '15.ISUZU'
when Model_Desc like '%NKS 58%' then '15.ISUZU'
when Model_Desc like '%NPR66%' then '15.ISUZU'
when Model_Desc like '%NPR 66%' then '15.ISUZU'
when Model_Desc like '%NPR71%' then '15.ISUZU'
when Model_Desc like '%NPR 71%' then '15.ISUZU'
when Model_Desc like '%NPR72%' then '15.ISUZU'
when Model_Desc like '%NPR 72%' then '15.ISUZU'
when Model_Desc like '%NPS71%' then '15.ISUZU'
when Model_Desc like '%NPS 71%' then '15.ISUZU'
when Model_Desc like '%V-CROSS%' then '15.ISUZU'
when Model_Desc like '%TROOPER%' then '15.ISUZU'
when Model_Desc like '%FTR32R%' then '15.ISUZU'
when Model_Desc like '%FTR33R%' then '15.ISUZU'
when Model_Desc like '%INVADER%2.8%' then '15.ISUZU'
when Model_Desc like '%TFR54%' then '15.ISUZU'
when Model_Desc like '%TFR85%' then '15.ISUZU'
when Model_Desc like '%TFS55%' then '15.ISUZU'
when Model_Desc like '%TFS77%' then '15.ISUZU'
when Model_Desc like '%TFS85%' then '15.ISUZU'
when Model_Desc like '%TFS86%' then '15.ISUZU'

when Model_Desc like '%MAZDA%' then '16.MAZDA'
when Model_Desc like '%BT50%' then '16.MAZDA'
when Model_Desc like '%BT-50%' then '16.MAZDA'
when Model_Desc like '%BT 50%' then '16.MAZDA'
when Model_Desc like '%CX5%' then '16.MAZDA'
when Model_Desc like '%CX 5%' then '16.MAZDA'
when Model_Desc like '%CX-5%' then '16.MAZDA'
when Model_Desc like '%CX7%' then '16.MAZDA'
when Model_Desc like '%CX 7%' then '16.MAZDA'
when Model_Desc like '%CX-7%' then '16.MAZDA'
when Model_Desc like '%CX9%' then '16.MAZDA'
when Model_Desc like '%CX 9%' then '16.MAZDA'
when Model_Desc like '%CX-9%' then '16.MAZDA'
when Model_Desc like '%RX 8%' then '16.MAZDA'
when Model_Desc like '%RX-8%' then '16.MAZDA'
when Model_Desc like '%2 1.5%' then '16.MAZDA'
when Model_Desc like '%3 1.6%' then '16.MAZDA'
when Model_Desc like '%3 2.0%' then '16.MAZDA'
when Model_Desc like '%5 2.0%' then '16.MAZDA'
when Model_Desc like '%6 2.0%' then '16.MAZDA'
when Model_Desc like '%6 2.5%' then '16.MAZDA'
when Model_Desc like '%8 2.3%' then '16.MAZDA'
when Model_Desc like '%2  1.5%' then '16.MAZDA'
when Model_Desc like '%3  1.6%' then '16.MAZDA'
when Model_Desc like '%3  2.0%' then '16.MAZDA'
when Model_Desc like '%5  2.0%' then '16.MAZDA'
when Model_Desc like '%6  2.0%' then '16.MAZDA'
when Model_Desc like '%6  2.5%' then '16.MAZDA'
when Model_Desc like '%8  2.3%' then '16.MAZDA'
when Model_Desc like '%2 SKYACTIV%' then '16.MAZDA'
when Model_Desc like '%3 SKYACTIV%' then '16.MAZDA'
when Model_Desc like '%6 SKYACTIV%' then '16.MAZDA'
when Model_Desc like '%2 SEDAN%' then '16.MAZDA'
when Model_Desc like '%2 SDN%' then '16.MAZDA'
when Model_Desc like '%3 SEDAN%' then '16.MAZDA'
when Model_Desc like '%3 SDN%' then '16.MAZDA'
when Model_Desc like '%6 SEDAN%' then '16.MAZDA'
when Model_Desc like '%6 SDN%' then '16.MAZDA'
when Model_Desc like '%RX8%' then '16.MAZDA'
when Model_Desc like '%RX-8%' then '16.MAZDA'
when Model_Desc like '%PREMACY%' then '16.MAZDA'
when Model_Desc like '%BIANTE%' then '16.MAZDA'
when Model_Desc like 'B2500%' then '16.MAZDA'
when Model_Desc like '3 SPORT%' then '16.MAZDA'

when Model_Desc like '%CHEVROLET%' then '17.CHEVROLET'
when Model_Desc like '%CRUZE%' then '17.CHEVROLET'
when Model_Desc like '%CAPTIVA%' then '17.CHEVROLET'
when Model_Desc like '%SONIC%' then '17.CHEVROLET'
when Model_Desc like '%OPTRA%' then '17.CHEVROLET'
when Model_Desc like '%ORLANDO%' then '17.CHEVROLET'
when Model_Desc like '%COLORADO%' then '17.CHEVROLET'
when Model_Desc like '%NABIRA%' then '17.CHEVROLET'
when Model_Desc like '%AVEO%' then '17.CHEVROLET'

when Model_Desc like '%SUBARU%' then '18.SUBARU'
when Model_Desc like '%IMPREZA%' then '18.SUBARU'
when Model_Desc like '%FORESTER%' then '18.SUBARU'
when Model_Desc like '%XV 2.0%' then '18.SUBARU'
when Model_Desc like '%XV2.0%' then '18.SUBARU'
when Model_Desc like 'LEGACY%' then '18.SUBARU'
when Model_Desc like 'XV %' then '18.SUBARU'

when Model_Desc like '%CHERY%' then '19.CHERY'
when Model_Desc like '%TIGGO%' then '19.CHERY'
when Model_Desc like '%TRANSCOM%' then '19.CHERY'
when Model_Desc like '%EASTER%' then '19.CHERY'
when Model_Desc like '%EASTAR%' then '19.CHERY'
when Model_Desc like 'QQ %' then '19.CHERY'

when Model_Desc like '%LEXUS%' then '20.LEXUS'
when Model_Desc like '%RX450%' then '20.LEXUS'
when Model_Desc like '%RX 450%' then '20.LEXUS'
when Model_Desc like '%RX350%' then '20.LEXUS'
when Model_Desc like '%RX 350%' then '20.LEXUS'
when Model_Desc like '%RX300%' then '20.LEXUS'
when Model_Desc like '%RX 300%' then '20.LEXUS'
when Model_Desc like '%RX270%' then '20.LEXUS'
when Model_Desc like '%RX 270%' then '20.LEXUS'
when Model_Desc like '%CT200%' then '20.LEXUS'
when Model_Desc like '%CT 200%' then '20.LEXUS'
when Model_Desc like '%ES 250%' then '20.LEXUS'
when Model_Desc like '%ES250%' then '20.LEXUS'
when Model_Desc like '%GS250%' then '20.LEXUS'
when Model_Desc like '%GS300%' then '20.LEXUS'
when Model_Desc like '%GS350%' then '20.LEXUS'
when Model_Desc like '%GS 250%' then '20.LEXUS'
when Model_Desc like '%GS 300%' then '20.LEXUS'
when Model_Desc like '%GS 350%' then '20.LEXUS'
when Model_Desc like '%IS250%' then '20.LEXUS'
when Model_Desc like '%IS 250%' then '20.LEXUS'
when Model_Desc like '%NX200%' then '20.LEXUS'
when Model_Desc like '%NX 200%' then '20.LEXUS'

when Model_Desc like '%HICOM%' then '21.HICOM'
when Model_Desc like '%MTB150%' then '21.HICOM'
when Model_Desc like '%MTB 150%' then '21.HICOM'
when Model_Desc like '%MTB145%' then '21.HICOM'
when Model_Desc like '%MTB 145%' then '21.HICOM'
when Model_Desc like '%PERKASA%' then '21.HICOM'

when Model_Desc like '%VOLVO%' then '22.VOLVO'
when Model_Desc like '%XC90%' then '22.VOLVO'
when Model_Desc like '%XC60%' then '22.VOLVO'
when Model_Desc like '%XC80%' then '22.VOLVO'
when Model_Desc like '%XC 90%' then '22.VOLVO'
when Model_Desc like '%XC 60%' then '22.VOLVO'
when Model_Desc like '%XC 80%' then '22.VOLVO'
when Model_Desc like 'V40%' then '22.VOLVO'
when Model_Desc like 'V50%' then '22.VOLVO'
when Model_Desc like 'V60%' then '22.VOLVO'
when Model_Desc like 'V70%' then '22.VOLVO'
when Model_Desc like 'S80 %' then '22.VOLVO'
when Model_Desc like 'S60 %' then '22.VOLVO'
when Model_Desc like 'S40 %' then '22.VOLVO'

when Model_Desc like 'AUDI%' then '23.AUDI'
when Model_Desc like 'TT%' then '23.AUDI'
when Model_Desc like 'Q7 %' then '23.AUDI'
when Model_Desc like 'Q5 %' then '23.AUDI'
when Model_Desc like 'Q3 %' then '23.AUDI'
when Model_Desc like 'A7 %' then '23.AUDI'
when Model_Desc like 'A6 %' then '23.AUDI'
when Model_Desc like 'A5 %' then '23.AUDI'
when Model_Desc like 'A4 %' then '23.AUDI'
when Model_Desc like 'A3 %' then '23.AUDI'
when Model_Desc like 'R8 %' then '23.AUDI'
when Model_Desc like 'S5 %' then '23.AUDI'
when Model_Desc like 'S4 %' then '23.AUDI'

when Model_Desc like '%PORSCHE%' then '24.PORSCHE'
when Model_Desc like '%CAYENNE%' then '24.PORSCHE'
when Model_Desc like '%CAYMAN%' then '24.PORSCHE'
when Model_Desc like '%MACAN%' then '24.PORSCHE'
when Model_Desc like '%PANAMERA%' then '24.PORSCHE'
when Model_Desc like '%BOXSTER%' then '24.PORSCHE'

else 0 end as VEHICLE_GROUP
from VEC_GROUP a
; """)

conn.commit()



VEC_GROUP1 = pd.read_sql_query("SELECT * FROM VEC_GROUP1", conn)



AITAB9_1 = AITAB9.merge(VEC_GROUP1[['MODEL_DESC','VEHICLE_GROUP']].drop_duplicates(),on='MODEL_DESC',how='left')



c.execute("drop table VEC_GROUP1")
conn.commit() 

conn.close()

# %%
application['Cus_No1'] = np.where(application.Cus_No == 0, 0, 1)
application2 = application.iloc[np.where(application.Cus_No1==1)]
application1 = application2[['Cus_No','Aa_number','Repayment_capacity']]
application1 = application1.groupby(['Cus_No','Aa_number'])[['Repayment_capacity']].sum().reset_index()
application1.columns = application1.columns.str.upper()

# %%
AITAB9a = pd.merge(AITAB9_1, application1, on=["CUS_NO","AA_NUMBER"], how="left")

# %%
AITAB9a.fillna(0,inplace=True)

# %%
def Race(M_RACE_CD):
    if M_RACE_CD==1.0:
        return 'Malay'
    elif M_RACE_CD==2.0:
        return 'Native'
    elif M_RACE_CD==3.0:
        return 'Chinese'
    elif M_RACE_CD==4.0:
        return 'Indian'
    elif M_RACE_CD==99.0:
        return 'Others'
    else: 
        return 'Not Populated' 
AITAB9a['RACE'] = AITAB9a['M_RACE_CD'].apply(Race)

#============================================================================

def Gender(SEX):
    if SEX==1.0:
        return 'Female'
    elif SEX==2.0: 
        return 'Male'
    else: 
        return 'Not Populated'
AITAB9a['GENDER'] = AITAB9a['SEX'].apply(Gender)

#============================================================================

AITAB9a.BTH_DT = AITAB9a.BTH_DT.astype(str)
AITAB9a['BIRTHDAYYEAR'] = AITAB9a.BTH_DT.str[-6:]

AITAB9a.BIRTHDAYYEAR = AITAB9a.BIRTHDAYYEAR.astype(float)

def AGE(BIRTHDAYYEAR):
    if BIRTHDAYYEAR == 0:
        return 0
    else:
        return 2022 - BIRTHDAYYEAR
AITAB9a['AGE'] = AITAB9a['BIRTHDAYYEAR'].apply(AGE)

#============================================================================

def AGE_RANGE(AGE):
    if AGE >= 1 and AGE < 25: 
        return 'A. <25'
    elif AGE >= 25 and AGE < 30:
        return 'B. 25-29'
    elif AGE >= 30 and AGE < 35:
        return 'C. 30-34'
    elif AGE >= 35 and AGE < 40: 
        return 'D. 35-39'
    elif AGE >= 40 and AGE < 45: 
        return 'E. 40-44'
    elif AGE >= 45 and AGE < 50: 
        return 'F. 45-49'
    elif AGE >= 50 and AGE < 55: 
        return 'G. 50-54'
    elif AGE >= 55 and AGE < 99: 
        return 'H. >=55'
    else: 
        return 'I. NOT POPULATED'
AITAB9a['AGE_RANGE'] = AITAB9a['AGE'].apply(AGE_RANGE)

#============================================================================

def MARITAL_STATUS(MARRIED):
    if MARRIED=='1': 
        return 'Single'
    elif MARRIED=='2':
        return 'Married'
    else: 
        return 'Not Populated'
AITAB9a['MARITAL_STATUS'] = AITAB9a['MARRIED'].apply(MARITAL_STATUS)

#============================================================================

# %%
AITAB9a.loc[AITAB9a.AMRT_TERM_MULT == 'M', 'TENURE'] = AITAB9a['AMRT_TERM']/12
AITAB9a.loc[AITAB9a.AMRT_TERM_MULT == 'D', 'TENURE'] = AITAB9a['AMRT_TERM']/365
AITAB9a.loc[~((AITAB9a.AMRT_TERM_MULT == 'M') | (AITAB9a.AMRT_TERM_MULT == 'D')), 'TENURE'] = AITAB9a['AMRT_TERM']

# %%
#============================================================================

import datetime

AITAB9a['Date_Released2'] = AITAB9a['DATE_RELEASED'].str.replace("-JAN-", "01").str.replace("-FEB-", "02").str.replace("-MAR-", "03").str.replace("-APR-", "04").str.replace("-MAY-", "05").str.replace("-JUN-", "06").str.replace("-JUL-", "07").str.replace("-AUG-", "08").str.replace("-SEP-", "09").str.replace("-OCT-", "10").str.replace("-NOV-", "11").str.replace("-DEC-", "12")
AITAB9a['Date_Released_Year'] = AITAB9a.Date_Released2.str[-4:]
AITAB9a["Date_Released_Year"].replace({"None": 0,".": 0 }, inplace=True)
AITAB9a.Date_Released_Year = AITAB9a.Date_Released_Year.astype(float)
AITAB9a['Date_Released_3'] = AITAB9a['Date_Released_Year'] - 2022
AITAB9a['Remaining_Tenure'] = AITAB9a['TENURE'] - AITAB9a['Date_Released_3']

# %%
#============================================================================

def Tenure_Grp(Tenure): 
    if Tenure <= 1: 
        return '01. <=1yr'
    elif Tenure > 1 and Tenure <= 3: 
        return '02. >1 - <=3yr'
    elif Tenure > 3 and Tenure <= 5: 
        return '03. >3 - <=5yr'
    elif Tenure > 5 and Tenure <= 7: 
        return '04. >5 - <=7yr'
    elif Tenure > 7 and Tenure <= 9: 
        return '05. >7 - <=9yr'
    elif Tenure > 9: 
        return '06. >9yr'
AITAB9a['Tenure_Grp'] = AITAB9a['TENURE'].apply(Tenure_Grp)

# %%
#============================================================================

def Remaining_Tenure_Grp(Remaining_Tenure):
    if Remaining_Tenure <= 1: 
        return '01. <=1yr'
    elif Remaining_Tenure > 1 and Remaining_Tenure <= 3: 
        return '02. >1 - <=3yr'
    elif Remaining_Tenure > 3 and Remaining_Tenure <= 5 :
        return '03. >3 - <=5yr'
    elif Remaining_Tenure > 5 and Remaining_Tenure <= 7 :
        return '04. >5 - <=7yr'
    elif Remaining_Tenure > 7 and Remaining_Tenure <= 9 :
        return '05. >7 - <=9yr'
    elif Remaining_Tenure > 9 :
        return '06. >9yr'
AITAB9a['Remaining_Tenure_Grp'] = AITAB9a['Remaining_Tenure'].apply(Remaining_Tenure_Grp)

# %%
#============================================================================

def Approved_Limit_Grp(Approved_Limit): 
    if Approved_Limit <= 20000 :
        return '01.<=20k'
    elif Approved_Limit > 20000 and Approved_Limit <= 30000 :
        return '02.>20k - 30k'
    elif Approved_Limit > 30000 and Approved_Limit <= 40000 :
        return '03.>30k - 40k'
    elif Approved_Limit > 40000 and Approved_Limit <= 50000 :
        return '04.>40k - 50k'
    elif Approved_Limit > 50000 and Approved_Limit <= 60000 :
        return '05.>50k - 60k'
    elif Approved_Limit > 60000 and Approved_Limit <= 70000 :
        return '06.>60k - 70k'
    elif Approved_Limit > 70000 and Approved_Limit <= 80000 :
        return '07.>70k - 80k'
    elif Approved_Limit > 80000 and Approved_Limit <= 90000 :
        return '08.>80k - 90k'
    elif Approved_Limit > 90000 and Approved_Limit <= 100000 :
        return '09.>90k - 100k'
    elif Approved_Limit > 100000 and Approved_Limit <= 150000 :
        return '10.>100k - 150k'
    elif Approved_Limit > 150000 and Approved_Limit <= 200000 :
        return '11.>150k - 200k'
    elif Approved_Limit > 200000:
        return '12.>200k'
AITAB9a['Approved_Limit_grp'] = AITAB9a['APPROVED_LIMIT'].apply(Approved_Limit_Grp)

# %%
#============================================================================

def VEHICLE_STATUS(Goods_Status):
     if Goods_Status is "N": 
        return "01.NEW"
     elif Goods_Status is "U":
        return "02.USED"
     elif Goods_Status is "R":
        return "03.RECON"
AITAB9a['VEHICLE_STATUS'] = AITAB9a['GOODS_STATUS'].apply(VEHICLE_STATUS)

#============================================================================

def F_SMA(Mths_Installment_In_Arrears):
    if Mths_Installment_In_Arrears == 2: 
        return 1
    elif Mths_Installment_In_Arrears == 3:
        return 1
    else:
        return 0
AITAB9a['F_SMA'] = AITAB9a['MTHS_INSTALLMENT_IN_ARREARS'].apply(F_SMA)

#============================================================================

def F_WATCHLIST(Mths_Installment_In_Arrears):
    if Mths_Installment_In_Arrears == 1 :
        return 1
    else:
        return 0
AITAB9a['F_WATCHLIST'] = AITAB9a['MTHS_INSTALLMENT_IN_ARREARS'].apply(F_WATCHLIST)

#============================================================================

def Total_mthly_income_grp(Total_mthly_income):
    if Total_mthly_income <= 1000: 
        return '1.<=1k'
    elif Total_mthly_income > 1000 and Total_mthly_income <= 2000:
        return '2.>1k - 2k'
    elif Total_mthly_income > 2000 and Total_mthly_income <= 3000: 
        return '3.>2k - 3k'
    elif Total_mthly_income > 3000 and Total_mthly_income <= 4000 :
        return '4.>3k - 4k'
    elif Total_mthly_income > 4000 and Total_mthly_income <= 5000 :
        return '5.>4k - 5k'
    elif Total_mthly_income > 5000 and Total_mthly_income <= 6000 :
        return '6.>5k - 6k'
    elif Total_mthly_income > 6000 and Total_mthly_income <= 7000 :
        return '7.>6k - 7k'
    elif Total_mthly_income > 7000 and Total_mthly_income <= 8000 :
        return '8.>7k - 8k'
    elif Total_mthly_income > 8000 and Total_mthly_income <= 9000 :
        return '9.>8k - 9k'
    elif Total_mthly_income > 9000 and Total_mthly_income <= 10000 :
        return '10.>9k - 10k'
    elif Total_mthly_income > 10000 and Total_mthly_income <= 15000 :
        return '11.>10k - 15k'
    elif Total_mthly_income > 15000 and Total_mthly_income <= 20000 :
        return '12.>15k - 20k'
    elif Total_mthly_income > 20000 and Total_mthly_income <= 25000 :
        return '13.>20k - 25k'
    elif Total_mthly_income > 25000 and Total_mthly_income <= 30000 :
        return '14.>25k - 30k'
    elif Total_mthly_income > 30000 :
        return '15.>30k'
AITAB9a['Total_mthly_income_grp'] = AITAB9a['Total_mthly_income'].apply(Total_mthly_income_grp)

# %%
#============================================================================

#case sept
AITAB9a['MOF'] = AITAB9a['APPROVED_LIMIT']/AITAB9a['CASH_PRICE']

#case as per usual
#def MOF(Approved_Limit,Cash_Price):
#    if Approved_Limit == 0:
#        return 0
#    elif Cash_Price == 0:
#        return 0
#    else:
#        return Approved_Limit/Cash_Price
#AITAB9a['MOF'] = AITAB9a.apply(lambda x: MOF(x['APPROVED_LIMIT'], x['CASH_PRICE']), axis=1)

# %%
#============================================================================


def MOF_BAND(MOF):
    if MOF >= 0 and MOF < 0.7: 
        return "01.<70%"
    elif MOF >= 0.7 and MOF <= 0.8: 
        return "02.70% - <80%"
    elif MOF >= 0.8 and MOF <= 0.85: 
        return "03.80% - <85%"
    else:
        return "04.>85%"
AITAB9a['MOF_BAND'] = AITAB9a['MOF'].apply(MOF_BAND)

#============================================================================

def Total_mthly_income_CM_grp(Total_mthly_income_Cust):
    if Total_mthly_income_Cust <= 1000: 
        return '1.<=1k'
    elif Total_mthly_income_Cust > 1000 and Total_mthly_income_Cust <= 2000: 
        return '2.>1k - 2k'
    elif Total_mthly_income_Cust > 2000 and Total_mthly_income_Cust <= 3000: 
        return '3.>2k - 3k'
    elif Total_mthly_income_Cust > 3000 and Total_mthly_income_Cust <= 4000:
        return '4.>3k - 4k'
    elif Total_mthly_income_Cust > 4000 and Total_mthly_income_Cust <= 5000 :
        return '5.>4k - 5k'
    elif Total_mthly_income_Cust > 5000 and Total_mthly_income_Cust <= 6000 :
        return '6.>5k - 6k'
    elif Total_mthly_income_Cust > 6000 and Total_mthly_income_Cust <= 7000 :
        return '7.>6k - 7k'
    elif Total_mthly_income_Cust > 7000 and Total_mthly_income_Cust <= 8000 :
        return '8.>7k - 8k'
    elif Total_mthly_income_Cust > 8000 and Total_mthly_income_Cust <= 9000 :
        return '9.>8k - 9k'
    elif Total_mthly_income_Cust > 9000 and Total_mthly_income_Cust <= 10000 :
        return '10.>9k - 10k'
    elif Total_mthly_income_Cust > 10000 and Total_mthly_income_Cust <= 15000 :
        return '11.>10k - 15k'
    elif Total_mthly_income_Cust > 15000 and Total_mthly_income_Cust <= 20000 :
        return '12.>15k - 20k'
    elif Total_mthly_income_Cust > 20000 and Total_mthly_income_Cust <= 25000 :
        return '13.>20k - 25k'
    elif Total_mthly_income_Cust > 25000 and Total_mthly_income_Cust <= 30000 :
        return '14.>25k - 30k'
    elif Total_mthly_income_Cust > 30000 :
        return '15.>30k'
AITAB9a['Total_mthly_income_CM_grp'] = AITAB9a['Total_mthly_income_Cust'].apply(Total_mthly_income_CM_grp)

#============================================================================

def DSR(Debt_ratio):
    if Debt_ratio <= 10: 
        return "01.<=10%"
    elif Debt_ratio > 10 and Debt_ratio <= 20 :
        return "02.<=20%"
    elif Debt_ratio > 20 and Debt_ratio <= 30 :
        return "03.<=30%"
    elif Debt_ratio > 30 and Debt_ratio <= 40 :
        return "04.<=40%"
    elif Debt_ratio > 40 and Debt_ratio <= 50 :
        return "05.<=50%"
    elif Debt_ratio > 50 and Debt_ratio <= 60 :
        return "06.<=60%"
    elif Debt_ratio > 60 and Debt_ratio <= 70 :
        return "07.<=70%"
    elif Debt_ratio > 70 and Debt_ratio <= 80 :
        return "08.<=80%"
    elif Debt_ratio > 80 :
        return "09.>80%"
    else:
        return "10.Not Populated"
AITAB9a['DSR'] = AITAB9a['Debt_ratio'].apply(DSR)

# %%
#============================================================================

import datetime
RDATE1 = pd.to_datetime(RATE_1, format='%Y%m%d')

AITAB9a['RDAY2'] = RDATE1 - (pd.to_datetime(AITAB9a['Date_Released2'], format='%d%m%Y')) 
AITAB9a['RDAY3'] = pd.to_numeric(AITAB9a['RDAY2'].dt.days, downcast='integer')

AITAB9a['MOB'] = (AITAB9a['RDAY3']/30.417) + 1 #30.417 tu hari dlm sebulan

# %%
AITAB9a.loc[AITAB9a['MOB'] < NMONTH, 'Avg_Book_Bal_YTD'] = AITAB9a['AVG_BOOK_BAL_SUM']/AITAB9a['MOB']

AITAB9a.loc[~(AITAB9a['MOB'] < NMONTH), 'Avg_Book_Bal_YTD'] = AITAB9a['AVG_BOOK_BAL_SUM']/NMONTH

AITAB9a.loc[AITAB9a['RDAY3'] < RDAY1, 'Non_Interest_Income_YTD'] = (NII*AITAB9a['Avg_Book_Bal_YTD'])/(AITAB9a['RDAY3']*nYear)

# %%
AITAB9a.loc[~(AITAB9a['RDAY3'] < RDAY1), 'Non_Interest_Income_YTD'] = (NII*AITAB9a['Avg_Book_Bal_YTD'])/(RDAY1*nYear)

AITAB9a.loc[AITAB9a['RDAY3'] < RDAY1, 'Overhead_Expenses_YTD'] = (OE*AITAB9a['Avg_Book_Bal_YTD'])/(AITAB9a['RDAY3']*nYear)

AITAB9a.loc[~(AITAB9a['RDAY3'] < RDAY1), 'Overhead_Expenses_YTD'] = (OE*AITAB9a['Avg_Book_Bal_YTD'])/(RDAY1*nYear)

AITAB9a.loc[AITAB9a['RDAY3'] < RDAY1, 'Interest_Income_Myr_Ann'] = AITAB9a['INTEREST_INCOME_MYR_YTD'] /(AITAB9a['RDAY3']*nYear)

AITAB9a.loc[~(AITAB9a['RDAY3'] < RDAY1), 'Interest_Income_Myr_Ann'] = AITAB9a['INTEREST_INCOME_MYR_YTD'] /(RDAY1 * nYear)

AITAB9a.loc[AITAB9a['RDAY3'] < RDAY1, 'Funds_Charge_Myr_Ann'] = AITAB9a['FUNDS_CHARGE_MYR_YTD'] / (AITAB9a['RDAY3'] * nYear)

AITAB9a.loc[~(AITAB9a['RDAY3'] < RDAY1), 'Funds_Charge_Myr_Ann'] = AITAB9a['FUNDS_CHARGE_MYR_YTD'] / (RDAY1 * nYear)

AITAB9a['Non_Interest_Income_Ann'] = NII * AITAB9a['Avg_Book_Bal_YTD']

AITAB9a['Overhead_Expenses_Ann'] = OE * AITAB9a['Avg_Book_Bal_YTD']

AITAB9a['Revenue'] = AITAB9a['Interest_Income_Myr_Ann'] - AITAB9a['Non_Interest_Income_Ann']

AITAB9a['NPM'] = AITAB9a['Interest_Income_Myr_Ann'] - AITAB9a['Funds_Charge_Myr_Ann']

AITAB10 = AITAB9a.drop(columns =['RDAY3', 'RDAY2','AVG_BOOK_BAL_SUM','Date_Released2',\
                                 'Date_Released_Year','Date_Released_3','BIRTHDAYYEAR'])

RDMS1 = RDMS[['Account_No','Approach','Sector_Category','Rsme_Inclusion_Indicator','Rs_Inclusion_Indicator','Report_Indicator']]
RDMS1 = RDMS1.fillna(0)
RDMS1.columns = RDMS1.columns.str.upper()

aitab = pd.merge(AITAB10, RDMS1, on="ACCOUNT_NO", how="left")

# %%
aitab.to_csv(r'T:\MIB Risk Management\Credit Risk Analytics - Historical\04_Infocube\06_AITAB\\'+str(RATE_1)+'\infocube_06_aitab'+str(RATE_1)+'.txt', index = False)

# %%
aitab.shape
# Out:
# (989887, 127)

# %%
AITAB4.shape
# Out:
# (989887, 59)
