# %% [markdown]
# # Exploratory Data Analysis
# explaning external variable dataset

# %%
import pandas as pd #data manipulation and analysis
import numpy as np #linear Algebra
import matplotlib.pyplot as plt #data visualisation
import seaborn as sns # data visualisation
import warnings #ignore warnings
warnings.filterwarnings('ignore')

# %%
pd.set_option("display.max_columns", None) 
pd.set_option("display.max_colwidth", 1000) #huruf dlm column
pd.set_option("display.max_rows", 100)
pd.set_option("display.precision", 2) #2 titik perpuluhan

# %%
df_ori = pd.read_excel(r"C:\Users\syahidhalid\OneDrive - Export-Import Bank of Malaysia (EXIM Bank)\Exim _ Syahid\Analytics\Loan Growth Model\2024\Loan Growth - Working.xlsx", sheet_name='External')

# %%
df_ori
# Out:
#     Year  LAF (RM'000)  Fed Interest Rates (Actual)  FX (1 USD)  \
# 0   2008      1.93e+06                         0.25        3.46
# 1   2009      2.38e+06                         0.25        3.42
# 2   2010      2.07e+06                         0.25        3.08
# 3   2011      2.46e+06                         0.25        3.18
# 4   2012      3.66e+06                         0.25        3.06
# 5   2013      5.83e+06                         0.25        3.28
# 6   2014      8.26e+06                         0.25        3.50
# 7   2015      1.22e+07                         0.50        4.29
# 8   2016      1.31e+07                         0.75        4.49
# 9   2017      1.17e+07                         1.50        4.06
# 10  2018      1.02e+07                         2.50        4.14
# 11  2019      6.78e+06                         1.75        4.09
# 12  2020      5.70e+06                         0.25        4.01
# 13  2021      5.27e+06                         0.25        4.18
# ...

# %%
#df = df_ori.iloc[np.where(df_ori.Year>=2020)][["LAF (RM'000)",
#                                               'Fed Interest Rates (Actual)',
#                                               'FX (1 USD)',
#                                               'OPR (BANK NEGARA)',
#                                               'KLSE Index @ FTSE Bursa MY KLCI Index @ Malaysia Stock Market',
#                                               'GDP per capita growth (annual %) - Malaysia']]

# %%
df_ori.head()
# Out:
#    Year  LAF (RM'000)  Fed Interest Rates (Actual)  FX (1 USD)  \
# 0  2008      1.93e+06                         0.25        3.46
# 1  2009      2.38e+06                         0.25        3.42
# 2  2010      2.07e+06                         0.25        3.08
# 3  2011      2.46e+06                         0.25        3.18
# 4  2012      3.66e+06                         0.25        3.06
#
#    OPR (BANK NEGARA)  \
# 0               3.25
# 1               2.00
# 2               2.75
# 3               3.00
# 4               3.00
#
#    KLSE Index @ FTSE Bursa MY KLCI Index @ Malaysia Stock Market  \
# 0                                                         876.75
# 1                                                        1272.78
# 2                                                        1518.91
# 3                                                        1530.73
# 4                                                        1688.95
#
#    GDP per capita growth (annual %) - Malaysia
# ...

# %%
df_ori.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16 entries, 0 to 15
# Data columns (total 7 columns):
#  #   Column                                                         Non-Null Count  Dtype
# ---  ------                                                         --------------  -----
#  0   Year                                                           16 non-null     int64
#  1   LAF (RM'000)                                                   16 non-null     float64
#  2   Fed Interest Rates (Actual)                                    16 non-null     float64
#  3   FX (1 USD)                                                     16 non-null     float64
#  4   OPR (BANK NEGARA)                                              16 non-null     float64
#  5   KLSE Index @ FTSE Bursa MY KLCI Index @ Malaysia Stock Market  16 non-null     float64
#  6   GDP per capita growth (annual %) - Malaysia                    16 non-null     float64
# dtypes: float64(6), int64(1)
# ...

# %%
df_ori.shape
# Out:
# (16, 7)

# %%
df_ori.columns
# Out:
# Index(['Year', 'LAF (RM'000)', 'Fed Interest Rates (Actual)', 'FX (1 USD)',
#        'OPR (BANK NEGARA)',
#        'KLSE Index @ FTSE Bursa MY KLCI Index @ Malaysia Stock Market',
#        'GDP per capita growth (annual %) - Malaysia'],
#       dtype='object')

# %%
df_ori.describe() #for non object
# Out:
#           Year  LAF (RM'000)  Fed Interest Rates (Actual)  FX (1 USD)  \
# count    16.00      1.60e+01                        16.00       16.00
# mean   2015.50      6.31e+06                         1.20        3.83
# std       4.76      3.75e+06                         1.64        0.53
# min    2008.00      1.93e+06                         0.25        3.06
# 25%    2011.75      3.36e+06                         0.25        3.39
# 50%    2015.50      5.49e+06                         0.25        4.04
# 75%    2019.25      8.75e+06                         1.56        4.21
# max    2023.00      1.31e+07                         5.50        4.60
#
#        OPR (BANK NEGARA)  \
# count              16.00
# mean                2.81
# std                 0.51
# min                 1.75
# 25%                 2.75
# 50%                 3.00
# 75%                 3.06
# max                 3.25
#
#        KLSE Index @ FTSE Bursa MY KLCI Index @ Malaysia Stock Market  \
# ...

# %%
df_ori.describe(include='O') #for object

# %%
df_ori.['column'].unique() #tuk object value unique

# %%
df_ori.isnull().sum()
# Out:
# Year                                                             0
# LAF (RM'000)                                                     0
# Fed Interest Rates (Actual)                                      0
# FX (1 USD)                                                       0
# OPR (BANK NEGARA)                                                0
# KLSE Index @ FTSE Bursa MY KLCI Index @ Malaysia Stock Market    0
# GDP per capita growth (annual %) - Malaysia                      0
# dtype: int64

# %%
df_ori[df_ori.duplicated]
# Out:
# Empty DataFrame
# Columns: [Year, LAF (RM'000), Fed Interest Rates (Actual), FX (1 USD), OPR (BANK NEGARA), KLSE Index @ FTSE Bursa MY KLCI Index @ Malaysia Stock Market, GDP per capita growth (annual %) - Malaysia]
# Index: []

# %%
df_ori.drop_duplicates(keep='first', inplace=True)

# %% [markdown]
# # Data Visualisation - univariate, bivariate and multivariate analysis

# %%
#1.Summary Statistics
#2.Frequency Distributions Table
#3.Charts ( Boxplot, Histogram, Barplot, Pie Chart)

# %%
plt.figure(figsize=(10,6))
sns.distplot(df_ori["LAF (RM'000)"],color='r')
plt.title('Gross Financing Asset', size=18)
plt.xlabel('LAF', size=14)
plt.ylabel('Density', size=14)
plt.show()

#to show distribution and kernel density,
#below is positively skew between 0.3 to 0.6

# %%
plt.figure(figsize=(10,6))
sns.distplot(df_ori["Fed Interest Rates (Actual)"])
plt.title('Fed Interest Rates (Actual)', size=18)
plt.xlabel('Fed Interest Rates (Actual)', size=14)
plt.ylabel('Density', size=14)
plt.show()

#to show distribution and kernel density,
#below is positively skew between 0.3 to 1

# %%
plt.figure(figsize=(10,6))
sns.distplot(df_ori["FX (1 USD)"],color='y')
plt.title('FX (1 USD)', size=18)
plt.xlabel('FX (1 USD)', size=14)
plt.ylabel('Density', size=14)
plt.show()

#to show distribution and kernel density,
#below is negatively skew between 4 to 4.5

# %%
#for obj

plt.figure(figsize=(10,6))
sns.countplot(x='Year', data=df_ori)
plt.title('Year', size=18)
plt.xlabel('Year', size=14)
plt.ylabel('Count', size=14)
plt.show()

#to show distribution and kernel density,
#below is negatively skew between 4 to 4.5

# %%
df_ori.Year.value_counts()
# Out:
# 2008    1
# 2009    1
# 2010    1
# 2011    1
# 2012    1
# 2013    1
# 2014    1
# 2015    1
# 2016    1
# 2017    1
# 2018    1
# 2019    1
# 2020    1
# 2021    1
# 2022    1
# 2023    1
# Name: Year, dtype: int64

# %%
#bivariate analysis

plt.figure(figsize=(10,6))
sns.scatterplot(x = "LAF (RM'000)", y = "GDP per capita growth (annual %) - Malaysia" ,color='r', data=df_ori)
plt.title('Gross Financing Asset VS Real GDP', size=18)
plt.xlabel('LAF', size=14)
plt.ylabel('GDP', size=14)
plt.show()

#to show distribution and kernel density,
#below is positively skew between 0.3 to 0.6

# %%
#untuk obj

plt.figure(figsize=(10,6))
sns.boxplot(x = "Year", y = "LAF (RM'000)", data=df_ori)
plt.title('LAF vs OPR', size=18)
# Out:
# Text(0.5, 1.0, 'LAF vs OPR')

# %%
sns.pairplot(df_ori,
                 markers="+",
                diag_kind='kde',
                kind='reg',
                plot_kws={'line_kws':{'color':'#aec6cf'},'scatter_kws':{'alpha':0.7,'color':'red'}},corner=True);

# %%
#size of correlation, Intepretation
#0.9 to 1, very high positive (negative) correlation
#0.7 to 0.9, high positive (negative) correlation
#0.5 to 0.7, moderate positive (negative) correlation
#0.4 to 0.5, Low positive (negative) correlation
#0 to 0.3, megligible corelation

# %%
plt.figure(figsize=(10,6))
sns.heatmap(df_ori.corr(),annot=True,square=True)
plt.title('Correlation Between Variables', size=18);
plt.xticks(size=13)
plt.yticks(size=13)
plt.show()

# %% [markdown]
# # Multiple Linear Regression

# %%
dfa = df_ori[["Year","LAF (RM'000)"]]

# %%
#import re
#import pandas as pd

#dfa["LAF (RM'000)"] = pd.to_numeric(dfa["LAF (RM'000)"].apply(lambda x: re.sub(',', '.', str(x))))
dfa["LAF (RM'000)"] = dfa["LAF (RM'000)"].astype(int)

# %%
dfa['YoY Growth'] = dfa["LAF (RM'000)"].pct_change(periods=1) * 100

# %%
dfa1 = dfa.iloc[np.where(dfa.Year>=2020)]

# %%
dfa1
# Out:
#     Year  LAF (RM'000)  YoY Growth
# 12  2020       5704225      -15.85
# 13  2021       5268869       -7.63
# 14  2022       4681504      -11.15
# 15  2023       4696266        0.32

# %%
fig = plt.figure(figsize = (10, 5))
 
# creating the bar plot
plt.bar(dfa["Year"], dfa["LAF (RM'000)"], color ='maroon', 
        width = 0.4)
 
plt.xlabel("Year")
plt.ylabel("Gross Financing")
plt.title("LAF Growth")

plt.show()

# %%
df.head(1)
# Out:
#     LAF (RM'000)  Fed Interest Rates (Actual)  FX (1 USD)  OPR (BANK NEGARA)  \
# 12      5.70e+06                         0.25        4.01               1.75
#
#     KLSE Index @ FTSE Bursa MY KLCI Index @ Malaysia Stock Market  \
# 12                                                        1627.21
#
#     GDP per capita growth (annual %) - Malaysia
# 12                                        -6.58

# %%
from statsmodels.tsa.stattools import grangercausalitytests

maxlag = 3
def grangers_causation_matrix(data, variables, test='ssr_chi2test', verbose=False):    
    """Check Granger Causality of all possible combinations of the Time series.
    The rows are the response variable, columns are predictors. The values in the table 
    are the P-Values. P-Values lesser than the significance level (0.05), implies 
    the Null Hypothesis that the coefficients of the corresponding past values is 
    zero, that is, the X does not cause Y can be rejected.

    data      : pandas dataframe containing the time series variables
    variables : list containing names of the time series variables.
    """
    df = pd.DataFrame(np.zeros((len(variables), len(variables))), columns=variables, index=variables)
    for c in df.columns:
        for r in df.index:
            test_result = grangercausalitytests(data[[r, c]], maxlag=maxlag, verbose=False)
            p_values = [round(test_result[i+1][0][test][1],4) for i in range(maxlag)]
            if verbose: print(f'Y = {r}, X = {c}, P Values = {p_values}')
            min_p_value = np.min(p_values)
            df.loc[r, c] = min_p_value
    df.columns = [var + '_x' for var in variables]
    df.index = [var + '_y' for var in variables]
    return df

A = df_ori[["LAF (RM'000)",'Fed Interest Rates (Actual)']]
B = df_ori[["LAF (RM'000)",'FX (1 USD)']]
C = df_ori[["LAF (RM'000)",'OPR (BANK NEGARA)']]
D = df_ori[["LAF (RM'000)",'KLSE Index @ FTSE Bursa MY KLCI Index @ Malaysia Stock Market']]
E = df_ori[["LAF (RM'000)",'GDP per capita growth (annual %) - Malaysia']]

grangers_causation_matrix(A, variables = A.columns)
# Out:
#                                LAF (RM'000)_x  Fed Interest Rates (Actual)_x
# LAF (RM'000)_y                            1.0                           0.09
# Fed Interest Rates (Actual)_y             0.0                           1.00

# %%
grangers_causation_matrix(B, variables = B.columns)
# Out:
#                 LAF (RM'000)_x  FX (1 USD)_x
# LAF (RM'000)_y            1.00          0.01
# FX (1 USD)_y              0.29          1.00

# %%
grangers_causation_matrix(C, variables = C.columns)
# Out:
#                      LAF (RM'000)_x  OPR (BANK NEGARA)_x
# LAF (RM'000)_y             1.00e+00                 0.17
# OPR (BANK NEGARA)_y        8.90e-03                 1.00

# %%
grangers_causation_matrix(D, variables = D.columns)
# Out:
#                                                                  LAF (RM'000)_x  \
# LAF (RM'000)_y                                                              1.0
# KLSE Index @ FTSE Bursa MY KLCI Index @ Malaysia Stock Market_y             0.1
#
#                                                                  KLSE Index @ FTSE Bursa MY KLCI Index @ Malaysia Stock Market_x
# LAF (RM'000)_y                                                                                                          6.00e-04
# KLSE Index @ FTSE Bursa MY KLCI Index @ Malaysia Stock Market_y                                                         1.00e+00

# %%
grangers_causation_matrix(E, variables = E.columns)
# Out:
#                                                LAF (RM'000)_x  \
# LAF (RM'000)_y                                       1.00e+00
# GDP per capita growth (annual %) - Malaysia_y        7.60e-03
#
#                                                GDP per capita growth (annual %) - Malaysia_x
# LAF (RM'000)_y                                                                           0.4
# GDP per capita growth (annual %) - Malaysia_y                                            1.0

# %%
from sklearn import linear_model

X = df_ori[['Fed Interest Rates (Actual)','FX (1 USD)','OPR (BANK NEGARA)','KLSE Index @ FTSE Bursa MY KLCI Index @ Malaysia Stock Market','GDP per capita growth (annual %) - Malaysia']]
y = df_ori["LAF (RM'000)"]

regr = linear_model.LinearRegression()
regr.fit(X, y)

#regr.coef_

#predictedCO2 = regr.predict([[2300, 1300]])
# Out:
# LinearRegression()

# %%
#display regression coefficients and R-squared value of model
print(regr.intercept_)
print(regr.coef_)
print(regr.score(X, y))

#Using this output, we can write the equation for the fitted regression model:

#y = -38812985.09142425  -1340658.31852561x1 +6715055.10983107x2 +3804337.33990844x3 + 6826.30448118x4 -134233.1218451x5

#We can also see that the R2 value of the model is 0.93. 
#This means that 93% of the variation in the response variable can be explained by the two predictor variables in the model.
#Although this output is useful, we still don’t know the overall F-statistic of the model, the p-values of the individual regression coefficients, and other useful metrics that can help us understand how well the model fits the dataset.
# Out:
# -38812985.09142425
# [-1340658.31852561  6715055.10983107  3804337.33990844     6826.30448118
#   -134233.1218451 ]
# 0.926161424273005

# %%
import statsmodels.api as sm


#add constant to predictor variables
x = sm.add_constant(X)

#fit linear regression model
model = sm.OLS(y, x).fit()

#view model summary
print(model.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:           LAF (RM'000)   R-squared:                       0.926
# Model:                            OLS   Adj. R-squared:                  0.889
# Method:                 Least Squares   F-statistic:                     25.09
# Date:                Mon, 22 Jan 2024   Prob (F-statistic):           2.34e-05
# Time:                        11:57:30   Log-Likelihood:                -243.54
# No. Observations:                  16   AIC:                             499.1
# Df Residuals:                      10   BIC:                             503.7
# Df Model:                           5
# Covariance Type:            nonrobust
# ...
#                                                                     coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------------------------------------------------------
# ...

# %%
intercept = -38812985.09142425
x1 = -1340658.31852561*df_ori["Fed Interest Rates (Actual)"]
x2 = +6715055.10983107*df_ori["FX (1 USD)"]
x3 = +3804337.33990844*df_ori["OPR (BANK NEGARA)"]
x4 = +6826.30448118*df_ori["KLSE Index @ FTSE Bursa MY KLCI Index @ Malaysia Stock Market"]
x5 = -134233.1218451*df_ori["GDP per capita growth (annual %) - Malaysia"]

df_ori["LAF (RM'000)_Predicted"] = intercept + x1 + x2 + x3 + x4 + x5

# %%
df_ori[["LAF (RM'000)","LAF (RM'000)_Predicted"]]
# Out:
#     LAF (RM'000)  LAF (RM'000)_Predicted
# 0       1.93e+06                2.10e+06
# 1       2.38e+06                6.07e+05
# 2       2.07e+06                1.64e+06
# 3       2.46e+06                3.56e+06
# 4       3.66e+06                3.82e+06
# 5       5.83e+06                6.64e+06
# 6       8.26e+06                8.12e+06
# 7       1.22e+07                1.28e+07
# 8       1.31e+07                1.25e+07
# 9       1.17e+07                9.55e+06
# 10      1.02e+07                9.06e+06
# 11      6.78e+06                8.16e+06
# 12      5.70e+06                6.45e+06
# 13      5.27e+06                5.96e+06
# 14      4.68e+06                4.45e+06
# 15      4.70e+06                5.52e+06

# %%
#Graph

plt.figure(figsize=(10,4))
plt.plot(df_ori["LAF (RM'000)"], color='b')
plt.plot(df_ori["LAF (RM'000)_Predicted"], color='r')

plt.legend(['LAF','Predicted LAF'], fontsize=8)

plt.show()

# %%
#example nk 15% growth 5400706.48015064

#y = -38812985.09142425  -1340658.31852561x1 +6715055.10983107x2 +3804337.33990844x3 + 6826.30448118x4 -134233.1218451x5

# %%
#'Fed Interest Rates (Actual)'

# ori x1 = 5.50

Fed23 = 5.50
FX23 = 4.60
OPR23 = 3.0
Bursa23 = 1454.66
GDP23 = 3.90

intercept = -38812985.09142425
x1 = -1340658.31852561*Fed23
x2 = +6715055.10983107*FX23
x3 = +3804337.33990844*OPR23
x4 = +6826.30448118*Bursa23
x5 = -134233.1218451*GDP23

fifteen = 5400706.48015064


newFed = (fifteen - (intercept+x2+x3+x4+x5))/-1340658.31852561

print(newFed)
# Out:
# 5.590549621184173

# %%
#'FX (1 USD)'

# ori x2 = 4.60

Fed23 = 5.50
FX23 = 4.60
OPR23 = 3.0
Bursa23 = 1454.66
GDP23 = 3.90

intercept = -38812985.09142425
x1 = -1340658.31852561*Fed23
x2 = +6715055.10983107*FX23
x3 = +3804337.33990844*OPR23
x4 = +6826.30448118*Bursa23
x5 = -134233.1218451*GDP23

fifteen = 5400706.48015064


newFX = (fifteen - (intercept+x1+x3+x4+x5))/+6715055.10983107

print(newFX)
# Out:
# 4.5819218009540705

# %%
#'OPR (BANK NEGARA)'

# ori x3 = 3.00

Fed23 = 5.50
FX23 = 4.60
OPR23 = 3.0
Bursa23 = 1454.66
GDP23 = 3.90

intercept = -38812985.09142425
x1 = -1340658.31852561*Fed23
x2 = +6715055.10983107*FX23
x3 = +3804337.33990844*OPR23
x4 = +6826.30448118*Bursa23
x5 = -134233.1218451*GDP23

fifteen = 5400706.48015064


newOPR = (fifteen - (intercept+x1+x2+x4+x5))/+3804337.33990844

print(newOPR)
# Out:
# 2.9680900792875464

# %%
#'KLSE Index @ FTSE Bursa MY KLCI Index @ Malaysia Stock Market'

# ori x4 = 1454.66

Fed23 = 5.50
FX23 = 4.60
OPR23 = 3.0
Bursa23 = 1454.66
GDP23 = 3.90

intercept = -38812985.09142425
x1 = -1340658.31852561*Fed23
x2 = +6715055.10983107*FX23
x3 = +3804337.33990844*OPR23
x4 = +6826.30448118*Bursa23
x5 = -134233.1218451*GDP23

fifteen = 5400706.48015064


newBursa = (fifteen - (intercept+x1+x2+x3+x5))/+6826.30448118

print(newBursa)
# Out:
# 1436.876424243221

# %%
#'GDP per capita growth (annual %) - Malaysia'

# ori x5 = 3.90

Fed23 = 5.50
FX23 = 4.60
OPR23 = 3.0
Bursa23 = 1454.66
GDP23 = 3.90

intercept = -38812985.09142425
x1 = -1340658.31852561*Fed23
x2 = +6715055.10983107*FX23
x3 = +3804337.33990844*OPR23
x4 = +6826.30448118*Bursa23
x5 = -134233.1218451*GDP23

fifteen = 5400706.48015064


newGDP = (fifteen - (intercept+x1+x2+x3+x4))/-134233.1218451

print(newGDP)
# Out:
# 4.804367723936215
