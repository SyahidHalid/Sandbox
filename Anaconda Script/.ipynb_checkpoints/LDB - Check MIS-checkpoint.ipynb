# %%
#control + F + dropdown new to search bar to find and replace 
import pandas as pd
import numpy as np
import xlsxwriter

#warnings.filterwarnings('ignore')
pd.set_option("display.max_columns", None) 
pd.set_option("display.max_colwidth", 1000) #huruf dlm column
pd.set_option("display.max_rows", 100)
pd.set_option("display.precision", 2) #2 titik perpuluhan

# %%
Location = r"C:\Users\syahidhalid\Syahid_PC\Analytics - FAD\00. Automation LDB\Data Source\202405\MIS"
BG = "MIS_CA_202405"
LC = "MIS_Collateral_202405"

CA = pd.read_csv(str(Location)+"\\"+str(BG)+".csv", encoding='ISO-8859-1', on_bad_lines='skip') 
Collateral = pd.read_csv(str(Location)+"\\"+str(LC)+".csv", encoding='ISO-8859-1', on_bad_lines='skip')

# %%
LDB = pd.read_excel(r"C:\Users\syahidhalid\Syahid_PC\Analytics - SPD\Loan Database\LBD 202412 - 202401 (CSP Sector).xlsx", sheet_name="May24")

# %%
Collateral.head(1)
# Out:
#    CIF Number         Customer Name     Exim Account Number Amount Approved  \
# 0  EXIM000012  Jewel Growth Sdn Bhd  3308-01137-209-0014-00      500,000.00
#
#     Account Status                 Facility Type Description  \
# 0  Fully Write-Off  Supplier Credit (Revolving) (Pre & Post)
#
#   Country Description Facility Currency Description Outstanding
# 0            Malaysia                           MYR        0.00

# %%
Collateral['Exim Account Number'].value_counts()
# Out:
# Exim Account Number
# 3308-01137-209-0014-00    1
# 3308-02105-205-0004-00    1
# 3308-01137-112-0180-00    1
# 3308-02246-201-0198-00    1
# 3308-01137-206-0168-00    1
#                          ..
# 3308-02137-112-0073-00    1
# 3308-02137-107-0187-00    1
# 3308-02137-107-0069-00    1
# 3308-01137-216-0062-00    1
# 3308-02138-200-0300-00    1
# Name: count, Length: 320, dtype: int64

# %%
Collateral.iloc[np.where(Collateral['Customer Name'].str.contains("SMH"))]
# Out:
#      CIF Number              Customer Name     Exim Account Number  \
# 169  EXIM000210           SMH RAIL SDN BHD  3308-01137-107-0281-00
# 170  EXIM000210           SMH RAIL SDN BHD  3308-02137-104-0225-00
# 171  EXIM000210           SMH RAIL SDN BHD  3308-02137-104-0227-00
# 172  EXIM000210           SMH RAIL SDN BHD  3308-02137-104-0243-00
# 173  EXIM000210           SMH RAIL SDN BHD  3308-02137-104-0289-00
# 174  EXIM000210           SMH RAIL SDN BHD  3308-02137-117-0222-00
# 175  EXIM000210           SMH RAIL SDN BHD  3308-02137-117-0244-00
# 176  EXIM000210           SMH RAIL SDN BHD  3308-02137-117-0245-00
# 177  EXIM000210           SMH RAIL SDN BHD  3308-02137-204-0116-00
# 178  EXIM000210           SMH RAIL SDN BHD  3308-02137-216-0046-00
# 274  EXIM000284  SMH RAIL THAILAND SDN BHD  3308-02137-107-0239-00
# 304  EXIM000471     SMH RAIL INDIA SDN BHD                     NaN
#
#     Amount Approved    Account Status       Facility Type Description  \
# ...

# %%
CA.head(1)
# Out:
#                                    Customer Name  \
# 0  The Ministry of Finance Government of Lao PDR
#
#   Credit Application Reference No Application Date  \
# 0                    AA0000000458       20-04-2020
#
#   Date of Complete Info Received AMLCFT Rating Final Status  \
# 0                              -           NaN     Approved
#
#   Approved/Rejected Date LO Acceptance Date Post Approval Stage  \
# 0             20-04-2020                  -        Disbursement
#
#   Date of Cancellation Date of Ready for Utilization (RU)  \
# 0                    -                                  -
#
#   1st Disbursement Date FA Date CP Date Date Extract of Decision  \
# 0                     -       -       -                        -
#
#   Ageing (by Days) - Issuance LO Ageing (by Days) - 1st Disbursement  \
# 0                              0                              -43939
#
#   SLO Issuance Date Relationship Manager         Team Banking Effective Date  \
# ...

# %%
test = LDB.merge(Collateral[['Customer Name','Exim Account Number']], on='Customer Name', how='left',indicator=True)

# %%
test._merge.value_counts()
# Out:
# _merge
# both          915
# left_only     119
# right_only      0
# Name: count, dtype: int64

# %%
test.iloc[np.where(test._merge=="left_only")]
# Out:
#       No.  CIF Number        EXIM Account No. Application System Code  \
# 8       9  EXIM000068  3308-02246-201-0009-00                     CBD
# 9      10  EXIM000070  3308-02137-200-0018-00                     EFD
# 110    68  EXIM000127  3308-02105-201-0065-00                     CBD
# 118    74  EXIM000134  3308-03137-110-0166-00                     NaN
# 119    75  EXIM000134  3308-02137-109-0126-00                     NaN
# ...   ...         ...                     ...                     ...
# 1029  488  EXIM000605              1071371629                     NaN
# 1030  489  EXIM000609              1331371638                     NaN
# 1031  489  EXIM000609              1221371639                     NaN
# 1032  489  EXIM000376              1101371584                     NaN
# 1033  490  EXIM000433               212137863                     NaN
#
#      CCRIS Master Account Number CCRIS Sub Account Number Finance(SAP) Number  \
# ...

# %%
import pandas as pd
import numpy as np
import xlsxwriter

#warnings.filterwarnings('ignore')
pd.set_option("display.max_columns", None) 
pd.set_option("display.max_colwidth", 1000) #huruf dlm column
pd.set_option("display.max_rows", 100)
pd.set_option("display.precision", 2) #2 titik perpuluhan

# %%
Debtor = pd.read_excel(r"C:\Users\syahidhalid\Syahid_PC\Analytics - FAD\00. Automation LDB\Data Source\202405\Debtor Listing May 2024 (python).xlsx", sheet_name="Export Worksheet")

# %%
Debtor.Customer_Account.value_counts()
# Out:
# Customer_Account
# 501051    1
# 500811    1
# 501025    1
# 500534    1
# 500530    1
#          ..
# 501080    1
# 501114    1
# 501109    1
# 500948    1
# 500931    1
# Name: count, Length: 259, dtype: int64

# %%
Debtor = pd.read_excel(r"C:\Users\syahidhalid\Syahid_PC\Analytics - FAD\00. Automation LDB\Data Source\202405\Debtor Listing May 2024 (python).xlsx", sheet_name="Contigent Liability MAY2024 (python)")
