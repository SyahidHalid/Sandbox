# %%
Location = r"C:\Users\syahidhalid\Syahid_PC\Analytics - FAD\00. Automation LDB\Data Source\202407"
File = "Loan Database as Jul 2024 (python) - Final"

import pandas as pd
import numpy as np
import xlsxwriter

pd.set_option("display.max_columns", None) 
pd.set_option("display.max_colwidth", 1000) #huruf dlm column
pd.set_option("display.max_rows", 100)
pd.set_option("display.precision", 2) #2 titik perpuluhan

LDB = pd.read_excel(str(Location)+"\\"+str(File)+".xlsx", sheet_name='Export Worksheet', header=1) # skiprows = 2, nrows=18,  usecols= 'A:D'

# %%
LDB1 = LDB.iloc[np.where(LDB['EXIM Account No.']!='Total')]

LDB1.columns = LDB1.columns.str.strip()
LDB1.columns = LDB1.columns.str.replace("\n", "")

# %%
LDB1.tail(1)
# Out:
#        No.  CIF Number          EXIM Account No. Application System Code  \
# 523  524.0  EXIM000624  PENDING FA NO. IN MIS 20                     NaN
#
#     CCRIS Master Account Number CCRIS Sub Account Number Finance(SAP) Number  \
# 523                         NaN                      NaN         NEW ACCOUNT
#
#                 Company Group             Customer Name  \
# 523  OCEAN21 OFFSHORE SDN BHD  OCEAN21 OFFSHORE SDN BHD
#
#     Relationship Manager (RM)        Banking Team Ownership Officer in Charge  \
# 523                   Hanaffy  Commercial Banking       NaN               NaN
#
#     Syndicated / Club Deal  Nature of Account          Facility  \
# 523         Not Applicable  Trade - Guarantee  Term Financing-i
#
#     Facility Currency Type of Financing Shariah Contract / Concept Fund Type  \
# 523               MYR           Islamic       Pending Banking info       NaN
#
#                                        Incentive  \
# 523  Skim Insentif Pemampanan Pengeksport (SIP2)
#
#                            Programme Guarantee                Status  \
# 523  SME Export Emergence "SMEXport"       NaN  Pending Disbursement
#
#        Post Approval Stage Date of Ready for Utilization (RU)  \
# 523  Pending LO Acceptance                                NaN
#
#     Restructured / Rescheduled(Y/N)  \
# 523                             NaN
#
#      Amount Approved / Facility Limit (Facility Currency)  \
# 523                                              2.20e+06
#
#      Amount Approved / Facility Limit (MYR)  \
# 523                                2.20e+06
#
#      Cost/Principal Outstanding (Facility Currency)  \
# 523                                             0.0
#
#      Cost/Principal Outstanding (MYR)  \
# 523                               0.0
#
#      Contingent Liability Letter of Credit (Facility Currency)  \
# 523                                                          0
#
#      Contingent Liability Letter of Credit (MYR)  \
# 523                                            0
#
#      Contingent Liability (Facility Currency)  Contingent Liability (MYR)  \
# 523                                       0.0                         0.0
#
#      Account Receivables/Past Due Claims (Facility Currency)  \
# 523                                                      0.0
#
#      Account Receivable/Past Due Claims (MYR)  \
# 523                                       0.0
#
#      Total Banking Exposure (Facility Currency)  Total Banking Exposure (MYR)  \
# 523                                         0.0                      2.20e+06
#
#      Accrued Profit/Interest of the month (Facility Currency)  \
# 523                                                       0.0
#
#      Accrued Profit/Interest of the month (MYR)  \
# 523                                         0.0
#
#      Modification of Loss (Facility Currency)  Modification of Loss (MYR)  \
# 523                                       0.0                         0.0
#
#      Cumulative Accrued Profit/Interest (Facility Currency)  \
# 523                                                     0.0
#
#      Cumulative Accrued Profit/Interest (MYR)  \
# 523                                       0.0
#
#      Penalty/Ta`widh (Facility Currency)  Penalty/Ta`widh (MYR)  \
# 523                                    0                      0
#
#      Income/Interest in Suspense (Facility Currency)  \
# 523                                              0.0
#
#      Income/Interest in Suspense (MYR)  Other Charges (Facility Currency)  \
# 523                                0.0                                0.0
#
#      Other Charges (MYR)  Total Loans Outstanding (Facility Currency)  \
# 523                  0.0                                          0.0
#
#      Total Loans Outstanding (MYR)  \
# 523                            0.0
#
#      Expected Credit Loss (ECL) LAF (Facility Currency)  \
# 523                                                 0.0
#
#      Expected Credit Loss LAF (ECL) (MYR)  \
# 523                                   0.0
#
#      Expected Credit Loss C&C (ECL) (Facility Currency)  \
# 523                                                 0.0
#
#      Expected Credit Loss C&C (ECL) (MYR) Disbursement/Drawdown Status  \
# 523                                   0.0                          NaN
#
#      Unutilised/Undrawn Amount (Facility Currency)  \
# 523                                            0.0
#
#      Unutilised/Undrawn Amount (MYR)  \
# 523                              0.0
#
#      Disbursement/Drawdown (Facility Currency)  Disbursement/Drawdown (MYR)  \
# 523                                        0.0                          0.0
#
#      Cumulative Disbursement/Drawdown (Facility Currency)  \
# 523                                                   0.0
#
#      Cumulative Disbursement/Drawdown (MYR)  \
# 523                                     0.0
#
#      Cost Payment/Principal Repayment (Facility Currency)  \
# 523                                                   0.0
#
#      Cost Payment/Principal Repayment (MYR)  \
# 523                                     0.0
#
#      Cumulative Cost Payment/Principal Repayment (Facility Currency)  \
# 523                                                              0.0
#
#      Cumulative Cost Payment/Principal Repayment (MYR)  \
# 523                                                0.0
#
#      Profit Payment/Interest Repayment (Facility Currency)  \
# 523                                                    0.0
#
#      Profit Payment/Interest Repayment (MYR)  \
# 523                                      0.0
#
#      Cumulative Profit Payment/Interest Repayment (Facility Currency)  \
# 523                                                               0.0
#
#      Cumulative Profit Payment/Interest Repayment (MYR)  \
# 523                                                 0.0
#
#      Ta`widh Payment/Penalty Repayment (Facility Currency)  \
# 523                                                    0.0
#
#      Ta`widh Payment/Penalty Repayment  (MYR)  \
# 523                                       0.0
#
#      Cumulative Ta`widh Payment/Penalty Repayment (Facility Currency)  \
# 523                                                               0.0
#
#      Cumulative Ta`widh Payment/Penalty Repayment  (MYR)  \
# 523                                                  0.0
#
#      Other Charges Payment (Facility Currency)  Other Charges Payment (MYR)  \
# 523                                        0.0                          0.0
#
#      Cumulative Other Charges Payment (Facility Currency)  \
# 523                                                   0.0
#
#      Cumulative Other Charges Payment (MYR) Rating at Origination PD  PF  \
# 523                                     0.0                     5  5 NaN
#
#      CRMS Obligor Risk Rating CRMS CG Rating  PD (%)  LGD (%)  \
# 523                      5.79            NaN     NaN      NaN
#
#                           Risk Analyst  MFRS9 Staging  \
# 523  Hakim Hariawan Muhammadan Mokhtar            NaN
#
#                 BNM Main Sector  \
# 523  Transportation and Storage
#
#                                             BNM Sub Sector  \
# 523  Service activities incidental to water transportation
#
#                               EXIM Main Sector Industry (Risk)  \
# 523  Transportation, Storage and Communication             NaN
#
#     Industry Classification  \
# 523                     NaN
#
#                                                                                                                               Purpose of Financing  \
# 523  For issuance of guanratee consists of Tender Bid Guarantee / Advance Payment Guarantee / Performance Guarantee to undertake overseas projects
#
#     Date Approved at Origination Approval Authority     LO issuance Date  \
# 523                    18/7/2024                 J2  2024-07-25 00:00:00
#
#     Date of LO Acceptance 1st Disbursement/Drawdown Date  \
# 523                   NaN                            NaT
#
#     1st Payment/Repayment Date Expiry of Availability Period  \
# 523                        NaT                           NaT
#
#     Facility Agreement Date Annual Review Date Watchlist Review Date  \
# 523                     NaN                NaN                   NaN
#
#     Maturity/Expired Date  Grace Period (Month)  Moratorium Period (Month)  \
# 523                   NaT                   NaN                        NaN
#
#     Start Moratorium Date        Tenure (Month)  \
# 523                   NaT  pending info banking
#
#     Payment/Repayment Frequency (Profit/Interest)  \
# 523                                           NaN
#
#     Payment/Repayment Frequency (Cost/Principal) Effective cost of borrowings  \
# 523                                          NaN                          NaN
#
#     Profit/Interest Margin  Average Profit/Interest Rate  \
# 523                    NaN                           NaN
#
#      Ta`widh Compensation/Penalty Rate   Operation Country Country Exposure  \
# 523                                NaN  Pending Cif update         Malaysia
#
#     Country Rating Region  Market Type  \
# 523           BBB+   Asia  Traditional
#
#     Classification of Entity / Customer Type Entity / Customer Type  \
# 523                        Business Entities                Company
#
#     Classification of Residency Status       Residency Status Corporate Type  \
# 523                           Resident  Bumiputera Controlled           Bumi
#
#     SME Commercial Corporate Corporate Status  \
# 523                     SME      SME - Medium
#
#                                                      Justification on Corporate Status  \
# 523  Fulfils the qualifying criteria of SMEs for 2 consecutive years. (Sales Turnover)
#
#     Restructured / Rescheduled Date of Approval Restructured / Rescheduled  \
# 523                        New                                         NaT
#
#     Effective Date Reason Date Untagged from R&R Justification for Untagged  \
# 523            NaN    NaN                    NaT                        NaN
#
#     Frequency  Date of Overdue Overdue (Days)  Month in Arrears  \
# 523       NaN              NaN            NaN               NaN
#
#      Overdue Amount (Facility Currency)  Overdue Amount (MYR)  \
# 523                                 NaN                   NaN
#
#     Date Classified as Watchlist Watchlist Reason  \
# 523                          NaT              NaN
#
#     Date Declassified from Watchlist Date Impaired Reason for Impairment  \
# 523                              NaT           NaT                   NaN
#
#     Partial Write off Date Write off Date  \
# 523                    NaT            NaT
#
#     Cancellation Date/Fully Settled Date Position as At LGD Risk Category  \
# 523                                  NaN      31/7/2024
#
#     Prudential Limit (%) EXIMs Shareholder Fund as at  \
# 523
#
#     EXIMs Shareholder Fund as at (MYR)  \
# 523
#
#     Single Customer Exposure Limit (SCEL)(MYR)  \
# 523
#
#     Percentage of Total Banking Exposure(MYR) to SCEL (MYR)  \
# 523
#
#     Percentage of Total Overall Banking Exposure (MYR) to SCEL (MYR) (%)
# 523

# %%
LDB1['LGD'] = ""
#LDB1['Fund Type'] = LDB1['Fund / Guarantee /Program / Insentif']
#Fund Type

LDB1['Risk Category'] = ""
LDB1['Prudential Limit (%)'] = ""
LDB1["EXIMs Shareholder Fund as at"] = ""
LDB1["EXIMs Shareholder Fund as at (MYR)"] = ""
LDB1['Single Customer Exposure Limit (SCEL)(MYR)'] = ""
LDB1['Percentage of Total Banking Exposure(MYR) to SCEL (MYR)'] = ""
LDB1['Percentage of Total Overall Banking Exposure (MYR) to SCEL (MYR) (%)'] = ""
# Out:
# C:\Users\syahidhalid\AppData\Local\Temp\1\ipykernel_12704\3906157623.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   LDB1['LGD'] = ""
# C:\Users\syahidhalid\AppData\Local\Temp\1\ipykernel_12704\3906157623.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   LDB1['Risk Category'] = ""
# C:\Users\syahidhalid\AppData\Local\Temp\1\ipykernel_12704\3906157623.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   LDB1['Prudential Limit (%)'] = ""
# C:\Users\syahidhalid\AppData\Local\Temp\1\ipykernel_12704\3906157623.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   LDB1["EXIMs Shareholder Fund as at"] = ""
# C:\Users\syahidhalid\AppData\Local\Temp\1\ipykernel_12704\3906157623.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   LDB1["EXIMs Shareholder Fund as at (MYR)"] = ""
# C:\Users\syahidhalid\AppData\Local\Temp\1\ipykernel_12704\3906157623.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   LDB1['Single Customer Exposure Limit (SCEL)(MYR)'] = ""
# C:\Users\syahidhalid\AppData\Local\Temp\1\ipykernel_12704\3906157623.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   LDB1['Percentage of Total Banking Exposure(MYR) to SCEL (MYR)'] = ""
# C:\Users\syahidhalid\AppData\Local\Temp\1\ipykernel_12704\3906157623.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   LDB1['Percentage of Total Overall Banking Exposure (MYR) to SCEL (MYR) (%)'] = ""

# %%
LDB1.shape
# Out:
# (524, 158)

# %%
#LDB2.shape

# %%
LDB2 = LDB1[['CIF Number',
             'EXIM Account No.',
                     'Application System Code',
                     'CCRIS Master Account Number',
                     'CCRIS Sub Account Number',
                            'Finance(SAP) Number',
                            'Company Group',
                            'Customer Name',
                            'Relationship Manager (RM)',
                            'Banking Team',
                            'Ownership',
                            'Officer in Charge',
                            'Syndicated / Club Deal',
                            'Nature of Account',
                            'Facility',
                            'Facility Currency',
                            'Type of Financing',
                            'Shariah Contract / Concept',
                            'Status',
                            'Post Approval Stage',
                            'Date of Ready for Utilization (RU)',
                            'Restructured / Rescheduled(Y/N)',
                            'Amount Approved / Facility Limit (Facility Currency)',
                            'Amount Approved / Facility Limit (MYR)',
                            'Cost/Principal Outstanding (Facility Currency)',
                            'Cost/Principal Outstanding (MYR)',
                            'Contingent Liability Letter of Credit (Facility Currency)',
                            'Contingent Liability Letter of Credit (MYR)',
                            'Contingent Liability (Facility Currency)',
                            'Contingent Liability (MYR)',
                            'Account Receivables/Past Due Claims (Facility Currency)',
                            'Account Receivable/Past Due Claims (MYR)',
                            'Total Banking Exposure (Facility Currency)',
                            'Total Banking Exposure (MYR)',
                            'Accrued Profit/Interest of the month (Facility Currency)',
                            'Accrued Profit/Interest of the month (MYR)',
                            'Modification of Loss (Facility Currency)',
                            'Modification of Loss (MYR)',
                            'Cumulative Accrued Profit/Interest (Facility Currency)',
                            'Cumulative Accrued Profit/Interest (MYR)',                            
                            'Penalty/Ta`widh (Facility Currency)',
                            'Penalty/Ta`widh (MYR)',
                            'Income/Interest in Suspense (Facility Currency)',
                            'Income/Interest in Suspense (MYR)',
                            'Other Charges (Facility Currency)',
                            'Other Charges (MYR)',
                            'Total Loans Outstanding (Facility Currency)',
                            'Total Loans Outstanding (MYR)',
             'Expected Credit Loss (ECL) LAF (Facility Currency)',
             'Expected Credit Loss LAF (ECL) (MYR)',
             'Expected Credit Loss C&C (ECL) (Facility Currency)',
             'Expected Credit Loss C&C (ECL) (MYR)',
                            'Disbursement/Drawdown Status',
                            'Unutilised/Undrawn Amount (Facility Currency)',
                            'Unutilised/Undrawn Amount (MYR)',
                            'Disbursement/Drawdown (Facility Currency)',
                            'Disbursement/Drawdown (MYR)',
                            'Cumulative Disbursement/Drawdown (Facility Currency)',
                            'Cumulative Disbursement/Drawdown (MYR)',
                            'Cost Payment/Principal Repayment (Facility Currency)',
                            'Cost Payment/Principal Repayment (MYR)',                            
                            'Cumulative Cost Payment/Principal Repayment (Facility Currency)',
                            'Cumulative Cost Payment/Principal Repayment (MYR)',
                            'Profit Payment/Interest Repayment (Facility Currency)',
                            'Profit Payment/Interest Repayment (MYR)',
                            'Cumulative Profit Payment/Interest Repayment (Facility Currency)',
                            'Cumulative Profit Payment/Interest Repayment (MYR)',
                            'Ta`widh Payment/Penalty Repayment (Facility Currency)',
                            'Ta`widh Payment/Penalty Repayment  (MYR)',
                            'Cumulative Ta`widh Payment/Penalty Repayment (Facility Currency)',
                            'Cumulative Ta`widh Payment/Penalty Repayment  (MYR)',
                            'Other Charges Payment (Facility Currency)',
                            'Other Charges Payment (MYR)',
                            'Cumulative Other Charges Payment (Facility Currency)',
                            'Cumulative Other Charges Payment (MYR)',
                            'Rating at Origination',
                            'PD',
                            'PF',
             'LGD',
                            'CRMS Obligor Risk Rating',
                            #'CRMS CG Rating',
                            'PD (%)',
                            'LGD (%)',
'Risk Category',
"Prudential Limit (%)",
"EXIMs Shareholder Fund as at",
"EXIMs Shareholder Fund as at (MYR)",
"Single Customer Exposure Limit (SCEL)(MYR)",
"Percentage of Total Banking Exposure(MYR) to SCEL (MYR)",
"Percentage of Total Overall Banking Exposure (MYR) to SCEL (MYR) (%)",
                            'Risk Analyst',
                            'MFRS9 Staging',
                            'BNM Main Sector',
                            'BNM Sub Sector',
                            'EXIM Main Sector',
                            'Industry (Risk)',
                            'Industry Classification',
                            'Purpose of Financing',
                            'Date Approved at Origination',
                            'Approval Authority',
                            'LO issuance Date',
                            'Date of LO Acceptance',
                            '1st Disbursement/Drawdown Date',
                            '1st Payment/Repayment Date',
                            'Expiry of Availability Period',
                            'Facility Agreement Date',
                            'Annual Review Date',
                            'Watchlist Review Date',
                            'Maturity/Expired Date',
                            'Grace Period (Month)',
                            'Moratorium Period (Month)',
                            'Start Moratorium Date',
             'Fund Type',
                            'Tenure (Month)',
                            'Payment/Repayment Frequency (Profit/Interest)',
                            'Payment/Repayment Frequency (Cost/Principal)',
                            'Effective cost of borrowings',
                            'Profit/Interest Margin',
                            'Average Profit/Interest Rate',
                            'Ta`widh Compensation/Penalty Rate',
                            'Operation Country',
                            'Country Exposure',
                            'Country Rating',
                            'Region',
                            'Market Type',
                            'Classification of Entity / Customer Type',
                            'Entity / Customer Type',
                            'Classification of Residency Status',
                            'Residency Status',
                            'Corporate Type',
                            'SME Commercial Corporate',
                            'Corporate Status',
                            'Justification on Corporate Status',
                            'Restructured / Rescheduled',
                            'Date of Approval Restructured / Rescheduled',
                            'Effective Date',
                            'Reason',
                            #'Date Untagged from R&R',
                            #'Justification for Untagged',
                            'Frequency',
                            'Date of Overdue',
             'Overdue (Days)',
             'Month in Arrears',
             'Overdue Amount (Facility Currency)',
             'Overdue Amount (MYR)',
                            'Date Classified as Watchlist',
                            'Watchlist Reason',
                            'Date Declassified from Watchlist',
                            'Date Impaired',
                            'Reason for Impairment',
                            'Partial Write off Date',
                            'Write off Date',
                            'Cancellation Date/Fully Settled Date','Position as At']]

# %%
LDB2.shape
# Out:
# (524, 151)

# %%
#LDB2['Finance(SAP) Number'].value_counts()
#LDB2.iloc[np.where(LDB2['Finance(SAP) Number'].isin(['BG-I','BG','500724']))]

# %%
LDB2['Finance(SAP) Number'].dtypes
# Out:
# dtype('O')

# %%
LDB2['Finance(SAP) Number'] = LDB2['Finance(SAP) Number'].astype(str)

LDB2.loc[(LDB2['Finance(SAP) Number'].isin(['BG-I','BG','500724'])),'Expected Credit Loss C&C (ECL) (MYR)'] = 0
LDB2.loc[(LDB2['Finance(SAP) Number'].isin(['BG-I','BG','500724'])),'Expected Credit Loss C&C (ECL) (Facility Currency)'] = 0

LDB2['Expected Credit Loss LAF (ECL) (MYR) 2'] = LDB2['Expected Credit Loss LAF (ECL) (MYR)'] + LDB2['Expected Credit Loss C&C (ECL) (MYR)']
LDB2['Expected Credit Loss (ECL) LAF (Facility Currency) 2'] = LDB2['Expected Credit Loss (ECL) LAF (Facility Currency)'] + LDB2['Expected Credit Loss C&C (ECL) (Facility Currency)']
# Out:
# C:\Users\syahidhalid\AppData\Local\Temp\1\ipykernel_12704\4205607302.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   LDB2['Finance(SAP) Number'] = LDB2['Finance(SAP) Number'].astype(str)
# C:\Users\syahidhalid\AppData\Local\Temp\1\ipykernel_12704\4205607302.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   LDB2['Expected Credit Loss LAF (ECL) (MYR) 2'] = LDB2['Expected Credit Loss LAF (ECL) (MYR)'] + LDB2['Expected Credit Loss C&C (ECL) (MYR)']
# C:\Users\syahidhalid\AppData\Local\Temp\1\ipykernel_12704\4205607302.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   LDB2['Expected Credit Loss (ECL) LAF (Facility Currency) 2'] = LDB2['Expected Credit Loss (ECL) LAF (Facility Currency)'] + LDB2['Expected Credit Loss C&C (ECL) (Facility Currency)']

# %%
sum(LDB.fillna(0).iloc[np.where(LDB['Finance(SAP) Number']==500776)]['Total Loans Outstanding (MYR)'])
# Out:
# 70452384.14

# %%
#humming bird
#a_humm = sum(LDB2.fillna(0).iloc[np.where(LDB2['Finance(SAP) Number']=='500776')]['Income/Interest in Suspense (Facility Currency)'])
#b_humm = sum(LDB2.fillna(0).iloc[np.where(LDB2['Finance(SAP) Number']=='500776')]['Income/Interest in Suspense (MYR)'])
#c_humm = sum(LDB2.fillna(0).iloc[np.where(LDB2['Finance(SAP) Number']=='500776')]['Other Charges (Facility Currency)'])
#d_humm = sum(LDB2.fillna(0).iloc[np.where(LDB2['Finance(SAP) Number']=='500776')]['Other Charges (MYR)'])
#e_humm = sum(LDB2.fillna(0).iloc[np.where(LDB2['Finance(SAP) Number']=='500776')]['Total Loans Outstanding (Facility Currency)'])
#f_humm = sum(LDB2.fillna(0).iloc[np.where(LDB2['Finance(SAP) Number']=='500776')]['Total Loans Outstanding (MYR)'])
#g_humm = sum(LDB2.fillna(0).iloc[np.where(LDB2['Finance(SAP) Number']=='500776')]['Expected Credit Loss (ECL) LAF (Facility Currency) 2'])
#h_humm = sum(LDB2.fillna(0).iloc[np.where(LDB2['Finance(SAP) Number']=='500776')]['Expected Credit Loss LAF (ECL) (MYR) 2'])

#LDB2.loc[(LDB2['EXIM Account No.']=='3308-02138-202-0109-01'),'Income/Interest in Suspense (Facility Currency)']] = 0.79*a_humm
#LDB2.loc[(LDB2['EXIM Account No.']=='3308-02138-202-0109-01'),'Income/Interest in Suspense (MYR)']] = 0.79*b_humm
#LDB2.loc[(LDB2['EXIM Account No.']=='3308-02138-202-0109-01'),'Other Charges (Facility Currency)']] = 0.79*c_humm
#LDB2.loc[(LDB2['EXIM Account No.']=='3308-02138-202-0109-01'),'Other Charges (MYR)']] = 0.79*d_humm
#LDB2.loc[(LDB2['EXIM Account No.']=='3308-02138-202-0109-01'),'Total Loans Outstanding (Facility Currency)']] = 0.79*e_humm
#LDB2.loc[(LDB2['EXIM Account No.']=='3308-02138-202-0109-01'),'Total Loans Outstanding (MYR)']] = 0.79*f_humm
#LDB2.loc[(LDB2['EXIM Account No.']=='3308-02138-202-0109-01'),'Expected Credit Loss (ECL) LAF (Facility Currency) 2']] = 0.79*g_humm
#LDB2.loc[(LDB2['EXIM Account No.']=='3308-02138-202-0109-01'),'Expected Credit Loss LAF (ECL) (MYR) 2']] = 0.79*h_humm

#LDB2.loc[(LDB2['EXIM Account No.']=='3308-02138-202-0109-02'),'Income/Interest in Suspense (Facility Currency)']] = 0.21*a_humm
#LDB2.loc[(LDB2['EXIM Account No.']=='3308-02138-202-0109-02'),'Income/Interest in Suspense (MYR)']] = 0.21*b_humm
#LDB2.loc[(LDB2['EXIM Account No.']=='3308-02138-202-0109-02'),'Other Charges (Facility Currency)']] = 0.21*c_humm
#LDB2.loc[(LDB2['EXIM Account No.']=='3308-02138-202-0109-02'),'Other Charges (MYR)']] = 0.21*d_humm
#LDB2.loc[(LDB2['EXIM Account No.']=='3308-02138-202-0109-02'),'Total Loans Outstanding (Facility Currency)']] = 0.21*e_humm
#LDB2.loc[(LDB2['EXIM Account No.']=='3308-02138-202-0109-02'),'Total Loans Outstanding (MYR)']] = 0.21*f_humm
#LDB2.loc[(LDB2['EXIM Account No.']=='3308-02138-202-0109-02'),'Expected Credit Loss (ECL) LAF (Facility Currency) 2']] = 0.21*g_humm
#LDB2.loc[(LDB2['EXIM Account No.']=='3308-02138-202-0109-02'),'Expected Credit Loss LAF (ECL) (MYR) 2']] = 0.21*h_humm

# %%
LDB3 = LDB2.drop(['Expected Credit Loss C&C (ECL) (MYR)','Expected Credit Loss C&C (ECL) (Facility Currency)'],axis=1)
#LDB2.iloc[np.where(LDB2['EXIM Account No.']=='3308-02138-202-0109-02')]

# %%
LDB4 = LDB3[['CIF Number',
             'EXIM Account No.',
                     'Application System Code',
                     'CCRIS Master Account Number',
                     'CCRIS Sub Account Number',
                            'Finance(SAP) Number',
                            'Company Group',
                            'Customer Name',
                            'Relationship Manager (RM)',
                            'Banking Team',
                            'Ownership',
                            'Officer in Charge',
                            'Syndicated / Club Deal',
                            'Nature of Account',
                            'Facility',
                            'Facility Currency',
                            'Type of Financing',
                            'Shariah Contract / Concept',
                            'Status',
                            'Post Approval Stage',
                            'Date of Ready for Utilization (RU)',
                            'Restructured / Rescheduled(Y/N)',
                            'Amount Approved / Facility Limit (Facility Currency)',
                            'Amount Approved / Facility Limit (MYR)',
                            'Cost/Principal Outstanding (Facility Currency)',
                            'Cost/Principal Outstanding (MYR)',
                            'Contingent Liability Letter of Credit (Facility Currency)',
                            'Contingent Liability Letter of Credit (MYR)',
                            'Contingent Liability (Facility Currency)',
                            'Contingent Liability (MYR)',
                            'Account Receivables/Past Due Claims (Facility Currency)',
                            'Account Receivable/Past Due Claims (MYR)',
                            'Total Banking Exposure (Facility Currency)',
                            'Total Banking Exposure (MYR)',
                            'Accrued Profit/Interest of the month (Facility Currency)',
                            'Accrued Profit/Interest of the month (MYR)',
                            'Modification of Loss (Facility Currency)',
                            'Modification of Loss (MYR)',
                            'Cumulative Accrued Profit/Interest (Facility Currency)',
                            'Cumulative Accrued Profit/Interest (MYR)',                            
                            'Penalty/Ta`widh (Facility Currency)',
                            'Penalty/Ta`widh (MYR)',
                            'Income/Interest in Suspense (Facility Currency)',
                            'Income/Interest in Suspense (MYR)',
                            'Other Charges (Facility Currency)',
                            'Other Charges (MYR)',
                            'Total Loans Outstanding (Facility Currency)',
                            'Total Loans Outstanding (MYR)',
             'Expected Credit Loss (ECL) LAF (Facility Currency) 2',
             'Expected Credit Loss LAF (ECL) (MYR) 2',
#             'Expected Credit Loss C&C (ECL) (Facility Currency)',
#             'Expected Credit Loss C&C (ECL) (MYR)',
                            'Disbursement/Drawdown Status',
                            'Unutilised/Undrawn Amount (Facility Currency)',
                            'Unutilised/Undrawn Amount (MYR)',
                            'Disbursement/Drawdown (Facility Currency)',
                            'Disbursement/Drawdown (MYR)',
                            'Cumulative Disbursement/Drawdown (Facility Currency)',
                            'Cumulative Disbursement/Drawdown (MYR)',
                            'Cost Payment/Principal Repayment (Facility Currency)',
                            'Cost Payment/Principal Repayment (MYR)',                            
                            'Cumulative Cost Payment/Principal Repayment (Facility Currency)',
                            'Cumulative Cost Payment/Principal Repayment (MYR)',
                            'Profit Payment/Interest Repayment (Facility Currency)',
                            'Profit Payment/Interest Repayment (MYR)',
                            'Cumulative Profit Payment/Interest Repayment (Facility Currency)',
                            'Cumulative Profit Payment/Interest Repayment (MYR)',
                            'Ta`widh Payment/Penalty Repayment (Facility Currency)',
                            'Ta`widh Payment/Penalty Repayment  (MYR)',
                            'Cumulative Ta`widh Payment/Penalty Repayment (Facility Currency)',
                            'Cumulative Ta`widh Payment/Penalty Repayment  (MYR)',
                            'Other Charges Payment (Facility Currency)',
                            'Other Charges Payment (MYR)',
                            'Cumulative Other Charges Payment (Facility Currency)',
                            'Cumulative Other Charges Payment (MYR)',
                            'Rating at Origination',
                            'PD',
                            'PF',
             'LGD',
                            'CRMS Obligor Risk Rating',
                            #'CRMS CG Rating',
                            'PD (%)',
                            'LGD (%)',
'Risk Category',
"Prudential Limit (%)",
"EXIMs Shareholder Fund as at",
"EXIMs Shareholder Fund as at (MYR)",
"Single Customer Exposure Limit (SCEL)(MYR)",
"Percentage of Total Banking Exposure(MYR) to SCEL (MYR)",
"Percentage of Total Overall Banking Exposure (MYR) to SCEL (MYR) (%)",
                            'Risk Analyst',
                            'MFRS9 Staging',
                            'BNM Main Sector',
                            'BNM Sub Sector',
                            'EXIM Main Sector',
                            'Industry (Risk)',
                            'Industry Classification',
                            'Purpose of Financing',
                            'Date Approved at Origination',
                            'Approval Authority',
                            'LO issuance Date',
                            'Date of LO Acceptance',
                            '1st Disbursement/Drawdown Date',
                            '1st Payment/Repayment Date',
                            'Expiry of Availability Period',
                            'Facility Agreement Date',
                            'Annual Review Date',
                            'Watchlist Review Date',
                            'Maturity/Expired Date',
                            'Grace Period (Month)',
                            'Moratorium Period (Month)',
                            'Start Moratorium Date',
             'Fund Type',
                            'Tenure (Month)',
                            'Payment/Repayment Frequency (Profit/Interest)',
                            'Payment/Repayment Frequency (Cost/Principal)',
                            'Effective cost of borrowings',
                            'Profit/Interest Margin',
                            'Average Profit/Interest Rate',
                            'Ta`widh Compensation/Penalty Rate',
                            'Operation Country',
                            'Country Exposure',
                            'Country Rating',
                            'Region',
                            'Market Type',
                            'Classification of Entity / Customer Type',
                            'Entity / Customer Type',
                            'Classification of Residency Status',
                            'Residency Status',
                            'Corporate Type',
                            'SME Commercial Corporate',
                            'Corporate Status',
                            'Justification on Corporate Status',
                            'Restructured / Rescheduled',
                            'Date of Approval Restructured / Rescheduled',
                            'Effective Date',
                            'Reason',
                            #'Date Untagged from R&R',
                            #'Justification for Untagged',
                            'Frequency',
                            'Date of Overdue',
             'Overdue (Days)',
             'Month in Arrears',
             'Overdue Amount (Facility Currency)',
             'Overdue Amount (MYR)',
                            'Date Classified as Watchlist',
                            'Watchlist Reason',
                            'Date Declassified from Watchlist',
                            'Date Impaired',
                            'Reason for Impairment',
                            'Partial Write off Date',
                            'Write off Date',
                            'Cancellation Date/Fully Settled Date','Position as At']]

# %%
LDB4.fillna(0,inplace=True)
# Out:
# C:\Users\syahidhalid\AppData\Local\Temp\1\ipykernel_12704\4124240016.py:1: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '0' has dtype incompatible with datetime64[ns], please explicitly cast to a compatible dtype first.
#   LDB4.fillna(0,inplace=True)
# C:\Users\syahidhalid\AppData\Local\Temp\1\ipykernel_12704\4124240016.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   LDB4.fillna(0,inplace=True)

# %%
LDB4.to_excel(str(Location)+'\\Loan Database as'+str(File[-26:-7])+'- CCRIS Raw.xlsx', sheet_name='loandatabase', index = False)

# %%
str(Location)+'\\Loan Database as'+str(File[-26:-7])+'- CCRIS Raw.xlsx'
# Out:
# 'C:\\Users\\syahidhalid\\Syahid_PC\\Analytics - FAD\\00. Automation LDB\\Data Source\\202407\\Loan Database as Jul 2024 (python) - CCRIS Raw.xlsx'
