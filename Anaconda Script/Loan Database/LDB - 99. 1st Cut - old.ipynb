# %%
Position = "30/6/2024"
Year = "202406"
File1 = "01. Debtor Listing Jun 2024 (python)"

Location = r"C:\Users\syahidhalid\Syahid_PC\Analytics - FAD\00. Automation LDB\Data Source\\"+str(Year)+"\\"


#control + F + dropdown new to search bar to find and replace 
import pandas as pd
import numpy as np
import xlsxwriter

#warnings.filterwarnings('ignore')
pd.set_option("display.max_columns", None) 
pd.set_option("display.max_colwidth", 1000) #huruf dlm column
pd.set_option("display.max_rows", 100)
pd.set_option("display.precision", 2) #2 titik perpuluhan

FILE1 = pd.read_excel(str(Location)+"\\"+str(File1)+".xlsx", sheet_name='Export Worksheet', header=0) # skiprows = 2, nrows=18,  usecols= 'A:D'

LDB_prev = pd.read_excel(r"C:\Users\syahidhalid\Syahid_PC\Analytics - SPD\Loan Database\LBD 202412 - 202401 (CSP Sector).xlsx", sheet_name='May24', header=0) # skiprows = 2, nrows=18,  usecols= 'A:D'

MRate = pd.read_excel(r"C:\Users\syahidhalid\Syahid_PC\Analytics - FAD\00. Automation LDB\Data Source\202406\\00. Month End Rate.xlsx", header=2) # skiprows = 2, nrows=18,  usecols= 'A:D'

#LDB_prev.columns = LDB_prev.columns.str.replace("\n", "_")
#LDB_prev.columns = LDB_prev.columns.str.replace(" ", "_")
#LDB_prev.columns = LDB_prev.columns.str.replace(".", "")

File2 = "02. Disbursement & Drawdown Jun 2024 (python)"
FILE2 = pd.read_excel(str(Location)+"\\"+str(File2)+".xlsx", sheet_name='Export Worksheet', header=0) # skiprows = 2, nrows=18,  usecols= 'A:D'


File5 = "05. Data Mirror Jun 2024 (python)"
FILE5 = pd.read_excel(str(Location)+"\\"+str(File5)+".xlsx", sheet_name='Other_Charges_Payment', header=0) # skiprows = 2, nrows=18,  usecols= 'A:D'


File_cont = "06. Contigent Liability Jun2024 (python)"
Contigent = pd.read_excel(str(Location)+"\\"+str(File_cont)+".xlsx", sheet_name='BG & LC', header=0) # skiprows = 2, nrows=18,  usecols= 'A:D'

Tr = "07. Undrawn Trade June 2024"
NTr = "07. Undrawn Non Trade June-24"

Undrawn_T = pd.read_excel(str(Location)+"\\"+str(Tr)+".xlsx", sheet_name='Export Worksheet', header=0) # skiprows = 2, nrows=18,  usecols= 'A:D'
Undrawn_NT = pd.read_excel(str(Location)+"\\"+str(NTr)+".xlsx", sheet_name='Export Worksheet', header=0) # skiprows = 2, nrows=18,  usecols= 'A:D'

# %%
FILE1_1 = FILE1.sort_values(by="Total Loans Outstanding (MYR)",ascending=False)

LDB_prev.columns = LDB_prev.columns.str.strip()
LDB_prev.columns = LDB_prev.columns.str.replace("\n", "")

LDB_prev1 = LDB_prev[['Finance(SAP) Number','EXIM Account No.','CIF Number','Customer Name','Facility Currency',
                      'Type of Financing','Country Exposure',
                            'Company Group',
                            'Relationship Manager (RM)',
                            'Banking Team',
                            'Ownership',
                            'Officer in Charge',
                            'Syndicated / Club Deal',
                            'Nature of Account',
                            'Facility',
                            'Shariah Contract / Concept',
                            'Fund / Guarantee /Program / Insentif',
                            'Status',
                            'Post Approval Stage',
                            'Date of Ready for Utilization (RU)',
                            'Restructured / Rescheduled(Y/N)',
                            'Amount Approved / Facility Limit (Facility Currency)',
                            'Amount Approved / Facility Limit (MYR)',
                            'Account Receivables/Past Due Claims (Facility Currency)',
                            'Account Receivable/Past Due Claims (MYR)',
                            'Total Banking Exposure (Facility Currency)',
                            'Total Banking Exposure (MYR)',
                            'Penalty/Ta`widh (Facility Currency)',
                            'Penalty/Ta`widh (MYR)',
                            'Disbursement/Drawdown Status',
                            'Cumulative Disbursement/Drawdown (Facility Currency)',
                            'Cumulative Disbursement/Drawdown (MYR)',
                            'Cumulative Cost Payment/Principal Repayment (Facility Currency)',
                            'Cumulative Cost Payment/Principal Repayment (MYR)',
                            'Cumulative Profit Payment/Interest Repayment (Facility Currency)',
                            'Cumulative Profit Payment/Interest Repayment (MYR)',
                            'Ta`widh Payment/Penalty Repayment (Facility Currency)',
                            'Ta`widh Payment/Penalty Repayment  (MYR)',
                            'Cumulative Ta`widh Payment/Penalty Repayment (Facility Currency)',
                            'Cumulative Ta`widh Payment/Penalty Repayment  (MYR)',
                            'Cumulative Other Charges Payment (Facility Currency)',
                            'Cumulative Other Charges Payment (MYR)',
                            'Rating at Origination',
                            'PD',
                            'PF',
                            'CRMS Obligor Risk Rating',
                            'CRMS CG Rating',
                            'PD (%)',
                            'LGD (%)',
                            'Risk Analyst',
                            'MFRS9 Staging',
                            'BNM Main Sector',
                            'BNM Sub Sector',
                            'EXIM Main Sector',
                            'Industry (Risk)',
                            'Industry Classification',
                            'Purpose of Financing',
                            'Date Approved at Origination',
                            'Approval Authority',
                            'LO issuance Date',
                            'Date of LO Acceptance',
                            '1st Disbursement/Drawdown Date',
                            '1st Payment/Repayment Date',
                            'Expiry of Availability Period',
                            'Facility Agreement Date',
                            'Annual Review Date',
                            'Watchlist Review Date',
                            'Maturity/Expired Date',
                            'Grace Period (Month)',
                            'Moratorium Period (Month)',
                            'Start Moratorium Date',
                            'Tenure (Month)',
                            'Payment/Repayment Frequency (Profit/Interest)',
                            'Payment/Repayment Frequency (Cost/Principal)',
                            'Effective cost of borrowings',
                            'Profit/Interest Margin',
                            'Average Profit/Interest Rate',
                            'Ta`widh Compensation/Penalty Rate',
                            'Operation Country',
                            'Country Rating',
                            'Region',
                            'Market Type',
                            'Classification of Entity / Customer Type',
                            'Entity / Customer Type',
                            'Classification of Residency Status',
                            'Residency Status',
                            'Corporate Type',
                            'SME Commercial Corporate',
                            'Corporate Status',
                            'Justification on Corporate Status',
                            'Restructured / Rescheduled',
                            'Date of Approval Restructured / Rescheduled',
                            'Effective Date',
                            'Reason',
                            'Date Untagged from R&R',
                            'Justification for Untagged',
                            'Frequency',
                            'Date of Overdue',
                            'Date Classified as Watchlist',
                            'Watchlist Reason',
                            'Date Declassified from Watchlist',
                            'Date Impaired',
                            'Reason for Impairment',
                            'Partial Write off Date',
                            'Write off Date',
                            'Cancellation Date/Fully Settled Date']].drop_duplicates('Finance(SAP) Number', keep='first')

# %%
FILE1_1['Finance(SAP) Number'].fillna(0,inplace=True)
FILE1_1['Finance(SAP) Number'] = FILE1_1['Finance(SAP) Number'].astype(str)

LDB_prev1['Finance(SAP) Number'].fillna(0,inplace=True)
LDB_prev1['Finance(SAP) Number'] = LDB_prev1['Finance(SAP) Number'].astype(str)

merge_ldb = FILE1_1.merge(LDB_prev1[['EXIM Account No.','CIF Number','Finance(SAP) Number','Customer Name','Facility Currency']].drop_duplicates('Finance(SAP) Number',keep='first'),on=['Finance(SAP) Number'],how='left', suffixes=('_x', ''))
#.rename(columns={'Finance(SAP)_Number':'Finance(SAP) Number'})

#, indicator=True

merge_ldb.sort_values('Total Loans Outstanding (MYR)', ascending=False, inplace=True)

merge_ldb['Facility Currency'].fillna(0,inplace=True)
merge_ldb.loc[merge_ldb['Facility Currency']==0, 'Facility Currency'] = merge_ldb['Facility Currency_x']

merge_ldb['Customer Name'].fillna(0,inplace=True)
merge_ldb.loc[merge_ldb['Customer Name']==0, 'Customer Name'] = merge_ldb['Customer Name_x']

merge_ldb = merge_ldb.drop(['Facility Currency_x','Customer Name_x'],axis=1)
#check klau ad yg xde account lg

# %%
LDB_prev2 = LDB_prev[['Finance(SAP) Number','EXIM Account No.','CIF Number','Customer Name','Facility Currency',
                      'Type of Financing','Country Exposure',
                            'Company Group',
                            'Relationship Manager (RM)',
                            'Banking Team',
                            'Ownership',
                            'Officer in Charge',
                            'Syndicated / Club Deal',
                            'Nature of Account',
                            'Facility',
                            'Shariah Contract / Concept',
                            'Fund / Guarantee /Program / Insentif',
                            'Status',
                            'Post Approval Stage',
                            'Date of Ready for Utilization (RU)',
                            'Restructured / Rescheduled(Y/N)',
                            'Amount Approved / Facility Limit (Facility Currency)',
                            'Amount Approved / Facility Limit (MYR)',
                            'Account Receivables/Past Due Claims (Facility Currency)',
                            'Account Receivable/Past Due Claims (MYR)',
                            'Total Banking Exposure (Facility Currency)',
                            'Total Banking Exposure (MYR)',
                            'Penalty/Ta`widh (Facility Currency)',
                            'Penalty/Ta`widh (MYR)',
                            'Disbursement/Drawdown Status',
                            'Cumulative Disbursement/Drawdown (Facility Currency)',
                            'Cumulative Disbursement/Drawdown (MYR)',
                            'Cumulative Cost Payment/Principal Repayment (Facility Currency)',
                            'Cumulative Cost Payment/Principal Repayment (MYR)',
                            'Cumulative Profit Payment/Interest Repayment (Facility Currency)',
                            'Cumulative Profit Payment/Interest Repayment (MYR)',
                            'Ta`widh Payment/Penalty Repayment (Facility Currency)',
                            'Ta`widh Payment/Penalty Repayment  (MYR)',
                            'Cumulative Ta`widh Payment/Penalty Repayment (Facility Currency)',
                            'Cumulative Ta`widh Payment/Penalty Repayment  (MYR)',
                            'Cumulative Other Charges Payment (Facility Currency)',
                            'Cumulative Other Charges Payment (MYR)',
                            'Rating at Origination',
                            'PD',
                            'PF',
                            'CRMS Obligor Risk Rating',
                            'CRMS CG Rating',
                            'PD (%)',
                            'LGD (%)',
                            'Risk Analyst',
                            'MFRS9 Staging',
                            'BNM Main Sector',
                            'BNM Sub Sector',
                            'EXIM Main Sector',
                            'Industry (Risk)',
                            'Industry Classification',
                            'Purpose of Financing',
                            'Date Approved at Origination',
                            'Approval Authority',
                            'LO issuance Date',
                            'Date of LO Acceptance',
                            '1st Disbursement/Drawdown Date',
                            '1st Payment/Repayment Date',
                            'Expiry of Availability Period',
                            'Facility Agreement Date',
                            'Annual Review Date',
                            'Watchlist Review Date',
                            'Maturity/Expired Date',
                            'Grace Period (Month)',
                            'Moratorium Period (Month)',
                            'Start Moratorium Date',
                            'Tenure (Month)',
                            'Payment/Repayment Frequency (Profit/Interest)',
                            'Payment/Repayment Frequency (Cost/Principal)',
                            'Effective cost of borrowings',
                            'Profit/Interest Margin',
                            'Average Profit/Interest Rate',
                            'Ta`widh Compensation/Penalty Rate',
                            'Operation Country',
                            'Country Rating',
                            'Region',
                            'Market Type',
                            'Classification of Entity / Customer Type',
                            'Entity / Customer Type',
                            'Classification of Residency Status',
                            'Residency Status',
                            'Corporate Type',
                            'SME Commercial Corporate',
                            'Corporate Status',
                            'Justification on Corporate Status',
                            'Restructured / Rescheduled',
                            'Date of Approval Restructured / Rescheduled',
                            'Effective Date',
                            'Reason',
                            'Date Untagged from R&R',
                            'Justification for Untagged',
                            'Frequency',
                            'Date of Overdue',
                            'Date Classified as Watchlist',
                            'Watchlist Reason',
                            'Date Declassified from Watchlist',
                            'Date Impaired',
                            'Reason for Impairment',
                            'Partial Write off Date',
                            'Write off Date',
                            'Cancellation Date/Fully Settled Date']]#.drop_duplicates('Finance(SAP) Number', keep='first')

# %%
# a = merge1.iloc[np.where(~(merge1._merge.isin(['both',"right_only"])))]
#a.to_excel(r"C:\Users\syahidhalid\Syahid_PC\Analytics - FAD\00. Automation LDB\Data Source\202406\Merge1 Left.xlsx", index=False)

# %%
#a.iloc[np.where(a['Finance(SAP) Number']=="501077")]

# %%
#LDB_prev2.iloc[np.where(LDB_prev2['Finance(SAP) Number']=="501077")]

# %%
#merge1._merge.value_counts()

# %%
merge_ldb['Finance(SAP) Number'].fillna(0,inplace=True)
merge_ldb['Finance(SAP) Number'] = merge_ldb['Finance(SAP) Number'].astype(str)

LDB_prev2['Finance(SAP) Number'].fillna(0,inplace=True)
LDB_prev2['Finance(SAP) Number'] = LDB_prev2['Finance(SAP) Number'].astype(str)

merge1 = merge_ldb.merge(LDB_prev2, on=['EXIM Account No.','CIF Number','Finance(SAP) Number'], how='outer', suffixes=('_x', ''),indicator=True)

#.drop(['Facility Currency','Customer Name'],axis=1)
#.drop('Profit Payment/Interest Repayment (MYR)',axis=1)
#.rename(columns={'Account':'Finance(SAP) Number'})

filterkn = merge1.iloc[np.where((merge1._merge.isin(['both',"right_only"])))] #&(merge1['Cost/Principal Outstanding (MYR)']>1)

filterkn = filterkn.drop('_merge',axis=1)
# Out:
# C:\Users\syahidhalid\AppData\Local\Temp\1\ipykernel_5580\1270935833.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   LDB_prev2['Finance(SAP) Number'].fillna(0,inplace=True)
# C:\Users\syahidhalid\AppData\Local\Temp\1\ipykernel_5580\1270935833.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   LDB_prev2['Finance(SAP) Number'] = LDB_prev2['Finance(SAP) Number'].astype(str)

# %%
merge1['Cumulative Cost Payment/Principal Repayment (MYR)'].value_counts()
# Out:
# Cumulative Cost Payment/Principal Repayment (MYR)
# 0.00e+00    419
# 1.15e+06      2
# 9.05e+04      1
# 1.82e+05      1
# 1.50e+05      1
# 1.17e+06      1
# 3.04e+05      1
# 7.00e+04      1
# 3.50e+03      1
# 5.73e+04      1
# 1.49e+05      1
# 1.78e+06      1
# 6.13e+05      1
# 1.50e+05      1
# 1.49e+05      1
# 1.58e+07      1
# 1.50e+07      1
# 1.99e+06      1
# 1.50e+05      1
# 1.92e+06      1
# 7.97e+06      1
# 5.69e+04      1
# 5.40e+05      1
# 1.00e+08      1
# 1.17e+05      1
# 2.14e+05      1
# 2.89e+06      1
# 6.05e+06      1
# 3.39e+04      1
# 1.57e+04      1
# 1.58e+04      1
# 2.06e+04      1
# 5.59e+05      1
# 2.08e+06      1
# 2.57e+04      1
# 5.06e+04      1
# 5.76e+05      1
# 8.32e+04      1
# 1.37e+07      1
# 1.66e+07      1
# 6.36e+06      1
# 1.19e+06      1
# 3.79e+07      1
# 9.70e+06      1
# 2.67e+06      1
# 3.33e+06      1
# 9.19e+06      1
# 4.61e+07      1
# 1.30e+06      1
# 8.33e+06      1
# 2.30e+06      1
# 1.26e+08      1
# ...

# %%
filterkn['Position as At'] = Position
#merge1.loc[merge1['Customer Name'].isna(), 'Customer Name'] = merge1['Customer Name_y']

#merge1.loc[merge1['Facility Currency'].isna(), 'Facility Currency'] = merge1['Facility Currency_y']
#merge1.loc[merge1['Type of Financing'].isna(), 'Type of Financing'] = merge1['Type of Financing_y']
#merge1.loc[merge1['CIF Number'].isna(), 'CIF Number'] = merge1['CIF Number_y']
#merge1.loc[merge1['Country Exposure'].isna(), 'Country Exposure'] = merge1['Country Exposure_y']

#filterkn['Cumulative Disbursement/Drawdown (Facility Currency)'] = filterkn['Cumulative Disbursement/Drawdown (Facility Currency)'] + filterkn['Disbursement/Drawdown (Facility Currency)']
filterkn['Cumulative Disbursement/Drawdown (MYR)'] = filterkn['Cumulative Disbursement/Drawdown (MYR)'] + filterkn['Disbursement/Drawdown (MYR)']

#filterkn['Cumulative Cost Payment/Principal Repayment (Facility Currency)'] = filterkn['Cumulative Cost Payment/Principal Repayment (Facility Currency)'] + filterkn['Cost Payment/Principal Repayment (Facility Currency)']
filterkn['Cumulative Cost Payment/Principal Repayment (MYR)'] = filterkn['Cost Payment/Principal Repayment (MYR)'] +  filterkn['Cumulative Cost Payment/Principal Repayment (MYR)'] 

#filterkn['Cumulative Profit Payment/Interest Repayment (Facility Currency)'] = filterkn['Profit Payment/Interest Repayment (Facility Currency)'] + filterkn['Cumulative Profit Payment/Interest Repayment (Facility Currency)']
filterkn['Cumulative Profit Payment/Interest Repayment (MYR)'] = filterkn['Profit Payment/Interest Repayment (MYR)'] + filterkn['Cumulative Profit Payment/Interest Repayment (MYR)']

filterkn.sort_values('Total Loans Outstanding (MYR)', ascending=False, inplace=True)

# %%
#merge1.head(1)

# %%
merge_final = filterkn#.drop(['Customer Name_y'],axis=1)

merge_final['Cost/Principal Outstanding (Facility Currency)'].fillna(0, inplace=True)
merge_final['Cost/Principal Outstanding (MYR)'].fillna(0, inplace=True)
merge_final['Accrued Profit/Interest of the month (Facility Currency)'].fillna(0, inplace=True)
merge_final['Accrued Profit/Interest of the month (MYR)'].fillna(0, inplace=True)
merge_final['Modification of Loss (Facility Currency)'].fillna(0, inplace=True)
merge_final['Modification of Loss (MYR)'].fillna(0, inplace=True)
merge_final['Cumulative Accrued Profit/Interest (Facility Currency)'].fillna(0, inplace=True)
merge_final['Cumulative Accrued Profit/Interest (MYR)'].fillna(0, inplace=True)
merge_final['Income/Interest in Suspense (Facility Currency)'].fillna(0, inplace=True)
merge_final['Income/Interest in Suspense (MYR)'].fillna(0, inplace=True)
merge_final['Other Charges (Facility Currency)'].fillna(0, inplace=True)
merge_final['Other Charges (MYR)'].fillna(0, inplace=True)
merge_final['Total Loans Outstanding (Facility Currency)'].fillna(0, inplace=True)
merge_final['Total Loans Outstanding (MYR)'].fillna(0, inplace=True)
merge_final['Disbursement/Drawdown (Facility Currency)'].fillna(0, inplace=True)
merge_final['Disbursement/Drawdown (MYR)'].fillna(0, inplace=True)
merge_final['Cost Payment/Principal Repayment (Facility Currency)'].fillna(0, inplace=True)
merge_final['Cost Payment/Principal Repayment (MYR)'].fillna(0, inplace=True)
merge_final['Profit Payment/Interest Repayment (Facility Currency)'].fillna(0, inplace=True)
merge_final['Profit Payment/Interest Repayment (MYR)'].fillna(0, inplace=True)
#merge_final['Other_Charges_Payment_FC'].fillna(0, inplace=True)
#merge_final['Other_Charges_Payment_MYR'].fillna(0, inplace=True)
merge_final['Cumulative Disbursement/Drawdown (Facility Currency)'].fillna(0, inplace=True)
merge_final['Cumulative Disbursement/Drawdown (MYR)'].fillna(0, inplace=True)
merge_final['Cumulative Cost Payment/Principal Repayment (Facility Currency)'].fillna(0, inplace=True)
merge_final['Cumulative Cost Payment/Principal Repayment (MYR)'].fillna(0, inplace=True) 
#merge_final['Cumulative Other Charges Payment (Facility Currency)'].fillna(0, inplace=True)
#merge_final['Cumulative Other Charges Payment (MYR)'].fillna(0, inplace=True)
merge_final['Cumulative Profit Payment/Interest Repayment (Facility Currency)'].fillna(0, inplace=True)
merge_final['Cumulative Profit Payment/Interest Repayment (MYR)'].fillna(0, inplace=True)
merge_final['Ta`widh Payment/Penalty Repayment (Facility Currency)'].fillna(0, inplace=True)
merge_final['Ta`widh Payment/Penalty Repayment  (MYR)'].fillna(0, inplace=True)
merge_final['Cumulative Ta`widh Payment/Penalty Repayment (Facility Currency)'].fillna(0, inplace=True)
merge_final['Cumulative Ta`widh Payment/Penalty Repayment  (MYR)'].fillna(0, inplace=True)

merge_final.sort_values('Total Loans Outstanding (MYR)', ascending=False, inplace=True)

# %%
merge_final1 = merge_final[['CIF Number','EXIM Account No.','Finance(SAP) Number',
                            'Company Group',
                            'Customer Name',
                            'Relationship Manager (RM)',
                            'Banking Team',
                            'Ownership',
                            'Officer in Charge',
                            'Syndicated / Club Deal',
                            'Nature of Account',
                            'Facility',
                            'Facility Currency',
                            'Type of Financing',
                            'Shariah Contract / Concept',
                            'Fund / Guarantee /Program / Insentif',
                            'Status',
                            'Post Approval Stage',
                            'Date of Ready for Utilization (RU)',
                            'Restructured / Rescheduled(Y/N)',
                            'Amount Approved / Facility Limit (Facility Currency)',
                            'Amount Approved / Facility Limit (MYR)',
                            'Cost/Principal Outstanding (Facility Currency)',
                            'Cost/Principal Outstanding (MYR)',
                            #'Contingent Liability Letter of Credit (FC)',
                            #'Contingent Liability Letter of Credit (MYR)',
                            #'Contingent Liability (FC)',
                            #'Contingent Liability (MYR)',
                            'Account Receivables/Past Due Claims (Facility Currency)',
                            'Account Receivable/Past Due Claims (MYR)',
                            'Total Banking Exposure (Facility Currency)',
                            'Total Banking Exposure (MYR)',
                            'Accrued Profit/Interest of the month (Facility Currency)',
                            'Accrued Profit/Interest of the month (MYR)',
                            'Modification of Loss (Facility Currency)',
                            'Modification of Loss (MYR)',
                            'Cumulative Accrued Profit/Interest (Facility Currency)',
                            'Cumulative Accrued Profit/Interest (MYR)',                            
                            'Penalty/Ta`widh (Facility Currency)',
                            'Penalty/Ta`widh (MYR)',
                            'Income/Interest in Suspense (Facility Currency)',
                            'Income/Interest in Suspense (MYR)',
                            'Other Charges (Facility Currency)',
                            'Other Charges (MYR)',
                            'Total Loans Outstanding (Facility Currency)',
                            'Total Loans Outstanding (MYR)',
                            #'LAF_ECL_FC',
                            #'LAF_ECL_MYR',
                            #'CnC_ECL_FC',
                            #'CnC_ECL_MYR',
                            'Disbursement/Drawdown Status',
                            #'Unutilised/Undrawn Amount (FC)',
                            #'Unutilised/Undrawn Amount (MYR)',
                            ##'Disbursement/Drawdown (Facility Currency)',
                            'Disbursement/Drawdown (MYR)',
                            'Cumulative Disbursement/Drawdown (Facility Currency)',
                            'Cumulative Disbursement/Drawdown (MYR)',
                            ##'Cost Payment/Principal Repayment (Facility Currency)',
                            'Cost Payment/Principal Repayment (MYR)',                            
                            'Cumulative Cost Payment/Principal Repayment (Facility Currency)',
                            'Cumulative Cost Payment/Principal Repayment (MYR)',
                            'Profit Payment/Interest Repayment (Facility Currency)',
                            'Profit Payment/Interest Repayment (MYR)',
                            'Cumulative Profit Payment/Interest Repayment (Facility Currency)',
                            'Cumulative Profit Payment/Interest Repayment (MYR)',
                            'Ta`widh Payment/Penalty Repayment (Facility Currency)',
                            'Ta`widh Payment/Penalty Repayment  (MYR)',
                            'Cumulative Ta`widh Payment/Penalty Repayment (Facility Currency)',
                            'Cumulative Ta`widh Payment/Penalty Repayment  (MYR)',
                            #'Other_Charges_Payment_FC',
                            #'Other_Charges_Payment_MYR',
                            #'Cumulative Other Charges Payment (Facility Currency)',
                            #'Cumulative Other Charges Payment (MYR)',
                            'Rating at Origination',
                            'PD',
                            'PF',
                            'CRMS Obligor Risk Rating',
                            'CRMS CG Rating',
                            'PD (%)',
                            'LGD (%)',
                            'Risk Analyst',
                            'MFRS9 Staging',
                            'BNM Main Sector',
                            'BNM Sub Sector',
                            'EXIM Main Sector',
                            'Industry (Risk)',
                            'Industry Classification',
                            'Purpose of Financing',
                            'Date Approved at Origination',
                            'Approval Authority',
                            'LO issuance Date',
                            'Date of LO Acceptance',
                            '1st Disbursement/Drawdown Date',
                            '1st Payment/Repayment Date',
                            'Expiry of Availability Period',
                            'Facility Agreement Date',
                            'Annual Review Date',
                            'Watchlist Review Date',
                            'Maturity/Expired Date',
                            'Grace Period (Month)',
                            'Moratorium Period (Month)',
                            'Start Moratorium Date',
                            'Tenure (Month)',
                            'Payment/Repayment Frequency (Profit/Interest)',
                            'Payment/Repayment Frequency (Cost/Principal)',
                            'Effective cost of borrowings',
                            'Profit/Interest Margin',
                            'Average Profit/Interest Rate',
                            'Ta`widh Compensation/Penalty Rate',
                            'Operation Country',
                            'Country Exposure',
                            'Country Rating',
                            'Region',
                            'Market Type',
                            'Classification of Entity / Customer Type',
                            'Entity / Customer Type',
                            'Classification of Residency Status',
                            'Residency Status',
                            'Corporate Type',
                            'SME Commercial Corporate',
                            'Corporate Status',
                            'Justification on Corporate Status',
                            'Restructured / Rescheduled',
                            'Date of Approval Restructured / Rescheduled',
                            'Effective Date',
                            'Reason',
                            'Date Untagged from R&R',
                            'Justification for Untagged',
                            'Frequency',
                            'Date of Overdue',
                            'Date Classified as Watchlist',
                            'Watchlist Reason',
                            'Date Declassified from Watchlist',
                            'Date Impaired',
                            'Reason for Impairment',
                            'Partial Write off Date',
                            'Write off Date',
                            'Cancellation Date/Fully Settled Date','Position as At']]

# %%
#Debtor Only

#merge_final1.to_excel(str(Location)+'\\Loan Database as '+str(File1[-17:])+' - First Cut.xlsx', sheet_name='Export Worksheet', index = False)

# %%
#merge_final1['Finance(SAP) Number'].value_counts().head(15)

# %%
#merge_final1.iloc[np.where(merge_final1['Finance(SAP) Number']=="500920")]

# %%
#FILE2.head(1)

# %%
#==================================================Disburse & Drawdown=====================================================
#==================================================Disburse & Drawdown=====================================================
#==================================================Disburse & Drawdown=====================================================


merge_final1['Finance(SAP) Number'] = merge_final1['Finance(SAP) Number'].astype(str)
FILE2['Account'] = FILE2['Account'].astype(str)

#.drop('Profit Payment/Interest Repayment (MYR)',axis=1)
#.drop(['Customer Name',''],axis=1)
merge_dis_draw = merge_final1.merge(FILE2.rename(columns={'Account':'Finance(SAP) Number',
                                                          'Curr.':'Facility Currency',
                                                          'Type_of_Financing':'Type of Financing'}),
                     on=['Finance(SAP) Number','Facility Currency','Type of Financing'], how='outer')

merge_dis_draw1 = merge_dis_draw.drop(['Disbursement_Drawdown_MYR',
                                        'Cost_Payment_Principal_Repayment_MYR'],axis=1).rename(columns={'Disbursement_Drawdown_Facility_Currency':'Disbursement/Drawdown (Facility Currency)',
                                                                                                       'Cost_Payment_Principal_Repayment_Facility_Currency':'Cost Payment/Principal Repayment (Facility Currency)'})

merge_dis_draw1['Cumulative Disbursement/Drawdown (Facility Currency)'] = merge_dis_draw1['Cumulative Disbursement/Drawdown (Facility Currency)'] + merge_dis_draw1['Disbursement/Drawdown (Facility Currency)']
#merge_dis_draw['Cumulative Disbursement/Drawdown (MYR)'] = merge_dis_draw['Cumulative Disbursement/Drawdown (MYR)'] + merge_dis_draw['Disbursement/Drawdown (MYR)']

merge_dis_draw1['Cumulative Cost Payment/Principal Repayment (Facility Currency)'] = merge_dis_draw1['Cumulative Cost Payment/Principal Repayment (Facility Currency)'] + merge_dis_draw1['Cost Payment/Principal Repayment (Facility Currency)']
#merge_dis_draw['Cumulative Cost Payment/Principal Repayment (MYR)'] = merge_dis_draw['Cost Payment/Principal Repayment (MYR)'] +  merge_dis_draw['Cost Payment/Principal Repayment (MYR)']
# Out:
# C:\Users\syahidhalid\AppData\Local\Temp\1\ipykernel_5580\3562819964.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   merge_final1['Finance(SAP) Number'] = merge_final1['Finance(SAP) Number'].astype(str)

# %%
merge_dis_draw2 = merge_dis_draw1[['CIF Number','EXIM Account No.','Finance(SAP) Number',
                            'Company Group',
                            'Customer Name',
                            'Relationship Manager (RM)',
                            'Banking Team',
                            'Ownership',
                            'Officer in Charge',
                            'Syndicated / Club Deal',
                            'Nature of Account',
                            'Facility',
                            'Facility Currency',
                            'Type of Financing',
                            'Shariah Contract / Concept',
                            'Fund / Guarantee /Program / Insentif',
                            'Status',
                            'Post Approval Stage',
                            'Date of Ready for Utilization (RU)',
                            'Restructured / Rescheduled(Y/N)',
                            'Amount Approved / Facility Limit (Facility Currency)',
                            'Amount Approved / Facility Limit (MYR)',
                            'Cost/Principal Outstanding (Facility Currency)',
                            'Cost/Principal Outstanding (MYR)',
                            #'Contingent Liability Letter of Credit (FC)',
                            #'Contingent Liability Letter of Credit (MYR)',
                            #'Contingent Liability (FC)',
                            #'Contingent Liability (MYR)',
                            'Account Receivables/Past Due Claims (Facility Currency)',
                            'Account Receivable/Past Due Claims (MYR)',
                            'Total Banking Exposure (Facility Currency)',
                            'Total Banking Exposure (MYR)',
                            'Accrued Profit/Interest of the month (Facility Currency)',
                            'Accrued Profit/Interest of the month (MYR)',
                            'Modification of Loss (Facility Currency)',
                            'Modification of Loss (MYR)',
                            'Cumulative Accrued Profit/Interest (Facility Currency)',
                            'Cumulative Accrued Profit/Interest (MYR)',                            
                            'Penalty/Ta`widh (Facility Currency)',
                            'Penalty/Ta`widh (MYR)',
                            'Income/Interest in Suspense (Facility Currency)',
                            'Income/Interest in Suspense (MYR)',
                            'Other Charges (Facility Currency)',
                            'Other Charges (MYR)',
                            'Total Loans Outstanding (Facility Currency)',
                            'Total Loans Outstanding (MYR)',
                            #'LAF_ECL_FC',
                            #'LAF_ECL_MYR',
                            #'CnC_ECL_FC',
                            #'CnC_ECL_MYR',
                            'Disbursement/Drawdown Status',
                            #'Unutilised/Undrawn Amount (FC)',
                            #'Unutilised/Undrawn Amount (MYR)',
                            'Disbursement/Drawdown (Facility Currency)',
                            'Disbursement/Drawdown (MYR)',
                            'Cumulative Disbursement/Drawdown (Facility Currency)',
                            'Cumulative Disbursement/Drawdown (MYR)',
                            'Cost Payment/Principal Repayment (Facility Currency)',
                            'Cost Payment/Principal Repayment (MYR)',                            
                            'Cumulative Cost Payment/Principal Repayment (Facility Currency)',
                            'Cumulative Cost Payment/Principal Repayment (MYR)',
                            'Profit Payment/Interest Repayment (Facility Currency)',
                            'Profit Payment/Interest Repayment (MYR)',
                            'Cumulative Profit Payment/Interest Repayment (Facility Currency)',
                            'Cumulative Profit Payment/Interest Repayment (MYR)',
                            'Ta`widh Payment/Penalty Repayment (Facility Currency)',
                            'Ta`widh Payment/Penalty Repayment  (MYR)',
                            'Cumulative Ta`widh Payment/Penalty Repayment (Facility Currency)',
                            'Cumulative Ta`widh Payment/Penalty Repayment  (MYR)',
                            #'Other Charges Payment (Facility Currency)',
                            #'Other Charges Payment (MYR)',
                            #'Cumulative Other Charges Payment (Facility Currency)',
                            #'Cumulative Other Charges Payment (MYR)',
                            'Rating at Origination',
                            'PD',
                            'PF',
                            'CRMS Obligor Risk Rating',
                            'CRMS CG Rating',
                            'PD (%)',
                            'LGD (%)',
                            'Risk Analyst',
                            'MFRS9 Staging',
                            'BNM Main Sector',
                            'BNM Sub Sector',
                            'EXIM Main Sector',
                            'Industry (Risk)',
                            'Industry Classification',
                            'Purpose of Financing',
                            'Date Approved at Origination',
                            'Approval Authority',
                            'LO issuance Date',
                            'Date of LO Acceptance',
                            '1st Disbursement/Drawdown Date',
                            '1st Payment/Repayment Date',
                            'Expiry of Availability Period',
                            'Facility Agreement Date',
                            'Annual Review Date',
                            'Watchlist Review Date',
                            'Maturity/Expired Date',
                            'Grace Period (Month)',
                            'Moratorium Period (Month)',
                            'Start Moratorium Date',
                            'Tenure (Month)',
                            'Payment/Repayment Frequency (Profit/Interest)',
                            'Payment/Repayment Frequency (Cost/Principal)',
                            'Effective cost of borrowings',
                            'Profit/Interest Margin',
                            'Average Profit/Interest Rate',
                            'Ta`widh Compensation/Penalty Rate',
                            'Operation Country',
                            'Country Exposure',
                            'Country Rating',
                            'Region',
                            'Market Type',
                            'Classification of Entity / Customer Type',
                            'Entity / Customer Type',
                            'Classification of Residency Status',
                            'Residency Status',
                            'Corporate Type',
                            'SME Commercial Corporate',
                            'Corporate Status',
                            'Justification on Corporate Status',
                            'Restructured / Rescheduled',
                            'Date of Approval Restructured / Rescheduled',
                            'Effective Date',
                            'Reason',
                            'Date Untagged from R&R',
                            'Justification for Untagged',
                            'Frequency',
                            'Date of Overdue',
                            'Date Classified as Watchlist',
                            'Watchlist Reason',
                            'Date Declassified from Watchlist',
                            'Date Impaired',
                            'Reason for Impairment',
                            'Partial Write off Date',
                            'Write off Date',
                            'Cancellation Date/Fully Settled Date','Position as At']]

# %%
#Debtor Listing
#Disburse & Drawdown

#merge_dis_draw2.to_excel(str(Location)+'\\Loan Database as '+str(File1[-17:])+' - Second Cut.xlsx', sheet_name='Export Worksheet', index = False)

# %%
#==================================================Data Mirror=====================================================
#==================================================Data Mirror=====================================================
#==================================================Data Mirror=====================================================

LDB_prev_oth_chr_pymnt = LDB_prev[['CIF Number','EXIM Account No.','Finance(SAP) Number','Type of Financing',
                            'Cumulative Other Charges Payment (Facility Currency)',
                            'Cumulative Other Charges Payment (MYR)']].drop_duplicates('Finance(SAP) Number',keep='first')

# %%
LDB_prev_oth_chr_pymnt['Finance(SAP) Number'] = LDB_prev_oth_chr_pymnt['Finance(SAP) Number'].astype(str)

FILE5.rename(columns={'Account':'Finance(SAP) Number','Type_of_Financing':'Type of Financing'},inplace=True)
FILE5['Finance(SAP) Number'] = FILE5['Finance(SAP) Number'].astype(str)

FILE5_1 = FILE5.merge(LDB_prev_oth_chr_pymnt, on=['Finance(SAP) Number','Type of Financing'], how='left')

# %%
merge_oth_chr_pymnt = merge_dis_draw2.merge(FILE5_1.drop('Type of Financing',axis=1), on=['Finance(SAP) Number','CIF Number','EXIM Account No.'], how='outer')

merge_oth_chr_pymnt = merge_oth_chr_pymnt.rename(columns={'Other_Charges_Payment_FC':'Other Charges Payment (Facility Currency)',
                                                  'Other_Charges_Payment_MYR':'Other Charges Payment (MYR)'})

merge_oth_chr_pymnt['Cumulative Other Charges Payment (Facility Currency)'] = merge_oth_chr_pymnt['Cumulative Other Charges Payment (Facility Currency)'] + merge_oth_chr_pymnt['Other Charges Payment (Facility Currency)']

merge_oth_chr_pymnt['Cumulative Other Charges Payment (MYR)'] = merge_oth_chr_pymnt['Cumulative Other Charges Payment (MYR)'] + merge_oth_chr_pymnt['Other Charges Payment (MYR)']

# %%
#to susun columnall

# %%
#to extract

# %%
#==================================================Contigent=====================================================
#==================================================Contigent=====================================================
#==================================================Contigent=====================================================

Contigent1 = Contigent.merge(MRate[['Month','Curr']].rename(columns={'Month':'Facility Currency'}),on='Facility Currency',how='left')

Contigent1['Contingent Liability Letter of Credit (FC)'] = Contigent1['Contingent Liability Letter of Credit (MYR)']*Contigent1['Curr']
Contigent1['Contingent Liability (FC)'] = Contigent1['Contingent Liability (MYR)']*Contigent1['Curr']

Contigent1['Contingent Liability Letter of Credit (FC)'].fillna(0,inplace=True)
Contigent1['Contingent Liability (FC)'].fillna(0,inplace=True)

# %%
merge_cont_FC = Contigent1.groupby(['EXIM Account No.',
                                    'CIF Number',
                                    'Finance(SAP) Number',
                                    'Customer Name',
                                    'Type of Financing'])[['Contingent Liability (MYR)','Contingent Liability (FC)',
                                                           'Contingent Liability Letter of Credit (MYR)',
                                                           'Contingent Liability Letter of Credit (FC)',
                                                           'Unutilised/Undrawn Amount (FC)',
                                                           'Unutilised/Undrawn Amount (MYR)']].sum().reset_index()

# %%
merge_cont_FC['EXIM Account No.'] = merge_cont_FC['EXIM Account No.'].astype(str)
merge_cont_FC['CIF Number'] = merge_cont_FC['CIF Number'].astype(str)

merge_oth_chr_pymnt['EXIM Account No.'] = merge_oth_chr_pymnt['EXIM Account No.'].astype(str)
merge_oth_chr_pymnt['CIF Number'] = merge_oth_chr_pymnt['CIF Number'].astype(str)

merge_cont = merge_oth_chr_pymnt.merge(merge_cont_FC[['CIF Number','EXIM Account No.',
                                                      'Contingent Liability (MYR)','Contingent Liability (FC)',
                                                      'Contingent Liability Letter of Credit (MYR)','Contingent Liability Letter of Credit (FC)']], on=['CIF Number','EXIM Account No.'], how='outer')

# %%
# susun column

# %%
#extrace

# %%
#==================================================Undrawn=====================================================
#==================================================Undrawn=====================================================
#==================================================Undrawn=====================================================

Undrawn = pd.concat([Undrawn_T, Undrawn_NT])

Undrawn['Finance(SAP) Number'] = Undrawn['Finance(SAP) Number'].astype(str)

#LDB_undrawn = LDB_prev[['CIF Number','EXIM Account No.','Finance(SAP) Number','Type of Financing']].drop_duplicates('Finance(SAP) Number',keep='first')
#LDB_undrawn['Finance(SAP) Number'] = LDB_undrawn['Finance(SAP) Number'].astype(str)
#Undrawn_1 = Undrawn.merge(LDB_undrawn, on=['Finance(SAP) Number','Type of Financing'], how='left')

Undrawn_cont = merge_cont_FC[['Finance(SAP) Number','Customer Name','Unutilised/Undrawn Amount (FC)','CIF Number','EXIM Account No.','Unutilised/Undrawn Amount (MYR)']]
Undrawn1 = Undrawn[['Finance(SAP) Number','Borrower name','Unutilised/ Undrawn Amount (Facility Currency)','CIF Number','EXIM Account No.','Unutilised/ Undrawn Amount (MYR)']]

Undrawn_cont.columns = Undrawn1.columns

UndrawnAll = pd.concat([Undrawn_cont, Undrawn1])

UndrawnAll['Unutilised/ Undrawn Amount (Facility Currency)'].fillna(0,inplace=True)
UndrawnAll['Unutilised/ Undrawn Amount (MYR)'].fillna(0,inplace=True)

UndrawnAll_1 = UndrawnAll.groupby(['EXIM Account No.',
                                    'CIF Number',
                                    'Finance(SAP) Number'])[['Unutilised/ Undrawn Amount (Facility Currency)',
                                                           'Unutilised/ Undrawn Amount (MYR)']].sum().reset_index()

merge_undrawn = merge_cont.merge(UndrawnAll_1.drop('Finance(SAP) Number',axis=1), on=['CIF Number','EXIM Account No.'], how='outer', indicator=True)

# %%
merge_undrawn1 = merge_undrawn[['CIF Number','EXIM Account No.','Finance(SAP) Number',
                            'Company Group',
                            'Customer Name',
                            'Relationship Manager (RM)',
                            'Banking Team',
                            'Ownership',
                            'Officer in Charge',
                            'Syndicated / Club Deal',
                            'Nature of Account',
                            'Facility',
                            'Facility Currency',
                            'Type of Financing',
                            'Shariah Contract / Concept',
                            'Fund / Guarantee /Program / Insentif',
                            'Status',
                            'Post Approval Stage',
                            'Date of Ready for Utilization (RU)',
                            'Restructured / Rescheduled(Y/N)',
                            'Amount Approved / Facility Limit (Facility Currency)',
                            'Amount Approved / Facility Limit (MYR)',
                            'Cost/Principal Outstanding (Facility Currency)',
                            'Cost/Principal Outstanding (MYR)',
                            'Contingent Liability Letter of Credit (FC)',
                            'Contingent Liability Letter of Credit (MYR)',
                            'Contingent Liability (FC)',
                            'Contingent Liability (MYR)',
                            'Account Receivables/Past Due Claims (Facility Currency)',
                            'Account Receivable/Past Due Claims (MYR)',
                            'Total Banking Exposure (Facility Currency)',
                            'Total Banking Exposure (MYR)',
                            'Accrued Profit/Interest of the month (Facility Currency)',
                            'Accrued Profit/Interest of the month (MYR)',
                            'Modification of Loss (Facility Currency)',
                            'Modification of Loss (MYR)',
                            'Cumulative Accrued Profit/Interest (Facility Currency)',
                            'Cumulative Accrued Profit/Interest (MYR)',                            
                            'Penalty/Ta`widh (Facility Currency)',
                            'Penalty/Ta`widh (MYR)',
                            'Income/Interest in Suspense (Facility Currency)',
                            'Income/Interest in Suspense (MYR)',
                            'Other Charges (Facility Currency)',
                            'Other Charges (MYR)',
                            'Total Loans Outstanding (Facility Currency)',
                            'Total Loans Outstanding (MYR)',
                            #'LAF_ECL_FC',
                            #'LAF_ECL_MYR',
                            #'CnC_ECL_FC',
                            #'CnC_ECL_MYR',
                            'Disbursement/Drawdown Status',
                            'Unutilised/ Undrawn Amount (Facility Currency)',
                            'Unutilised/ Undrawn Amount (MYR)',
                            'Disbursement/Drawdown (Facility Currency)',
                            'Disbursement/Drawdown (MYR)',
                            'Cumulative Disbursement/Drawdown (Facility Currency)',
                            'Cumulative Disbursement/Drawdown (MYR)',
                            'Cost Payment/Principal Repayment (Facility Currency)',
                            'Cost Payment/Principal Repayment (MYR)',                            
                            'Cumulative Cost Payment/Principal Repayment (Facility Currency)',
                            'Cumulative Cost Payment/Principal Repayment (MYR)',
                            'Profit Payment/Interest Repayment (Facility Currency)',
                            'Profit Payment/Interest Repayment (MYR)',
                            'Cumulative Profit Payment/Interest Repayment (Facility Currency)',
                            'Cumulative Profit Payment/Interest Repayment (MYR)',
                            'Ta`widh Payment/Penalty Repayment (Facility Currency)',
                            'Ta`widh Payment/Penalty Repayment  (MYR)',
                            'Cumulative Ta`widh Payment/Penalty Repayment (Facility Currency)',
                            'Cumulative Ta`widh Payment/Penalty Repayment  (MYR)',
                            'Other Charges Payment (Facility Currency)',
                            'Other Charges Payment (MYR)',
                            'Cumulative Other Charges Payment (Facility Currency)',
                            'Cumulative Other Charges Payment (MYR)',
                            'Rating at Origination',
                            'PD',
                            'PF',
                            'CRMS Obligor Risk Rating',
                            'CRMS CG Rating',
                            'PD (%)',
                            'LGD (%)',
                            'Risk Analyst',
                            'MFRS9 Staging',
                            'BNM Main Sector',
                            'BNM Sub Sector',
                            'EXIM Main Sector',
                            'Industry (Risk)',
                            'Industry Classification',
                            'Purpose of Financing',
                            'Date Approved at Origination',
                            'Approval Authority',
                            'LO issuance Date',
                            'Date of LO Acceptance',
                            '1st Disbursement/Drawdown Date',
                            '1st Payment/Repayment Date',
                            'Expiry of Availability Period',
                            'Facility Agreement Date',
                            'Annual Review Date',
                            'Watchlist Review Date',
                            'Maturity/Expired Date',
                            'Grace Period (Month)',
                            'Moratorium Period (Month)',
                            'Start Moratorium Date',
                            'Tenure (Month)',
                            'Payment/Repayment Frequency (Profit/Interest)',
                            'Payment/Repayment Frequency (Cost/Principal)',
                            'Effective cost of borrowings',
                            'Profit/Interest Margin',
                            'Average Profit/Interest Rate',
                            'Ta`widh Compensation/Penalty Rate',
                            'Operation Country',
                            'Country Exposure',
                            'Country Rating',
                            'Region',
                            'Market Type',
                            'Classification of Entity / Customer Type',
                            'Entity / Customer Type',
                            'Classification of Residency Status',
                            'Residency Status',
                            'Corporate Type',
                            'SME Commercial Corporate',
                            'Corporate Status',
                            'Justification on Corporate Status',
                            'Restructured / Rescheduled',
                            'Date of Approval Restructured / Rescheduled',
                            'Effective Date',
                            'Reason',
                            'Date Untagged from R&R',
                            'Justification for Untagged',
                            'Frequency',
                            'Date of Overdue',
                            'Date Classified as Watchlist',
                            'Watchlist Reason',
                            'Date Declassified from Watchlist',
                            'Date Impaired',
                            'Reason for Impairment',
                            'Partial Write off Date',
                            'Write off Date',
                            'Cancellation Date/Fully Settled Date','Position as At']]

# %%
#merge_undrawn1.to_excel(str(Location)+'\\Loan Database as '+str(File1[-17:])+' - First Cut.xlsx', sheet_name='Export Worksheet', index = False)

# %%
#merge_undrawn1.iloc[np.where(merge_undrawn1['EXIM Account No.']=="3308-01137-107-0335-00")]
#merge_undrawn1.iloc[np.where(merge_undrawn1['Finance(SAP) Number']=="500555")]
#merge_undrawn1.iloc[np.where(merge_undrawn1['Finance(SAP) Number']=="100374")] #"Bina Puri"

# %%
#==========================================================Manual Adjustment====================================================

#Kian Joo
merge_undrawn1.loc[merge_undrawn1['EXIM Account No.']=="3308-01137-107-0335-00",'Status'] = "Active"
merge_undrawn1.loc[merge_undrawn1['EXIM Account No.']=="3308-01137-107-0335-00",'Disbursement/Drawdown Status'] = "Fully Disbursed"
merge_undrawn1.loc[merge_undrawn1['EXIM Account No.']=="3308-01137-107-0335-00",'1st Disbursement/Drawdown Date'] = "2024-06-28"
merge_undrawn1.loc[merge_undrawn1['EXIM Account No.']=="3308-01137-107-0335-00",'Officer in Charge'] = "NOR AZLIN AHMAD TRIDI"
merge_undrawn1.loc[merge_undrawn1['EXIM Account No.']=="3308-01137-107-0335-00",'MFRS9 Staging'] = 1
merge_undrawn1.loc[merge_undrawn1['EXIM Account No.']=="3308-01137-107-0335-00",'Effective cost of borrowings'] = "COF-i"
merge_undrawn1.loc[merge_undrawn1['EXIM Account No.']=="3308-01137-107-0335-00",'Profit/Interest Margin'] = 1.5

#teras budi
merge_undrawn1.loc[merge_undrawn1['EXIM Account No.']=="3308-01137-107-0336-00",'Status'] = "Active"
merge_undrawn1.loc[merge_undrawn1['EXIM Account No.']=="3308-01137-107-0336-00",'Disbursement/Drawdown Status'] = "Ongoing Disbursement"
merge_undrawn1.loc[merge_undrawn1['EXIM Account No.']=="3308-01137-107-0336-00",'1st Disbursement/Drawdown Date'] = "2024-06-25"
merge_undrawn1.loc[merge_undrawn1['EXIM Account No.']=="3308-01137-107-0336-00",'Officer in Charge'] = "Muhammad Izmi Farhan Ibrahim"
merge_undrawn1.loc[merge_undrawn1['EXIM Account No.']=="3308-01137-107-0336-00",'MFRS9 Staging'] = 1
merge_undrawn1.loc[merge_undrawn1['EXIM Account No.']=="3308-01137-107-0336-00",'Effective cost of borrowings'] = "COF-i"
merge_undrawn1.loc[merge_undrawn1['EXIM Account No.']=="3308-01137-107-0336-00",'Profit/Interest Margin'] = 3.65

#glide
merge_undrawn1.loc[merge_undrawn1['EXIM Account No.']=="3308-01137-107-0337-00",'Status'] = "Active"
merge_undrawn1.loc[merge_undrawn1['EXIM Account No.']=="3308-01137-107-0337-00",'Disbursement/Drawdown Status'] = "Ongoing Disbursement"
merge_undrawn1.loc[merge_undrawn1['EXIM Account No.']=="3308-01137-107-0337-00",'1st Disbursement/Drawdown Date'] = "2024-06-21"
merge_undrawn1.loc[merge_undrawn1['EXIM Account No.']=="3308-01137-107-0337-00",'Officer in Charge'] = "Wan Nur Syahida Wan Draman"
merge_undrawn1.loc[merge_undrawn1['EXIM Account No.']=="3308-01137-107-0337-00",'MFRS9 Staging'] = 1
merge_undrawn1.loc[merge_undrawn1['EXIM Account No.']=="3308-01137-107-0337-00",'Effective cost of borrowings'] = "COF-i"
merge_undrawn1.loc[merge_undrawn1['EXIM Account No.']=="3308-01137-107-0337-00",'Profit/Interest Margin'] = 2.5

#siti khadiajh
merge_undrawn1.loc[merge_undrawn1['EXIM Account No.']=="3308-01137-110-0340-00",'Status'] = "Active"
merge_undrawn1.loc[merge_undrawn1['EXIM Account No.']=="3308-01137-110-0340-00",'Disbursement/Drawdown Status'] = "Ongoing Disbursement"
merge_undrawn1.loc[merge_undrawn1['EXIM Account No.']=="3308-01137-110-0340-00",'1st Disbursement/Drawdown Date'] = "2024-06-13"
merge_undrawn1.loc[merge_undrawn1['EXIM Account No.']=="3308-01137-110-0340-00",'Officer in Charge'] = "Nadiah Abdul Mutallib"
merge_undrawn1.loc[merge_undrawn1['EXIM Account No.']=="3308-01137-110-0340-00",'MFRS9 Staging'] = 1
merge_undrawn1.loc[merge_undrawn1['EXIM Account No.']=="3308-01137-110-0340-00",'Effective cost of borrowings'] = "COF-i"
merge_undrawn1.loc[merge_undrawn1['EXIM Account No.']=="3308-01137-110-0340-00",'Profit/Interest Margin'] = 2.0

#impact metal
merge_undrawn1.loc[merge_undrawn1['EXIM Account No.']=="3308-01137-110-0339-00",'Status'] = "Active"
merge_undrawn1.loc[merge_undrawn1['EXIM Account No.']=="3308-01137-110-0339-00",'Disbursement/Drawdown Status'] = "Ongoing Disbursement"
merge_undrawn1.loc[merge_undrawn1['EXIM Account No.']=="3308-01137-110-0339-00",'1st Disbursement/Drawdown Date'] = "2024-06-18"
merge_undrawn1.loc[merge_undrawn1['EXIM Account No.']=="3308-01137-110-0339-00",'Officer in Charge'] = "Nadiah Abdul Mutallib"
merge_undrawn1.loc[merge_undrawn1['EXIM Account No.']=="3308-01137-110-0339-00",'MFRS9 Staging'] = 1
merge_undrawn1.loc[merge_undrawn1['EXIM Account No.']=="3308-01137-110-0339-00",'Effective cost of borrowings'] = "COF-i"
merge_undrawn1.loc[merge_undrawn1['EXIM Account No.']=="3308-01137-110-0339-00",'Profit/Interest Margin'] = 2.0

#bertam
merge_undrawn1.loc[merge_undrawn1['EXIM Account No.']=="3308-01137-110-0341-00",'Status'] = "Active"
merge_undrawn1.loc[merge_undrawn1['EXIM Account No.']=="3308-01137-110-0341-00",'Disbursement/Drawdown Status'] = "Ongoing Disbursement"
merge_undrawn1.loc[merge_undrawn1['EXIM Account No.']=="3308-01137-110-0341-00",'1st Disbursement/Drawdown Date'] = "2024-06-28"
merge_undrawn1.loc[merge_undrawn1['EXIM Account No.']=="3308-01137-110-0341-00",'Officer in Charge'] = "Nadiah Abdul Mutallib"
merge_undrawn1.loc[merge_undrawn1['EXIM Account No.']=="3308-01137-110-0341-00",'MFRS9 Staging'] = 1
merge_undrawn1.loc[merge_undrawn1['EXIM Account No.']=="3308-01137-110-0341-00",'Effective cost of borrowings'] = "COF-i"
merge_undrawn1.loc[merge_undrawn1['EXIM Account No.']=="3308-01137-110-0341-00",'Profit/Interest Margin'] = 3.0

#tristar
merge_undrawn1.loc[merge_undrawn1['EXIM Account No.']=="3308-01137-110-0342-00",'Status'] = "Active"
merge_undrawn1.loc[merge_undrawn1['EXIM Account No.']=="3308-01137-110-0342-00",'Disbursement/Drawdown Status'] = "Ongoing Disbursement"
merge_undrawn1.loc[merge_undrawn1['EXIM Account No.']=="3308-01137-110-0342-00",'1st Disbursement/Drawdown Date'] = "2024-06-28"
merge_undrawn1.loc[merge_undrawn1['EXIM Account No.']=="3308-01137-110-0342-00",'Officer in Charge'] = "Nadiah Abdul Mutallib"
merge_undrawn1.loc[merge_undrawn1['EXIM Account No.']=="3308-01137-110-0342-00",'MFRS9 Staging'] = 1
merge_undrawn1.loc[merge_undrawn1['EXIM Account No.']=="3308-01137-110-0342-00",'Effective cost of borrowings'] = "COF-i"
merge_undrawn1.loc[merge_undrawn1['EXIM Account No.']=="3308-01137-110-0342-00",'Profit/Interest Margin'] = 3.0

#solartif
merge_undrawn1.loc[merge_undrawn1['Finance(SAP) Number']=="500555",'Ta`widh Payment/Penalty Repayment (Facility Currency)'] = 57379.3
merge_undrawn1.loc[merge_undrawn1['Finance(SAP) Number']=="500555",'Ta`widh Payment/Penalty Repayment  (MYR)'] = 57379.3
merge_undrawn1.loc[merge_undrawn1['Finance(SAP) Number']=="500555",'Cumulative Ta`widh Payment/Penalty Repayment (Facility Currency)'] = 15856.13
merge_undrawn1.loc[merge_undrawn1['Finance(SAP) Number']=="500555",'Cumulative Ta`widh Payment/Penalty Repayment  (MYR)'] = 15856.13
 
#Binapuri
#principal + Other charges + IIS asset + IIS Liability
merge_undrawn1.loc[merge_undrawn1['Finance(SAP) Number']=="100374",'Account Receivables/Past Due Claims (Facility Currency)'] = 4636268.98+7422.35+173378.43-173378.43
merge_undrawn1.loc[merge_undrawn1['Finance(SAP) Number']=="100374",'Account Receivable/Past Due Claims (MYR)'] = 21880871.45+35029.8+818259.5-818259.5

# %%
#merge_undrawn1['Expiry of Availability Period'] = merge_undrawn1['Expiry of Availability Period'].astype(str)

#merge_undrawn1.loc[merge_undrawn1['Expiry of Availability Period']=="00:00:00",'Expiry of Availability Period'] = ""

#merge_undrawn1.iloc[np.where(merge_undrawn1['Expiry of Availability Period']=="00:00:00")].shape

# %%
merge_undrawn1.to_excel(str(Location)+'\\Loan Database as '+str(File1[-17:])+' - First Cut.xlsx', sheet_name='Export Worksheet', index = False)

# %%
#sum(merge_undrawn1['Cost/Principal Outstanding (MYR)'])

#merge_ldb
#merge1
#filterkn
#merge_final1

#merge_dis_draw2
#merge_undrawn1

# %%
#merge_undrawn1.iloc[np.where(merge_undrawn1['Customer Name'].isna())]

# %%
#merge_undrawn1['Expiry of Availability Period'].value_counts()

# %%
#merge_undrawn1.iloc[np.where(merge_undrawn1['Finance(SAP) Number']=="500555")]
